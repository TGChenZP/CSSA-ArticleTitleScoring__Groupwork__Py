# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
# Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = False

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import GradientBoostingRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'learning_rate': (1e-8, 1e-6, 1e-4, 1e-2, 1e-1, 1, 10),
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'subsample': (0.25, 0.4, 0.55, 0.7, 0.85, 1),
    'min_samples_split': (2, 4, 8, 16, 32, 64),
    'max_depth': (3, 6, 12, 24, 48, 96, 192, 384),
    'max_features': (0.25, 0.4, 0.55, 0.7, 0.85, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': 42,
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis=1)
train_y = train_data['label']
val_X = val_data.drop('label', axis=1)
val_y = val_data['label']
test_X = test_data.drop('label', axis=1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 72576: (0, 5, 5, 5, 4, 5), taking 0.36 seconds to get val score of -0.009
#         Current best combo: (0, 5, 5, 5, 4, 5) with val score -0.009
# Trained and Tested combination 2 of 72576: (6, 5, 0, 5, 7, 0), taking 0.2 seconds to get val score of 0
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0
# Trained and Tested combination 3 of 72576: (0, 0, 5, 0, 7, 0), taking 0.04 seconds to get val score of -0.009
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0
# Trained and Tested combination 4 of 72576: (0, 0, 5, 0, 4, 0), taking 0.04 seconds to get val score of -0.009
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0
# Trained and Tested combination 5 of 72576: (3, 5, 0, 0, 0, 5), taking 0.21 seconds to get val score of 0.0878
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 6 of 72576: (3, 0, 0, 0, 4, 0), taking 0.01 seconds to get val score of 0.0174
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 7 of 72576: (0, 0, 5, 5, 7, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 8 of 72576: (6, 5, 5, 5, 4, 5), taking 0.32 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 9 of 72576: (3, 0, 0, 5, 0, 5), taking 0.01 seconds to get val score of -0.0072
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 10 of 72576: (6, 0, 0, 0, 0, 0), taking 0.01 seconds to get val score of -1.6692208495541813e+46
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 11 of 72576: (6, 5, 0, 5, 4, 5), taking 0.19 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 12 of 72576: (6, 5, 5, 0, 4, 0), taking 1.36 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 13 of 72576: (6, 0, 5, 0, 4, 5), taking 0.01 seconds to get val score of -6.127867616815097e+47
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0034
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 172 of 72576 combinations so far
# Trained and Tested combination 173 of 72576: (3, 3, 2, 2, 4, 3), taking 0.26 seconds to get val score of 0.0454
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 174 of 72576: (3, 3, 2, 4, 4, 3), taking 0.17 seconds to get val score of 0.0538
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 175 of 72576: (3, 3, 2, 3, 3, 3), taking 0.23 seconds to get val score of 0.0119
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 176 of 72576: (3, 3, 2, 3, 5, 3), taking 0.22 seconds to get val score of 0.0119
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 177 of 72576: (3, 3, 2, 3, 4, 2), taking 0.19 seconds to get val score of 0.0526
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 178 of 72576: (3, 3, 2, 3, 4, 4), taking 0.26 seconds to get val score of -0.004
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 179 of 72576: (2, 3, 3, 4, 4, 3), taking 0.26 seconds to get val score of -0.0065
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 180 of 72576: (4, 3, 3, 4, 4, 3), taking 0.3 seconds to get val score of -0.1329
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 2, 3, 4, 4, 3), which had val score of 0.0273
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 180 of 72576 combinations so far
# Trained and Tested combination 181 of 72576: (3, 4, 3, 4, 4, 3), taking 0.62 seconds to get val score of -0.0111
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 2, 4, 4, 3), which had val score of 0.0538
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 181 of 72576 combinations so far
# Trained and Tested combination 182 of 72576: (3, 3, 4, 4, 4, 3), taking 0.35 seconds to get val score of 0.0152
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0034
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 182 of 72576 combinations so far
# Trained and Tested combination 183 of 72576: (3, 3, 3, 5, 4, 3), taking 0.19 seconds to get val score of 0.0357
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 184 of 72576: (3, 3, 3, 4, 3, 3), taking 0.26 seconds to get val score of 0.0274
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 185 of 72576: (3, 3, 3, 4, 5, 3), taking 0.26 seconds to get val score of 0.0274
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 186 of 72576: (3, 3, 3, 4, 4, 2), taking 0.21 seconds to get val score of 0.0193
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 187 of 72576: (3, 3, 3, 4, 4, 4), taking 0.3 seconds to get val score of 0.0124
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 188 of 72576: (2, 3, 3, 3, 3, 3), taking 0.29 seconds to get val score of -0.0062
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 189 of 72576: (4, 3, 3, 3, 3, 3), taking 0.38 seconds to get val score of -0.2704
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 2, 3, 3, 3, 3), which had val score of 0.0143
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 189 of 72576 combinations so far
# Trained and Tested combination 190 of 72576: (3, 4, 3, 3, 3, 3), taking 1.29 seconds to get val score of -0.0325
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3), which had val score of 0.0119
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 190 of 72576 combinations so far
# Trained and Tested combination 191 of 72576: (3, 3, 4, 3, 3, 3), taking 0.81 seconds to get val score of -0.0181
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 192 of 72576: (3, 3, 3, 2, 3, 3), taking 0.41 seconds to get val score of -0.0311
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 3, 4, 3, 3), which had val score of 0.0274
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 192 of 72576 combinations so far
# Trained and Tested combination 193 of 72576: (3, 3, 3, 3, 2, 3), taking 0.37 seconds to get val score of 0.0012
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0034
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 193 of 72576 combinations so far
# Trained and Tested combination 194 of 72576: (3, 3, 3, 3, 3, 2), taking 0.27 seconds to get val score of -0.0031
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 195 of 72576: (3, 3, 3, 3, 3, 4), taking 0.41 seconds to get val score of 0.0159
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 196 of 72576: (2, 3, 3, 3, 5, 3), taking 0.32 seconds to get val score of -0.0062
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 197 of 72576: (4, 3, 3, 3, 5, 3), taking 0.43 seconds to get val score of -0.2704
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 2, 3, 3, 5, 3), which had val score of 0.0143
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 197 of 72576 combinations so far
# Trained and Tested combination 198 of 72576: (3, 4, 3, 3, 5, 3), taking 0.71 seconds to get val score of -0.0325
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 2, 3, 5, 3), which had val score of 0.0119
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 198 of 72576 combinations so far
# Trained and Tested combination 199 of 72576: (3, 3, 4, 3, 5, 3), taking 0.42 seconds to get val score of -0.0181
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 200 of 72576: (3, 3, 3, 2, 5, 3), taking 0.63 seconds to get val score of -0.0311
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 3, 4, 5, 3), which had val score of 0.0274
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 200 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0034
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 200 of 72576 combinations so far
# Trained and Tested combination 201 of 72576: (3, 3, 3, 3, 6, 3), taking 0.36 seconds to get val score of 0.0034
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 202 of 72576: (3, 3, 3, 3, 5, 2), taking 0.31 seconds to get val score of -0.0031
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 203 of 72576: (3, 3, 3, 3, 5, 4), taking 0.37 seconds to get val score of 0.0159
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 204 of 72576: (2, 3, 3, 3, 4, 4), taking 0.34 seconds to get val score of -0.0069
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 205 of 72576: (4, 3, 3, 3, 4, 4), taking 0.47 seconds to get val score of -0.0604
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 2, 3, 3, 4, 4), which had val score of 0.0383
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 205 of 72576 combinations so far
# Trained and Tested combination 206 of 72576: (3, 4, 3, 3, 4, 4), taking 0.96 seconds to get val score of -0.0422
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 2, 3, 4, 4), which had val score of -0.004
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 206 of 72576 combinations so far
# Trained and Tested combination 207 of 72576: (3, 3, 4, 3, 4, 4), taking 0.73 seconds to get val score of 0.0271
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 208 of 72576: (3, 3, 3, 2, 4, 4), taking 0.62 seconds to get val score of -0.0588
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 3, 3, 4, 4, 4), which had val score of 0.0124
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 208 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 3, 4), which had val score of 0.0159
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 208 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 5, 4), which had val score of 0.0159
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 208 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0034
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 208 of 72576 combinations so far
# Trained and Tested combination 209 of 72576: (3, 3, 3, 3, 4, 5), taking 0.07 seconds to get val score of 0.0254
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 210 of 72576: (2, 5, 0, 0, 0, 5), taking 0.19 seconds to get val score of -0.0059
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 211 of 72576: (4, 5, 0, 0, 0, 5), taking 0.19 seconds to get val score of -0.0425
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 212 of 72576: (3, 4, 0, 0, 0, 5), taking 0.11 seconds to get val score of 0.0818
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 213 of 72576: (3, 5, 1, 0, 0, 5), taking 0.23 seconds to get val score of 0.0455
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 214 of 72576: (3, 5, 0, 1, 0, 5), taking 0.62 seconds to get val score of 0.0814
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 215 of 72576: (3, 5, 0, 0, 1, 5), taking 0.57 seconds to get val score of 0.0708
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 216 of 72576: (3, 5, 0, 0, 0, 4), taking 0.73 seconds to get val score of 0.056
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# % Combos Checked Thus Far: 216 out of 72576 which is 0.297619%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 217 of 72576: (2, 0, 5, 0, 7, 0), taking 0.04 seconds to get val score of -0.0086
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 218 of 72576: (4, 0, 5, 0, 7, 0), taking 0.04 seconds to get val score of -0.0115
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 219 of 72576: (3, 1, 5, 0, 7, 0), taking 0.07 seconds to get val score of 0.0376
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 220 of 72576: (3, 0, 4, 0, 7, 0), taking 0.03 seconds to get val score of 0.0218
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 221 of 72576: (3, 0, 5, 1, 7, 0), taking 0.03 seconds to get val score of 0.0426
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 222 of 72576: (3, 0, 5, 0, 6, 0), taking 0.04 seconds to get val score of 0.0333
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 223 of 72576: (3, 0, 5, 0, 7, 1), taking 0.05 seconds to get val score of 0.0306
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# 	round 1 iteration:  1
#
# Trained and Tested combination 224 of 72576: (2, 1, 5, 0, 7, 0), taking 0.07 seconds to get val score of -0.0084
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 225 of 72576: (4, 1, 5, 0, 7, 0), taking 0.07 seconds to get val score of -0.0249
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 0, 5, 0, 7, 0), which had val score of 0.0333
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 225 of 72576 combinations so far
# Trained and Tested combination 226 of 72576: (3, 2, 5, 0, 7, 0), taking 0.14 seconds to get val score of 0.0347
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 227 of 72576: (3, 1, 4, 0, 7, 0), taking 0.06 seconds to get val score of 0.0207
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 228 of 72576: (3, 1, 5, 1, 7, 0), taking 0.06 seconds to get val score of 0.0385
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 229 of 72576: (3, 1, 5, 0, 6, 0), taking 0.08 seconds to get val score of 0.0376
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 230 of 72576: (3, 1, 5, 0, 7, 1), taking 0.14 seconds to get val score of 0.0551
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 231 of 72576: (2, 0, 5, 1, 7, 0), taking 0.07 seconds to get val score of -0.0084
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Trained and Tested combination 232 of 72576: (4, 0, 5, 1, 7, 0), taking 0.08 seconds to get val score of -0.0403
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# Already Trained and Tested combination (3, 1, 5, 1, 7, 0), which had val score of 0.0385
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878.
#         Has trained 232 of 72576 combinations so far
# Trained and Tested combination 233 of 72576: (3, 0, 4, 1, 7, 0), taking 0.08 seconds to get val score of 0.0144
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.0878
# ...
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Already Trained and Tested combination (1, 0, 0, 0, 4, 4), which had val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1796 of 72576 combinations so far
# Already Trained and Tested combination (0, 1, 0, 0, 4, 4), which had val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1796 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 4, 4), which had val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1796 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 0, 1, 4, 4), which had val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1796 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 3, 4), which had val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1796 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 5, 4), which had val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1796 of 72576 combinations so far
# Trained and Tested combination 1797 of 72576: (0, 0, 0, 0, 4, 3), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Already Trained and Tested combination (0, 0, 0, 0, 4, 5), which had val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1797 of 72576 combinations so far
# % Combos Checked Thus Far: 1797 out of 72576 which is 2.476025%
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 55
#
# 	round 55 iteration:  0
#
# Already Trained and Tested combination (2, 0, 0, 0, 4, 5), which had val score of -0.0089
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1797 of 72576 combinations so far
# Trained and Tested combination 1798 of 72576: (4, 0, 0, 0, 4, 5), taking 0.01 seconds to get val score of -0.0831
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1799 of 72576: (3, 1, 0, 0, 4, 5), taking 0.01 seconds to get val score of 0.0052
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1800 of 72576: (3, 0, 1, 0, 4, 5), taking 0.01 seconds to get val score of 0.0259
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1801 of 72576: (3, 0, 0, 1, 4, 5), taking 0.01 seconds to get val score of -0.0044
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1802 of 72576: (3, 0, 0, 0, 3, 5), taking 0.01 seconds to get val score of 0.0003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1803 of 72576: (3, 0, 0, 0, 5, 5), taking 0.01 seconds to get val score of 0.0003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1804 of 72576: (3, 0, 0, 0, 4, 4), taking 0.02 seconds to get val score of 0.014
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# 	round 55 iteration:  1
#
# Trained and Tested combination 1805 of 72576: (2, 1, 0, 0, 4, 5), taking 0.01 seconds to get val score of -0.0087
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1806 of 72576: (4, 1, 0, 0, 4, 5), taking 0.01 seconds to get val score of -0.1456
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5), which had val score of 0.0003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1806 of 72576 combinations so far
# Trained and Tested combination 1807 of 72576: (3, 2, 0, 0, 4, 5), taking 0.03 seconds to get val score of 0.003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1808 of 72576: (3, 1, 1, 0, 4, 5), taking 0.02 seconds to get val score of 0.0463
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1809 of 72576: (3, 1, 0, 1, 4, 5), taking 0.01 seconds to get val score of 0.0109
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1810 of 72576: (3, 1, 0, 0, 3, 5), taking 0.01 seconds to get val score of 0.0052
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1811 of 72576: (3, 1, 0, 0, 5, 5), taking 0.01 seconds to get val score of 0.0052
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1812 of 72576: (3, 1, 0, 0, 4, 4), taking 0.04 seconds to get val score of 0.035
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1813 of 72576: (2, 0, 1, 0, 4, 5), taking 0.01 seconds to get val score of -0.0086
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1814 of 72576: (4, 0, 1, 0, 4, 5), taking 0.01 seconds to get val score of -0.0959
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Already Trained and Tested combination (3, 1, 1, 0, 4, 5), which had val score of 0.0463
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1814 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5), which had val score of 0.0003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1814 of 72576 combinations so far
# Trained and Tested combination 1815 of 72576: (3, 0, 2, 0, 4, 5), taking 0.02 seconds to get val score of 0.0201
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1816 of 72576: (3, 0, 1, 1, 4, 5), taking 0.01 seconds to get val score of 0.0205
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1817 of 72576: (3, 0, 1, 0, 3, 5), taking 0.01 seconds to get val score of 0.0259
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1818 of 72576: (3, 0, 1, 0, 5, 5), taking 0.01 seconds to get val score of 0.0259
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1819 of 72576: (3, 0, 1, 0, 4, 4), taking 0.03 seconds to get val score of 0.0158
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1820 of 72576: (2, 0, 0, 1, 4, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1821 of 72576: (4, 0, 0, 1, 4, 5), taking 0.01 seconds to get val score of -0.184
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Already Trained and Tested combination (3, 1, 0, 1, 4, 5), which had val score of 0.0109
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1821 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 1, 4, 5), which had val score of 0.0205
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1821 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5), which had val score of 0.0003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1821 of 72576 combinations so far
# Trained and Tested combination 1822 of 72576: (3, 0, 0, 2, 4, 5), taking 0.01 seconds to get val score of -0.0031
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1823 of 72576: (3, 0, 0, 1, 3, 5), taking 0.01 seconds to get val score of -0.0044
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1824 of 72576: (3, 0, 0, 1, 5, 5), taking 0.01 seconds to get val score of -0.0044
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1825 of 72576: (3, 0, 0, 1, 4, 4), taking 0.02 seconds to get val score of 0.018
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1826 of 72576: (2, 0, 0, 0, 3, 5), taking 0.01 seconds to get val score of -0.0089
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1827 of 72576: (4, 0, 0, 0, 3, 5), taking 0.01 seconds to get val score of -0.0831
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Already Trained and Tested combination (3, 1, 0, 0, 3, 5), which had val score of 0.0052
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1827 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 3, 5), which had val score of 0.0259
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1827 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 3, 5), which had val score of -0.0044
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1827 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 2, 5), which had val score of -0.009
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1827 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5), which had val score of 0.0003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1827 of 72576 combinations so far
# Trained and Tested combination 1828 of 72576: (3, 0, 0, 0, 3, 4), taking 0.02 seconds to get val score of 0.014
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1829 of 72576: (2, 0, 0, 0, 5, 5), taking 0.01 seconds to get val score of -0.0089
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1830 of 72576: (4, 0, 0, 0, 5, 5), taking 0.01 seconds to get val score of -0.0831
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Already Trained and Tested combination (3, 1, 0, 0, 5, 5), which had val score of 0.0052
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1830 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 5, 5), which had val score of 0.0259
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1830 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 5, 5), which had val score of -0.0044
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1830 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5), which had val score of 0.0003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1830 of 72576 combinations so far
# Trained and Tested combination 1831 of 72576: (3, 0, 0, 0, 6, 5), taking 0.01 seconds to get val score of 0.0003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1832 of 72576: (3, 0, 0, 0, 5, 4), taking 0.02 seconds to get val score of 0.014
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1833 of 72576: (2, 0, 0, 0, 4, 4), taking 0.02 seconds to get val score of -0.0087
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Trained and Tested combination 1834 of 72576: (4, 0, 0, 0, 4, 4), taking 0.02 seconds to get val score of -0.0299
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Already Trained and Tested combination (3, 1, 0, 0, 4, 4), which had val score of 0.035
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1834 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 4, 4), which had val score of 0.0158
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1834 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 4, 4), which had val score of 0.018
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1834 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 3, 4), which had val score of 0.014
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1834 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 5, 4), which had val score of 0.014
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1834 of 72576 combinations so far
# Trained and Tested combination 1835 of 72576: (3, 0, 0, 0, 4, 3), taking 0.02 seconds to get val score of 0.0351
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5), which had val score of 0.0003
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1835 of 72576 combinations so far
# % Combos Checked Thus Far: 1835 out of 72576 which is 2.528384%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (3, 0, 0, 0, 1, 5), which had val score of 0.0067
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1835 of 72576 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 1, 5), which had val score of -1505.8585
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1835 of 72576 combinations so far
# Already Trained and Tested combination (4, 1, 0, 0, 1, 5), which had val score of 0.0545
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1835 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 1, 5), which had val score of -0.0203
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1835 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 1, 1, 5), which had val score of -0.116
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1835 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 0, 5), which had val score of 0.0539
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1835 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 2, 5), which had val score of -0.0612
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1835 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 1, 4), which had val score of -0.1004
#         Current best combo: (4, 0, 0, 0, 1, 5) with val score 0.1619.
#         Has trained 1835 of 72576 combinations so far
# % Combos Checked Thus Far: 1835 out of 72576 which is 2.528384%
# Max Score:
#  0.16194301366574415
# Max Test Score:
#  -0.021606
# Max Combo Index:
#  (4, 0, 0, 0, 1, 5) out of [7, 6, 6, 6, 8, 6] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'learning_rate': 0.1, 'n_estimators': 25, 'subsample': 0.25, 'min_samples_split': 2, 'max_depth': 6, 'max_features': 1}
# % Combos Checked: 1835 out of 72576 which is 2.528384%
