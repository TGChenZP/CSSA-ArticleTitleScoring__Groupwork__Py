# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(poly)'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVR as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVR'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# Successfully read in tuning result of 185 rows, for 185.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (5, 8, 5, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 8, 5, 0, 0), which had val score of -0.0081
#         Current best combo: (5, 8, 5, 0, 0) with val score -0.0081.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 1), which had val score of -1.1962
#         Current best combo: (5, 8, 5, 0, 0) with val score -0.0081.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 0), which had val score of -0.0081
#         Current best combo: (5, 8, 5, 0, 0) with val score -0.0081.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 0), which had val score of -0.231
#         Current best combo: (5, 8, 5, 0, 0) with val score -0.0081.
#         Has trained 185 of 3888 combinations so far
# As new Best Combo (0, 8, 0, 5, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 8, 0, 5, 0), which had val score of 0.0838
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 0), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 0), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 1), which had val score of -0.7218
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0), which had val score of -0.8611
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 0), which had val score of -0.0068
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 1), which had val score of -0.0077
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 0), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 1), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 1), which had val score of -0.2461
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 1), which had val score of 0.0133
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 0), which had val score of -0.0514
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 1), which had val score of 0.0832
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0), which had val score of 0.068
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 1), which had val score of 0.0805
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 1), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 1), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 0), which had val score of -0.1701
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 1), which had val score of -0.0668
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 1), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 0), which had val score of 0.0816
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 1), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0), which had val score of -0.2209
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0), which had val score of -0.4987
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 1), which had val score of -0.0069
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 1), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 0), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 1), which had val score of -0.0084
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 0), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 1), which had val score of -0.0081
#         Current best combo: (0, 8, 0, 5, 0) with val score 0.0838.
#         Has trained 185 of 3888 combinations so far
# As new Best Combo (5, 8, 0, 5, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 8, 0, 5, 0), which had val score of 0.1
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 1), which had val score of -0.0081
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 0), which had val score of -0.0081
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 1), which had val score of -0.0081
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1), which had val score of -0.219
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 1), which had val score of -0.2102
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 0), which had val score of -0.0081
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1), which had val score of -0.0081
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 1), which had val score of -0.0081
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 1), which had val score of -0.0081
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0), which had val score of -0.044
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1), which had val score of 0.0844
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (2, 4, 3, 3, 1), which had val score of 0.0112
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1), which had val score of 0.0999
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1), which had val score of 0.0947
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1), which had val score of 0.0761
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1), which had val score of 0.0884
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 4, 3, 1), which had val score of -0.0081
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1), which had val score of 0.0844
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1), which had val score of 0.0844
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 0), which had val score of 0.0804
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (3, 4, 3, 3, 1), which had val score of 0.0844
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 1), which had val score of 0.0797
#         Current best combo: (5, 8, 0, 5, 0) with val score 0.1.
#         Has trained 185 of 3888 combinations so far
# As new Best Combo (4, 3, 3, 3, 1) was read in, best_clf is set to None
# Already Trained and Tested combination (4, 3, 3, 3, 1), which had val score of 0.1114
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 5, 3, 3, 1), which had val score of 0.0965
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 2, 3, 1), which had val score of 0.1013
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 4, 3, 1), which had val score of -0.0081
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 3, 2, 1), which had val score of 0.0999
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 3, 4, 1), which had val score of 0.0999
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 0), which had val score of 0.0804
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (2, 3, 3, 3, 1), which had val score of 0.0037
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 1), which had val score of 0.1114
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 2, 3, 3, 1), which had val score of 0.0902
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1), which had val score of 0.0844
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1), which had val score of 0.1016
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 1), which had val score of -0.0081
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1), which had val score of 0.0947
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1), which had val score of 0.0947
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 0), which had val score of 0.0498
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (2, 4, 2, 3, 1), which had val score of 0.0118
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 2, 3, 1), which had val score of 0.1013
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1), which had val score of 0.1016
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 5, 2, 3, 1), which had val score of 0.081
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 1, 3, 1), which had val score of 0.089
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1), which had val score of 0.0844
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1), which had val score of 0.0884
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1), which had val score of 0.0884
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 0), which had val score of 0.0813
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (2, 4, 3, 2, 1), which had val score of 0.0112
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 3, 2, 1), which had val score of 0.0999
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1), which had val score of 0.0947
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 5, 3, 2, 1), which had val score of 0.0761
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1), which had val score of 0.0884
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 4, 2, 1), which had val score of -0.0081
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 1, 1), which had val score of 0.0769
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1), which had val score of 0.0844
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 0), which had val score of 0.0636
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (2, 4, 3, 4, 1), which had val score of 0.0112
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 3, 4, 1), which had val score of 0.0999
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1), which had val score of 0.0947
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 5, 3, 4, 1), which had val score of 0.0761
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1), which had val score of 0.0884
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 4, 4, 1), which had val score of -0.0081
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1), which had val score of 0.0844
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 5, 1), which had val score of 0.0844
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 0), which had val score of 0.0804
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (2, 4, 3, 3, 0), which had val score of 0.0665
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 0), which had val score of 0.0804
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 0), which had val score of 0.0498
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 0), which had val score of 0.0604
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 0), which had val score of 0.0813
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 4, 3, 0), which had val score of -0.0081
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 0), which had val score of 0.0636
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 0), which had val score of 0.0804
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1), which had val score of 0.0844
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1), which had val score of 0.0947
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 1), which had val score of 0.0563
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 2, 3, 3, 1), which had val score of 0.1009
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1), which had val score of 0.0999
#         Current best combo: (4, 3, 3, 3, 1) with val score 0.1114.
#         Has trained 185 of 3888 combinations so far
# As new Best Combo (4, 3, 2, 3, 1) was read in, best_clf is set to None
# Already Trained and Tested combination (4, 3, 2, 3, 1), which had val score of 0.1136
#         Current best combo: (4, 3, 2, 3, 1) with val score 0.1136.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 4, 3, 1), which had val score of -0.0081
#         Current best combo: (4, 3, 2, 3, 1) with val score 0.1136.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 3, 2, 1), which had val score of 0.1114
#         Current best combo: (4, 3, 2, 3, 1) with val score 0.1136.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 3, 4, 1), which had val score of 0.1114
#         Current best combo: (4, 3, 2, 3, 1) with val score 0.1136.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 0), which had val score of 0.0388
#         Current best combo: (4, 3, 2, 3, 1) with val score 0.1136.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1), which had val score of 0.1016
#         Current best combo: (4, 3, 2, 3, 1) with val score 0.1136.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 1), which had val score of 0.0587
#         Current best combo: (4, 3, 2, 3, 1) with val score 0.1136.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 2, 2, 3, 1), which had val score of 0.1059
#         Current best combo: (4, 3, 2, 3, 1) with val score 0.1136.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 2, 3, 1), which had val score of 0.1013
#         Current best combo: (4, 3, 2, 3, 1) with val score 0.1136.
#         Has trained 185 of 3888 combinations so far
# As new Best Combo (4, 3, 1, 3, 1) was read in, best_clf is set to None
# Already Trained and Tested combination (4, 3, 1, 3, 1), which had val score of 0.114
#         Current best combo: (4, 3, 1, 3, 1) with val score 0.114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 1), which had val score of 0.1114
#         Current best combo: (4, 3, 1, 3, 1) with val score 0.114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 1), which had val score of 0.1124
#         Current best combo: (4, 3, 1, 3, 1) with val score 0.114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 2, 4, 1), which had val score of 0.1136
#         Current best combo: (4, 3, 1, 3, 1) with val score 0.114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 0), which had val score of 0.0493
#         Current best combo: (4, 3, 1, 3, 1) with val score 0.114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 1), which had val score of 0.102
#         Current best combo: (4, 3, 1, 3, 1) with val score 0.114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 1, 3, 1), which had val score of 0.0591
#         Current best combo: (4, 3, 1, 3, 1) with val score 0.114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 2, 1, 3, 1), which had val score of 0.1063
#         Current best combo: (4, 3, 1, 3, 1) with val score 0.114.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 1, 3, 1), which had val score of 0.1017
#         Current best combo: (4, 3, 1, 3, 1) with val score 0.114.
#         Has trained 185 of 3888 combinations so far
# As new Best Combo (4, 3, 0, 3, 1) was read in, best_clf is set to None
# Already Trained and Tested combination (4, 3, 0, 3, 1), which had val score of 0.1141
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 1), which had val score of 0.1136
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 2, 1), which had val score of 0.1124
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 4, 1), which had val score of 0.114
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 3, 0), which had val score of 0.0494
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 1), which had val score of 0.1021
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 1), which had val score of 0.0591
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 2, 0, 3, 1), which had val score of 0.1064
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 0, 3, 1), which had val score of 0.1018
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 3, 1), which had val score of 0.114
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 2, 1), which had val score of 0.1124
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 1), which had val score of 0.1141
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 3, 0), which had val score of 0.0494
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# % Combos Checked Thus Far: 185 out of 3888 which is 4.75823%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Already Trained and Tested combination (1, 8, 0, 5, 0), which had val score of 0.0849
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 7, 0, 5, 0), which had val score of 0.093
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 1, 5, 0), which had val score of 0.0838
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 4, 0), which had val score of 0.0838
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 1), which had val score of -0.0077
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (0, 8, 0, 5, 0), which had val score of 0.0838
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (2, 8, 0, 5, 0), which had val score of 0.0996
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (1, 7, 0, 5, 0), which had val score of 0.0714
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (1, 8, 1, 5, 0), which had val score of 0.0849
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (1, 8, 0, 4, 0), which had val score of 0.0849
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (1, 8, 0, 5, 1), which had val score of -0.0099
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (1, 7, 0, 5, 0), which had val score of 0.0714
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 6, 0, 5, 0), which had val score of 0.0934
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 0), which had val score of 0.0838
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 7, 1, 5, 0), which had val score of 0.093
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 7, 0, 4, 0), which had val score of 0.093
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 7, 0, 5, 1), which had val score of -0.0075
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (1, 8, 1, 5, 0), which had val score of 0.0849
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 7, 1, 5, 0), which had val score of 0.093
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 0), which had val score of 0.0838
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 2, 5, 0), which had val score of 0.0837
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 1, 4, 0), which had val score of 0.0838
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 1, 5, 1), which had val score of -0.0077
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (1, 8, 0, 4, 0), which had val score of 0.0849
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 7, 0, 4, 0), which had val score of 0.093
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 1, 4, 0), which had val score of 0.0838
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 3, 0), which had val score of 0.0831
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 0), which had val score of 0.0838
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (0, 8, 0, 4, 1), which had val score of -0.0077
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# % Combos Checked Thus Far: 185 out of 3888 which is 4.75823%
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Already Trained and Tested combination (4, 8, 0, 5, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 7, 0, 5, 0), which had val score of 0.0808
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 1, 5, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 4, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 1), which had val score of 0.0805
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# 	round 2 iteration:  1
#
# Already Trained and Tested combination (3, 8, 0, 5, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 7, 0, 5, 0), which had val score of 0.0808
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 8, 1, 5, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 8, 0, 4, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 8, 0, 5, 1), which had val score of 0.0904
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 8, 1, 5, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 7, 1, 5, 0), which had val score of 0.0808
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 2, 5, 0), which had val score of 0.0998
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 1, 4, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 1, 5, 1), which had val score of 0.0805
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 8, 0, 4, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 7, 0, 4, 0), which had val score of 0.0808
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 1, 4, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 3, 0), which had val score of 0.0918
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 0), which had val score of 0.1
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 8, 0, 4, 1), which had val score of 0.0805
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# % Combos Checked Thus Far: 185 out of 3888 which is 4.75823%
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (4, 4, 0, 5, 1), which had val score of 0.1018
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 0, 5, 1), which had val score of 0.0593
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 5, 0, 5, 1), which had val score of 0.0648
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 1, 5, 1), which had val score of 0.0832
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 1), which had val score of 0.0832
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 0), which had val score of 0.0816
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (3, 4, 0, 5, 1), which had val score of 0.0891
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 1), which had val score of 0.0832
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 5, 1), which had val score of 0.1141
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 5, 0, 5, 1), which had val score of 0.0987
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 1, 5, 1), which had val score of 0.1017
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 1), which had val score of 0.1018
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 0, 5, 0), which had val score of 0.0816
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 1, 5, 1), which had val score of 0.1017
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 1, 5, 1), which had val score of 0.0592
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 5, 1, 5, 1), which had val score of 0.0648
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 1), which had val score of 0.0832
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 2, 5, 1), which had val score of 0.0828
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 1, 4, 1), which had val score of 0.0832
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 1, 5, 0), which had val score of 0.0816
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 1), which had val score of 0.1018
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1), which had val score of 0.0593
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 1), which had val score of 0.0648
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 1, 4, 1), which had val score of 0.0832
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 3, 1), which had val score of 0.083
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 1), which had val score of 0.0832
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0), which had val score of 0.0816
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 0, 5, 0), which had val score of 0.0816
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 0, 5, 0), which had val score of 0.0497
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 5, 0, 5, 0), which had val score of 0.0629
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 1, 5, 0), which had val score of 0.0816
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0), which had val score of 0.0816
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 1), which had val score of 0.0832
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# % Combos Checked Thus Far: 185 out of 3888 which is 4.75823%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (3, 3, 0, 3, 1), which had val score of 0.1021
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 1), which had val score of 0.0591
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 2, 0, 3, 1), which had val score of 0.1064
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 0, 3, 1), which had val score of 0.1018
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 3, 1), which had val score of 0.114
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 2, 1), which had val score of 0.1124
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 1), which had val score of 0.1141
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 3, 0), which had val score of 0.0494
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (3, 3, 1, 3, 1), which had val score of 0.102
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 1, 3, 1), which had val score of 0.0591
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 2, 1, 3, 1), which had val score of 0.1063
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 1, 3, 1), which had val score of 0.1017
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 3, 1), which had val score of 0.1141
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 1), which had val score of 0.1136
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 2, 1), which had val score of 0.1124
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 4, 1), which had val score of 0.114
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 3, 0), which had val score of 0.0494
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 0, 2, 1), which had val score of 0.1021
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 0, 2, 1), which had val score of 0.0471
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 2, 0, 2, 1), which had val score of 0.1048
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 0, 2, 1), which had val score of 0.1002
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 2, 1), which had val score of 0.1124
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 1, 1), which had val score of 0.0913
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 3, 1), which had val score of 0.1141
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 2, 0), which had val score of 0.0374
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1), which had val score of 0.1021
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1), which had val score of 0.0593
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 2, 0, 4, 1), which had val score of 0.1064
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 1), which had val score of 0.1018
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 1, 4, 1), which had val score of 0.114
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 3, 1), which had val score of 0.1141
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 5, 1), which had val score of 0.1141
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0), which had val score of 0.0497
#         Current best combo: (4, 3, 0, 3, 1) with val score 0.1141.
#         Has trained 185 of 3888 combinations so far
# % Combos Checked Thus Far: 185 out of 3888 which is 4.75823%
# Max Score:
#  0.1141
# Max Test Score:
#  0.030889
# Max Combo Index:
#  (4, 3, 0, 3, 1) out of [6, 9, 6, 6, 2] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 1, 'degree': 4, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale'}
# % Combos Checked: 185 out of 3888 which is 4.75823%
