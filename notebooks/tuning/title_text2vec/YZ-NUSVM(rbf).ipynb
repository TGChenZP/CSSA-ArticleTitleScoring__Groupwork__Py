# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nusvc(rbf)'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import NuSVR as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto'),
    'nu': (0.1, 0.3, 0.5, 0.7, 0.9)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.NuSVR'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# Successfully read in tuning result of 252 rows, for 252.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (5, 0, 0, 5, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 0, 0, 5, 0, 0), which had val score of -0.16
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score -0.16.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 1, 4), which had val score of -1.1958
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score -0.16.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (0, 8, 0, 5, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 8, 0, 5, 0, 0), which had val score of -0.0486
#         Current best combo: (0, 8, 0, 5, 0, 0) with val score -0.0486.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (0, 0, 0, 0, 1, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0), which had val score of -0.0089
#         Current best combo: (0, 0, 0, 0, 1, 0) with val score -0.0089.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 0, 0, 0, 1, 0) with val score -0.0089.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (0, 0, 0, 5, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 0, 5, 0, 0), which had val score of -0.0086
#         Current best combo: (0, 0, 0, 5, 0, 0) with val score -0.0086.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (5, 0, 0, 5, 0, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 0, 0, 5, 0, 4), which had val score of 0.0796
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 0), which had val score of -0.0092
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 0), which had val score of -0.2447
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 4), which had val score of -0.4079
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 0), which had val score of -2.3394
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 1, 4), which had val score of -0.0357
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 0, 0), which had val score of -0.0144
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 1, 4), which had val score of -0.2624
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 1, 4), which had val score of -0.1579
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 0, 4), which had val score of -1.0512
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 1, 4), which had val score of -0.1047
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 1, 0), which had val score of -0.0132
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 1, 0), which had val score of 0.0503
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 1, 4), which had val score of 0.0004
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 0, 4), which had val score of -0.3108
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 1, 0), which had val score of -0.0132
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 4), which had val score of -0.6106
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (0, 4, 0, 5, 0, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0879
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 1, 0), which had val score of -0.0089
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 0, 4), which had val score of -0.0248
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 1, 0), which had val score of -0.0005
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 1, 0), which had val score of -0.0132
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 1, 4), which had val score of -0.0065
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 1, 4), which had val score of -0.3624
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 0, 0), which had val score of 0.0062
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 1, 0), which had val score of -0.2549
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 1, 0), which had val score of -0.3949
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 0, 0), which had val score of -0.5321
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 4), which had val score of -0.7035
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 1, 4), which had val score of 0.0664
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 0, 4), which had val score of 0.0825
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 1, 0), which had val score of -0.1383
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 4), which had val score of -1.1058
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 0, 4), which had val score of -0.0053
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0), which had val score of -0.0086
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 0, 4), which had val score of -0.0636
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 1, 4), which had val score of -0.2842
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 1, 0), which had val score of -0.0343
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 1, 4), which had val score of -0.0079
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 0, 0), which had val score of -1.7294
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 4), which had val score of -0.7044
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 1, 0), which had val score of -0.6084
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 0), which had val score of -0.2105
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (2, 4, 3, 3, 1, 2), which had val score of 0.011
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1, 2), which had val score of 0.0805
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 2), which had val score of 0.0372
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1, 2), which had val score of 0.0276
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 4, 3, 1, 2), which had val score of -0.6903
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 2), which had val score of 0.0314
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1, 2), which had val score of -0.0123
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 0, 2), which had val score of -0.0184
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 1), which had val score of 0.012
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 3), which had val score of 0.0791
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 1, 2), which had val score of 0.0121
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (4, 3, 3, 3, 1, 2) was read in, best_clf is set to None
# Already Trained and Tested combination (4, 3, 3, 3, 1, 2), which had val score of 0.091
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 5, 3, 3, 1, 2), which had val score of 0.0877
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 2, 3, 1, 2), which had val score of 0.0805
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 4, 3, 1, 2), which had val score of -0.6903
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 2, 1, 2), which had val score of 0.0498
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 4, 1, 2), which had val score of 0.0818
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 0, 2), which had val score of -0.0349
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1, 1), which had val score of 0.082
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1, 3), which had val score of 0.071
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 3, 3, 3, 1, 2), which had val score of 0.0085
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 1, 2), which had val score of 0.091
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 3, 3, 1, 2), which had val score of 0.0863
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 2), which had val score of 0.0372
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 1, 2), which had val score of -0.6903
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1, 2), which had val score of 0.0291
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1, 2), which had val score of 0.0676
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 0, 2), which had val score of -0.0075
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 1), which had val score of 0.022
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (3, 3, 3, 3, 1, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 3, 3, 1, 3), which had val score of 0.1063
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 2, 3, 1, 2), which had val score of 0.011
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 2, 3, 1, 2), which had val score of 0.0805
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 2), which had val score of 0.0372
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 2, 3, 1, 2), which had val score of 0.0276
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 1, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1, 2), which had val score of 0.0314
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1, 2), which had val score of -0.0123
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 0, 2), which had val score of -0.0184
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 1), which had val score of 0.012
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 3), which had val score of 0.0791
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 3, 2, 1, 2), which had val score of 0.0165
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 2, 1, 2), which had val score of 0.0498
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1, 2), which had val score of 0.0291
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 2, 1, 2), which had val score of 0.0268
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1, 2), which had val score of 0.0314
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 4, 2, 1, 2), which had val score of -0.6903
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 1, 1, 2), which had val score of -0.0558
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 0, 2), which had val score of 0.0461
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 1), which had val score of -0.0079
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 3), which had val score of 0.0785
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 3, 3, 1, 3), which had val score of -0.0288
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1, 3), which had val score of 0.071
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 3), which had val score of 0.1063
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1, 3), which had val score of 0.0749
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 3), which had val score of 0.0791
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 4, 3, 1, 3), which had val score of -0.8097
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 3), which had val score of 0.0785
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1, 3), which had val score of 0.0802
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 0, 3), which had val score of -0.0148
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (3, 4, 3, 3, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 4, 3, 3, 1, 4), which had val score of 0.1088
#         Current best combo: (3, 4, 3, 3, 1, 4) with val score 0.1088.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 3, 3, 1, 4), which had val score of 0.0222
#         Current best combo: (3, 4, 3, 3, 1, 4) with val score 0.1088.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1, 4), which had val score of 0.0677
#         Current best combo: (3, 4, 3, 3, 1, 4) with val score 0.1088.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (3, 3, 3, 3, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 3, 3, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1, 4), which had val score of 0.1092
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 4), which had val score of 0.1174
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 4, 3, 1, 4), which had val score of -1.2797
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 4), which had val score of 0.1012
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1, 4), which had val score of 0.1088
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 0, 4), which had val score of -0.028
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 3), which had val score of 0.0791
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 3, 3, 3, 1, 4), which had val score of 0.0406
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 1, 4), which had val score of 0.0848
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 3, 3, 1, 4), which had val score of 0.0949
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 4), which had val score of 0.1088
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (3, 3, 2, 3, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 3, 1, 4), which had val score of 0.1254
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 1, 4), which had val score of -1.2797
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1, 4), which had val score of 0.1115
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 0, 4), which had val score of -0.021
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 3), which had val score of 0.1063
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 3, 2, 3, 1, 4), which had val score of 0.0432
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 1, 4), which had val score of 0.0869
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 4), which had val score of 0.1057
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 4), which had val score of 0.1174
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 1, 4), which had val score of 0.1254
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 4), which had val score of 0.1115
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (3, 3, 2, 4, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 0, 4), which had val score of -0.021
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 3), which had val score of 0.1063
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 3, 2, 4, 1, 4), which had val score of 0.0403
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 2, 4, 1, 4), which had val score of 0.0864
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 2, 4, 1, 4), which had val score of 0.1055
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1, 4), which had val score of 0.1174
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 4), which had val score of 0.1254
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 252 of 19440 combinations so far
# As new Best Combo (3, 3, 2, 5, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 5, 1, 4), which had val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 0, 4), which had val score of -0.0041
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 1, 3), which had val score of 0.1109
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 3, 2, 5, 1, 4), which had val score of 0.0403
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 2, 5, 1, 4), which had val score of 0.0866
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 2, 5, 1, 4), which had val score of 0.1104
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 5, 1, 4), which had val score of 0.1175
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 5, 1, 4), which had val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 5, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 5, 0, 4), which had val score of -0.0005
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 5, 1, 3), which had val score of 0.1142
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# % Combos Checked Thus Far: 252 out of 19440 which is 1.2962960000000001%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
# ...
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 1, 0, 5, 0, 4), which had val score of -0.2328
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 1, 5, 0, 4), which had val score of 0.0796
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 0, 4), which had val score of -0.0956
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 1, 4), which had val score of -0.1047
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 0, 3), which had val score of -0.1686
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# 	round 2 iteration:  1
#
# Already Trained and Tested combination (4, 0, 1, 5, 0, 4), which had val score of -0.0983
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 1, 1, 5, 0, 4), which had val score of -0.2328
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 0, 4), which had val score of 0.0796
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 2, 5, 0, 4), which had val score of 0.0796
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 1, 4, 0, 4), which had val score of -0.0956
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 1, 5, 1, 4), which had val score of -0.1047
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 1, 5, 0, 3), which had val score of -0.1686
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# % Combos Checked Thus Far: 252 out of 19440 which is 1.2962960000000001%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (1, 4, 0, 5, 0, 4), which had val score of 0.0806
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 3, 0, 5, 0, 4), which had val score of 0.0505
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 0, 4), which had val score of 0.1118
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 5, 0, 4), which had val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 4, 0, 4), which had val score of 0.0869
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 1, 4), which had val score of -0.0065
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 3), which had val score of 0.0733
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (1, 5, 0, 5, 0, 4), which had val score of 0.0767
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 6, 0, 5, 0, 4), which had val score of 0.0853
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 1, 5, 0, 4), which had val score of 0.1117
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 4, 0, 4), which had val score of 0.1117
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 1, 4), which had val score of -0.0063
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 0, 3), which had val score of 0.1006
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (1, 4, 1, 5, 0, 4), which had val score of 0.0806
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 3, 1, 5, 0, 4), which had val score of 0.0505
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 1, 5, 0, 4), which had val score of 0.1117
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 2, 5, 0, 4), which had val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 4, 0, 4), which had val score of 0.0869
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 5, 1, 4), which had val score of -0.0065
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 5, 0, 3), which had val score of 0.0733
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (1, 4, 0, 4, 0, 4), which had val score of 0.0804
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 4), which had val score of 0.0523
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 4, 0, 4), which had val score of 0.1117
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 4, 0, 4), which had val score of 0.0869
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 3, 0, 4), which had val score of 0.0868
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 4, 1, 4), which had val score of -0.0065
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 4, 0, 3), which had val score of 0.0729
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# % Combos Checked Thus Far: 252 out of 19440 which is 1.2962960000000001%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (2, 3, 2, 5, 1, 4), which had val score of 0.0403
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 2, 5, 1, 4), which had val score of 0.0866
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 2, 5, 1, 4), which had val score of 0.1104
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 5, 1, 4), which had val score of 0.1175
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 5, 1, 4), which had val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 5, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 5, 0, 4), which had val score of -0.0005
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 5, 1, 3), which had val score of 0.1142
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (2, 3, 1, 5, 1, 4), which had val score of 0.0397
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 1, 5, 1, 4), which had val score of 0.0867
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 1, 5, 1, 4), which had val score of 0.11
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 1, 5, 1, 4), which had val score of 0.1175
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 0, 5, 1, 4), which had val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 5, 1, 4), which had val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 5, 0, 4), which had val score of -0.0
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 5, 1, 3), which had val score of 0.1142
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (2, 3, 2, 4, 1, 4), which had val score of 0.0403
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 2, 4, 1, 4), which had val score of 0.0864
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 2, 4, 1, 4), which had val score of 0.1055
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1, 4), which had val score of 0.1174
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 4), which had val score of 0.1254
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 5, 1, 4), which had val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 0, 4), which had val score of -0.0041
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 1, 3), which had val score of 0.1109
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# % Combos Checked Thus Far: 252 out of 19440 which is 1.2962960000000001%
# Max Score:
#  0.12612
# Max Test Score:
#  0.018601
# Max Combo Index:
#  (3, 3, 2, 5, 1, 4) out of [6, 9, 6, 6, 2, 5] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.1, 'degree': 4, 'tol': 0.01, 'max_iter': 1600, 'gamma': 'scale', 'nu': 0.9}
# % Combos Checked: 252 out of 19440 which is 1.2962960000000001%
