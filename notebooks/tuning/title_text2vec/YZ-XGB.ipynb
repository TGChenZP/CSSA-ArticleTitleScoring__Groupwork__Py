# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
# Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = False

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': 19260817,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis=1)
train_y = train_data['label']
val_X = val_data.drop('label', axis=1)
val_y = val_data['label']
test_X = test_data.drop('label', axis=1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 31500: (5, 0, 0, 4, 0, 0), taking 13.67 seconds to get val score of -0.0018
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score -0.0018
# Trained and Tested combination 2 of 31500: (5, 0, 0, 0, 4, 5), taking 5.13 seconds to get val score of 0
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 3 of 31500: (0, 6, 0, 4, 0, 0), taking 1.51 seconds to get val score of -0.0106
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 4 of 31500: (0, 0, 0, 0, 4, 0), taking 0.29 seconds to get val score of -0.0108
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 5 of 31500: (0, 6, 4, 4, 0, 0), taking 2.29 seconds to get val score of -0.0103
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 6 of 31500: (0, 0, 0, 4, 0, 0), taking 0.39 seconds to get val score of -0.0106
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 7 of 31500: (5, 0, 0, 4, 0, 5), taking 5.67 seconds to get val score of 0
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 8 of 31500: (0, 3, 0, 4, 0, 0), taking 1.37 seconds to get val score of -0.0106
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 9 of 31500: (0, 0, 4, 0, 0, 0), taking 0.54 seconds to get val score of -0.0108
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 10 of 31500: (5, 3, 4, 0, 4, 0), taking 64.1 seconds to get val score of 0.0008
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 11 of 31500: (0, 6, 4, 4, 4, 0), taking 2.58 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 12 of 31500: (0, 3, 4, 0, 0, 5), taking 2.91 seconds to get val score of -9.496037247368613e+40
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 13 of 31500: (0, 3, 0, 0, 0, 0), taking 1.06 seconds to get val score of -0.0109
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 14 of 31500: (0, 3, 4, 0, 4, 0), taking 1.94 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 15 of 31500: (5, 3, 0, 0, 0, 5), taking 7.64 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 16 of 31500: (5, 0, 0, 0, 0, 0), taking 16.01 seconds to get val score of -0.005
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 17 of 31500: (0, 3, 4, 0, 4, 5), taking 1.91 seconds to get val score of -3.20093763522419e+42
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 18 of 31500: (0, 6, 0, 4, 4, 5), taking 0.85 seconds to get val score of -5.346585494067083e+43
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 19 of 31500: (5, 0, 4, 0, 4, 5), taking 5.61 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 20 of 31500: (5, 3, 4, 4, 4, 0), taking 82.22 seconds to get val score of -0.0016
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 21 of 31500: (5, 3, 0, 4, 0, 0), taking 127.78 seconds to get val score of 0.0006
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 22 of 31500: (0, 3, 0, 0, 4, 5), taking 4.07 seconds to get val score of -4.1021870025280776e+43
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 23 of 31500: (5, 6, 4, 0, 4, 5), taking 31.97 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 24 of 31500: (0, 6, 0, 0, 4, 5), taking 4.01 seconds to get val score of -4.1021870025280776e+43
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 25 of 31500: (5, 6, 4, 0, 0, 5), taking 28.92 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 26 of 31500: (5, 6, 0, 0, 0, 5), taking 23.7 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 27 of 31500: (0, 3, 4, 4, 0, 5), taking 8.27 seconds to get val score of -1.8917670239827062e+44
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 28 of 31500: (0, 6, 4, 0, 0, 5), taking 8.18 seconds to get val score of -9.496037247368613e+40
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 29 of 31500: (5, 0, 0, 4, 4, 5), taking 11.63 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 30 of 31500: (0, 3, 0, 4, 4, 0), taking 4.02 seconds to get val score of -0.0105
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0008
# Trained and Tested combination 31 of 31500: (5, 3, 0, 4, 4, 0), taking 128.77 seconds to get val score of 0.0008
#         Current best combo: (5, 3, 0, 4, 4, 0) with val score 0.0008
# Trained and Tested combination 32 of 31500: (5, 3, 0, 4, 4, 5), taking 18.11 seconds to get val score of 0
#         Current best combo: (5, 3, 0, 4, 4, 0) with val score 0.0008
# Trained and Tested combination 33 of 31500: (0, 6, 0, 0, 0, 5), taking 0.86 seconds to get val score of -1.9707000218658118e+41
#         Current best combo: (5, 3, 0, 4, 4, 0) with val score 0.0008
# Trained and Tested combination 34 of 31500: (0, 3, 0, 0, 4, 0), taking 2.21 seconds to get val score of -0.0109
#         Current best combo: (5, 3, 0, 4, 4, 0) with val score 0.0008
# Trained and Tested combination 35 of 31500: (0, 3, 0, 0, 0, 5), taking 0.86 seconds to get val score of -1.9707000218658118e+41
#         Current best combo: (5, 3, 0, 4, 4, 0) with val score 0.0008
# Trained and Tested combination 36 of 31500: (0, 3, 0, 4, 0, 5), taking 1.34 seconds to get val score of -1.640454861813266e+45
#         Current best combo: (5, 3, 0, 4, 4, 0) with val score 0.0008
# Trained and Tested combination 37 of 31500: (5, 3, 4, 4, 4, 5), taking 4.63 seconds to get val score of 0
#         Current best combo: (5, 3, 0, 4, 4, 0) with val score 0.0008
# Trained and Tested combination 38 of 31500: (5, 0, 4, 4, 0, 5), taking 10.21 seconds to get val score of 0
#         Current best combo: (5, 3, 0, 4, 4, 0) with val score 0.0008
# Trained and Tested combination 39 of 31500: (5, 3, 4, 4, 0, 0), taking 174.48 seconds to get val score of 0.0033
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 40 of 31500: (0, 0, 0, 4, 4, 0), taking 1.65 seconds to get val score of -0.0106
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 41 of 31500: (5, 6, 4, 0, 0, 0), taking 237.6 seconds to get val score of 0.0012
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 42 of 31500: (5, 3, 0, 4, 0, 5), taking 2.87 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 43 of 31500: (0, 6, 0, 0, 4, 0), taking 0.54 seconds to get val score of -0.0109
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 44 of 31500: (5, 6, 4, 4, 0, 5), taking 11.42 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 45 of 31500: (0, 0, 4, 0, 4, 5), taking 1.45 seconds to get val score of -8.442828807289942e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 46 of 31500: (0, 6, 0, 4, 4, 0), taking 0.41 seconds to get val score of -0.0105
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 47 of 31500: (0, 6, 4, 0, 4, 5), taking 1.04 seconds to get val score of -3.20093763522419e+42
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 48 of 31500: (5, 6, 4, 4, 0, 0), taking 173.86 seconds to get val score of 0.0033
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 49 of 31500: (0, 3, 0, 4, 4, 5), taking 3.61 seconds to get val score of -5.346585494067083e+43
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 50 of 31500: (5, 6, 0, 0, 4, 5), taking 22.48 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 51 of 31500: (5, 6, 0, 4, 0, 0), taking 142.95 seconds to get val score of 0.0006
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 52 of 31500: (5, 3, 4, 0, 0, 5), taking 33.24 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 53 of 31500: (0, 6, 4, 4, 0, 5), taking 8.74 seconds to get val score of -1.8917670239827062e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 54 of 31500: (0, 0, 4, 4, 0, 5), taking 1.51 seconds to get val score of -1.7082234381308105e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 55 of 31500: (5, 3, 0, 0, 4, 0), taking 90.91 seconds to get val score of -0.0032
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 56 of 31500: (5, 0, 0, 0, 4, 0), taking 52.77 seconds to get val score of -0.0048
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 57 of 31500: (0, 6, 0, 0, 0, 0), taking 4.82 seconds to get val score of -0.0109
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 58 of 31500: (0, 0, 4, 0, 0, 5), taking 1.47 seconds to get val score of -8.442828807289942e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 59 of 31500: (0, 0, 0, 0, 0, 5), taking 1.33 seconds to get val score of -3.406226049668466e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 60 of 31500: (5, 0, 4, 0, 4, 0), taking 54.45 seconds to get val score of -0.0067
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 61 of 31500: (5, 6, 0, 4, 4, 5), taking 24.64 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 62 of 31500: (0, 3, 4, 4, 4, 0), taking 6.77 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 63 of 31500: (0, 6, 0, 4, 0, 5), taking 3.65 seconds to get val score of -1.640454861813266e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 64 of 31500: (5, 3, 4, 0, 4, 5), taking 28.23 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 65 of 31500: (0, 0, 4, 4, 4, 5), taking 1.95 seconds to get val score of -1.6919594087250347e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 66 of 31500: (5, 3, 4, 4, 0, 5), taking 29.92 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 67 of 31500: (0, 6, 4, 0, 0, 0), taking 7.99 seconds to get val score of -0.0105
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 68 of 31500: (5, 0, 4, 4, 4, 5), taking 22.69 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 69 of 31500: (5, 0, 4, 4, 4, 0), taking 37.59 seconds to get val score of -0.0134
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 70 of 31500: (5, 0, 0, 4, 4, 0), taking 7.4 seconds to get val score of -0.0018
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 71 of 31500: (5, 0, 0, 0, 0, 5), taking 1.83 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 72 of 31500: (5, 6, 4, 4, 4, 0), taking 123.04 seconds to get val score of -0.0016
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 73 of 31500: (0, 3, 4, 4, 0, 0), taking 6.04 seconds to get val score of -0.0103
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 74 of 31500: (0, 0, 0, 4, 0, 5), taking 1.55 seconds to get val score of -6.802184194503251e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 75 of 31500: (0, 0, 4, 4, 0, 0), taking 1.67 seconds to get val score of -0.0109
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 76 of 31500: (0, 0, 0, 0, 0, 0), taking 1.38 seconds to get val score of -0.0108
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 77 of 31500: (5, 6, 0, 4, 0, 5), taking 12.47 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 78 of 31500: (5, 6, 4, 4, 4, 5), taking 23.99 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 79 of 31500: (5, 0, 4, 0, 0, 0), taking 47.13 seconds to get val score of -0.0065
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 80 of 31500: (5, 3, 0, 0, 4, 5), taking 24.17 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 81 of 31500: (0, 3, 4, 0, 0, 0), taking 7.14 seconds to get val score of -0.0105
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 82 of 31500: (5, 6, 0, 4, 4, 0), taking 137.51 seconds to get val score of 0.0008
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 83 of 31500: (0, 0, 0, 4, 4, 5), taking 1.79 seconds to get val score of -5.253838791617309e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 84 of 31500: (5, 0, 4, 4, 0, 0), taking 55.43 seconds to get val score of -0.0134
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 85 of 31500: (0, 3, 4, 4, 4, 5), taking 5.85 seconds to get val score of -4.2195563593446456e+43
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 86 of 31500: (5, 6, 4, 0, 4, 0), taking 109.69 seconds to get val score of 0.0008
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 87 of 31500: (0, 0, 4, 4, 4, 0), taking 1.7 seconds to get val score of -0.0109
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 88 of 31500: (5, 6, 0, 0, 0, 0), taking 137.07 seconds to get val score of -0.0028
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 89 of 31500: (5, 0, 4, 0, 0, 5), taking 21.57 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 90 of 31500: (0, 0, 4, 0, 4, 0), taking 1.64 seconds to get val score of -0.0108
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 91 of 31500: (0, 0, 0, 0, 4, 5), taking 1.6 seconds to get val score of -3.6506553145165666e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 92 of 31500: (5, 6, 0, 0, 4, 0), taking 139.85 seconds to get val score of -0.0032
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 93 of 31500: (5, 3, 4, 0, 0, 0), taking 135.81 seconds to get val score of 0.0012
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 94 of 31500: (0, 6, 4, 0, 4, 0), taking 1.02 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 95 of 31500: (3, 3, 2, 2, 2, 3), taking 9.2 seconds to get val score of -0.0016
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 96 of 31500: (0, 6, 4, 4, 4, 5), taking 6.14 seconds to get val score of -4.2195563593446456e+43
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 97 of 31500: (5, 3, 0, 0, 0, 0), taking 114.9 seconds to get val score of -0.0028
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 98 of 31500: (2, 3, 2, 2, 2, 3), taking 27.7 seconds to get val score of -0.0006
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 99 of 31500: (4, 3, 2, 2, 2, 3), taking 95.36 seconds to get val score of -0.0055
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 100 of 31500: (3, 2, 2, 2, 2, 3), taking 46.32 seconds to get val score of -0.0475
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 101 of 31500: (3, 4, 2, 2, 2, 3), taking 32.05 seconds to get val score of -0.0016
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 102 of 31500: (3, 3, 1, 2, 2, 3), taking 25.23 seconds to get val score of -0.0752
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 103 of 31500: (3, 3, 3, 2, 2, 3), taking 62.52 seconds to get val score of -0.0787
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 104 of 31500: (3, 3, 2, 1, 2, 3), taking 50.25 seconds to get val score of -0.0909
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 105 of 31500: (3, 3, 2, 3, 2, 3), taking 47.39 seconds to get val score of -0.0441
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 106 of 31500: (3, 3, 2, 2, 1, 3), taking 38.03 seconds to get val score of -0.0134
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 107 of 31500: (3, 3, 2, 2, 3, 3), taking 49.89 seconds to get val score of -0.0448
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 108 of 31500: (3, 3, 2, 2, 2, 2), taking 51.0 seconds to get val score of -0.0046
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# Trained and Tested combination 109 of 31500: (3, 3, 2, 2, 2, 4), taking 15.63 seconds to get val score of -0.6571
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0033
# 	round 0 iteration:  1
#
# Trained and Tested combination 110 of 31500: (1, 3, 2, 2, 2, 3), taking 3.48 seconds to get val score of 0.0107
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of -0.0016
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107.
#         Has trained 110 of 31500 combinations so far
# Trained and Tested combination 111 of 31500: (2, 2, 2, 2, 2, 3), taking 5.13 seconds to get val score of -0.0421
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107
# Trained and Tested combination 112 of 31500: (2, 4, 2, 2, 2, 3), taking 18.37 seconds to get val score of -0.0006
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107
# Trained and Tested combination 113 of 31500: (2, 3, 1, 2, 2, 3), taking 3.72 seconds to get val score of -0.0728
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107
# Trained and Tested combination 114 of 31500: (2, 3, 3, 2, 2, 3), taking 2.76 seconds to get val score of -0.0786
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107
# Trained and Tested combination 115 of 31500: (2, 3, 2, 1, 2, 3), taking 23.95 seconds to get val score of -0.088
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107
# Trained and Tested combination 116 of 31500: (2, 3, 2, 3, 2, 3), taking 24.75 seconds to get val score of -0.0404
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107
# Trained and Tested combination 117 of 31500: (2, 3, 2, 2, 1, 3), taking 25.35 seconds to get val score of -0.0117
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107
# Trained and Tested combination 118 of 31500: (2, 3, 2, 2, 3, 3), taking 23.56 seconds to get val score of -0.0474
#         Current best combo: (1, 3, 2, 2, 2, 3) with val score 0.0107
# Trained and Tested combination 119 of 31500: (2, 3, 2, 2, 2, 2), taking 23.44 seconds to get val score of 0.0298
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 120 of 31500: (2, 3, 2, 2, 2, 4), taking 22.23 seconds to get val score of -0.6507
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of -0.0016
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298.
#         Has trained 120 of 31500 combinations so far
# Trained and Tested combination 121 of 31500: (5, 3, 2, 2, 2, 3), taking 148.32 seconds to get val score of -0.0043
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 122 of 31500: (4, 2, 2, 2, 2, 3), taking 38.4 seconds to get val score of -0.0483
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 123 of 31500: (4, 4, 2, 2, 2, 3), taking 7.85 seconds to get val score of -0.0055
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 124 of 31500: (4, 3, 1, 2, 2, 3), taking 8.08 seconds to get val score of -0.0744
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 125 of 31500: (4, 3, 3, 2, 2, 3), taking 10.74 seconds to get val score of -0.0784
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 126 of 31500: (4, 3, 2, 1, 2, 3), taking 8.49 seconds to get val score of -0.0956
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 127 of 31500: (4, 3, 2, 3, 2, 3), taking 8.63 seconds to get val score of -0.0461
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 128 of 31500: (4, 3, 2, 2, 1, 3), taking 4.36 seconds to get val score of -0.0147
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 129 of 31500: (4, 3, 2, 2, 3, 3), taking 7.88 seconds to get val score of -0.0503
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 130 of 31500: (4, 3, 2, 2, 2, 2), taking 6.77 seconds to get val score of -0.0354
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 131 of 31500: (4, 3, 2, 2, 2, 4), taking 6.2 seconds to get val score of -0.6576
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Already Trained and Tested combination (2, 4, 2, 2, 2, 3), which had val score of -0.0006
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298.
#         Has trained 131 of 31500 combinations so far
# Already Trained and Tested combination (4, 4, 2, 2, 2, 3), which had val score of -0.0055
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298.
#         Has trained 131 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of -0.0016
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298.
#         Has trained 131 of 31500 combinations so far
# Trained and Tested combination 132 of 31500: (3, 5, 2, 2, 2, 3), taking 2.34 seconds to get val score of -0.0016
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 133 of 31500: (3, 4, 1, 2, 2, 3), taking 2.65 seconds to get val score of -0.0752
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 134 of 31500: (3, 4, 3, 2, 2, 3), taking 3.79 seconds to get val score of -0.0787
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 135 of 31500: (3, 4, 2, 1, 2, 3), taking 3.41 seconds to get val score of -0.0909
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 136 of 31500: (3, 4, 2, 3, 2, 3), taking 3.34 seconds to get val score of -0.0441
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 137 of 31500: (3, 4, 2, 2, 1, 3), taking 2.44 seconds to get val score of -0.0134
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 138 of 31500: (3, 4, 2, 2, 3, 3), taking 3.37 seconds to get val score of -0.0448
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 139 of 31500: (3, 4, 2, 2, 2, 2), taking 2.68 seconds to get val score of -0.0046
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Trained and Tested combination 140 of 31500: (3, 4, 2, 2, 2, 4), taking 2.99 seconds to get val score of -0.6571
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Already Trained and Tested combination (2, 3, 2, 2, 2, 2), which had val score of 0.0298
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298.
#         Has trained 140 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 2, 2), which had val score of -0.0354
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298.
#         Has trained 140 of 31500 combinations so far
# Trained and Tested combination 141 of 31500: (3, 2, 2, 2, 2, 2), taking 3.07 seconds to get val score of -0.0007
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298
# Already Trained and Tested combination (3, 4, 2, 2, 2, 2), which had val score of -0.0046
#         Current best combo: (2, 3, 2, 2, 2, 2) with val score 0.0298.
#         Has trained 141 of 31500 combinations so far
# Trained and Tested combination 142 of 31500: (3, 3, 1, 2, 2, 2), taking 2.69 seconds to get val score of 0.0604
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 143 of 31500: (3, 3, 3, 2, 2, 2), taking 3.78 seconds to get val score of -0.0494
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 144 of 31500: (3, 3, 2, 1, 2, 2), taking 3.35 seconds to get val score of 0.0121
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 145 of 31500: (3, 3, 2, 3, 2, 2), taking 3.16 seconds to get val score of 0.0164
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 146 of 31500: (3, 3, 2, 2, 1, 2), taking 3.15 seconds to get val score of -0.0056
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 147 of 31500: (3, 3, 2, 2, 3, 2), taking 2.35 seconds to get val score of 0.0001
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 148 of 31500: (3, 3, 2, 2, 2, 1), taking 2.32 seconds to get val score of 0.0117
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of -0.0016
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 148 of 31500 combinations so far
# Trained and Tested combination 149 of 31500: (2, 3, 1, 2, 2, 2), taking 1.04 seconds to get val score of 0.0598
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 150 of 31500: (4, 3, 1, 2, 2, 2), taking 4.48 seconds to get val score of 0.04
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 151 of 31500: (3, 2, 1, 2, 2, 2), taking 2.04 seconds to get val score of 0.0541
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 152 of 31500: (3, 4, 1, 2, 2, 2), taking 2.09 seconds to get val score of 0.0604
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 153 of 31500: (3, 3, 0, 2, 2, 2), taking 1.64 seconds to get val score of 0.0584
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Already Trained and Tested combination (3, 3, 2, 2, 2, 2), which had val score of -0.0046
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 153 of 31500 combinations so far
# Trained and Tested combination 154 of 31500: (3, 3, 1, 1, 2, 2), taking 2.03 seconds to get val score of 0.0529
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 155 of 31500: (3, 3, 1, 3, 2, 2), taking 2.1 seconds to get val score of 0.0448
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 156 of 31500: (3, 3, 1, 2, 1, 2), taking 2.0 seconds to get val score of 0.0565
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 157 of 31500: (3, 3, 1, 2, 3, 2), taking 2.13 seconds to get val score of 0.0576
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Trained and Tested combination 158 of 31500: (3, 3, 1, 2, 2, 1), taking 2.0 seconds to get val score of 0.0193
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604
# Already Trained and Tested combination (3, 3, 1, 2, 2, 3), which had val score of -0.0752
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# % Combos Checked Thus Far: 158 out of 31500 which is 0.501587%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (2, 3, 1, 2, 2, 2), which had val score of 0.0598
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 1, 2, 2, 2), which had val score of 0.04
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2, 2), which had val score of 0.0541
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 1, 2, 2, 2), which had val score of 0.0604
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 2, 2, 2), which had val score of 0.0584
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 2), which had val score of -0.0046
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 1, 2, 2), which had val score of 0.0529
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 2, 2), which had val score of 0.0448
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 1, 2), which had val score of 0.0565
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 3, 2), which had val score of 0.0576
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 1), which had val score of 0.0193
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 3), which had val score of -0.0752
#         Current best combo: (3, 3, 1, 2, 2, 2) with val score 0.0604.
#         Has trained 158 of 31500 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 159 of 31500: (1, 3, 1, 2, 2, 2), taking 0.5 seconds to get val score of 0.0637
#         Current best combo: (1, 3, 1, 2, 2, 2) with val score 0.0637
# Already Trained and Tested combination (3, 3, 1, 2, 2, 2), which had val score of 0.0604
#         Current best combo: (1, 3, 1, 2, 2, 2) with val score 0.0637.
#         Has trained 159 of 31500 combinations so far
# Trained and Tested combination 160 of 31500: (2, 2, 1, 2, 2, 2), taking 0.95 seconds to get val score of 0.0598
#         Current best combo: (1, 3, 1, 2, 2, 2) with val score 0.0637
# Trained and Tested combination 161 of 31500: (2, 4, 1, 2, 2, 2), taking 0.95 seconds to get val score of 0.0598
#         Current best combo: (1, 3, 1, 2, 2, 2) with val score 0.0637
# Trained and Tested combination 162 of 31500: (2, 3, 0, 2, 2, 2), taking 0.87 seconds to get val score of 0.0771
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Already Trained and Tested combination (2, 3, 2, 2, 2, 2), which had val score of 0.0298
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771.
#         Has trained 162 of 31500 combinations so far
# Trained and Tested combination 163 of 31500: (2, 3, 1, 1, 2, 2), taking 1.0 seconds to get val score of 0.0513
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 164 of 31500: (2, 3, 1, 3, 2, 2), taking 1.02 seconds to get val score of 0.0604
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 165 of 31500: (2, 3, 1, 2, 1, 2), taking 0.94 seconds to get val score of 0.062
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 166 of 31500: (2, 3, 1, 2, 3, 2), taking 0.97 seconds to get val score of 0.0568
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 167 of 31500: (2, 3, 1, 2, 2, 1), taking 1.01 seconds to get val score of 0.0042
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Already Trained and Tested combination (2, 3, 1, 2, 2, 3), which had val score of -0.0728
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771.
#         Has trained 167 of 31500 combinations so far
# Already Trained and Tested combination (2, 4, 1, 2, 2, 2), which had val score of 0.0598
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771.
#         Has trained 167 of 31500 combinations so far
# Trained and Tested combination 168 of 31500: (4, 4, 1, 2, 2, 2), taking 4.34 seconds to get val score of 0.04
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Already Trained and Tested combination (3, 3, 1, 2, 2, 2), which had val score of 0.0604
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771.
#         Has trained 168 of 31500 combinations so far
# Trained and Tested combination 169 of 31500: (3, 5, 1, 2, 2, 2), taking 2.02 seconds to get val score of 0.0604
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 170 of 31500: (3, 4, 0, 2, 2, 2), taking 1.61 seconds to get val score of 0.0584
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Already Trained and Tested combination (3, 4, 2, 2, 2, 2), which had val score of -0.0046
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771.
#         Has trained 170 of 31500 combinations so far
# Trained and Tested combination 171 of 31500: (3, 4, 1, 1, 2, 2), taking 2.03 seconds to get val score of 0.0529
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 172 of 31500: (3, 4, 1, 3, 2, 2), taking 2.04 seconds to get val score of 0.0448
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 173 of 31500: (3, 4, 1, 2, 1, 2), taking 2.01 seconds to get val score of 0.0565
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 174 of 31500: (3, 4, 1, 2, 3, 2), taking 2.14 seconds to get val score of 0.0576
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 175 of 31500: (3, 4, 1, 2, 2, 1), taking 2.1 seconds to get val score of 0.0193
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Already Trained and Tested combination (3, 4, 1, 2, 2, 3), which had val score of -0.0752
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771.
#         Has trained 175 of 31500 combinations so far
# Already Trained and Tested combination (2, 3, 0, 2, 2, 2), which had val score of 0.0771
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771.
#         Has trained 175 of 31500 combinations so far
# Trained and Tested combination 176 of 31500: (4, 3, 0, 2, 2, 2), taking 3.56 seconds to get val score of 0.0319
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 177 of 31500: (3, 2, 0, 2, 2, 2), taking 1.64 seconds to get val score of 0.0584
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Already Trained and Tested combination (3, 4, 0, 2, 2, 2), which had val score of 0.0584
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771.
#         Has trained 177 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 2), which had val score of 0.0604
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771.
#         Has trained 177 of 31500 combinations so far
# Trained and Tested combination 178 of 31500: (3, 3, 0, 1, 2, 2), taking 1.74 seconds to get val score of 0.0548
#         Current best combo: (2, 3, 0, 2, 2, 2) with val score 0.0771
# Trained and Tested combination 179 of 31500: (3, 3, 0, 3, 2, 2), taking 1.65 seconds to get val score of 0.0967
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 180 of 31500: (3, 3, 0, 2, 1, 2), taking 1.6 seconds to get val score of 0.0593
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 181 of 31500: (3, 3, 0, 2, 3, 2), taking 1.72 seconds to get val score of 0.0547
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 182 of 31500: (3, 3, 0, 2, 2, 1), taking 1.63 seconds to get val score of 0.0182
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 183 of 31500: (3, 3, 0, 2, 2, 3), taking 1.84 seconds to get val score of 0.0556
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Already Trained and Tested combination (2, 3, 1, 2, 1, 2), which had val score of 0.062
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 183 of 31500 combinations so far
# Trained and Tested combination 184 of 31500: (4, 3, 1, 2, 1, 2), taking 4.36 seconds to get val score of 0.0382
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 185 of 31500: (3, 2, 1, 2, 1, 2), taking 1.99 seconds to get val score of 0.0528
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Already Trained and Tested combination (3, 4, 1, 2, 1, 2), which had val score of 0.0565
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 185 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 2, 1, 2), which had val score of 0.0593
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 185 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 2), which had val score of -0.0056
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 185 of 31500 combinations so far
# Trained and Tested combination 186 of 31500: (3, 3, 1, 1, 1, 2), taking 2.11 seconds to get val score of 0.0617
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 187 of 31500: (3, 3, 1, 3, 1, 2), taking 2.01 seconds to get val score of 0.0403
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 188 of 31500: (3, 3, 1, 2, 0, 2), taking 2.14 seconds to get val score of 0.0565
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Already Trained and Tested combination (3, 3, 1, 2, 2, 2), which had val score of 0.0604
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 188 of 31500 combinations so far
# Trained and Tested combination 189 of 31500: (3, 3, 1, 2, 1, 1), taking 2.47 seconds to get val score of 0.0193
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 190 of 31500: (3, 3, 1, 2, 1, 3), taking 2.48 seconds to get val score of -0.0694
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Already Trained and Tested combination (2, 3, 1, 2, 3, 2), which had val score of 0.0568
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 190 of 31500 combinations so far
# Trained and Tested combination 191 of 31500: (4, 3, 1, 2, 3, 2), taking 4.36 seconds to get val score of 0.0408
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 192 of 31500: (3, 2, 1, 2, 3, 2), taking 2.12 seconds to get val score of 0.0576
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Already Trained and Tested combination (3, 4, 1, 2, 3, 2), which had val score of 0.0576
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 192 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 2, 3, 2), which had val score of 0.0547
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 192 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 2), which had val score of 0.0001
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 192 of 31500 combinations so far
# Trained and Tested combination 193 of 31500: (3, 3, 1, 1, 3, 2), taking 2.1 seconds to get val score of 0.0614
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 194 of 31500: (3, 3, 1, 3, 3, 2), taking 2.07 seconds to get val score of 0.0562
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Already Trained and Tested combination (3, 3, 1, 2, 2, 2), which had val score of 0.0604
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 194 of 31500 combinations so far
# Trained and Tested combination 195 of 31500: (3, 3, 1, 2, 4, 2), taking 2.03 seconds to get val score of 0.0736
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 196 of 31500: (3, 3, 1, 2, 3, 1), taking 2.06 seconds to get val score of 0.0194
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 197 of 31500: (3, 3, 1, 2, 3, 3), taking 2.13 seconds to get val score of 0.0011
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 198 of 31500: (2, 3, 0, 3, 2, 2), taking 0.8 seconds to get val score of 0.0909
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 199 of 31500: (4, 3, 0, 3, 2, 2), taking 3.47 seconds to get val score of 0.0788
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 200 of 31500: (3, 2, 0, 3, 2, 2), taking 1.69 seconds to get val score of 0.0967
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Trained and Tested combination 201 of 31500: (3, 4, 0, 3, 2, 2), taking 1.73 seconds to get val score of 0.0967
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967
# Already Trained and Tested combination (3, 3, 1, 3, 2, 2), which had val score of 0.0448
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 201 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 2, 2, 2), which had val score of 0.0584
#         Current best combo: (3, 3, 0, 3, 2, 2) with val score 0.0967.
#         Has trained 201 of 31500 combinations so far
# Trained and Tested combination 202 of 31500: (3, 3, 0, 4, 2, 2), taking 1.9 seconds to get val score of 0.1071
#         Current best combo: (3, 3, 0, 4, 2, 2) with val score 0.1071
# Trained and Tested combination 203 of 31500: (3, 3, 0, 3, 1, 2), taking 1.61 seconds to get val score of 0.0943
#         Current best combo: (3, 3, 0, 4, 2, 2) with val score 0.1071
# Trained and Tested combination 204 of 31500: (3, 3, 0, 3, 3, 2), taking 1.64 seconds to get val score of 0.0697
#         Current best combo: (3, 3, 0, 4, 2, 2) with val score 0.1071
# Trained and Tested combination 205 of 31500: (3, 3, 0, 3, 2, 1), taking 1.65 seconds to get val score of 0.0206
#         Current best combo: (3, 3, 0, 4, 2, 2) with val score 0.1071
# Trained and Tested combination 206 of 31500: (3, 3, 0, 3, 2, 3), taking 1.8 seconds to get val score of -0.0316
#         Current best combo: (3, 3, 0, 4, 2, 2) with val score 0.1071
# Trained and Tested combination 207 of 31500: (2, 3, 0, 4, 2, 2), taking 1.02 seconds to get val score of 0.1064
#         Current best combo: (3, 3, 0, 4, 2, 2) with val score 0.1071
# Trained and Tested combination 208 of 31500: (4, 3, 0, 4, 2, 2), taking 3.38 seconds to get val score of 0.0857
#         Current best combo: (3, 3, 0, 4, 2, 2) with val score 0.1071
# Trained and Tested combination 209 of 31500: (3, 2, 0, 4, 2, 2), taking 1.67 seconds to get val score of 0.1078
#         Current best combo: (3, 2, 0, 4, 2, 2) with val score 0.1078
# Trained and Tested combination 210 of 31500: (3, 4, 0, 4, 2, 2), taking 1.69 seconds to get val score of 0.1071
#         Current best combo: (3, 2, 0, 4, 2, 2) with val score 0.1078
# Trained and Tested combination 211 of 31500: (3, 3, 1, 4, 2, 2), taking 2.0 seconds to get val score of 0.0485
#         Current best combo: (3, 2, 0, 4, 2, 2) with val score 0.1078
# Already Trained and Tested combination (3, 3, 0, 3, 2, 2), which had val score of 0.0967
#         Current best combo: (3, 2, 0, 4, 2, 2) with val score 0.1078.
#         Has trained 211 of 31500 combinations so far
# Trained and Tested combination 212 of 31500: (3, 3, 0, 4, 1, 2), taking 1.71 seconds to get val score of 0.1069
#         Current best combo: (3, 2, 0, 4, 2, 2) with val score 0.1078
# Trained and Tested combination 213 of 31500: (3, 3, 0, 4, 3, 2), taking 1.67 seconds to get val score of 0.1183
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 214 of 31500: (3, 3, 0, 4, 2, 1), taking 1.62 seconds to get val score of 0.016
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 215 of 31500: (3, 3, 0, 4, 2, 3), taking 1.84 seconds to get val score of -0.0745
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 216 of 31500: (2, 3, 0, 4, 3, 2), taking 1.04 seconds to get val score of 0.1049
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 217 of 31500: (4, 3, 0, 4, 3, 2), taking 3.55 seconds to get val score of 0.0886
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 218 of 31500: (3, 2, 0, 4, 3, 2), taking 1.71 seconds to get val score of 0.1103
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 219 of 31500: (3, 4, 0, 4, 3, 2), taking 1.77 seconds to get val score of 0.1183
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 220 of 31500: (3, 3, 1, 4, 3, 2), taking 2.01 seconds to get val score of 0.064
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Already Trained and Tested combination (3, 3, 0, 3, 3, 2), which had val score of 0.0697
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 220 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2), which had val score of 0.1071
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 220 of 31500 combinations so far
# Trained and Tested combination 221 of 31500: (3, 3, 0, 4, 4, 2), taking 1.65 seconds to get val score of 0.1021
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 222 of 31500: (3, 3, 0, 4, 3, 1), taking 1.52 seconds to get val score of 0.0154
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 223 of 31500: (3, 3, 0, 4, 3, 3), taking 1.73 seconds to get val score of 0.0501
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# % Combos Checked Thus Far: 223 out of 31500 which is 0.7079369999999999%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (2, 3, 0, 4, 3, 2), which had val score of 0.1049
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 3, 2), which had val score of 0.0886
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 0, 4, 3, 2), which had val score of 0.1103
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 0, 4, 3, 2), which had val score of 0.1183
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 4, 3, 2), which had val score of 0.064
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 3, 2), which had val score of 0.0697
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2), which had val score of 0.1071
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 4, 2), which had val score of 0.1021
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 3, 1), which had val score of 0.0154
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 3, 3), which had val score of 0.0501
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 223 of 31500 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 224 of 31500: (2, 4, 0, 4, 3, 2), taking 0.87 seconds to get val score of 0.1049
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 225 of 31500: (4, 4, 0, 4, 3, 2), taking 3.62 seconds to get val score of 0.0886
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Already Trained and Tested combination (3, 3, 0, 4, 3, 2), which had val score of 0.1183
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 225 of 31500 combinations so far
# Trained and Tested combination 226 of 31500: (3, 5, 0, 4, 3, 2), taking 1.7 seconds to get val score of 0.1183
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 227 of 31500: (3, 4, 1, 4, 3, 2), taking 1.99 seconds to get val score of 0.064
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 228 of 31500: (3, 4, 0, 3, 3, 2), taking 1.66 seconds to get val score of 0.0697
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Already Trained and Tested combination (3, 4, 0, 4, 2, 2), which had val score of 0.1071
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183.
#         Has trained 228 of 31500 combinations so far
# Trained and Tested combination 229 of 31500: (3, 4, 0, 4, 4, 2), taking 1.71 seconds to get val score of 0.1021
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 230 of 31500: (3, 4, 0, 4, 3, 1), taking 1.63 seconds to get val score of 0.0154
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# Trained and Tested combination 231 of 31500: (3, 4, 0, 4, 3, 3), taking 1.74 seconds to get val score of 0.0501
#         Current best combo: (3, 3, 0, 4, 3, 2) with val score 0.1183
# % Combos Checked Thus Far: 231 out of 31500 which is 0.733333%
# Max Score:
#  0.11826841198624283
# Max Test Score:
#  0.078605
# Max Combo Index:
#  (3, 3, 0, 4, 3, 2) out of [6, 7, 5, 5, 5, 6] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.01, 'eta': 0.01}
# % Combos Checked: 231 out of 31500 which is 0.733333%
