# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'cb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from catboost import CatBoostRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {

    'n_estimators': (25, 50, 100, 200),
    'max_depth': (2, 4, 8, 16),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bylevel': (0.4, 0.55, 0.7, 0.85, 1),
    'max_bin': (64, 256),
    'reg_lambda': (0.01, 0.1, 1),
    'learning_rate': (0.001, 0.01, 0.1, 1),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
      'random_state': 19260817,
      'verbose': False
      }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'catboost.core.CatBoostRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# Successfully read in tuning result of 605 rows, for 605.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (0, 3, 4, 0, 1, 2, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 3, 4, 0, 1, 2, 3), which had val score of 0.0183
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 1, 0, 0), which had val score of -0.0044
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 0, 3), which had val score of -0.3321
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 1, 0, 3), which had val score of -0.2816
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 0, 0, 3), which had val score of -0.527
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 0, 2, 3), which had val score of -0.5392
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 0, 3), which had val score of -0.2696
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 1, 2, 3), which had val score of -0.0911
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 0, 0, 0), which had val score of -0.008
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 2, 0), which had val score of -0.0072
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 0, 3), which had val score of -0.3745
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 2, 0), which had val score of -0.0062
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 0, 3), which had val score of -0.18
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 1, 2, 0), which had val score of -0.0038
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 0, 3), which had val score of -0.3745
#         Current best combo: (0, 3, 4, 0, 1, 2, 3) with val score 0.0183.
#         Has trained 605 of 9600 combinations so far
# As new Best Combo (3, 3, 4, 4, 0, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 4, 4, 0, 0, 0), which had val score of 0.0187
#         Current best combo: (3, 3, 4, 4, 0, 0, 0) with val score 0.0187.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 1, 0, 0), which had val score of -0.0058
#         Current best combo: (3, 3, 4, 4, 0, 0, 0) with val score 0.0187.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 1, 2, 3), which had val score of -0.2825
#         Current best combo: (3, 3, 4, 4, 0, 0, 0) with val score 0.0187.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 2, 3), which had val score of -0.2347
#         Current best combo: (3, 3, 4, 4, 0, 0, 0) with val score 0.0187.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 2, 0), which had val score of 0.0085
#         Current best combo: (3, 3, 4, 4, 0, 0, 0) with val score 0.0187.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 2, 0), which had val score of -0.0061
#         Current best combo: (3, 3, 4, 4, 0, 0, 0) with val score 0.0187.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 1, 2, 3), which had val score of -0.1617
#         Current best combo: (3, 3, 4, 4, 0, 0, 0) with val score 0.0187.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 2, 3), which had val score of -0.0712
#         Current best combo: (3, 3, 4, 4, 0, 0, 0) with val score 0.0187.
#         Has trained 605 of 9600 combinations so far
# As new Best Combo (3, 3, 0, 0, 1, 0, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 0, 1, 0, 3), which had val score of 0.0797
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 0), which had val score of 0.0075
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0, 0), which had val score of -0.0084
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 0, 0), which had val score of -0.0093
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 0, 2, 0), which had val score of 0.0072
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 0, 3), which had val score of -0.3273
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 0, 0), which had val score of -0.0086
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 0, 0), which had val score of 0.0213
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 1, 0, 3), which had val score of -0.1846
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 0, 3), which had val score of -0.3273
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 3), which had val score of -0.039
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0, 3), which had val score of -0.4524
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 2, 0), which had val score of -0.0085
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 0, 0), which had val score of -0.0034
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 0, 0), which had val score of -0.0044
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 2, 0), which had val score of -0.0067
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 1, 2, 3), which had val score of -0.588
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 2, 0), which had val score of -0.0084
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 1, 0, 0), which had val score of -0.0036
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 2, 3), which had val score of -0.0377
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 1, 2, 0), which had val score of 0.0089
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 0, 2, 3), which had val score of -0.2177
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 1, 2, 3), which had val score of -0.7322
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 1, 0, 3), which had val score of -0.1777
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 2, 0), which had val score of -0.0085
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 1, 0, 3), which had val score of -0.3223
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 2, 0), which had val score of 0.01
#         Current best combo: (3, 3, 0, 0, 1, 0, 3) with val score 0.0797.
#         Has trained 605 of 9600 combinations so far
# As new Best Combo (0, 3, 0, 0, 1, 2, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 3, 0, 0, 1, 2, 3), which had val score of 0.1429
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 2, 3), which had val score of -0.1114
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 2, 0), which had val score of -0.0033
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 1, 0, 3), which had val score of -0.0453
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 1, 0, 0), which had val score of -0.0084
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 2, 3), which had val score of -0.039
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 1, 0, 3), which had val score of -0.136
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 0, 3), which had val score of -0.2679
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 2, 0), which had val score of -0.0091
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 1, 2, 0), which had val score of -0.008
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 0, 0), which had val score of -0.0068
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 1, 0, 0), which had val score of -0.0032
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 0, 2, 0), which had val score of -0.0079
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 0, 0, 3), which had val score of -0.2106
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 0, 3), which had val score of 0.0797
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 2, 0), which had val score of -0.0058
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 1, 0, 3), which had val score of 0.0883
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 3), which had val score of 0.0098
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 1, 0, 3), which had val score of -0.448
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 0, 0), which had val score of 0.02
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 1, 2, 3), which had val score of 0.1429
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 0, 2, 3), which had val score of -0.0377
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 1, 0, 3), which had val score of -0.7052
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 1, 2, 0), which had val score of -0.0084
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 0, 0), which had val score of 0.019
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 1, 0, 0), which had val score of -0.0076
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 0, 0), which had val score of -0.0044
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 1, 2, 3), which had val score of 0.1084
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 2, 3), which had val score of -0.2477
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 2, 3), which had val score of -0.5001
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 2, 0), which had val score of 0.0072
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 1, 0, 0), which had val score of 0.0214
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 2, 3), which had val score of -0.034
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 0, 3), which had val score of -0.4524
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 2, 0), which had val score of 0.0086
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 1, 0, 3), which had val score of 0.0883
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 0, 2, 0), which had val score of -0.0051
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 0, 0), which had val score of 0.016
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 1, 0, 0), which had val score of 0.0176
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 0, 3), which had val score of -0.2541
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 1, 2, 3), which had val score of -0.3465
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 1, 2, 0), which had val score of -0.0035
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 2, 3), which had val score of -0.2347
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0, 0), which had val score of -0.0061
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 1, 2, 3), which had val score of 0.1084
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 1, 2, 0), which had val score of -0.0058
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 1, 2, 0), which had val score of -0.0063
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 0, 0, 3), which had val score of -0.3721
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 1, 2, 0), which had val score of -0.007
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 0, 3), which had val score of -0.2679
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 1, 2, 0), which had val score of 0.0081
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 1, 0, 0), which had val score of -0.008
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0, 3), which had val score of -0.5843
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 1, 0, 0), which had val score of -0.0085
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 0), which had val score of -0.0085
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 0, 0), which had val score of 0.0184
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 2, 3), which had val score of -0.0712
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 2, 3), which had val score of -0.1114
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 0, 0), which had val score of -0.0044
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 2, 3), which had val score of -0.2307
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 0, 0), which had val score of -0.0086
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 0, 3), which had val score of -0.0453
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 2, 3), which had val score of -0.6849
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 1, 0, 0), which had val score of -0.0052
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 1, 2, 3), which had val score of -0.138
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 0, 2, 3), which had val score of -0.5496
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 0, 0, 3), which had val score of 0.0523
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 1, 2, 0), which had val score of -0.0085
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 0, 0, 0), which had val score of -0.0062
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 0, 3), which had val score of 0.0523
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 2, 0), which had val score of -0.0086
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 2, 3), which had val score of -0.1056
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 2, 3), which had val score of 0.0183
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 0, 2, 0), which had val score of -0.0061
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 0, 0, 0), which had val score of -0.005
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 2, 0), which had val score of -0.0072
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 0, 0), which had val score of -0.0031
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 1, 2, 0), which had val score of -0.0077
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 2), which had val score of 0.0169
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (1, 2, 2, 2, 1, 1, 2), which had val score of 0.0288
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 1, 1, 2), which had val score of 0.015
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 1, 2, 2, 1, 1, 2), which had val score of -0.01
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 1, 1, 2), which had val score of 0.063
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 2, 1, 1, 2), which had val score of 0.107
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 3, 2, 1, 1, 2), which had val score of -0.0035
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 1, 1, 1, 2), which had val score of 0.0485
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 3, 1, 1, 2), which had val score of 0.0646
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 0, 1, 2), which had val score of -0.1021
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 0, 2), which had val score of 0.0653
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 2, 2), which had val score of 0.0522
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 1), which had val score of 0.0657
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 3), which had val score of -0.5211
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (0, 2, 2, 2, 1, 1, 2), which had val score of 0.0217
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 2), which had val score of 0.0169
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 1, 1, 2), which had val score of 0.0003
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 1, 2), which had val score of 0.0622
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 1, 2, 1, 1, 2), which had val score of 0.1059
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 3, 2, 1, 1, 2), which had val score of -0.0067
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 1, 1, 1, 2), which had val score of 0.0571
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 3, 1, 1, 2), which had val score of 0.0677
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 0, 1, 2), which had val score of -0.0902
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 0, 2), which had val score of 0.0653
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 2, 2), which had val score of 0.0577
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 1, 1), which had val score of 0.0394
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 1, 3), which had val score of -0.5211
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 2), which had val score of 0.0169
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 1, 2, 2, 1, 1, 2), which had val score of -0.0204
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 1, 2), which had val score of 0.063
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 1, 1, 2), which had val score of 0.1087
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 3, 2, 1, 1, 2), which had val score of -0.0052
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 1, 1, 1, 2), which had val score of 0.0477
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 1, 2), which had val score of 0.0643
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 0, 1, 2), which had val score of -0.1026
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 1, 0, 2), which had val score of 0.0652
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 1, 2, 2), which had val score of 0.0491
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 1, 1, 1), which had val score of 0.0862
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 1, 1, 3), which had val score of -0.5211
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 1, 1, 2), which had val score of 0.0622
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 1, 2), which had val score of 0.063
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 2), which had val score of 0.0169
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 1, 2, 1, 1, 2), which had val score of 0.0647
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 3, 2, 1, 1, 2), which had val score of 0.0346
#         Current best combo: (0, 3, 0, 0, 1, 2, 3) with val score 0.1429.
#         Has trained 605 of 9600 combinations so far
# As new Best Combo (2, 3, 2, 1, 1, 1, 2) was read in, best_clf is set to None
# Already Trained and Tested combination (2, 3, 2, 1, 1, 1, 2), which had val score of 0.19
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 2, 3, 1, 1, 2), which had val score of 0.0897
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 0, 1, 2), which had val score of 0.0599
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 1, 0, 2), which had val score of 0.0629
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 1, 2, 2), which had val score of 0.0728
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 1, 1, 1), which had val score of 0.0717
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 1, 1, 3), which had val score of 0.0759
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 1, 2, 1, 1, 2), which had val score of 0.1059
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 1, 1, 2), which had val score of 0.1087
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 1, 1, 2, 1, 1, 2), which had val score of -0.0052
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 1, 2, 1, 1, 2), which had val score of 0.0647
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 0, 2, 1, 1, 2), which had val score of -0.0221
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 2), which had val score of 0.0169
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 1, 1, 1, 2), which had val score of -0.0187
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 3, 1, 1, 2), which had val score of 0.0373
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 2, 0, 1, 2), which had val score of 0.0867
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 2, 1, 0, 2), which had val score of 0.1249
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 2, 1, 2, 2), which had val score of 0.1148
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 2, 1, 1, 1), which had val score of 0.0776
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 2, 1, 1, 3), which had val score of -0.5939
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 1, 1, 1, 2), which had val score of 0.0571
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 1, 1, 1, 2), which had val score of 0.0477
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 1, 2, 1, 1, 1, 2), which had val score of -0.069
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 2, 1, 1, 1, 2), which had val score of 0.19
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 1, 1, 1, 2), which had val score of -0.0187
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 3, 1, 1, 1, 2), which had val score of 0.0295
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 0, 1, 1, 2), which had val score of -0.0667
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 2), which had val score of 0.0169
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 1, 0, 1, 2), which had val score of 0.0536
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 1, 1, 0, 2), which had val score of 0.073
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 1, 1, 2, 2), which had val score of 0.0975
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 1, 1, 1, 1), which had val score of 0.0548
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 1, 1, 1, 3), which had val score of -0.4531
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 3, 1, 1, 2), which had val score of 0.0677
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 1, 2), which had val score of 0.0643
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 1, 2, 3, 1, 1, 2), which had val score of 0.0062
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 2, 3, 1, 1, 2), which had val score of 0.0897
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 1, 3, 1, 1, 2), which had val score of 0.0373
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 3, 3, 1, 1, 2), which had val score of 0.0409
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 2), which had val score of 0.0169
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 4, 1, 1, 2), which had val score of -0.029
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 3, 0, 1, 2), which had val score of 0.126
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 3, 1, 0, 2), which had val score of 0.0644
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 3, 1, 2, 2), which had val score of 0.0353
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 3, 1, 1, 1), which had val score of 0.0659
#         Current best combo: (2, 3, 2, 1, 1, 1, 2) with val score 0.19.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 3, 1, 1, 3), which had val score of -0.2959
# ...
#         Current best combo: (3, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 4, 4, 0, 2, 2), which had val score of 0.0894
#         Current best combo: (3, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 4, 4, 1, 2, 3), which had val score of 0.1084
#         Current best combo: (3, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 2, 4, 4, 1, 2, 3), which had val score of -0.2015
#         Current best combo: (3, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 605 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 3, 4, 1, 2, 3), which had val score of 0.0884
#         Current best combo: (3, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 605 of 9600 combinations so far
# Trained and Tested combination 606 of 9600: (0, 3, 4, 3, 1, 2, 3), taking 28.35 seconds to get val score of 0.1918
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (0, 3, 4, 4, 0, 2, 3), which had val score of -0.0377
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 606 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 1, 1, 3), which had val score of 0.0942
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 606 of 9600 combinations so far
# Trained and Tested combination 607 of 9600: (0, 3, 4, 4, 1, 2, 2), taking 21.05 seconds to get val score of 0.07
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (1, 3, 4, 4, 0, 2, 2), which had val score of 0.0894
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 607 of 9600 combinations so far
# Trained and Tested combination 608 of 9600: (0, 2, 4, 4, 0, 2, 2), taking 0.1 seconds to get val score of 0.0531
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 609 of 9600: (0, 3, 3, 4, 0, 2, 2), taking 9.1 seconds to get val score of 0.0489
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 610 of 9600: (0, 3, 4, 3, 0, 2, 2), taking 9.14 seconds to get val score of 0.0748
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (0, 3, 4, 4, 1, 2, 2), which had val score of 0.07
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 610 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 1, 2), which had val score of 0.1339
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 610 of 9600 combinations so far
# Trained and Tested combination 611 of 9600: (0, 3, 4, 4, 0, 2, 1), taking 11.77 seconds to get val score of 0.0225
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (0, 3, 4, 4, 0, 2, 3), which had val score of -0.0377
#         Current best combo: (0, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 611 of 9600 combinations so far
# Trained and Tested combination 612 of 9600: (1, 3, 4, 3, 1, 2, 3), taking 41.37 seconds to get val score of 0.1918
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 613 of 9600: (0, 2, 4, 3, 1, 2, 3), taking 0.1 seconds to get val score of -0.1937
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 614 of 9600: (0, 3, 3, 3, 1, 2, 3), taking 18.52 seconds to get val score of 0.0014
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 615 of 9600: (0, 3, 4, 2, 1, 2, 3), taking 15.3 seconds to get val score of 0.0672
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (0, 3, 4, 4, 1, 2, 3), which had val score of 0.1084
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 615 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 3, 0, 2, 3), which had val score of -0.3008
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 615 of 9600 combinations so far
# Trained and Tested combination 616 of 9600: (0, 3, 4, 3, 1, 1, 3), taking 19.93 seconds to get val score of 0.1525
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 617 of 9600: (0, 3, 4, 3, 1, 2, 2), taking 18.32 seconds to get val score of 0.0947
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (0, 3, 4, 3, 1, 2, 3), which had val score of 0.1918
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 617 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 4, 3, 1, 2, 3), which had val score of 0.1918
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 617 of 9600 combinations so far
# Trained and Tested combination 618 of 9600: (1, 2, 4, 3, 1, 2, 3), taking 0.27 seconds to get val score of -0.1937
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 619 of 9600: (1, 3, 3, 3, 1, 2, 3), taking 38.72 seconds to get val score of 0.0014
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 620 of 9600: (1, 3, 4, 2, 1, 2, 3), taking 25.53 seconds to get val score of 0.0672
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (1, 3, 4, 4, 1, 2, 3), which had val score of 0.1084
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 620 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 4, 3, 0, 2, 3), which had val score of -0.3008
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 620 of 9600 combinations so far
# Trained and Tested combination 621 of 9600: (1, 3, 4, 3, 1, 1, 3), taking 37.15 seconds to get val score of 0.1525
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 622 of 9600: (1, 3, 4, 3, 1, 2, 2), taking 40.82 seconds to get val score of 0.1185
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# % Combos Checked Thus Far: 622 out of 9600 which is 6.4791669999999995%
# Cruising Coordrdinate 0 of 128
#
# Cruising Coordrdinate 0 of 128
#
# Cruise suspended due to suspicious case
# Guidance: round 30
#
# 	round 30 iteration:  0
#
# Trained and Tested combination 623 of 9600: (2, 3, 4, 0, 1, 2, 3), taking 39.83 seconds to get val score of 0.0183
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 624 of 9600: (3, 2, 4, 0, 1, 2, 3), taking 0.76 seconds to get val score of -0.0921
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 625 of 9600: (3, 3, 3, 0, 1, 2, 3), taking 62.56 seconds to get val score of -0.153
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 626 of 9600: (3, 3, 4, 1, 1, 2, 3), taking 99.67 seconds to get val score of 0.0603
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 3), which had val score of -0.039
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 626 of 9600 combinations so far
# Trained and Tested combination 627 of 9600: (3, 3, 4, 0, 1, 1, 3), taking 65.26 seconds to get val score of -0.0546
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 628 of 9600: (3, 3, 4, 0, 1, 2, 2), taking 81.56 seconds to get val score of 0.0897
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# 	round 30 iteration:  1
#
# Already Trained and Tested combination (1, 3, 4, 0, 1, 2, 3), which had val score of 0.0183
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 628 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 2, 3), which had val score of 0.0183
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 628 of 9600 combinations so far
# Trained and Tested combination 629 of 9600: (2, 2, 4, 0, 1, 2, 3), taking 0.26 seconds to get val score of -0.0921
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 630 of 9600: (2, 3, 3, 0, 1, 2, 3), taking 27.84 seconds to get val score of -0.153
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 631 of 9600: (2, 3, 4, 1, 1, 2, 3), taking 55.87 seconds to get val score of 0.0603
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (2, 3, 4, 0, 0, 2, 3), which had val score of -0.039
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 631 of 9600 combinations so far
# Trained and Tested combination 632 of 9600: (2, 3, 4, 0, 1, 1, 3), taking 34.74 seconds to get val score of -0.0546
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 633 of 9600: (2, 3, 4, 0, 1, 2, 2), taking 42.58 seconds to get val score of 0.0893
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (2, 3, 4, 1, 1, 2, 3), which had val score of 0.0603
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 633 of 9600 combinations so far
# Trained and Tested combination 634 of 9600: (3, 2, 4, 1, 1, 2, 3), taking 0.84 seconds to get val score of -0.0566
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 635 of 9600: (3, 3, 3, 1, 1, 2, 3), taking 85.0 seconds to get val score of 0.1502
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (3, 3, 4, 0, 1, 2, 3), which had val score of 0.0183
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 635 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 2, 1, 2, 3), which had val score of 0.0672
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 635 of 9600 combinations so far
# Trained and Tested combination 636 of 9600: (3, 3, 4, 1, 0, 2, 3), taking 32.18 seconds to get val score of -0.1491
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 637 of 9600: (3, 3, 4, 1, 1, 1, 3), taking 100.85 seconds to get val score of -0.0394
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 638 of 9600: (3, 3, 4, 1, 1, 2, 2), taking 147.45 seconds to get val score of 0.0631
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (2, 3, 4, 0, 1, 2, 2), which had val score of 0.0893
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 638 of 9600 combinations so far
# Trained and Tested combination 639 of 9600: (3, 2, 4, 0, 1, 2, 2), taking 0.75 seconds to get val score of 0.0947
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Trained and Tested combination 640 of 9600: (3, 3, 3, 0, 1, 2, 2), taking 105.0 seconds to get val score of 0.0259
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (3, 3, 4, 1, 1, 2, 2), which had val score of 0.0631
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 640 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 2), which had val score of 0.0685
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 640 of 9600 combinations so far
# Trained and Tested combination 641 of 9600: (3, 3, 4, 0, 1, 1, 2), taking 80.3 seconds to get val score of 0.0646
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918
# Already Trained and Tested combination (3, 3, 4, 0, 1, 2, 1), which had val score of 0.0794
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 2, 3), which had val score of 0.0183
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# % Combos Checked Thus Far: 641 out of 9600 which is 6.6770830000000005%
# Cruising Coordrdinate 0 of 128
#
# Cruise suspended due to suspicious case
# Guidance: round 31
#
# 	round 31 iteration:  0
#
# % Combos Checked Thus Far: 641 out of 9600 which is 6.6770830000000005%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (0, 3, 4, 3, 1, 2, 3), which had val score of 0.1918
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# Already Trained and Tested combination (2, 3, 4, 3, 1, 2, 3), which had val score of 0.1918
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# Already Trained and Tested combination (1, 2, 4, 3, 1, 2, 3), which had val score of -0.1937
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 3, 3, 1, 2, 3), which had val score of 0.0014
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 4, 2, 1, 2, 3), which had val score of 0.0672
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 4, 4, 1, 2, 3), which had val score of 0.1084
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 4, 3, 0, 2, 3), which had val score of -0.3008
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 4, 3, 1, 1, 3), which had val score of 0.1525
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# Already Trained and Tested combination (1, 3, 4, 3, 1, 2, 2), which had val score of 0.1185
#         Current best combo: (1, 3, 4, 3, 1, 2, 3) with val score 0.1918.
#         Has trained 641 of 9600 combinations so far
# % Combos Checked Thus Far: 641 out of 9600 which is 6.6770830000000005%
# Max Score:
#  0.19175424530173346
# Max Test Score:
#  -0.178121
# Max Combo Index:
#  (1, 3, 4, 3, 1, 2, 3) out of [4, 4, 5, 5, 2, 3, 4] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 16, 'subsample': 1, 'colsample_bylevel': 0.85, 'max_bin': 256, 'reg_lambda': 1, 'learning_rate': 1}
# % Combos Checked: 641 out of 9600 which is 6.6770830000000005%
