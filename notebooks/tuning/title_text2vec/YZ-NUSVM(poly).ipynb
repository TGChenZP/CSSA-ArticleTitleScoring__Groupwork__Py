# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nusvc(poly)'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd
# Out:
# /Users/devin/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import NuSVR as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto'),
    'nu': (0.1, 0.3, 0.5, 0.7, 0.9)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.NuSVR'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 19440: (5, 0, 0, 5, 0, 0), taking 0.01 seconds to get val score of -0.16
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score -0.16
# Trained and Tested combination 2 of 19440: (5, 0, 0, 0, 1, 4), taking 0.0 seconds to get val score of -1.1958
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score -0.16
# Trained and Tested combination 3 of 19440: (0, 8, 0, 5, 0, 0), taking 0.0 seconds to get val score of -0.0486
#         Current best combo: (0, 8, 0, 5, 0, 0) with val score -0.0486
# Trained and Tested combination 4 of 19440: (0, 0, 0, 0, 1, 0), taking 0.0 seconds to get val score of -0.0089
#         Current best combo: (0, 0, 0, 0, 1, 0) with val score -0.0089
# Trained and Tested combination 5 of 19440: (0, 8, 5, 5, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 0, 0, 0, 1, 0) with val score -0.0089
# Trained and Tested combination 6 of 19440: (0, 0, 0, 5, 0, 0), taking 0.0 seconds to get val score of -0.0086
#         Current best combo: (0, 0, 0, 5, 0, 0) with val score -0.0086
# Trained and Tested combination 7 of 19440: (5, 0, 0, 5, 0, 4), taking 0.01 seconds to get val score of 0.0796
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 8 of 19440: (0, 4, 0, 5, 0, 0), taking 0.0 seconds to get val score of -0.0092
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 9 of 19440: (0, 0, 5, 0, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 10 of 19440: (5, 4, 5, 0, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 11 of 19440: (0, 8, 5, 5, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 12 of 19440: (0, 4, 5, 0, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 13 of 19440: (0, 4, 0, 0, 0, 0), taking 0.0 seconds to get val score of -0.2447
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 14 of 19440: (0, 4, 5, 0, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 15 of 19440: (5, 4, 0, 0, 0, 4), taking 0.0 seconds to get val score of -0.4079
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 16 of 19440: (5, 0, 0, 0, 0, 0), taking 0.0 seconds to get val score of -2.3394
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 17 of 19440: (0, 4, 5, 0, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 18 of 19440: (0, 8, 0, 5, 1, 4), taking 0.0 seconds to get val score of -0.0357
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 19 of 19440: (5, 0, 5, 0, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 20 of 19440: (5, 4, 5, 5, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 21 of 19440: (5, 4, 0, 5, 0, 0), taking 0.0 seconds to get val score of -0.0144
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 22 of 19440: (0, 4, 0, 0, 1, 4), taking 0.0 seconds to get val score of -0.2624
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 23 of 19440: (5, 8, 5, 0, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 24 of 19440: (0, 8, 0, 0, 1, 4), taking 0.0 seconds to get val score of -0.1579
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 25 of 19440: (5, 8, 5, 0, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 26 of 19440: (5, 8, 0, 0, 0, 4), taking 0.0 seconds to get val score of -1.0512
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 27 of 19440: (0, 4, 5, 5, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 28 of 19440: (0, 8, 5, 0, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 29 of 19440: (5, 0, 0, 5, 1, 4), taking 0.01 seconds to get val score of -0.1047
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 30 of 19440: (0, 4, 0, 5, 1, 0), taking 0.0 seconds to get val score of -0.0132
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 31 of 19440: (5, 4, 0, 5, 1, 0), taking 0.0 seconds to get val score of 0.0503
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 32 of 19440: (5, 4, 0, 5, 1, 4), taking 0.01 seconds to get val score of 0.0004
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 33 of 19440: (0, 8, 0, 0, 0, 4), taking 0.0 seconds to get val score of -0.3108
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 34 of 19440: (0, 4, 0, 0, 1, 0), taking 0.0 seconds to get val score of -0.0132
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 35 of 19440: (0, 4, 0, 0, 0, 4), taking 0.0 seconds to get val score of -0.6106
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.0796
# Trained and Tested combination 36 of 19440: (0, 4, 0, 5, 0, 4), taking 0.0 seconds to get val score of 0.0879
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 37 of 19440: (5, 4, 5, 5, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 38 of 19440: (5, 0, 5, 5, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 39 of 19440: (5, 4, 5, 5, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 40 of 19440: (0, 0, 0, 5, 1, 0), taking 0.0 seconds to get val score of -0.0089
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 41 of 19440: (5, 8, 5, 0, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 42 of 19440: (5, 4, 0, 5, 0, 4), taking 0.01 seconds to get val score of -0.0248
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 43 of 19440: (0, 8, 0, 0, 1, 0), taking 0.0 seconds to get val score of -0.0005
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 44 of 19440: (5, 8, 5, 5, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 45 of 19440: (0, 0, 5, 0, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 46 of 19440: (0, 8, 0, 5, 1, 0), taking 0.0 seconds to get val score of -0.0132
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 47 of 19440: (0, 8, 5, 0, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 48 of 19440: (5, 8, 5, 5, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 49 of 19440: (0, 4, 0, 5, 1, 4), taking 0.0 seconds to get val score of -0.0065
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 50 of 19440: (5, 8, 0, 0, 1, 4), taking 0.0 seconds to get val score of -0.3624
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 51 of 19440: (5, 8, 0, 5, 0, 0), taking 0.0 seconds to get val score of 0.0062
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 52 of 19440: (5, 4, 5, 0, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 53 of 19440: (0, 8, 5, 5, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 54 of 19440: (0, 0, 5, 5, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 55 of 19440: (5, 4, 0, 0, 1, 0), taking 0.0 seconds to get val score of -0.2549
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 56 of 19440: (5, 0, 0, 0, 1, 0), taking 0.0 seconds to get val score of -0.3949
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 57 of 19440: (0, 8, 0, 0, 0, 0), taking 0.0 seconds to get val score of -0.5321
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 58 of 19440: (0, 0, 5, 0, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 59 of 19440: (0, 0, 0, 0, 0, 4), taking 0.0 seconds to get val score of -0.7035
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 60 of 19440: (5, 0, 5, 0, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 61 of 19440: (5, 8, 0, 5, 1, 4), taking 0.01 seconds to get val score of 0.0664
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 62 of 19440: (0, 4, 5, 5, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 63 of 19440: (0, 8, 0, 5, 0, 4), taking 0.01 seconds to get val score of 0.0825
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 64 of 19440: (5, 4, 5, 0, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 65 of 19440: (0, 0, 5, 5, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 66 of 19440: (5, 4, 5, 5, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 67 of 19440: (0, 8, 5, 0, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 68 of 19440: (5, 0, 5, 5, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 69 of 19440: (5, 0, 5, 5, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 70 of 19440: (5, 0, 0, 5, 1, 0), taking 0.0 seconds to get val score of -0.1383
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 71 of 19440: (5, 0, 0, 0, 0, 4), taking 0.0 seconds to get val score of -1.1058
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 72 of 19440: (5, 8, 5, 5, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 73 of 19440: (0, 4, 5, 5, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 74 of 19440: (0, 0, 0, 5, 0, 4), taking 0.0 seconds to get val score of -0.0053
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 75 of 19440: (0, 0, 5, 5, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 76 of 19440: (0, 0, 0, 0, 0, 0), taking 0.0 seconds to get val score of -0.0086
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 77 of 19440: (5, 8, 0, 5, 0, 4), taking 0.01 seconds to get val score of -0.0636
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 78 of 19440: (5, 8, 5, 5, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 79 of 19440: (5, 0, 5, 0, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 80 of 19440: (5, 4, 0, 0, 1, 4), taking 0.0 seconds to get val score of -0.2842
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 81 of 19440: (0, 4, 5, 0, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 82 of 19440: (5, 8, 0, 5, 1, 0), taking 0.0 seconds to get val score of -0.0343
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 83 of 19440: (0, 0, 0, 5, 1, 4), taking 0.0 seconds to get val score of -0.0079
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 84 of 19440: (5, 0, 5, 5, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 85 of 19440: (0, 4, 5, 5, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 86 of 19440: (5, 8, 5, 0, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 87 of 19440: (0, 0, 5, 5, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 88 of 19440: (5, 8, 0, 0, 0, 0), taking 0.0 seconds to get val score of -1.7294
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 89 of 19440: (5, 0, 5, 0, 0, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 90 of 19440: (0, 0, 5, 0, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 91 of 19440: (0, 0, 0, 0, 1, 4), taking 0.0 seconds to get val score of -0.7044
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 92 of 19440: (5, 8, 0, 0, 1, 0), taking 0.0 seconds to get val score of -0.6084
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 93 of 19440: (5, 4, 5, 0, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 94 of 19440: (0, 8, 5, 0, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 95 of 19440: (3, 4, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.0329
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 96 of 19440: (0, 8, 5, 5, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 97 of 19440: (5, 4, 0, 0, 0, 0), taking 0.0 seconds to get val score of -0.2105
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 98 of 19440: (2, 4, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.011
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 99 of 19440: (4, 4, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.0805
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 100 of 19440: (3, 3, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.0372
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 101 of 19440: (3, 5, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.0276
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 102 of 19440: (3, 4, 2, 3, 1, 2), taking 0.0 seconds to get val score of 0.0329
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 103 of 19440: (3, 4, 4, 3, 1, 2), taking 0.0 seconds to get val score of -0.6903
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 104 of 19440: (3, 4, 3, 2, 1, 2), taking 0.0 seconds to get val score of 0.0314
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 105 of 19440: (3, 4, 3, 4, 1, 2), taking 0.0 seconds to get val score of -0.0123
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 106 of 19440: (3, 4, 3, 3, 0, 2), taking 0.0 seconds to get val score of -0.0184
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 107 of 19440: (3, 4, 3, 3, 1, 1), taking 0.0 seconds to get val score of 0.012
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 108 of 19440: (3, 4, 3, 3, 1, 3), taking 0.0 seconds to get val score of 0.0791
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879.
#         Has trained 108 of 19440 combinations so far
# Trained and Tested combination 109 of 19440: (5, 4, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.0121
#         Current best combo: (0, 4, 0, 5, 0, 4) with val score 0.0879
# Trained and Tested combination 110 of 19440: (4, 3, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.091
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 111 of 19440: (4, 5, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.0877
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 112 of 19440: (4, 4, 2, 3, 1, 2), taking 0.0 seconds to get val score of 0.0805
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 113 of 19440: (4, 4, 4, 3, 1, 2), taking 0.0 seconds to get val score of -0.6903
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 114 of 19440: (4, 4, 3, 2, 1, 2), taking 0.0 seconds to get val score of 0.0498
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 115 of 19440: (4, 4, 3, 4, 1, 2), taking 0.0 seconds to get val score of 0.0818
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 116 of 19440: (4, 4, 3, 3, 0, 2), taking 0.0 seconds to get val score of -0.0349
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 117 of 19440: (4, 4, 3, 3, 1, 1), taking 0.0 seconds to get val score of 0.082
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 118 of 19440: (4, 4, 3, 3, 1, 3), taking 0.0 seconds to get val score of 0.071
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 119 of 19440: (2, 3, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.0085
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Already Trained and Tested combination (4, 3, 3, 3, 1, 2), which had val score of 0.091
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 119 of 19440 combinations so far
# Trained and Tested combination 120 of 19440: (3, 2, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.0863
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091.
#         Has trained 120 of 19440 combinations so far
# Trained and Tested combination 121 of 19440: (3, 3, 2, 3, 1, 2), taking 0.0 seconds to get val score of 0.0372
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 122 of 19440: (3, 3, 4, 3, 1, 2), taking 0.0 seconds to get val score of -0.6903
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 123 of 19440: (3, 3, 3, 2, 1, 2), taking 0.0 seconds to get val score of 0.0291
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 124 of 19440: (3, 3, 3, 4, 1, 2), taking 0.0 seconds to get val score of 0.0676
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 125 of 19440: (3, 3, 3, 3, 0, 2), taking 0.0 seconds to get val score of -0.0075
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 126 of 19440: (3, 3, 3, 3, 1, 1), taking 0.0 seconds to get val score of 0.022
#         Current best combo: (4, 3, 3, 3, 1, 2) with val score 0.091
# Trained and Tested combination 127 of 19440: (3, 3, 3, 3, 1, 3), taking 0.0 seconds to get val score of 0.1063
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 128 of 19440: (2, 4, 2, 3, 1, 2), taking 0.0 seconds to get val score of 0.011
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Already Trained and Tested combination (4, 4, 2, 3, 1, 2), which had val score of 0.0805
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 128 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 2), which had val score of 0.0372
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 128 of 19440 combinations so far
# Trained and Tested combination 129 of 19440: (3, 5, 2, 3, 1, 2), taking 0.0 seconds to get val score of 0.0276
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 130 of 19440: (3, 4, 1, 3, 1, 2), taking 0.0 seconds to get val score of 0.0329
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 130 of 19440 combinations so far
# Trained and Tested combination 131 of 19440: (3, 4, 2, 2, 1, 2), taking 0.0 seconds to get val score of 0.0314
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 132 of 19440: (3, 4, 2, 4, 1, 2), taking 0.0 seconds to get val score of -0.0123
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 133 of 19440: (3, 4, 2, 3, 0, 2), taking 0.0 seconds to get val score of -0.0184
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 134 of 19440: (3, 4, 2, 3, 1, 1), taking 0.0 seconds to get val score of 0.012
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 135 of 19440: (3, 4, 2, 3, 1, 3), taking 0.0 seconds to get val score of 0.0791
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 136 of 19440: (2, 4, 3, 2, 1, 2), taking 0.0 seconds to get val score of 0.0165
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Already Trained and Tested combination (4, 4, 3, 2, 1, 2), which had val score of 0.0498
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 136 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1, 2), which had val score of 0.0291
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 136 of 19440 combinations so far
# Trained and Tested combination 137 of 19440: (3, 5, 3, 2, 1, 2), taking 0.0 seconds to get val score of 0.0268
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Already Trained and Tested combination (3, 4, 2, 2, 1, 2), which had val score of 0.0314
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 137 of 19440 combinations so far
# Trained and Tested combination 138 of 19440: (3, 4, 4, 2, 1, 2), taking 0.0 seconds to get val score of -0.6903
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 139 of 19440: (3, 4, 3, 1, 1, 2), taking 0.0 seconds to get val score of -0.0558
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 139 of 19440 combinations so far
# Trained and Tested combination 140 of 19440: (3, 4, 3, 2, 0, 2), taking 0.0 seconds to get val score of 0.0461
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 141 of 19440: (3, 4, 3, 2, 1, 1), taking 0.0 seconds to get val score of -0.0079
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 142 of 19440: (3, 4, 3, 2, 1, 3), taking 0.0 seconds to get val score of 0.0785
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 143 of 19440: (2, 4, 3, 3, 1, 3), taking 0.0 seconds to get val score of -0.0288
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Already Trained and Tested combination (4, 4, 3, 3, 1, 3), which had val score of 0.071
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 143 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 3), which had val score of 0.1063
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 143 of 19440 combinations so far
# Trained and Tested combination 144 of 19440: (3, 5, 3, 3, 1, 3), taking 0.0 seconds to get val score of 0.0749
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Already Trained and Tested combination (3, 4, 2, 3, 1, 3), which had val score of 0.0791
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 144 of 19440 combinations so far
# Trained and Tested combination 145 of 19440: (3, 4, 4, 3, 1, 3), taking 0.0 seconds to get val score of -0.8097
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Already Trained and Tested combination (3, 4, 3, 2, 1, 3), which had val score of 0.0785
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 145 of 19440 combinations so far
# Trained and Tested combination 146 of 19440: (3, 4, 3, 4, 1, 3), taking 0.0 seconds to get val score of 0.0802
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Trained and Tested combination 147 of 19440: (3, 4, 3, 3, 0, 3), taking 0.0 seconds to get val score of -0.0148
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0329
#         Current best combo: (3, 3, 3, 3, 1, 3) with val score 0.1063.
#         Has trained 147 of 19440 combinations so far
# Trained and Tested combination 148 of 19440: (3, 4, 3, 3, 1, 4), taking 0.0 seconds to get val score of 0.1088
#         Current best combo: (3, 4, 3, 3, 1, 4) with val score 0.1088
# Trained and Tested combination 149 of 19440: (2, 4, 3, 3, 1, 4), taking 0.0 seconds to get val score of 0.0222
#         Current best combo: (3, 4, 3, 3, 1, 4) with val score 0.1088
# Trained and Tested combination 150 of 19440: (4, 4, 3, 3, 1, 4), taking 0.0 seconds to get val score of 0.0677
#         Current best combo: (3, 4, 3, 3, 1, 4) with val score 0.1088
# Trained and Tested combination 151 of 19440: (3, 3, 3, 3, 1, 4), taking 0.0 seconds to get val score of 0.1211
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Trained and Tested combination 152 of 19440: (3, 5, 3, 3, 1, 4), taking 0.0 seconds to get val score of 0.1092
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Trained and Tested combination 153 of 19440: (3, 4, 2, 3, 1, 4), taking 0.0 seconds to get val score of 0.1174
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Trained and Tested combination 154 of 19440: (3, 4, 4, 3, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Trained and Tested combination 155 of 19440: (3, 4, 3, 2, 1, 4), taking 0.0 seconds to get val score of 0.1012
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Trained and Tested combination 156 of 19440: (3, 4, 3, 4, 1, 4), taking 0.0 seconds to get val score of 0.1088
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Trained and Tested combination 157 of 19440: (3, 4, 3, 3, 0, 4), taking 0.0 seconds to get val score of -0.028
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Already Trained and Tested combination (3, 4, 3, 3, 1, 3), which had val score of 0.0791
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 157 of 19440 combinations so far
# Trained and Tested combination 158 of 19440: (2, 3, 3, 3, 1, 4), taking 0.0 seconds to get val score of 0.0406
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Trained and Tested combination 159 of 19440: (4, 3, 3, 3, 1, 4), taking 0.0 seconds to get val score of 0.0848
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Trained and Tested combination 160 of 19440: (3, 2, 3, 3, 1, 4), taking 0.0 seconds to get val score of 0.0949
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211
# Already Trained and Tested combination (3, 4, 3, 3, 1, 4), which had val score of 0.1088
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1211.
#         Has trained 160 of 19440 combinations so far
# Trained and Tested combination 161 of 19440: (3, 3, 2, 3, 1, 4), taking 0.0 seconds to get val score of 0.1254
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Trained and Tested combination 162 of 19440: (3, 3, 4, 3, 1, 4), taking 0.0 seconds to get val score of -1.2797
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Trained and Tested combination 163 of 19440: (3, 3, 3, 2, 1, 4), taking 0.0 seconds to get val score of 0.1115
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Trained and Tested combination 164 of 19440: (3, 3, 3, 4, 1, 4), taking 0.0 seconds to get val score of 0.1211
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Trained and Tested combination 165 of 19440: (3, 3, 3, 3, 0, 4), taking 0.0 seconds to get val score of -0.021
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Already Trained and Tested combination (3, 3, 3, 3, 1, 3), which had val score of 0.1063
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 165 of 19440 combinations so far
# Trained and Tested combination 166 of 19440: (2, 3, 2, 3, 1, 4), taking 0.0 seconds to get val score of 0.0432
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Trained and Tested combination 167 of 19440: (4, 3, 2, 3, 1, 4), taking 0.0 seconds to get val score of 0.0869
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Trained and Tested combination 168 of 19440: (3, 2, 2, 3, 1, 4), taking 0.0 seconds to get val score of 0.1057
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Already Trained and Tested combination (3, 4, 2, 3, 1, 4), which had val score of 0.1174
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 168 of 19440 combinations so far
# Trained and Tested combination 169 of 19440: (3, 3, 1, 3, 1, 4), taking 0.0 seconds to get val score of 0.1254
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Already Trained and Tested combination (3, 3, 3, 3, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254.
#         Has trained 169 of 19440 combinations so far
# Trained and Tested combination 170 of 19440: (3, 3, 2, 2, 1, 4), taking 0.0 seconds to get val score of 0.1115
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1254
# Trained and Tested combination 171 of 19440: (3, 3, 2, 4, 1, 4), taking 0.0 seconds to get val score of 0.1258
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258
# Trained and Tested combination 172 of 19440: (3, 3, 2, 3, 0, 4), taking 0.0 seconds to get val score of -0.021
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258
# Trained and Tested combination 173 of 19440: (3, 3, 2, 3, 1, 3), taking 0.0 seconds to get val score of 0.1063
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258
# Trained and Tested combination 174 of 19440: (2, 3, 2, 4, 1, 4), taking 0.0 seconds to get val score of 0.0403
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258
# Trained and Tested combination 175 of 19440: (4, 3, 2, 4, 1, 4), taking 0.0 seconds to get val score of 0.0864
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258
# Trained and Tested combination 176 of 19440: (3, 2, 2, 4, 1, 4), taking 0.0 seconds to get val score of 0.1055
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258
# Trained and Tested combination 177 of 19440: (3, 4, 2, 4, 1, 4), taking 0.0 seconds to get val score of 0.1174
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258
# Trained and Tested combination 178 of 19440: (3, 3, 1, 4, 1, 4), taking 0.0 seconds to get val score of 0.1258
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258
# Already Trained and Tested combination (3, 3, 3, 4, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 178 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 4), which had val score of 0.1254
#         Current best combo: (3, 3, 2, 4, 1, 4) with val score 0.1258.
#         Has trained 178 of 19440 combinations so far
# Trained and Tested combination 179 of 19440: (3, 3, 2, 5, 1, 4), taking 0.0 seconds to get val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 180 of 19440: (3, 3, 2, 4, 0, 4), taking 0.0 seconds to get val score of -0.0041
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 181 of 19440: (3, 3, 2, 4, 1, 3), taking 0.0 seconds to get val score of 0.1109
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 182 of 19440: (2, 3, 2, 5, 1, 4), taking 0.0 seconds to get val score of 0.0403
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 183 of 19440: (4, 3, 2, 5, 1, 4), taking 0.0 seconds to get val score of 0.0866
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 184 of 19440: (3, 2, 2, 5, 1, 4), taking 0.0 seconds to get val score of 0.1104
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 185 of 19440: (3, 4, 2, 5, 1, 4), taking 0.0 seconds to get val score of 0.1175
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 186 of 19440: (3, 3, 1, 5, 1, 4), taking 0.0 seconds to get val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 187 of 19440: (3, 3, 3, 5, 1, 4), taking 0.0 seconds to get val score of 0.1211
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (3, 3, 2, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 187 of 19440 combinations so far
# Trained and Tested combination 188 of 19440: (3, 3, 2, 5, 0, 4), taking 0.01 seconds to get val score of -0.0005
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 189 of 19440: (3, 3, 2, 5, 1, 3), taking 0.0 seconds to get val score of 0.1142
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# % Combos Checked Thus Far: 189 out of 19440 which is 0.972222%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 190 of 19440: (1, 8, 0, 5, 0, 4), taking 0.01 seconds to get val score of -0.0017
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 191 of 19440: (0, 7, 0, 5, 0, 4), taking 0.01 seconds to get val score of 0.0896
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 192 of 19440: (0, 8, 1, 5, 0, 4), taking 0.01 seconds to get val score of 0.0825
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 193 of 19440: (0, 8, 0, 4, 0, 4), taking 0.0 seconds to get val score of 0.0809
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 8, 0, 5, 1, 4), which had val score of -0.0357
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 193 of 19440 combinations so far
# Trained and Tested combination 194 of 19440: (0, 8, 0, 5, 0, 3), taking 0.01 seconds to get val score of 0.0807
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# 	round 1 iteration:  1
#
# Trained and Tested combination 195 of 19440: (1, 7, 0, 5, 0, 4), taking 0.01 seconds to get val score of 0.0328
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 196 of 19440: (0, 6, 0, 5, 0, 4), taking 0.0 seconds to get val score of 0.0853
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 8, 0, 5, 0, 4), which had val score of 0.0825
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 196 of 19440 combinations so far
# Trained and Tested combination 197 of 19440: (0, 7, 1, 5, 0, 4), taking 0.01 seconds to get val score of 0.0896
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 198 of 19440: (0, 7, 0, 4, 0, 4), taking 0.0 seconds to get val score of 0.0854
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 199 of 19440: (0, 7, 0, 5, 1, 4), taking 0.0 seconds to get val score of -0.0026
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 200 of 19440: (0, 7, 0, 5, 0, 3), taking 0.0 seconds to get val score of 0.0866
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 201 of 19440: (1, 8, 1, 5, 0, 4), taking 0.01 seconds to get val score of -0.0017
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 7, 1, 5, 0, 4), which had val score of 0.0896
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 201 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 0, 4), which had val score of 0.0825
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 201 of 19440 combinations so far
# Trained and Tested combination 202 of 19440: (0, 8, 2, 5, 0, 4), taking 0.01 seconds to get val score of 0.0824
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 203 of 19440: (0, 8, 1, 4, 0, 4), taking 0.0 seconds to get val score of 0.0809
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 204 of 19440: (0, 8, 1, 5, 1, 4), taking 0.0 seconds to get val score of -0.0357
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 205 of 19440: (0, 8, 1, 5, 0, 3), taking 0.01 seconds to get val score of 0.0807
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 206 of 19440: (1, 8, 0, 4, 0, 4), taking 0.0 seconds to get val score of -0.0825
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 7, 0, 4, 0, 4), which had val score of 0.0854
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 206 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 1, 4, 0, 4), which had val score of 0.0809
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 206 of 19440 combinations so far
# Trained and Tested combination 207 of 19440: (0, 8, 0, 3, 0, 4), taking 0.0 seconds to get val score of 0.0548
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 8, 0, 5, 0, 4), which had val score of 0.0825
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 207 of 19440 combinations so far
# Trained and Tested combination 208 of 19440: (0, 8, 0, 4, 1, 4), taking 0.0 seconds to get val score of -0.0356
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 209 of 19440: (0, 8, 0, 4, 0, 3), taking 0.0 seconds to get val score of 0.0752
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 210 of 19440: (1, 8, 0, 5, 0, 3), taking 0.01 seconds to get val score of -0.007
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 7, 0, 5, 0, 3), which had val score of 0.0866
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 210 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 1, 5, 0, 3), which had val score of 0.0807
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 210 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 4, 0, 3), which had val score of 0.0752
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 210 of 19440 combinations so far
# Trained and Tested combination 211 of 19440: (0, 8, 0, 5, 1, 3), taking 0.0 seconds to get val score of -0.0269
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 212 of 19440: (0, 8, 0, 5, 0, 2), taking 0.0 seconds to get val score of 0.089
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 8, 0, 5, 0, 4), which had val score of 0.0825
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 212 of 19440 combinations so far
# % Combos Checked Thus Far: 212 out of 19440 which is 1.090535%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 213 of 19440: (4, 0, 0, 5, 0, 4), taking 0.0 seconds to get val score of -0.0983
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 214 of 19440: (5, 1, 0, 5, 0, 4), taking 0.01 seconds to get val score of -0.2328
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 215 of 19440: (5, 0, 1, 5, 0, 4), taking 0.01 seconds to get val score of 0.0796
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 216 of 19440: (5, 0, 0, 4, 0, 4), taking 0.0 seconds to get val score of -0.0956
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (5, 0, 0, 5, 1, 4), which had val score of -0.1047
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 216 of 19440 combinations so far
# Trained and Tested combination 217 of 19440: (5, 0, 0, 5, 0, 3), taking 0.01 seconds to get val score of -0.1686
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# 	round 2 iteration:  1
#
# Trained and Tested combination 218 of 19440: (4, 0, 1, 5, 0, 4), taking 0.0 seconds to get val score of -0.0983
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 219 of 19440: (5, 1, 1, 5, 0, 4), taking 0.01 seconds to get val score of -0.2328
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (5, 0, 0, 5, 0, 4), which had val score of 0.0796
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 219 of 19440 combinations so far
# Trained and Tested combination 220 of 19440: (5, 0, 2, 5, 0, 4), taking 0.01 seconds to get val score of 0.0796
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 221 of 19440: (5, 0, 1, 4, 0, 4), taking 0.0 seconds to get val score of -0.0956
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 222 of 19440: (5, 0, 1, 5, 1, 4), taking 0.01 seconds to get val score of -0.1047
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 223 of 19440: (5, 0, 1, 5, 0, 3), taking 0.01 seconds to get val score of -0.1686
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# % Combos Checked Thus Far: 223 out of 19440 which is 1.147119%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 224 of 19440: (1, 4, 0, 5, 0, 4), taking 0.0 seconds to get val score of 0.0806
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 225 of 19440: (0, 3, 0, 5, 0, 4), taking 0.0 seconds to get val score of 0.0505
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 226 of 19440: (0, 5, 0, 5, 0, 4), taking 0.0 seconds to get val score of 0.1118
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 227 of 19440: (0, 4, 1, 5, 0, 4), taking 0.0 seconds to get val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 228 of 19440: (0, 4, 0, 4, 0, 4), taking 0.0 seconds to get val score of 0.0869
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 4, 0, 5, 1, 4), which had val score of -0.0065
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 228 of 19440 combinations so far
# Trained and Tested combination 229 of 19440: (0, 4, 0, 5, 0, 3), taking 0.0 seconds to get val score of 0.0733
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# 	round 3 iteration:  1
#
# Trained and Tested combination 230 of 19440: (1, 5, 0, 5, 0, 4), taking 0.01 seconds to get val score of 0.0767
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 230 of 19440 combinations so far
# Already Trained and Tested combination (0, 6, 0, 5, 0, 4), which had val score of 0.0853
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 230 of 19440 combinations so far
# Trained and Tested combination 231 of 19440: (0, 5, 1, 5, 0, 4), taking 0.0 seconds to get val score of 0.1117
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 232 of 19440: (0, 5, 0, 4, 0, 4), taking 0.0 seconds to get val score of 0.1117
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 233 of 19440: (0, 5, 0, 5, 1, 4), taking 0.0 seconds to get val score of -0.0063
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 234 of 19440: (0, 5, 0, 5, 0, 3), taking 0.0 seconds to get val score of 0.1006
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 235 of 19440: (1, 4, 1, 5, 0, 4), taking 0.0 seconds to get val score of 0.0806
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 236 of 19440: (0, 3, 1, 5, 0, 4), taking 0.0 seconds to get val score of 0.0505
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 5, 1, 5, 0, 4), which had val score of 0.1117
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 236 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 236 of 19440 combinations so far
# Trained and Tested combination 237 of 19440: (0, 4, 2, 5, 0, 4), taking 0.0 seconds to get val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 238 of 19440: (0, 4, 1, 4, 0, 4), taking 0.0 seconds to get val score of 0.0869
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 239 of 19440: (0, 4, 1, 5, 1, 4), taking 0.0 seconds to get val score of -0.0065
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 240 of 19440: (0, 4, 1, 5, 0, 3), taking 0.0 seconds to get val score of 0.0733
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 241 of 19440: (1, 4, 0, 4, 0, 4), taking 0.0 seconds to get val score of 0.0804
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 242 of 19440: (0, 3, 0, 4, 0, 4), taking 0.0 seconds to get val score of 0.0523
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 5, 0, 4, 0, 4), which had val score of 0.1117
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 242 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 4, 0, 4), which had val score of 0.0869
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 242 of 19440 combinations so far
# Trained and Tested combination 243 of 19440: (0, 4, 0, 3, 0, 4), taking 0.0 seconds to get val score of 0.0868
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0879
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 243 of 19440 combinations so far
# Trained and Tested combination 244 of 19440: (0, 4, 0, 4, 1, 4), taking 0.0 seconds to get val score of -0.0065
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 245 of 19440: (0, 4, 0, 4, 0, 3), taking 0.0 seconds to get val score of 0.0729
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# % Combos Checked Thus Far: 245 out of 19440 which is 1.260288%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (2, 3, 2, 5, 1, 4), which had val score of 0.0403
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 245 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 2, 5, 1, 4), which had val score of 0.0866
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 245 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 2, 5, 1, 4), which had val score of 0.1104
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 245 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 5, 1, 4), which had val score of 0.1175
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 245 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 5, 1, 4), which had val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 245 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 5, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 245 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 245 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 5, 0, 4), which had val score of -0.0005
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 245 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 5, 1, 3), which had val score of 0.1142
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 245 of 19440 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 246 of 19440: (2, 3, 1, 5, 1, 4), taking 0.0 seconds to get val score of 0.0397
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 247 of 19440: (4, 3, 1, 5, 1, 4), taking 0.0 seconds to get val score of 0.0867
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 248 of 19440: (3, 2, 1, 5, 1, 4), taking 0.0 seconds to get val score of 0.11
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 249 of 19440: (3, 4, 1, 5, 1, 4), taking 0.0 seconds to get val score of 0.1175
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 250 of 19440: (3, 3, 0, 5, 1, 4), taking 0.0 seconds to get val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (3, 3, 2, 5, 1, 4), which had val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 250 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 250 of 19440 combinations so far
# Trained and Tested combination 251 of 19440: (3, 3, 1, 5, 0, 4), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Trained and Tested combination 252 of 19440: (3, 3, 1, 5, 1, 3), taking 0.0 seconds to get val score of 0.1142
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261
# Already Trained and Tested combination (2, 3, 2, 4, 1, 4), which had val score of 0.0403
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 2, 4, 1, 4), which had val score of 0.0864
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 2, 4, 1, 4), which had val score of 0.1055
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1, 4), which had val score of 0.1174
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 4, 1, 4), which had val score of 0.1258
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1, 4), which had val score of 0.1211
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 4), which had val score of 0.1254
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 5, 1, 4), which had val score of 0.1261
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 0, 4), which had val score of -0.0041
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 1, 3), which had val score of 0.1109
#         Current best combo: (3, 3, 2, 5, 1, 4) with val score 0.1261.
#         Has trained 252 of 19440 combinations so far
# % Combos Checked Thus Far: 252 out of 19440 which is 1.2962960000000001%
# Max Score:
#  0.12611976913950373
# Max Test Score:
#  0.018601
# Max Combo Index:
#  (3, 3, 2, 5, 1, 4) out of [6, 9, 6, 6, 2, 5] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.1, 'degree': 4, 'tol': 0.01, 'max_iter': 1600, 'gamma': 'scale', 'nu': 0.9}
# % Combos Checked: 252 out of 19440 which is 1.2962960000000001%
