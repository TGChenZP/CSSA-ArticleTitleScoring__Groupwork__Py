# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'google-bert_bert-base-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import RandomForestRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 5250: (5, 6, 4, 0, 0), taking 0.71 seconds to get val score of -0.0045
#         Current best combo: (5, 6, 4, 0, 0) with val score -0.0045
# Trained and Tested combination 2 of 5250: (0, 6, 0, 0, 4), taking 0.04 seconds to get val score of -0.0039
#         Current best combo: (0, 6, 0, 0, 4) with val score -0.0039
# Trained and Tested combination 3 of 5250: (0, 0, 4, 0, 0), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 6, 0, 0, 4) with val score -0.0039
# Trained and Tested combination 4 of 5250: (5, 6, 0, 0, 0), taking 0.94 seconds to get val score of 0.104
#         Current best combo: (5, 6, 0, 0, 0) with val score 0.104
# Trained and Tested combination 5 of 5250: (0, 6, 0, 4, 0), taking 0.04 seconds to get val score of 0.0627
#         Current best combo: (5, 6, 0, 0, 0) with val score 0.104
# Trained and Tested combination 6 of 5250: (0, 6, 4, 4, 0), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (5, 6, 0, 0, 0) with val score 0.104
# Trained and Tested combination 7 of 5250: (0, 3, 4, 4, 0), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (5, 6, 0, 0, 0) with val score 0.104
# Trained and Tested combination 8 of 5250: (5, 0, 0, 0, 4), taking 0.86 seconds to get val score of -0.0079
#         Current best combo: (5, 6, 0, 0, 0) with val score 0.104
# Trained and Tested combination 9 of 5250: (5, 6, 4, 4, 0), taking 0.7 seconds to get val score of -0.0045
#         Current best combo: (5, 6, 0, 0, 0) with val score 0.104
# Trained and Tested combination 10 of 5250: (0, 3, 0, 0, 0), taking 0.03 seconds to get val score of 0.1509
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 11 of 5250: (0, 0, 0, 4, 0), taking 0.04 seconds to get val score of 0.0601
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 12 of 5250: (0, 6, 0, 4, 4), taking 0.03 seconds to get val score of -0.0039
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 13 of 5250: (0, 0, 4, 4, 0), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 14 of 5250: (5, 0, 4, 0, 4), taking 0.72 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 15 of 5250: (0, 3, 0, 0, 4), taking 0.03 seconds to get val score of -0.0039
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 16 of 5250: (5, 0, 0, 4, 4), taking 0.82 seconds to get val score of -0.0079
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 17 of 5250: (5, 0, 0, 4, 0), taking 0.87 seconds to get val score of 0.0411
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 18 of 5250: (5, 3, 0, 4, 4), taking 0.89 seconds to get val score of -0.0079
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 19 of 5250: (0, 3, 0, 4, 0), taking 0.03 seconds to get val score of 0.0627
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 20 of 5250: (0, 6, 4, 0, 0), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 21 of 5250: (5, 6, 0, 4, 4), taking 0.87 seconds to get val score of -0.0079
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 22 of 5250: (0, 3, 4, 0, 4), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 23 of 5250: (5, 6, 4, 0, 4), taking 0.68 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 24 of 5250: (0, 6, 0, 0, 0), taking 0.03 seconds to get val score of 0.1509
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 25 of 5250: (5, 3, 0, 0, 4), taking 0.93 seconds to get val score of -0.0079
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 26 of 5250: (5, 3, 4, 0, 4), taking 0.7 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 27 of 5250: (5, 3, 0, 4, 0), taking 0.88 seconds to get val score of 0.0969
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 28 of 5250: (5, 0, 4, 4, 4), taking 0.69 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 29 of 5250: (0, 0, 0, 0, 0), taking 0.03 seconds to get val score of 0.1065
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 30 of 5250: (5, 0, 0, 0, 0), taking 0.86 seconds to get val score of 0.0812
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 31 of 5250: (0, 3, 0, 4, 4), taking 0.03 seconds to get val score of -0.0039
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 32 of 5250: (5, 3, 4, 4, 4), taking 0.68 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 33 of 5250: (0, 3, 4, 0, 0), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 34 of 5250: (5, 3, 4, 4, 0), taking 0.75 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 35 of 5250: (0, 0, 0, 4, 4), taking 0.03 seconds to get val score of -0.0039
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 36 of 5250: (5, 0, 4, 4, 0), taking 0.68 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 37 of 5250: (0, 3, 4, 4, 4), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 38 of 5250: (5, 6, 0, 4, 0), taking 0.87 seconds to get val score of 0.0969
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 39 of 5250: (0, 0, 4, 4, 4), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 40 of 5250: (5, 0, 4, 0, 0), taking 0.7 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 41 of 5250: (0, 0, 4, 0, 4), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 42 of 5250: (0, 0, 0, 0, 4), taking 0.03 seconds to get val score of -0.0039
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 43 of 5250: (5, 6, 0, 0, 4), taking 0.92 seconds to get val score of -0.0079
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 44 of 5250: (5, 3, 4, 0, 0), taking 0.66 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 45 of 5250: (0, 6, 4, 0, 4), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 46 of 5250: (5, 6, 4, 4, 4), taking 0.66 seconds to get val score of -0.0045
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 47 of 5250: (0, 6, 4, 4, 4), taking 0.03 seconds to get val score of -0.0594
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 48 of 5250: (5, 3, 0, 0, 0), taking 0.88 seconds to get val score of 0.104
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 49 of 5250: (3, 3, 2, 2, 2), taking 0.26 seconds to get val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 50 of 5250: (2, 3, 2, 2, 2), taking 0.13 seconds to get val score of 0.1091
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 51 of 5250: (4, 3, 2, 2, 2), taking 0.5 seconds to get val score of 0.1065
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 52 of 5250: (3, 2, 2, 2, 2), taking 0.25 seconds to get val score of 0.0752
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 53 of 5250: (3, 4, 2, 2, 2), taking 0.26 seconds to get val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 54 of 5250: (3, 3, 1, 2, 2), taking 0.25 seconds to get val score of 0.1037
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 55 of 5250: (3, 3, 3, 2, 2), taking 0.27 seconds to get val score of 0.0952
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 56 of 5250: (3, 3, 2, 1, 2), taking 0.25 seconds to get val score of 0.1105
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 57 of 5250: (3, 3, 2, 3, 2), taking 0.27 seconds to get val score of 0.1071
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 58 of 5250: (3, 3, 2, 2, 1), taking 0.26 seconds to get val score of 0.0804
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 59 of 5250: (3, 3, 2, 2, 3), taking 0.27 seconds to get val score of 0.0583
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# 	round 0 iteration:  1
#
# Trained and Tested combination 60 of 5250: (1, 3, 2, 2, 2), taking 0.07 seconds to get val score of 0.084
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (3, 3, 2, 2, 2), which had val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 60 of 5250 combinations so far
# Trained and Tested combination 61 of 5250: (2, 2, 2, 2, 2), taking 0.14 seconds to get val score of 0.1048
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 62 of 5250: (2, 4, 2, 2, 2), taking 0.14 seconds to get val score of 0.1091
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 63 of 5250: (2, 3, 1, 2, 2), taking 0.14 seconds to get val score of 0.1111
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 64 of 5250: (2, 3, 3, 2, 2), taking 0.14 seconds to get val score of 0.1216
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 65 of 5250: (2, 3, 2, 1, 2), taking 0.14 seconds to get val score of 0.1087
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 66 of 5250: (2, 3, 2, 3, 2), taking 0.15 seconds to get val score of 0.1191
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 67 of 5250: (2, 3, 2, 2, 1), taking 0.14 seconds to get val score of 0.1064
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 68 of 5250: (2, 3, 2, 2, 3), taking 0.15 seconds to get val score of 0.0588
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (3, 3, 2, 2, 2), which had val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 68 of 5250 combinations so far
# Trained and Tested combination 69 of 5250: (5, 3, 2, 2, 2), taking 1.04 seconds to get val score of 0.1148
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 70 of 5250: (4, 2, 2, 2, 2), taking 0.53 seconds to get val score of 0.1043
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 71 of 5250: (4, 4, 2, 2, 2), taking 0.51 seconds to get val score of 0.1065
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 72 of 5250: (4, 3, 1, 2, 2), taking 0.5 seconds to get val score of 0.124
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 73 of 5250: (4, 3, 3, 2, 2), taking 0.54 seconds to get val score of 0.116
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 74 of 5250: (4, 3, 2, 1, 2), taking 0.56 seconds to get val score of 0.0927
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 75 of 5250: (4, 3, 2, 3, 2), taking 0.58 seconds to get val score of 0.1098
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 76 of 5250: (4, 3, 2, 2, 1), taking 0.52 seconds to get val score of 0.1049
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 77 of 5250: (4, 3, 2, 2, 3), taking 0.51 seconds to get val score of 0.0574
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (2, 2, 2, 2, 2), which had val score of 0.1048
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 77 of 5250 combinations so far
# Already Trained and Tested combination (4, 2, 2, 2, 2), which had val score of 0.1043
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 77 of 5250 combinations so far
# Trained and Tested combination 78 of 5250: (3, 1, 2, 2, 2), taking 0.25 seconds to get val score of 0.0922
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (3, 3, 2, 2, 2), which had val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 78 of 5250 combinations so far
# Trained and Tested combination 79 of 5250: (3, 2, 1, 2, 2), taking 0.25 seconds to get val score of 0.1005
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 80 of 5250: (3, 2, 3, 2, 2), taking 0.27 seconds to get val score of 0.1068
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 81 of 5250: (3, 2, 2, 1, 2), taking 0.26 seconds to get val score of 0.1031
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 82 of 5250: (3, 2, 2, 3, 2), taking 0.27 seconds to get val score of 0.1082
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 83 of 5250: (3, 2, 2, 2, 1), taking 0.26 seconds to get val score of 0.077
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 84 of 5250: (3, 2, 2, 2, 3), taking 0.26 seconds to get val score of 0.0583
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (2, 4, 2, 2, 2), which had val score of 0.1091
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 84 of 5250 combinations so far
# Already Trained and Tested combination (4, 4, 2, 2, 2), which had val score of 0.1065
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 84 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2), which had val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 84 of 5250 combinations so far
# Trained and Tested combination 85 of 5250: (3, 5, 2, 2, 2), taking 0.25 seconds to get val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 86 of 5250: (3, 4, 1, 2, 2), taking 0.24 seconds to get val score of 0.1037
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 87 of 5250: (3, 4, 3, 2, 2), taking 0.26 seconds to get val score of 0.0952
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 88 of 5250: (3, 4, 2, 1, 2), taking 0.27 seconds to get val score of 0.1105
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 89 of 5250: (3, 4, 2, 3, 2), taking 0.27 seconds to get val score of 0.1071
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 90 of 5250: (3, 4, 2, 2, 1), taking 0.26 seconds to get val score of 0.0804
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 91 of 5250: (3, 4, 2, 2, 3), taking 0.25 seconds to get val score of 0.0583
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (2, 3, 1, 2, 2), which had val score of 0.1111
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 91 of 5250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 2, 2), which had val score of 0.124
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 91 of 5250 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2), which had val score of 0.1005
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 91 of 5250 combinations so far
# Already Trained and Tested combination (3, 4, 1, 2, 2), which had val score of 0.1037
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 91 of 5250 combinations so far
# Trained and Tested combination 92 of 5250: (3, 3, 0, 2, 2), taking 0.24 seconds to get val score of 0.0676
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (3, 3, 2, 2, 2), which had val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 92 of 5250 combinations so far
# Trained and Tested combination 93 of 5250: (3, 3, 1, 1, 2), taking 0.25 seconds to get val score of 0.1154
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 94 of 5250: (3, 3, 1, 3, 2), taking 0.25 seconds to get val score of 0.1033
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 95 of 5250: (3, 3, 1, 2, 1), taking 0.24 seconds to get val score of 0.104
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 96 of 5250: (3, 3, 1, 2, 3), taking 0.24 seconds to get val score of 0.0613
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (2, 3, 3, 2, 2), which had val score of 0.1216
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 96 of 5250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 2, 2), which had val score of 0.116
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 96 of 5250 combinations so far
# Already Trained and Tested combination (3, 2, 3, 2, 2), which had val score of 0.1068
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 96 of 5250 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 2), which had val score of 0.0952
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 96 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2), which had val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 96 of 5250 combinations so far
# Trained and Tested combination 97 of 5250: (3, 3, 4, 2, 2), taking 0.17 seconds to get val score of -0.0072
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 98 of 5250: (3, 3, 3, 1, 2), taking 0.26 seconds to get val score of 0.1178
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 99 of 5250: (3, 3, 3, 3, 2), taking 0.28 seconds to get val score of 0.0912
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 100 of 5250: (3, 3, 3, 2, 1), taking 0.27 seconds to get val score of 0.0943
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 101 of 5250: (3, 3, 3, 2, 3), taking 0.27 seconds to get val score of 0.0421
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (2, 3, 2, 1, 2), which had val score of 0.1087
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 101 of 5250 combinations so far
# Already Trained and Tested combination (4, 3, 2, 1, 2), which had val score of 0.0927
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 101 of 5250 combinations so far
# Already Trained and Tested combination (3, 2, 2, 1, 2), which had val score of 0.1031
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 101 of 5250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 1, 2), which had val score of 0.1105
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 101 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 1, 1, 2), which had val score of 0.1154
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 101 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 3, 1, 2), which had val score of 0.1178
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 101 of 5250 combinations so far
# Trained and Tested combination 102 of 5250: (3, 3, 2, 0, 2), taking 0.27 seconds to get val score of 0.1184
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (3, 3, 2, 2, 2), which had val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 102 of 5250 combinations so far
# Trained and Tested combination 103 of 5250: (3, 3, 2, 1, 1), taking 0.26 seconds to get val score of 0.1088
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 104 of 5250: (3, 3, 2, 1, 3), taking 0.26 seconds to get val score of 0.053
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (2, 3, 2, 3, 2), which had val score of 0.1191
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 104 of 5250 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 2), which had val score of 0.1098
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 104 of 5250 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 2), which had val score of 0.1082
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 104 of 5250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 2), which had val score of 0.1071
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 104 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 2), which had val score of 0.1033
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 104 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 2), which had val score of 0.0912
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 104 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2), which had val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 104 of 5250 combinations so far
# Trained and Tested combination 105 of 5250: (3, 3, 2, 4, 2), taking 0.24 seconds to get val score of 0.1194
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 106 of 5250: (3, 3, 2, 3, 1), taking 0.28 seconds to get val score of 0.1074
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 107 of 5250: (3, 3, 2, 3, 3), taking 0.28 seconds to get val score of 0.0611
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (2, 3, 2, 2, 1), which had val score of 0.1064
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 107 of 5250 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 1), which had val score of 0.1049
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 107 of 5250 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 1), which had val score of 0.077
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 107 of 5250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1), which had val score of 0.0804
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 107 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 1), which had val score of 0.104
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 107 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1), which had val score of 0.0943
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 107 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1), which had val score of 0.1088
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 107 of 5250 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1), which had val score of 0.1074
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 107 of 5250 combinations so far
# Trained and Tested combination 108 of 5250: (3, 3, 2, 2, 0), taking 0.28 seconds to get val score of 0.0802
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (3, 3, 2, 2, 2), which had val score of 0.0784
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 108 of 5250 combinations so far
# Trained and Tested combination 109 of 5250: (1, 3, 0, 0, 0), taking 0.07 seconds to get val score of 0.1375
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 110 of 5250: (0, 2, 0, 0, 0), taking 0.04 seconds to get val score of 0.1362
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 111 of 5250: (0, 4, 0, 0, 0), taking 0.04 seconds to get val score of 0.1509
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 112 of 5250: (0, 3, 1, 0, 0), taking 0.04 seconds to get val score of 0.0451
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 113 of 5250: (0, 3, 0, 1, 0), taking 0.03 seconds to get val score of 0.1232
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 114 of 5250: (0, 3, 0, 0, 1), taking 0.04 seconds to get val score of 0.1505
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# % Combos Checked Thus Far: 114 out of 5250 which is 2.1714290000000003%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruising Coordrdinate 0 of 48
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 115 of 5250: (1, 0, 0, 0, 0), taking 0.06 seconds to get val score of 0.081
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 116 of 5250: (0, 1, 0, 0, 0), taking 0.03 seconds to get val score of 0.1502
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 117 of 5250: (0, 0, 1, 0, 0), taking 0.03 seconds to get val score of 0.146
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 118 of 5250: (0, 0, 0, 1, 0), taking 0.03 seconds to get val score of 0.0717
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 119 of 5250: (0, 0, 0, 0, 1), taking 0.04 seconds to get val score of 0.1065
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# 	round 1 iteration:  1
#
# Trained and Tested combination 120 of 5250: (1, 1, 0, 0, 0), taking 0.06 seconds to get val score of 0.0981
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (0, 0, 0, 0, 0), which had val score of 0.1065
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 120 of 5250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 0, 0), which had val score of 0.1362
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 120 of 5250 combinations so far
# Trained and Tested combination 121 of 5250: (0, 1, 1, 0, 0), taking 0.04 seconds to get val score of 0.0702
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 122 of 5250: (0, 1, 0, 1, 0), taking 0.04 seconds to get val score of 0.0518
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 123 of 5250: (0, 1, 0, 0, 1), taking 0.04 seconds to get val score of 0.1502
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 124 of 5250: (1, 0, 1, 0, 0), taking 0.06 seconds to get val score of 0.0955
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (0, 1, 1, 0, 0), which had val score of 0.0702
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 124 of 5250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0), which had val score of 0.1065
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 124 of 5250 combinations so far
# Trained and Tested combination 125 of 5250: (0, 0, 2, 0, 0), taking 0.04 seconds to get val score of 0.1394
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 126 of 5250: (0, 0, 1, 1, 0), taking 0.03 seconds to get val score of 0.0805
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 127 of 5250: (0, 0, 1, 0, 1), taking 0.03 seconds to get val score of 0.146
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 128 of 5250: (1, 0, 0, 0, 1), taking 0.06 seconds to get val score of 0.081
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (0, 1, 0, 0, 1), which had val score of 0.1502
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 128 of 5250 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 1), which had val score of 0.146
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 128 of 5250 combinations so far
# Trained and Tested combination 129 of 5250: (0, 0, 0, 1, 1), taking 0.04 seconds to get val score of 0.0717
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (0, 0, 0, 0, 0), which had val score of 0.1065
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 129 of 5250 combinations so far
# Trained and Tested combination 130 of 5250: (0, 0, 0, 0, 2), taking 0.03 seconds to get val score of 0.1062
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# % Combos Checked Thus Far: 130 out of 5250 which is 2.47619%
# Cruising Coordrdinate 0 of 48
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 131 of 5250: (1, 6, 0, 0, 0), taking 0.07 seconds to get val score of 0.1375
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 132 of 5250: (0, 5, 0, 0, 0), taking 0.04 seconds to get val score of 0.1509
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 133 of 5250: (0, 6, 1, 0, 0), taking 0.04 seconds to get val score of 0.0451
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 134 of 5250: (0, 6, 0, 1, 0), taking 0.04 seconds to get val score of 0.1232
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 135 of 5250: (0, 6, 0, 0, 1), taking 0.04 seconds to get val score of 0.1505
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# 	round 2 iteration:  1
#
# Trained and Tested combination 136 of 5250: (1, 5, 0, 0, 0), taking 0.06 seconds to get val score of 0.1375
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (0, 4, 0, 0, 0), which had val score of 0.1509
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 136 of 5250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0), which had val score of 0.1509
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 136 of 5250 combinations so far
# Trained and Tested combination 137 of 5250: (0, 5, 1, 0, 0), taking 0.04 seconds to get val score of 0.0451
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 138 of 5250: (0, 5, 0, 1, 0), taking 0.04 seconds to get val score of 0.1232
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 139 of 5250: (0, 5, 0, 0, 1), taking 0.04 seconds to get val score of 0.1505
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 140 of 5250: (1, 6, 0, 0, 1), taking 0.06 seconds to get val score of 0.1372
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (0, 5, 0, 0, 1), which had val score of 0.1505
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 140 of 5250 combinations so far
# Trained and Tested combination 141 of 5250: (0, 6, 1, 0, 1), taking 0.04 seconds to get val score of 0.0452
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Trained and Tested combination 142 of 5250: (0, 6, 0, 1, 1), taking 0.04 seconds to get val score of 0.123
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509
# Already Trained and Tested combination (0, 6, 0, 0, 0), which had val score of 0.1509
#         Current best combo: (0, 3, 0, 0, 0) with val score 0.1509.
#         Has trained 142 of 5250 combinations so far
# Trained and Tested combination 143 of 5250: (0, 6, 0, 0, 2), taking 0.04 seconds to get val score of 0.1555
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 144 of 5250: (1, 6, 0, 0, 2), taking 0.07 seconds to get val score of 0.1398
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 145 of 5250: (0, 5, 0, 0, 2), taking 0.04 seconds to get val score of 0.1555
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 146 of 5250: (0, 6, 1, 0, 2), taking 0.04 seconds to get val score of 0.0443
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 147 of 5250: (0, 6, 0, 1, 2), taking 0.04 seconds to get val score of 0.1203
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Already Trained and Tested combination (0, 6, 0, 0, 1), which had val score of 0.1505
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 147 of 5250 combinations so far
# Trained and Tested combination 148 of 5250: (0, 6, 0, 0, 3), taking 0.04 seconds to get val score of 0.0953
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# % Combos Checked Thus Far: 148 out of 5250 which is 2.819048%
# Cruising Coordrdinate 0 of 48
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (1, 3, 0, 0, 0), which had val score of 0.1375
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 148 of 5250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 0, 0), which had val score of 0.1362
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 148 of 5250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0), which had val score of 0.1509
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 148 of 5250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 0), which had val score of 0.0451
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 148 of 5250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 1, 0), which had val score of 0.1232
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 148 of 5250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1), which had val score of 0.1505
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 148 of 5250 combinations so far
# 	round 3 iteration:  1
#
# Trained and Tested combination 149 of 5250: (1, 3, 0, 0, 1), taking 0.07 seconds to get val score of 0.1372
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 150 of 5250: (0, 2, 0, 0, 1), taking 0.04 seconds to get val score of 0.1357
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 151 of 5250: (0, 4, 0, 0, 1), taking 0.04 seconds to get val score of 0.1505
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 152 of 5250: (0, 3, 1, 0, 1), taking 0.04 seconds to get val score of 0.0452
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 153 of 5250: (0, 3, 0, 1, 1), taking 0.04 seconds to get val score of 0.123
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Already Trained and Tested combination (0, 3, 0, 0, 0), which had val score of 0.1509
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 153 of 5250 combinations so far
# Trained and Tested combination 154 of 5250: (0, 3, 0, 0, 2), taking 0.04 seconds to get val score of 0.1555
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# % Combos Checked Thus Far: 154 out of 5250 which is 2.933333%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (1, 6, 0, 0, 2), which had val score of 0.1398
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 154 of 5250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 2), which had val score of 0.1555
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 154 of 5250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 0, 2), which had val score of 0.0443
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 154 of 5250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 1, 2), which had val score of 0.1203
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 154 of 5250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 1), which had val score of 0.1505
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 154 of 5250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 3), which had val score of 0.0953
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 154 of 5250 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 155 of 5250: (1, 5, 0, 0, 2), taking 0.07 seconds to get val score of 0.1398
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 156 of 5250: (0, 4, 0, 0, 2), taking 0.04 seconds to get val score of 0.1555
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Already Trained and Tested combination (0, 6, 0, 0, 2), which had val score of 0.1555
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 156 of 5250 combinations so far
# Trained and Tested combination 157 of 5250: (0, 5, 1, 0, 2), taking 0.04 seconds to get val score of 0.0443
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Trained and Tested combination 158 of 5250: (0, 5, 0, 1, 2), taking 0.04 seconds to get val score of 0.1203
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# Already Trained and Tested combination (0, 5, 0, 0, 1), which had val score of 0.1505
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555.
#         Has trained 158 of 5250 combinations so far
# Trained and Tested combination 159 of 5250: (0, 5, 0, 0, 3), taking 0.04 seconds to get val score of 0.0953
#         Current best combo: (0, 6, 0, 0, 2) with val score 0.1555
# % Combos Checked Thus Far: 159 out of 5250 which is 3.028571%
# Max Score:
#  0.1554969014822064
# Max Test Score:
#  0.084791
# Max Combo Index:
#  (0, 6, 0, 0, 2) out of [6, 7, 5, 5, 5] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001}
# % Combos Checked: 159 out of 5250 which is 3.028571%
