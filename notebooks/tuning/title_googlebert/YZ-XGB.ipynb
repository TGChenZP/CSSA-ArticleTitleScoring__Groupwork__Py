# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'google-bert_bert-base-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
# Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = False

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': 19260817,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis=1)
train_y = train_data['label']
val_X = val_data.drop('label', axis=1)
val_y = val_data['label']
test_X = test_data.drop('label', axis=1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 31500: (5, 0, 0, 4, 0, 0), taking 13.85 seconds to get val score of 0.0022
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score 0.0022
# Trained and Tested combination 2 of 31500: (5, 0, 0, 0, 4, 5), taking 10.6 seconds to get val score of 0
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score 0.0022
# Trained and Tested combination 3 of 31500: (0, 6, 0, 4, 0, 0), taking 3.74 seconds to get val score of -0.0104
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score 0.0022
# Trained and Tested combination 4 of 31500: (0, 0, 0, 0, 4, 0), taking 2.09 seconds to get val score of -0.0107
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score 0.0022
# Trained and Tested combination 5 of 31500: (0, 6, 4, 4, 0, 0), taking 7.63 seconds to get val score of -0.01
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score 0.0022
# Trained and Tested combination 6 of 31500: (0, 0, 0, 4, 0, 0), taking 1.54 seconds to get val score of -0.0106
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score 0.0022
# Trained and Tested combination 7 of 31500: (5, 0, 0, 4, 0, 5), taking 20.03 seconds to get val score of 0
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score 0.0022
# Trained and Tested combination 8 of 31500: (0, 3, 0, 4, 0, 0), taking 4.29 seconds to get val score of -0.0104
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score 0.0022
# Trained and Tested combination 9 of 31500: (0, 0, 4, 0, 0, 0), taking 1.95 seconds to get val score of -0.0107
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score 0.0022
# Trained and Tested combination 10 of 31500: (5, 3, 4, 0, 4, 0), taking 209.79 seconds to get val score of 0.0083
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 11 of 31500: (0, 6, 4, 4, 4, 0), taking 5.66 seconds to get val score of -0.0105
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 12 of 31500: (0, 3, 4, 0, 0, 5), taking 7.77 seconds to get val score of -8.055241610117969e+40
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 13 of 31500: (0, 3, 0, 0, 0, 0), taking 4.38 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 14 of 31500: (0, 3, 4, 0, 4, 0), taking 6.93 seconds to get val score of -0.0103
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 15 of 31500: (5, 3, 0, 0, 0, 5), taking 25.22 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 16 of 31500: (5, 0, 0, 0, 0, 0), taking 50.91 seconds to get val score of -0.0013
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 17 of 31500: (0, 3, 4, 0, 4, 5), taking 7.33 seconds to get val score of -3.178429431198909e+41
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 18 of 31500: (0, 6, 0, 4, 4, 5), taking 2.78 seconds to get val score of -5.7286086305593006e+44
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 19 of 31500: (5, 0, 4, 0, 4, 5), taking 20.3 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 20 of 31500: (5, 3, 4, 4, 4, 0), taking 150.83 seconds to get val score of -0.0035
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 21 of 31500: (5, 3, 0, 4, 0, 0), taking 146.45 seconds to get val score of 0.005
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 22 of 31500: (0, 3, 0, 0, 4, 5), taking 3.44 seconds to get val score of -1.0040415407900819e+44
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 23 of 31500: (5, 6, 4, 0, 4, 5), taking 26.17 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 24 of 31500: (0, 6, 0, 0, 4, 5), taking 3.57 seconds to get val score of -1.0040415407900819e+44
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 25 of 31500: (5, 6, 4, 0, 0, 5), taking 26.01 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 26 of 31500: (5, 6, 0, 0, 0, 5), taking 24.67 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 27 of 31500: (0, 3, 4, 4, 0, 5), taking 6.71 seconds to get val score of -7.805347674634799e+43
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 28 of 31500: (0, 6, 4, 0, 0, 5), taking 7.04 seconds to get val score of -8.055241610117969e+40
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 29 of 31500: (5, 0, 0, 4, 4, 5), taking 19.52 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 30 of 31500: (0, 3, 0, 4, 4, 0), taking 3.61 seconds to get val score of -0.0105
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 31 of 31500: (5, 3, 0, 4, 4, 0), taking 58.16 seconds to get val score of 0.0045
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 32 of 31500: (5, 3, 0, 4, 4, 5), taking 12.25 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 33 of 31500: (0, 6, 0, 0, 0, 5), taking 0.87 seconds to get val score of -4.133196449029531e+41
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 34 of 31500: (0, 3, 0, 0, 4, 0), taking 0.46 seconds to get val score of -0.0105
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 35 of 31500: (0, 3, 0, 0, 0, 5), taking 0.41 seconds to get val score of -4.133196449029531e+41
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 36 of 31500: (0, 3, 0, 4, 0, 5), taking 0.27 seconds to get val score of -3.0927745335402124e+45
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 37 of 31500: (5, 3, 4, 4, 4, 5), taking 5.98 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 38 of 31500: (5, 0, 4, 4, 0, 5), taking 11.55 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 39 of 31500: (5, 3, 4, 4, 0, 0), taking 229.36 seconds to get val score of 0.003
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 40 of 31500: (0, 0, 0, 4, 4, 0), taking 1.97 seconds to get val score of -0.0106
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0083
# Trained and Tested combination 41 of 31500: (5, 6, 4, 0, 0, 0), taking 176.92 seconds to get val score of 0.0099
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 42 of 31500: (5, 3, 0, 4, 0, 5), taking 24.39 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 43 of 31500: (0, 6, 0, 0, 4, 0), taking 4.47 seconds to get val score of -0.0105
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 44 of 31500: (5, 6, 4, 4, 0, 5), taking 27.99 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 45 of 31500: (0, 0, 4, 0, 4, 5), taking 1.65 seconds to get val score of -4.068484285135677e+44
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 46 of 31500: (0, 6, 0, 4, 4, 0), taking 4.1 seconds to get val score of -0.0105
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 47 of 31500: (0, 6, 4, 0, 4, 5), taking 8.06 seconds to get val score of -3.178429431198909e+41
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 48 of 31500: (5, 6, 4, 4, 0, 0), taking 227.19 seconds to get val score of 0.003
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 49 of 31500: (0, 3, 0, 4, 4, 5), taking 3.12 seconds to get val score of -5.7286086305593006e+44
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 50 of 31500: (5, 6, 0, 0, 4, 5), taking 14.93 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 51 of 31500: (5, 6, 0, 4, 0, 0), taking 44.97 seconds to get val score of 0.005
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 52 of 31500: (5, 3, 4, 0, 0, 5), taking 26.37 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 53 of 31500: (0, 6, 4, 4, 0, 5), taking 7.67 seconds to get val score of -7.805347674634799e+43
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 54 of 31500: (0, 0, 4, 4, 0, 5), taking 1.35 seconds to get val score of -4.092913609576969e+45
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 55 of 31500: (5, 3, 0, 0, 4, 0), taking 48.6 seconds to get val score of 0.0015
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 56 of 31500: (5, 0, 0, 0, 4, 0), taking 39.09 seconds to get val score of -0.0014
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 57 of 31500: (0, 6, 0, 0, 0, 0), taking 4.0 seconds to get val score of -0.0104
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 58 of 31500: (0, 0, 4, 0, 0, 5), taking 1.52 seconds to get val score of -4.068484285135677e+44
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 59 of 31500: (0, 0, 0, 0, 0, 5), taking 1.25 seconds to get val score of -2.8491593383296424e+45
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 60 of 31500: (5, 0, 4, 0, 4, 0), taking 46.88 seconds to get val score of 0.0016
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 61 of 31500: (5, 6, 0, 4, 4, 5), taking 21.82 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 62 of 31500: (0, 3, 4, 4, 4, 0), taking 7.55 seconds to get val score of -0.0105
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 63 of 31500: (0, 6, 0, 4, 0, 5), taking 2.79 seconds to get val score of -3.0927745335402124e+45
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 64 of 31500: (5, 3, 4, 0, 4, 5), taking 30.13 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 65 of 31500: (0, 0, 4, 4, 4, 5), taking 1.37 seconds to get val score of -4.08011432052289e+45
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 66 of 31500: (5, 3, 4, 4, 0, 5), taking 26.98 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 67 of 31500: (0, 6, 4, 0, 0, 0), taking 7.0 seconds to get val score of -0.0102
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 68 of 31500: (5, 0, 4, 4, 4, 5), taking 21.36 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 69 of 31500: (5, 0, 4, 4, 4, 0), taking 56.38 seconds to get val score of -0.009
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 70 of 31500: (5, 0, 0, 4, 4, 0), taking 55.63 seconds to get val score of 0.0021
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 71 of 31500: (5, 0, 0, 0, 0, 5), taking 19.57 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 72 of 31500: (5, 6, 4, 4, 4, 0), taking 95.49 seconds to get val score of -0.0035
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 73 of 31500: (0, 3, 4, 4, 0, 0), taking 7.26 seconds to get val score of -0.01
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 74 of 31500: (0, 0, 0, 4, 0, 5), taking 1.37 seconds to get val score of -8.173866987272488e+43
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 75 of 31500: (0, 0, 4, 4, 0, 0), taking 1.65 seconds to get val score of -0.0108
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 76 of 31500: (0, 0, 0, 0, 0, 0), taking 1.53 seconds to get val score of -0.0107
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 77 of 31500: (5, 6, 0, 4, 0, 5), taking 20.94 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 78 of 31500: (5, 6, 4, 4, 4, 5), taking 23.16 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 79 of 31500: (5, 0, 4, 0, 0, 0), taking 51.91 seconds to get val score of 0.0019
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 80 of 31500: (5, 3, 0, 0, 4, 5), taking 24.11 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 81 of 31500: (0, 3, 4, 0, 0, 0), taking 7.29 seconds to get val score of -0.0102
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 82 of 31500: (5, 6, 0, 4, 4, 0), taking 130.71 seconds to get val score of 0.0045
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 83 of 31500: (0, 0, 0, 4, 4, 5), taking 1.77 seconds to get val score of -8.992680162615183e+44
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 84 of 31500: (5, 0, 4, 4, 0, 0), taking 42.62 seconds to get val score of -0.0077
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 85 of 31500: (0, 3, 4, 4, 4, 5), taking 1.87 seconds to get val score of -1.8638601200629441e+43
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 86 of 31500: (5, 6, 4, 0, 4, 0), taking 125.15 seconds to get val score of 0.0083
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 87 of 31500: (0, 0, 4, 4, 4, 0), taking 0.37 seconds to get val score of -0.0109
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 88 of 31500: (5, 6, 0, 0, 0, 0), taking 94.67 seconds to get val score of 0.0025
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 89 of 31500: (5, 0, 4, 0, 0, 5), taking 19.36 seconds to get val score of 0
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 90 of 31500: (0, 0, 4, 0, 4, 0), taking 1.18 seconds to get val score of -0.0107
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 91 of 31500: (0, 0, 0, 0, 4, 5), taking 0.73 seconds to get val score of -1.4362909459411282e+45
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 92 of 31500: (5, 6, 0, 0, 4, 0), taking 116.07 seconds to get val score of 0.0015
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 93 of 31500: (5, 3, 4, 0, 0, 0), taking 182.06 seconds to get val score of 0.0099
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 94 of 31500: (0, 6, 4, 0, 4, 0), taking 8.93 seconds to get val score of -0.0103
#         Current best combo: (5, 6, 4, 0, 0, 0) with val score 0.0099
# Trained and Tested combination 95 of 31500: (3, 3, 2, 2, 2, 3), taking 49.42 seconds to get val score of 0.0232
#         Current best combo: (3, 3, 2, 2, 2, 3) with val score 0.0232
# Trained and Tested combination 96 of 31500: (0, 6, 4, 4, 4, 5), taking 5.2 seconds to get val score of -1.8638601200629441e+43
#         Current best combo: (3, 3, 2, 2, 2, 3) with val score 0.0232
# Trained and Tested combination 97 of 31500: (5, 3, 0, 0, 0, 0), taking 130.07 seconds to get val score of 0.0025
#         Current best combo: (3, 3, 2, 2, 2, 3) with val score 0.0232
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 98 of 31500: (2, 3, 2, 2, 2, 3), taking 28.28 seconds to get val score of 0.0198
#         Current best combo: (3, 3, 2, 2, 2, 3) with val score 0.0232
# Trained and Tested combination 99 of 31500: (4, 3, 2, 2, 2, 3), taking 40.31 seconds to get val score of 0.024
#         Current best combo: (4, 3, 2, 2, 2, 3) with val score 0.024
# Trained and Tested combination 100 of 31500: (3, 2, 2, 2, 2, 3), taking 24.92 seconds to get val score of 0.0421
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.0421
# Trained and Tested combination 101 of 31500: (3, 4, 2, 2, 2, 3), taking 20.39 seconds to get val score of 0.0232
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.0421
# Trained and Tested combination 102 of 31500: (3, 3, 1, 2, 2, 3), taking 42.48 seconds to get val score of -0.0111
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.0421
# Trained and Tested combination 103 of 31500: (3, 3, 3, 2, 2, 3), taking 54.47 seconds to get val score of 0.0868
#         Current best combo: (3, 3, 3, 2, 2, 3) with val score 0.0868
# Trained and Tested combination 104 of 31500: (3, 3, 2, 1, 2, 3), taking 47.34 seconds to get val score of 0.0299
#         Current best combo: (3, 3, 3, 2, 2, 3) with val score 0.0868
# Trained and Tested combination 105 of 31500: (3, 3, 2, 3, 2, 3), taking 46.63 seconds to get val score of 0.0675
#         Current best combo: (3, 3, 3, 2, 2, 3) with val score 0.0868
# Trained and Tested combination 106 of 31500: (3, 3, 2, 2, 1, 3), taking 35.83 seconds to get val score of 0.0281
#         Current best combo: (3, 3, 3, 2, 2, 3) with val score 0.0868
# Trained and Tested combination 107 of 31500: (3, 3, 2, 2, 3, 3), taking 44.57 seconds to get val score of -0.0287
#         Current best combo: (3, 3, 3, 2, 2, 3) with val score 0.0868
# Trained and Tested combination 108 of 31500: (3, 3, 2, 2, 2, 2), taking 4.96 seconds to get val score of 0.1164
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 109 of 31500: (3, 3, 2, 2, 2, 4), taking 26.29 seconds to get val score of -1.0095
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# 	round 0 iteration:  1
#
# Trained and Tested combination 110 of 31500: (1, 3, 2, 2, 2, 3), taking 8.29 seconds to get val score of 0.0181
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0232
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164.
#         Has trained 110 of 31500 combinations so far
# Trained and Tested combination 111 of 31500: (2, 2, 2, 2, 2, 3), taking 2.29 seconds to get val score of 0.0392
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 112 of 31500: (2, 4, 2, 2, 2, 3), taking 2.2 seconds to get val score of 0.0198
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 113 of 31500: (2, 3, 1, 2, 2, 3), taking 1.32 seconds to get val score of -0.0223
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 114 of 31500: (2, 3, 3, 2, 2, 3), taking 1.69 seconds to get val score of 0.0861
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 115 of 31500: (2, 3, 2, 1, 2, 3), taking 2.87 seconds to get val score of 0.0265
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 116 of 31500: (2, 3, 2, 3, 2, 3), taking 2.21 seconds to get val score of 0.0682
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 117 of 31500: (2, 3, 2, 2, 1, 3), taking 2.72 seconds to get val score of 0.0283
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 118 of 31500: (2, 3, 2, 2, 3, 3), taking 2.57 seconds to get val score of -0.0313
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 119 of 31500: (2, 3, 2, 2, 2, 2), taking 2.75 seconds to get val score of 0.0895
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 120 of 31500: (2, 3, 2, 2, 2, 4), taking 2.25 seconds to get val score of -1.0081
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0232
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164.
#         Has trained 120 of 31500 combinations so far
# Trained and Tested combination 121 of 31500: (5, 3, 2, 2, 2, 3), taking 17.35 seconds to get val score of 0.0266
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 122 of 31500: (4, 2, 2, 2, 2, 3), taking 7.88 seconds to get val score of 0.0435
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 123 of 31500: (4, 4, 2, 2, 2, 3), taking 7.82 seconds to get val score of 0.024
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 124 of 31500: (4, 3, 1, 2, 2, 3), taking 5.96 seconds to get val score of -0.0097
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 125 of 31500: (4, 3, 3, 2, 2, 3), taking 7.48 seconds to get val score of 0.0851
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 126 of 31500: (4, 3, 2, 1, 2, 3), taking 5.32 seconds to get val score of 0.0302
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 127 of 31500: (4, 3, 2, 3, 2, 3), taking 6.66 seconds to get val score of 0.0671
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 128 of 31500: (4, 3, 2, 2, 1, 3), taking 3.54 seconds to get val score of 0.0281
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 129 of 31500: (4, 3, 2, 2, 3, 3), taking 6.74 seconds to get val score of -0.0303
#         Current best combo: (3, 3, 2, 2, 2, 2) with val score 0.1164
# Trained and Tested combination 130 of 31500: (4, 3, 2, 2, 2, 2), taking 5.83 seconds to get val score of 0.1218
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 131 of 31500: (4, 3, 2, 2, 2, 4), taking 5.89 seconds to get val score of -1.0495
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Already Trained and Tested combination (2, 2, 2, 2, 2, 3), which had val score of 0.0392
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 131 of 31500 combinations so far
# Already Trained and Tested combination (4, 2, 2, 2, 2, 3), which had val score of 0.0435
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 131 of 31500 combinations so far
# Trained and Tested combination 132 of 31500: (3, 1, 2, 2, 2, 3), taking 1.87 seconds to get val score of -0.1081
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0232
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 132 of 31500 combinations so far
# Trained and Tested combination 133 of 31500: (3, 2, 1, 2, 2, 3), taking 2.91 seconds to get val score of -0.0111
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 134 of 31500: (3, 2, 3, 2, 2, 3), taking 3.7 seconds to get val score of 0.1166
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 135 of 31500: (3, 2, 2, 1, 2, 3), taking 3.32 seconds to get val score of 0.0644
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 136 of 31500: (3, 2, 2, 3, 2, 3), taking 2.77 seconds to get val score of 0.0576
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 137 of 31500: (3, 2, 2, 2, 1, 3), taking 1.85 seconds to get val score of 0.038
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 138 of 31500: (3, 2, 2, 2, 3, 3), taking 2.53 seconds to get val score of -0.0287
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 139 of 31500: (3, 2, 2, 2, 2, 2), taking 2.15 seconds to get val score of 0.0995
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 140 of 31500: (3, 2, 2, 2, 2, 4), taking 2.42 seconds to get val score of -1.013
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Already Trained and Tested combination (2, 4, 2, 2, 2, 3), which had val score of 0.0198
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 140 of 31500 combinations so far
# Already Trained and Tested combination (4, 4, 2, 2, 2, 3), which had val score of 0.024
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 140 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0232
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 140 of 31500 combinations so far
# Trained and Tested combination 141 of 31500: (3, 5, 2, 2, 2, 3), taking 2.62 seconds to get val score of 0.0232
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 142 of 31500: (3, 4, 1, 2, 2, 3), taking 2.21 seconds to get val score of -0.0111
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 143 of 31500: (3, 4, 3, 2, 2, 3), taking 2.63 seconds to get val score of 0.0868
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 144 of 31500: (3, 4, 2, 1, 2, 3), taking 2.58 seconds to get val score of 0.0299
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 145 of 31500: (3, 4, 2, 3, 2, 3), taking 2.42 seconds to get val score of 0.0675
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 146 of 31500: (3, 4, 2, 2, 1, 3), taking 1.96 seconds to get val score of 0.0281
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 147 of 31500: (3, 4, 2, 2, 3, 3), taking 2.51 seconds to get val score of -0.0287
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 148 of 31500: (3, 4, 2, 2, 2, 2), taking 2.18 seconds to get val score of 0.1164
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 149 of 31500: (3, 4, 2, 2, 2, 4), taking 2.28 seconds to get val score of -1.0095
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Already Trained and Tested combination (2, 3, 3, 2, 2, 3), which had val score of 0.0861
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 149 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 3, 2, 2, 3), which had val score of 0.0851
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 149 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 3, 2, 2, 3), which had val score of 0.1166
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 149 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 2, 3), which had val score of 0.0868
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 149 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0232
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218.
#         Has trained 149 of 31500 combinations so far
# Trained and Tested combination 150 of 31500: (3, 3, 4, 2, 2, 3), taking 2.86 seconds to get val score of 0.0724
#         Current best combo: (4, 3, 2, 2, 2, 2) with val score 0.1218
# Trained and Tested combination 151 of 31500: (3, 3, 3, 1, 2, 3), taking 2.69 seconds to get val score of 0.1507
#         Current best combo: (3, 3, 3, 1, 2, 3) with val score 0.1507
# Trained and Tested combination 152 of 31500: (3, 3, 3, 3, 2, 3), taking 2.96 seconds to get val score of 0.1818
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 153 of 31500: (3, 3, 3, 2, 1, 3), taking 1.6 seconds to get val score of 0.0828
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 154 of 31500: (3, 3, 3, 2, 3, 3), taking 2.65 seconds to get val score of 0.0858
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 155 of 31500: (3, 3, 3, 2, 2, 2), taking 2.52 seconds to get val score of 0.1234
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 156 of 31500: (3, 3, 3, 2, 2, 4), taking 2.48 seconds to get val score of -0.8494
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (2, 3, 2, 1, 2, 3), which had val score of 0.0265
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 156 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 1, 2, 3), which had val score of 0.0302
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 156 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 1, 2, 3), which had val score of 0.0644
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 156 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 1, 2, 3), which had val score of 0.0299
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 156 of 31500 combinations so far
# Trained and Tested combination 157 of 31500: (3, 3, 1, 1, 2, 3), taking 2.23 seconds to get val score of 0.0651
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (3, 3, 3, 1, 2, 3), which had val score of 0.1507
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 157 of 31500 combinations so far
# Trained and Tested combination 158 of 31500: (3, 3, 2, 0, 2, 3), taking 2.57 seconds to get val score of 0.0458
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0232
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 158 of 31500 combinations so far
# Trained and Tested combination 159 of 31500: (3, 3, 2, 1, 1, 3), taking 1.91 seconds to get val score of 0.0224
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 160 of 31500: (3, 3, 2, 1, 3, 3), taking 2.58 seconds to get val score of -0.0595
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 161 of 31500: (3, 3, 2, 1, 2, 2), taking 2.26 seconds to get val score of 0.1055
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 162 of 31500: (3, 3, 2, 1, 2, 4), taking 2.27 seconds to get val score of -0.037
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (2, 3, 2, 3, 2, 3), which had val score of 0.0682
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 162 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 2, 3), which had val score of 0.0671
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 162 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 2, 3), which had val score of 0.0576
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 162 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 2, 3), which had val score of 0.0675
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 162 of 31500 combinations so far
# Trained and Tested combination 163 of 31500: (3, 3, 1, 3, 2, 3), taking 2.2 seconds to get val score of 0.0069
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (3, 3, 3, 3, 2, 3), which had val score of 0.1818
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 163 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0232
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 163 of 31500 combinations so far
# Trained and Tested combination 164 of 31500: (3, 3, 2, 4, 2, 3), taking 2.55 seconds to get val score of 0.0446
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 165 of 31500: (3, 3, 2, 3, 1, 3), taking 1.9 seconds to get val score of 0.0799
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 166 of 31500: (3, 3, 2, 3, 3, 3), taking 2.64 seconds to get val score of 0.0518
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 167 of 31500: (3, 3, 2, 3, 2, 2), taking 2.23 seconds to get val score of 0.0986
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 168 of 31500: (3, 3, 2, 3, 2, 4), taking 2.35 seconds to get val score of -0.5301
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (2, 3, 2, 2, 1, 3), which had val score of 0.0283
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 168 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 1, 3), which had val score of 0.0281
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 168 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 1, 3), which had val score of 0.038
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 168 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1, 3), which had val score of 0.0281
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 168 of 31500 combinations so far
# Trained and Tested combination 169 of 31500: (3, 3, 1, 2, 1, 3), taking 1.95 seconds to get val score of 0.0076
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (3, 3, 3, 2, 1, 3), which had val score of 0.0828
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 169 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 3), which had val score of 0.0224
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 169 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 3), which had val score of 0.0799
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 169 of 31500 combinations so far
# Trained and Tested combination 170 of 31500: (3, 3, 2, 2, 0, 3), taking 1.99 seconds to get val score of 0.0281
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0232
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 170 of 31500 combinations so far
# Trained and Tested combination 171 of 31500: (3, 3, 2, 2, 1, 2), taking 2.82 seconds to get val score of 0.0963
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 172 of 31500: (3, 3, 2, 2, 1, 4), taking 1.4 seconds to get val score of -1.082
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (2, 3, 2, 2, 2, 2), which had val score of 0.0895
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 2, 2), which had val score of 0.1218
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 2, 2), which had val score of 0.0995
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 2, 2), which had val score of 0.1164
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 172 of 31500 combinations so far
# Trained and Tested combination 173 of 31500: (3, 3, 1, 2, 2, 2), taking 2.21 seconds to get val score of 0.1299
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (3, 3, 3, 2, 2, 2), which had val score of 0.1234
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 173 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 2, 2), which had val score of 0.1055
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 173 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 2), which had val score of 0.0986
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 173 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 2), which had val score of 0.0963
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 173 of 31500 combinations so far
# Trained and Tested combination 174 of 31500: (3, 3, 2, 2, 3, 2), taking 2.32 seconds to get val score of 0.0904
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 175 of 31500: (3, 3, 2, 2, 2, 1), taking 2.26 seconds to get val score of 0.0302
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0232
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818.
#         Has trained 175 of 31500 combinations so far
# Trained and Tested combination 176 of 31500: (2, 3, 3, 3, 2, 3), taking 1.43 seconds to get val score of 0.1809
#         Current best combo: (3, 3, 3, 3, 2, 3) with val score 0.1818
# Trained and Tested combination 177 of 31500: (4, 3, 3, 3, 2, 3), taking 5.46 seconds to get val score of 0.1824
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824
# Trained and Tested combination 178 of 31500: (3, 2, 3, 3, 2, 3), taking 2.71 seconds to get val score of 0.1659
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824
# Trained and Tested combination 179 of 31500: (3, 4, 3, 3, 2, 3), taking 2.67 seconds to get val score of 0.1818
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824
# Already Trained and Tested combination (3, 3, 2, 3, 2, 3), which had val score of 0.0675
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824.
#         Has trained 179 of 31500 combinations so far
# Trained and Tested combination 180 of 31500: (3, 3, 4, 3, 2, 3), taking 2.97 seconds to get val score of -0.1503
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824
# Already Trained and Tested combination (3, 3, 3, 2, 2, 3), which had val score of 0.0868
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824.
#         Has trained 180 of 31500 combinations so far
# Trained and Tested combination 181 of 31500: (3, 3, 3, 4, 2, 3), taking 2.92 seconds to get val score of 0.0519
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824
# Trained and Tested combination 182 of 31500: (3, 3, 3, 3, 1, 3), taking 1.8 seconds to get val score of 0.1542
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824
# Trained and Tested combination 183 of 31500: (3, 3, 3, 3, 3, 3), taking 2.98 seconds to get val score of 0.1443
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824
# Trained and Tested combination 184 of 31500: (3, 3, 3, 3, 2, 2), taking 2.54 seconds to get val score of 0.1188
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824
# Trained and Tested combination 185 of 31500: (3, 3, 3, 3, 2, 4), taking 2.51 seconds to get val score of -0.529
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824
# Already Trained and Tested combination (3, 3, 3, 3, 2, 3), which had val score of 0.1818
#         Current best combo: (4, 3, 3, 3, 2, 3) with val score 0.1824.
#         Has trained 185 of 31500 combinations so far
# Trained and Tested combination 186 of 31500: (5, 3, 3, 3, 2, 3), taking 10.92 seconds to get val score of 0.1827
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 187 of 31500: (4, 2, 3, 3, 2, 3), taking 5.18 seconds to get val score of 0.1665
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 188 of 31500: (4, 4, 3, 3, 2, 3), taking 5.59 seconds to get val score of 0.1824
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (4, 3, 2, 3, 2, 3), which had val score of 0.0671
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 188 of 31500 combinations so far
# Trained and Tested combination 189 of 31500: (4, 3, 4, 3, 2, 3), taking 6.06 seconds to get val score of -0.1503
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (4, 3, 3, 2, 2, 3), which had val score of 0.0851
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 189 of 31500 combinations so far
# Trained and Tested combination 190 of 31500: (4, 3, 3, 4, 2, 3), taking 5.28 seconds to get val score of 0.0525
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 191 of 31500: (4, 3, 3, 3, 1, 3), taking 2.44 seconds to get val score of 0.1543
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 192 of 31500: (4, 3, 3, 3, 3, 3), taking 5.61 seconds to get val score of 0.1454
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 193 of 31500: (4, 3, 3, 3, 2, 2), taking 5.37 seconds to get val score of 0.1107
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 194 of 31500: (4, 3, 3, 3, 2, 4), taking 3.18 seconds to get val score of -0.5283
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (4, 3, 3, 3, 2, 3), which had val score of 0.1824
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 194 of 31500 combinations so far
# Trained and Tested combination 195 of 31500: (5, 2, 3, 3, 2, 3), taking 5.91 seconds to get val score of 0.1672
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 196 of 31500: (5, 4, 3, 3, 2, 3), taking 6.22 seconds to get val score of 0.1827
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 197 of 31500: (5, 3, 2, 3, 2, 3), taking 4.27 seconds to get val score of 0.0643
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 198 of 31500: (5, 3, 4, 3, 2, 3), taking 1.23 seconds to get val score of -0.1505
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 199 of 31500: (5, 3, 3, 2, 2, 3), taking 1.07 seconds to get val score of 0.0865
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 200 of 31500: (5, 3, 3, 4, 2, 3), taking 1.16 seconds to get val score of 0.0526
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 201 of 31500: (5, 3, 3, 3, 1, 3), taking 0.51 seconds to get val score of 0.1548
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 202 of 31500: (5, 3, 3, 3, 3, 3), taking 1.1 seconds to get val score of 0.1437
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 203 of 31500: (5, 3, 3, 3, 2, 2), taking 1.13 seconds to get val score of 0.1072
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 204 of 31500: (5, 3, 3, 3, 2, 4), taking 1.09 seconds to get val score of -0.5291
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# % Combos Checked Thus Far: 204 out of 31500 which is 0.647619%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 205 of 31500: (1, 0, 0, 0, 0, 0), taking 0.03 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# ...
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2004 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 0, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2004 of 31500 combinations so far
# Trained and Tested combination 2005 of 31500: (5, 3, 4, 4, 2, 5), taking 0.32 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2006 of 31500: (5, 3, 4, 4, 1, 4), taking 0.36 seconds to get val score of -0.1937
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# % Combos Checked Thus Far: 2006 out of 31500 which is 6.368253999999999%
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 72
#
# 	round 72 iteration:  0
#
# Trained and Tested combination 2007 of 31500: (4, 3, 4, 4, 4, 5), taking 0.21 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (5, 2, 4, 4, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2007 of 31500 combinations so far
# Already Trained and Tested combination (5, 4, 4, 4, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2007 of 31500 combinations so far
# Trained and Tested combination 2008 of 31500: (5, 3, 3, 4, 4, 5), taking 0.41 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2009 of 31500: (5, 3, 4, 3, 4, 5), taking 0.36 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2010 of 31500: (5, 3, 4, 4, 3, 5), taking 0.44 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2011 of 31500: (5, 3, 4, 4, 4, 4), taking 1.57 seconds to get val score of -0.5369
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# 	round 72 iteration:  1
#
# Trained and Tested combination 2012 of 31500: (3, 3, 4, 4, 4, 5), taking 0.1 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (5, 3, 4, 4, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2012 of 31500 combinations so far
# Trained and Tested combination 2013 of 31500: (4, 2, 4, 4, 4, 5), taking 0.26 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2014 of 31500: (4, 4, 4, 4, 4, 5), taking 0.2 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2015 of 31500: (4, 3, 3, 4, 4, 5), taking 0.2 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2016 of 31500: (4, 3, 4, 3, 4, 5), taking 0.2 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2017 of 31500: (4, 3, 4, 4, 3, 5), taking 0.2 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2018 of 31500: (4, 3, 4, 4, 4, 4), taking 0.81 seconds to get val score of -0.5369
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (4, 3, 3, 4, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2018 of 31500 combinations so far
# Trained and Tested combination 2019 of 31500: (5, 2, 3, 4, 4, 5), taking 0.4 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2020 of 31500: (5, 4, 3, 4, 4, 5), taking 0.53 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (5, 3, 2, 4, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2020 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2020 of 31500 combinations so far
# Trained and Tested combination 2021 of 31500: (5, 3, 3, 3, 4, 5), taking 0.51 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2022 of 31500: (5, 3, 3, 4, 3, 5), taking 0.4 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2023 of 31500: (5, 3, 3, 4, 4, 4), taking 1.58 seconds to get val score of -0.527
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (4, 3, 4, 3, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2023 of 31500 combinations so far
# Trained and Tested combination 2024 of 31500: (5, 2, 4, 3, 4, 5), taking 0.31 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2025 of 31500: (5, 4, 4, 3, 4, 5), taking 0.31 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (5, 3, 3, 3, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2025 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 2, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2025 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2025 of 31500 combinations so far
# Trained and Tested combination 2026 of 31500: (5, 3, 4, 3, 3, 5), taking 0.31 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2027 of 31500: (5, 3, 4, 3, 4, 4), taking 1.16 seconds to get val score of -0.7533
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (4, 3, 4, 4, 3, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2027 of 31500 combinations so far
# Trained and Tested combination 2028 of 31500: (5, 2, 4, 4, 3, 5), taking 0.37 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2029 of 31500: (5, 4, 4, 4, 3, 5), taking 0.31 seconds to get val score of 0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Already Trained and Tested combination (5, 3, 3, 4, 3, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2029 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 3, 3, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2029 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 2, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2029 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 4, 5), which had val score of 0.0
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2029 of 31500 combinations so far
# Trained and Tested combination 2030 of 31500: (5, 3, 4, 4, 3, 4), taking 1.36 seconds to get val score of -0.3126
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# % Combos Checked Thus Far: 2030 out of 31500 which is 6.444444000000001%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (4, 3, 3, 3, 2, 3), which had val score of 0.1824
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 2, 3, 3, 2, 3), which had val score of 0.1672
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 2, 3), which had val score of 0.1827
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 2, 3), which had val score of 0.0643
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 3, 2, 3), which had val score of -0.1505
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 2, 3), which had val score of 0.0865
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 4, 2, 3), which had val score of 0.0526
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 1, 3), which had val score of 0.1548
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 3, 3), which had val score of 0.1437
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 2, 2), which had val score of 0.1072
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 2, 4), which had val score of -0.5291
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (3, 3, 3, 3, 2, 3), which had val score of 0.1818
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 2, 3), which had val score of 0.1827
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 2, 3, 3, 2, 3), which had val score of 0.1665
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 2, 3), which had val score of 0.1824
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 2, 3), which had val score of 0.0671
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 4, 3, 2, 3), which had val score of -0.1503
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 3, 2, 2, 3), which had val score of 0.0851
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 3, 4, 2, 3), which had val score of 0.0525
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 1, 3), which had val score of 0.1543
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 3, 3), which had val score of 0.1454
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 2, 2), which had val score of 0.1107
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 2, 4), which had val score of -0.5283
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 2, 3), which had val score of 0.1824
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 2, 3), which had val score of 0.1827
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827.
#         Has trained 2030 of 31500 combinations so far
# Trained and Tested combination 2031 of 31500: (5, 5, 3, 3, 2, 3), taking 1.45 seconds to get val score of 0.1827
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2032 of 31500: (5, 4, 2, 3, 2, 3), taking 1.27 seconds to get val score of 0.0643
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2033 of 31500: (5, 4, 4, 3, 2, 3), taking 2.17 seconds to get val score of -0.1505
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2034 of 31500: (5, 4, 3, 2, 2, 3), taking 1.59 seconds to get val score of 0.0865
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2035 of 31500: (5, 4, 3, 4, 2, 3), taking 1.94 seconds to get val score of 0.0526
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2036 of 31500: (5, 4, 3, 3, 1, 3), taking 1.03 seconds to get val score of 0.1548
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2037 of 31500: (5, 4, 3, 3, 3, 3), taking 3.09 seconds to get val score of 0.1437
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2038 of 31500: (5, 4, 3, 3, 2, 2), taking 1.85 seconds to get val score of 0.1072
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# Trained and Tested combination 2039 of 31500: (5, 4, 3, 3, 2, 4), taking 1.41 seconds to get val score of -0.5291
#         Current best combo: (5, 3, 3, 3, 2, 3) with val score 0.1827
# % Combos Checked Thus Far: 2039 out of 31500 which is 6.473015999999999%
# Max Score:
#  0.1826768029703707
# Max Test Score:
#  -0.031785
# Max Combo Index:
#  (5, 3, 3, 3, 2, 3) out of [6, 7, 5, 5, 5, 6] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1}
# % Combos Checked: 2039 out of 31500 which is 6.473015999999999%
