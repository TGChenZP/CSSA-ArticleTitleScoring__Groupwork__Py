# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nusvc(rbf)'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'google-bert_bert-base-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import NuSVR as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto'),
    'nu': (0.1, 0.3, 0.5, 0.7, 0.9)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.NuSVR'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# Successfully read in tuning result of 271 rows, for 271.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (5, 0, 0, 5, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 0, 0, 5, 0, 0), which had val score of -0.3436
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score -0.3436.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 1, 4), which had val score of -0.6176
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score -0.3436.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (0, 8, 0, 5, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 8, 0, 5, 0, 0), which had val score of -0.0284
#         Current best combo: (0, 8, 0, 5, 0, 0) with val score -0.0284.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (0, 0, 0, 0, 1, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0), which had val score of -0.0088
#         Current best combo: (0, 0, 0, 0, 1, 0) with val score -0.0088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 0, 0, 0, 1, 0) with val score -0.0088.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (0, 0, 0, 5, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 0, 5, 0, 0), which had val score of -0.0083
#         Current best combo: (0, 0, 0, 5, 0, 0) with val score -0.0083.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 0, 4), which had val score of -0.0325
#         Current best combo: (0, 0, 0, 5, 0, 0) with val score -0.0083.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (0, 4, 0, 5, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 4, 0, 5, 0, 0), which had val score of -0.007
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 0), which had val score of -0.0092
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 4), which had val score of -0.2713
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 0), which had val score of -0.6401
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 4, 0, 5, 0, 0) with val score -0.007.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (0, 8, 0, 5, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 8, 0, 5, 1, 4), which had val score of -0.0044
#         Current best combo: (0, 8, 0, 5, 1, 4) with val score -0.0044.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (0, 8, 0, 5, 1, 4) with val score -0.0044.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (0, 8, 0, 5, 1, 4) with val score -0.0044.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (5, 4, 0, 5, 0, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 4, 0, 5, 0, 0), which had val score of 0.0348
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 1, 4), which had val score of -0.2522
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 1, 4), which had val score of -0.3906
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 0, 4), which had val score of -0.8461
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 1, 4), which had val score of -0.0668
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 1, 0), which had val score of -0.011
#         Current best combo: (5, 4, 0, 5, 0, 0) with val score 0.0348.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (5, 4, 0, 5, 1, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 4, 0, 5, 1, 0), which had val score of 0.098
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 1, 4), which had val score of 0.0288
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 0, 4), which had val score of -0.3048
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 1, 0), which had val score of -0.011
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 4), which had val score of -0.2807
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0944
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 1, 0), which had val score of -0.0088
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 0, 4), which had val score of -0.0178
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 1, 0), which had val score of -0.0134
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 1, 0), which had val score of -0.0134
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 1, 4), which had val score of -0.0082
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 1, 4), which had val score of -0.5828
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 0, 0), which had val score of 0.0521
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 1, 0), which had val score of -0.1905
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 1, 0), which had val score of -1.0367
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 0, 0), which had val score of -2.0109
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 4), which had val score of -0.9637
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 1, 4), which had val score of 0.0147
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 0, 5, 0, 4), which had val score of 0.0165
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 5, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 1, 0), which had val score of -0.3226
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 4), which had val score of -2.7
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 0, 4), which had val score of -0.0044
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0), which had val score of -0.0083
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 0, 4), which had val score of 0.0504
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 1, 4), which had val score of -0.2713
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 5, 1, 0), which had val score of 0.0021
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 1, 4), which had val score of -0.0077
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 5, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 0, 0), which had val score of -1.7633
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 5, 0, 0, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 4), which had val score of -0.9689
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 8, 0, 0, 1, 0), which had val score of -1.8697
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 0, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 0), which had val score of -0.5332
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 8, 5, 5, 1, 4), which had val score of -1.2797
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 0), which had val score of -0.3259
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (2, 4, 3, 3, 1, 2), which had val score of 0.0122
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1, 2), which had val score of 0.0963
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 2), which had val score of 0.0726
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1, 2), which had val score of 0.0491
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 4, 3, 1, 2), which had val score of -0.6903
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 2), which had val score of 0.0618
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1, 2), which had val score of 0.0562
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 0, 2), which had val score of 0.0256
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 1), which had val score of 0.009
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 3), which had val score of 0.0856
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 1, 2), which had val score of 0.0401
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 1, 2), which had val score of 0.0852
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 5, 3, 3, 1, 2), which had val score of 0.0587
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 2, 3, 1, 2), which had val score of 0.0963
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 4, 3, 1, 2), which had val score of -0.6903
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 2, 1, 2), which had val score of 0.0883
#         Current best combo: (5, 4, 0, 5, 1, 0) with val score 0.098.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (4, 4, 3, 4, 1, 2) was read in, best_clf is set to None
# Already Trained and Tested combination (4, 4, 3, 4, 1, 2), which had val score of 0.0988
#         Current best combo: (4, 4, 3, 4, 1, 2) with val score 0.0988.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 0, 2), which had val score of 0.0307
#         Current best combo: (4, 4, 3, 4, 1, 2) with val score 0.0988.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (4, 4, 3, 3, 1, 1) was read in, best_clf is set to None
# Already Trained and Tested combination (4, 4, 3, 3, 1, 1), which had val score of 0.1088
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1, 3), which had val score of 0.0824
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 3, 3, 3, 1, 2), which had val score of 0.011
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 1, 2), which had val score of 0.0852
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 3, 3, 1, 2), which had val score of 0.0955
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 2), which had val score of 0.0727
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 1, 2), which had val score of -0.6903
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1, 2), which had val score of 0.0747
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1, 2), which had val score of 0.0726
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 0, 2), which had val score of -0.1407
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 1), which had val score of 0.0165
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 3), which had val score of 0.0984
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 5, 3, 3, 1, 2), which had val score of 0.0092
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 5, 3, 3, 1, 2), which had val score of 0.0587
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 6, 3, 3, 1, 2), which had val score of 0.0305
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 2, 3, 1, 2), which had val score of 0.0491
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 4, 3, 1, 2), which had val score of -0.6903
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 2, 1, 2), which had val score of 0.0373
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 4, 1, 2), which had val score of 0.0472
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 0, 2), which had val score of -0.0193
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1, 1), which had val score of 0.0163
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1, 3), which had val score of 0.078
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 2, 3, 1, 2), which had val score of 0.0122
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 2, 3, 1, 2), which had val score of 0.0963
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 2), which had val score of 0.0727
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 2, 3, 1, 2), which had val score of 0.0491
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 1, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1, 2), which had val score of 0.0618
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1, 2), which had val score of 0.0551
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 0, 2), which had val score of 0.0256
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 1), which had val score of 0.0098
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 3), which had val score of 0.0856
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 3, 2, 1, 2), which had val score of 0.0122
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 2, 1, 2), which had val score of 0.0883
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1, 2), which had val score of 0.0747
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 2, 1, 2), which had val score of 0.0373
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1, 2), which had val score of 0.0618
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 4, 2, 1, 2), which had val score of -0.6903
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 1, 1, 2), which had val score of 0.0069
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 0, 2), which had val score of 0.0602
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 1), which had val score of 0.0178
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 3), which had val score of 0.071
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 3, 4, 1, 2), which had val score of 0.0122
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 4, 1, 2), which had val score of 0.0988
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1, 2), which had val score of 0.0726
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 4, 1, 2), which had val score of 0.0472
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1, 2), which had val score of 0.0551
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 4, 4, 1, 2), which had val score of -0.6903
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 5, 1, 2), which had val score of 0.0562
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 0, 2), which had val score of 0.023
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1, 1), which had val score of 0.009
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1, 3), which had val score of 0.0903
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 3, 3, 1, 3), which had val score of 0.0223
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1, 3), which had val score of 0.0824
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 3), which had val score of 0.0984
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1, 3), which had val score of 0.078
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 3), which had val score of 0.0856
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 4, 3, 1, 3), which had val score of -0.8097
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 3), which had val score of 0.071
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1, 3), which had val score of 0.0903
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 0, 3), which had val score of 0.0259
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0379
#         Current best combo: (4, 4, 3, 3, 1, 1) with val score 0.1088.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (3, 4, 3, 3, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 4, 3, 3, 1, 4), which had val score of 0.1122
#         Current best combo: (3, 4, 3, 3, 1, 4) with val score 0.1122.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 3, 3, 1, 4), which had val score of 0.0246
#         Current best combo: (3, 4, 3, 3, 1, 4) with val score 0.1122.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 1, 4), which had val score of 0.0775
#         Current best combo: (3, 4, 3, 3, 1, 4) with val score 0.1122.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (3, 3, 3, 3, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 3, 3, 1, 4), which had val score of 0.1124
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1124.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1, 4), which had val score of 0.1041
#         Current best combo: (3, 3, 3, 3, 1, 4) with val score 0.1124.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (3, 4, 2, 3, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 4, 2, 3, 1, 4), which had val score of 0.1136
#         Current best combo: (3, 4, 2, 3, 1, 4) with val score 0.1136.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 4, 3, 1, 4), which had val score of -1.2797
#         Current best combo: (3, 4, 2, 3, 1, 4) with val score 0.1136.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 1, 4), which had val score of 0.1122
#         Current best combo: (3, 4, 2, 3, 1, 4) with val score 0.1136.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1, 4), which had val score of 0.1122
#         Current best combo: (3, 4, 2, 3, 1, 4) with val score 0.1136.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 0, 4), which had val score of 0.0204
#         Current best combo: (3, 4, 2, 3, 1, 4) with val score 0.1136.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 3), which had val score of 0.0856
#         Current best combo: (3, 4, 2, 3, 1, 4) with val score 0.1136.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 4, 2, 3, 1, 4), which had val score of 0.0394
#         Current best combo: (3, 4, 2, 3, 1, 4) with val score 0.1136.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 4, 2, 3, 1, 4), which had val score of 0.0775
#         Current best combo: (3, 4, 2, 3, 1, 4) with val score 0.1136.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (3, 3, 2, 3, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 3, 1, 4), which had val score of 0.1153
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 2, 3, 1, 4), which had val score of 0.106
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 1, 3, 1, 4), which had val score of 0.1138
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 4), which had val score of 0.1122
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1, 4), which had val score of 0.1136
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1, 4), which had val score of 0.1136
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 0, 4), which had val score of 0.0204
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 3), which had val score of 0.0856
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 3, 2, 3, 1, 4), which had val score of 0.045
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 1, 4), which had val score of 0.0479
#         Current best combo: (3, 3, 2, 3, 1, 4) with val score 0.1153.
#         Has trained 271 of 19440 combinations so far
# As new Best Combo (3, 2, 2, 3, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 2, 2, 3, 1, 4), which had val score of 0.1234
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 4), which had val score of 0.1136
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 1, 4), which had val score of 0.115
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 4), which had val score of 0.1124
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 4), which had val score of 0.114
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 1, 4), which had val score of 0.1153
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 0, 4), which had val score of -0.1634
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 3), which had val score of 0.0984
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 2, 2, 3, 1, 4), which had val score of 0.0522
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 2, 2, 3, 1, 4), which had val score of 0.0713
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 1, 2, 3, 1, 4), which had val score of 0.0826
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 4), which had val score of 0.1153
#         Current best combo: (3, 2, 2, 3, 1, 4) with val score 0.1234.
#         Has trained 271 of 19440 combinations so far
# ...
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 3, 1, 0), which had val score of 0.0977
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 5, 1, 0), which had val score of 0.098
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0, 0), which had val score of 0.0348
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 1, 1), which had val score of 0.0418
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# % Combos Checked Thus Far: 271 out of 19440 which is 1.394033%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Already Trained and Tested combination (1, 4, 0, 5, 0, 4), which had val score of 0.0779
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 3, 0, 5, 0, 4), which had val score of 0.0603
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 0, 4), which had val score of 0.0919
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 5, 0, 4), which had val score of 0.0944
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 4, 0, 4), which had val score of 0.0919
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 1, 4), which had val score of -0.0082
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 3), which had val score of 0.0702
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# 	round 2 iteration:  1
#
# Already Trained and Tested combination (1, 5, 0, 5, 0, 4), which had val score of 0.0714
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0944
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 6, 0, 5, 0, 4), which had val score of 0.0411
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 1, 5, 0, 4), which had val score of 0.0918
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 4, 0, 4), which had val score of 0.0918
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 1, 4), which had val score of -0.0079
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 0, 3), which had val score of 0.0715
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (1, 4, 1, 5, 0, 4), which had val score of 0.0778
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 3, 1, 5, 0, 4), which had val score of 0.0604
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 1, 5, 0, 4), which had val score of 0.0918
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0944
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 2, 5, 0, 4), which had val score of 0.0944
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 4, 0, 4), which had val score of 0.0919
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 5, 1, 4), which had val score of -0.0082
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 5, 0, 3), which had val score of 0.0701
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (1, 4, 0, 4, 0, 4), which had val score of 0.0779
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 4), which had val score of 0.0603
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 5, 0, 4, 0, 4), which had val score of 0.0918
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 1, 4, 0, 4), which had val score of 0.0919
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 3, 0, 4), which had val score of 0.0896
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 5, 0, 4), which had val score of 0.0944
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 4, 1, 4), which had val score of -0.0082
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (0, 4, 0, 4, 0, 3), which had val score of 0.0751
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# % Combos Checked Thus Far: 271 out of 19440 which is 1.394033%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (2, 2, 0, 4, 1, 4), which had val score of 0.0521
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 2, 0, 4, 1, 4), which had val score of 0.0724
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 1, 0, 4, 1, 4), which had val score of 0.0811
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 4), which had val score of 0.1152
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 1, 4, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 3, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 5, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 4, 0, 4), which had val score of 0.0719
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 4, 1, 3), which had val score of 0.1065
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (2, 2, 1, 4, 1, 4), which had val score of 0.0522
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 2, 1, 4, 1, 4), which had val score of 0.0724
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 1, 1, 4, 1, 4), which had val score of 0.0812
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 1, 4, 1, 4), which had val score of 0.1152
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 4, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 2, 4, 1, 4), which had val score of 0.1234
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 1, 5, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 1, 4, 0, 4), which had val score of 0.0719
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 1, 4, 1, 3), which had val score of 0.1064
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 2, 0, 3, 1, 4), which had val score of 0.0521
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 2, 0, 3, 1, 4), which had val score of 0.0713
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 1, 0, 3, 1, 4), which had val score of 0.0812
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 0, 3, 1, 4), which had val score of 0.115
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 1, 4), which had val score of 0.1233
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 4, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 3, 0, 4), which had val score of 0.0801
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 3, 1, 3), which had val score of 0.1065
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (2, 2, 0, 5, 1, 4), which had val score of 0.0521
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (4, 2, 0, 5, 1, 4), which had val score of 0.0717
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 1, 0, 5, 1, 4), which had val score of 0.0811
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 0, 5, 1, 4), which had val score of 0.1156
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 1, 5, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 4, 1, 4), which had val score of 0.125
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 5, 0, 4), which had val score of 0.0704
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# Already Trained and Tested combination (3, 2, 0, 5, 1, 3), which had val score of 0.1065
#         Current best combo: (3, 2, 0, 4, 1, 4) with val score 0.125.
#         Has trained 271 of 19440 combinations so far
# % Combos Checked Thus Far: 271 out of 19440 which is 1.394033%
# Max Score:
#  0.125032
# Max Test Score:
#  0.056539
# Max Combo Index:
#  (3, 2, 0, 4, 1, 4) out of [6, 9, 6, 6, 2, 5] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.1, 'degree': 3, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'nu': 0.9}
# % Combos Checked: 271 out of 19440 which is 1.394033%
