# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'cb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'google-bert_bert-base-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from catboost import CatBoostRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {

    'n_estimators': (25, 50, 100, 200),
    'max_depth': (2, 4, 8, 16),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bylevel': (0.4, 0.55, 0.7, 0.85, 1),
    'max_bin': (64, 256),
    'reg_lambda': (0.01, 0.1, 1),
    'learning_rate': (0.001, 0.01, 0.1, 1),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
      'random_state': 19260817,
      'verbose': False
      }
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/sunkings126.com/Desktop/University/Year_1/Clubs/cssa/CSSA-ArticleTitleScoring__Groupwork__Py/notebooks/tuning/title_googlebert/YZ-CB.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/Users/sunkings126.com/Desktop/University/Year_1/Clubs/cssa/CSSA-ArticleTitleScoring__Groupwork__Py/notebooks/tuning/title_googlebert/YZ-CB.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # model to use to tune
# ----> <a href='vscode-notebook-cell:/Users/sunkings126.com/Desktop/University/Year_1/Clubs/cssa/CSSA-ArticleTitleScoring__Groupwork__Py/notebooks/tuning/title_googlebert/YZ-CB.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> from catboost import CatBoostRegressor as clf
#       <a href='vscode-notebook-cell:/Users/sunkings126.com/Desktop/University/Year_1/Clubs/cssa/CSSA-ArticleTitleScoring__Groupwork__Py/notebooks/tuning/title_googlebert/YZ-CB.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> # what values to try for each hyperparameter
#       <a href='vscode-notebook-cell:/Users/sunkings126.com/Desktop/University/Year_1/Clubs/cssa/CSSA-ArticleTitleScoring__Groupwork__Py/notebooks/tuning/title_googlebert/YZ-CB.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> parameter_choices = {
#       <a href='vscode-notebook-cell:/Users/sunkings126.com/Desktop/University/Year_1/Clubs/cssa/CSSA-ArticleTitleScoring__Groupwork__Py/notebooks/tuning/title_googlebert/YZ-CB.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>
#       <a href='vscode-notebook-cell:/Users/sunkings126.com/Desktop/University/Year_1/Clubs/cssa/CSSA-ArticleTitleScoring__Groupwork__Py/notebooks/tuning/title_googlebert/YZ-CB.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>     'n_estimators': (25, 50, 100, 200),
#    (...)
#      <a href='vscode-notebook-cell:/Users/sunkings126.com/Desktop/University/Year_1/Clubs/cssa/CSSA-ArticleTitleScoring__Groupwork__Py/notebooks/tuning/title_googlebert/YZ-CB.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a>
#      <a href='vscode-notebook-cell:/Users/sunkings126.com/Desktop/University/Year_1/Clubs/cssa/CSSA-ArticleTitleScoring__Groupwork__Py/notebooks/tuning/title_googlebert/YZ-CB.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> }
#
# ModuleNotFoundError: No module named 'catboost'

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'catboost.core.CatBoostRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# Successfully read in tuning result of 874 rows, for 874.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Already Trained and Tested combination (0, 3, 4, 0, 1, 2, 3), which had val score of -0.0815
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 1, 0, 0), which had val score of -0.0046
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 0, 3), which had val score of -0.6626
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 1, 0, 3), which had val score of -0.3566
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 0, 0, 3), which had val score of -0.1987
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 0, 2, 3), which had val score of -0.4254
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 0, 3), which had val score of -0.2199
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 1, 2, 3), which had val score of 0.0244
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 0, 0, 0), which had val score of 0.0059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 2, 0), which had val score of -0.0072
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 0, 3), which had val score of -0.3701
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 2, 0), which had val score of -0.0064
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 0, 3), which had val score of -0.5356
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 1, 2, 0), which had val score of -0.0011
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 0, 3), which had val score of -0.3701
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 0, 0, 0), which had val score of 0.0149
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 1, 0, 0), which had val score of 0.0028
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 1, 2, 3), which had val score of -0.0351
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 2, 3), which had val score of -0.1948
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 2, 0), which had val score of 0.0066
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 2, 0), which had val score of -0.0068
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 1, 2, 3), which had val score of -0.1318
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 2, 3), which had val score of -0.0476
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 1, 0, 3), which had val score of -0.0946
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 0), which had val score of 0.0074
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0, 0), which had val score of -0.0074
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 0, 0), which had val score of -0.0071
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 0, 2, 0), which had val score of 0.0047
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 0, 3), which had val score of -0.3885
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 0, 0), which had val score of -0.0074
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 0, 0), which had val score of 0.0141
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 1, 0, 3), which had val score of -0.0624
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 0, 3), which had val score of -0.3885
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 3), which had val score of 0.0235
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0, 3), which had val score of -0.7232
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 2, 0), which had val score of -0.0074
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 0, 0), which had val score of -0.0048
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 0, 0), which had val score of -0.0063
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 2, 0), which had val score of -0.0068
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 1, 2, 3), which had val score of -0.2179
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 2, 0), which had val score of -0.0075
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 1, 0, 0), which had val score of -0.0003
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 2, 3), which had val score of -0.0985
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 1, 2, 0), which had val score of 0.0076
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 0, 2, 3), which had val score of -0.3664
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 1, 2, 3), which had val score of -0.29
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 1, 0, 3), which had val score of -0.2511
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 2, 0), which had val score of -0.0072
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 1, 0, 3), which had val score of -0.3834
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 2, 0), which had val score of 0.0084
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 2, 3), which had val score of -0.0073
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 2, 3), which had val score of -0.1459
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 2, 0), which had val score of 0.0012
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 1, 0, 3), which had val score of 0.0095
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 1, 0, 0), which had val score of -0.0068
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 2, 3), which had val score of 0.0235
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 1, 0, 3), which had val score of -0.0955
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 0, 3), which had val score of -0.1484
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 2, 0), which had val score of -0.007
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 1, 2, 0), which had val score of -0.0074
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 0, 0), which had val score of -0.0059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 1, 0, 0), which had val score of 0.0001
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 0, 2, 0), which had val score of 0.0052
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 0, 0, 3), which had val score of -0.4756
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 0, 3), which had val score of -0.0946
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 2, 0), which had val score of -0.0062
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 1, 0, 3), which had val score of -0.6553
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 3), which had val score of -0.5859
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 1, 0, 3), which had val score of -0.4511
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 0, 0), which had val score of 0.0184
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 1, 2, 3), which had val score of -0.0073
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 0, 2, 3), which had val score of -0.0985
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 1, 0, 3), which had val score of -0.142
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 1, 2, 0), which had val score of -0.0069
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 0, 0), which had val score of 0.017
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 1, 0, 0), which had val score of 0.0034
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 0, 0), which had val score of -0.0045
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 1, 2, 3), which had val score of -0.1992
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 2, 3), which had val score of -0.3973
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 2, 3), which had val score of -0.3286
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 2, 0), which had val score of 0.0057
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 1, 0, 0), which had val score of 0.0161
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 2, 3), which had val score of -0.4656
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 0, 3), which had val score of -0.7232
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 2, 0), which had val score of 0.0035
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 1, 0, 3), which had val score of -0.6553
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 0, 2, 0), which had val score of -0.0002
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 0, 0), which had val score of 0.0153
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 1, 0, 0), which had val score of 0.0143
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 0, 3), which had val score of -0.6946
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 1, 2, 3), which had val score of -0.2933
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 1, 2, 0), which had val score of -0.0003
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 2, 3), which had val score of -0.1948
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0, 0), which had val score of -0.0046
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 1, 2, 3), which had val score of -0.1992
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 1, 2, 0), which had val score of 0.0023
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 1, 2, 0), which had val score of -0.0071
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 0, 0, 3), which had val score of -0.6262
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 1, 2, 0), which had val score of -0.0066
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 0, 3), which had val score of -0.1484
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 1, 2, 0), which had val score of 0.006
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 1, 0, 0), which had val score of -0.0072
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0, 3), which had val score of -0.0339
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 1, 0, 0), which had val score of -0.0072
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 0), which had val score of -0.0071
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 0, 0), which had val score of 0.0182
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 2, 3), which had val score of -0.0476
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 2, 3), which had val score of -0.1459
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 0, 0), which had val score of -0.0049
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 2, 3), which had val score of -0.1526
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 0, 0), which had val score of -0.0073
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 0, 3), which had val score of 0.0095
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 2, 3), which had val score of -0.2405
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 1, 0, 0), which had val score of -0.0053
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 1, 2, 3), which had val score of -0.0932
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 0, 2, 3), which had val score of -0.3623
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 0, 0, 3), which had val score of -0.2979
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 1, 2, 0), which had val score of -0.0073
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 0, 0, 0), which had val score of 0.0043
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 0, 3), which had val score of -0.2979
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 2, 0), which had val score of -0.0075
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 2, 3), which had val score of 0.0543
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 1, 2, 3), which had val score of -0.0815
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 0, 2, 0), which had val score of 0.0037
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 0, 0, 0), which had val score of 0.0001
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 2, 0), which had val score of -0.0067
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 0, 0, 0), which had val score of 0.0016
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (3, 0, 4, 4, 1, 2, 0), which had val score of 0.0028
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 1, 1, 2), which had val score of 0.0055
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 877 of 9600 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# % Combos Checked Thus Far: 877 out of 9600 which is 9.135417%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 128
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 878 of 9600: (2, 3, 0, 0, 0, 2, 0), taking 11.89 seconds to get val score of -0.0006
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 2, 0, 0, 0, 2, 0), which had val score of 0.0086
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 878 of 9600 combinations so far
# Trained and Tested combination 879 of 9600: (3, 3, 1, 0, 0, 2, 0), taking 26.11 seconds to get val score of 0.0034
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 880 of 9600: (3, 3, 0, 1, 0, 2, 0), taking 39.74 seconds to get val score of 0.0051
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 0, 0, 1, 2, 0), which had val score of 0.0076
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 880 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 1, 0), which had val score of 0.0135
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 880 of 9600 combinations so far
# Trained and Tested combination 881 of 9600: (3, 3, 0, 0, 0, 2, 1), taking 27.6 seconds to get val score of 0.0813
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# 	round 1 iteration:  1
#
# Trained and Tested combination 882 of 9600: (2, 3, 0, 1, 0, 2, 0), taking 18.99 seconds to get val score of -0.0017
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 883 of 9600: (3, 2, 0, 1, 0, 2, 0), taking 0.52 seconds to get val score of 0.0071
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 884 of 9600: (3, 3, 1, 1, 0, 2, 0), taking 35.87 seconds to get val score of 0.0059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 0, 0, 0, 2, 0), which had val score of 0.0084
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 884 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 2, 0, 2, 0), which had val score of 0.0059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 884 of 9600 combinations so far
# Trained and Tested combination 885 of 9600: (3, 3, 0, 1, 1, 2, 0), taking 94.56 seconds to get val score of 0.007
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 886 of 9600: (3, 3, 0, 1, 0, 1, 0), taking 35.78 seconds to get val score of 0.0162
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 887 of 9600: (3, 3, 0, 1, 0, 2, 1), taking 34.08 seconds to get val score of 0.059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 888 of 9600: (2, 3, 0, 0, 1, 2, 0), taking 28.33 seconds to get val score of -0.0
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 889 of 9600: (3, 2, 0, 0, 1, 2, 0), taking 0.74 seconds to get val score of 0.0087
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 890 of 9600: (3, 3, 1, 0, 1, 2, 0), taking 64.69 seconds to get val score of 0.0073
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 0, 1, 1, 2, 0), which had val score of 0.007
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 890 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 0, 2, 0), which had val score of 0.0084
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 890 of 9600 combinations so far
# Trained and Tested combination 891 of 9600: (3, 3, 0, 0, 1, 1, 0), taking 59.36 seconds to get val score of 0.0136
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 892 of 9600: (3, 3, 0, 0, 1, 2, 1), taking 62.62 seconds to get val score of 0.0724
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 893 of 9600: (2, 3, 0, 0, 0, 2, 1), taking 12.34 seconds to get val score of 0.063
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 894 of 9600: (3, 2, 0, 0, 0, 2, 1), taking 0.47 seconds to get val score of 0.0863
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 895 of 9600: (3, 3, 1, 0, 0, 2, 1), taking 27.6 seconds to get val score of 0.0519
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 0, 1, 0, 2, 1), which had val score of 0.059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 895 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 0, 0, 1, 2, 1), which had val score of 0.0724
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 895 of 9600 combinations so far
# Trained and Tested combination 896 of 9600: (3, 3, 0, 0, 0, 1, 1), taking 30.29 seconds to get val score of 0.0593
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 0, 0, 0, 2, 0), which had val score of 0.0084
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 896 of 9600 combinations so far
# Trained and Tested combination 897 of 9600: (3, 3, 0, 0, 0, 2, 2), taking 29.97 seconds to get val score of 0.0392
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# % Combos Checked Thus Far: 897 out of 9600 which is 9.34375%
# Cruising Coordrdinate 0 of 128
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 898 of 9600: (2, 3, 4, 0, 0, 0, 0), taking 12.65 seconds to get val score of 0.008
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 2, 4, 0, 0, 0, 0), which had val score of 0.0186
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 898 of 9600 combinations so far
# Trained and Tested combination 899 of 9600: (3, 3, 3, 0, 0, 0, 0), taking 23.69 seconds to get val score of 0.0177
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 900 of 9600: (3, 3, 4, 1, 0, 0, 0), taking 37.1 seconds to get val score of 0.013
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 4, 0, 1, 0, 0), which had val score of 0.0182
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 900 of 9600 combinations so far
# Trained and Tested combination 901 of 9600: (3, 3, 4, 0, 0, 1, 0), taking 25.77 seconds to get val score of 0.0168
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 902 of 9600: (3, 3, 4, 0, 0, 0, 1), taking 24.13 seconds to get val score of 0.0765
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# 	round 2 iteration:  1
#
# Trained and Tested combination 903 of 9600: (2, 3, 3, 0, 0, 0, 0), taking 12.17 seconds to get val score of 0.0069
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 904 of 9600: (3, 2, 3, 0, 0, 0, 0), taking 0.39 seconds to get val score of 0.0196
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 2, 0, 0, 0, 0), which had val score of 0.017
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 904 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 0, 0), which had val score of 0.0184
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 904 of 9600 combinations so far
# Trained and Tested combination 905 of 9600: (3, 3, 3, 1, 0, 0, 0), taking 34.35 seconds to get val score of 0.016
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 906 of 9600: (3, 3, 3, 0, 1, 0, 0), taking 58.93 seconds to get val score of 0.0159
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 907 of 9600: (3, 3, 3, 0, 0, 1, 0), taking 22.43 seconds to get val score of 0.0163
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 908 of 9600: (3, 3, 3, 0, 0, 0, 1), taking 25.76 seconds to get val score of 0.0846
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 909 of 9600: (2, 3, 4, 0, 1, 0, 0), taking 26.53 seconds to get val score of 0.0059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 910 of 9600: (3, 2, 4, 0, 1, 0, 0), taking 0.66 seconds to get val score of 0.0184
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 3, 0, 1, 0, 0), which had val score of 0.0159
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 910 of 9600 combinations so far
# Trained and Tested combination 911 of 9600: (3, 3, 4, 1, 1, 0, 0), taking 74.2 seconds to get val score of 0.0177
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 4, 0, 0, 0, 0), which had val score of 0.0184
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 911 of 9600 combinations so far
# Trained and Tested combination 912 of 9600: (3, 3, 4, 0, 1, 1, 0), taking 52.87 seconds to get val score of 0.0137
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 913 of 9600: (3, 3, 4, 0, 1, 0, 1), taking 54.42 seconds to get val score of 0.0661
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 914 of 9600: (2, 3, 4, 0, 0, 1, 0), taking 11.41 seconds to get val score of 0.007
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 915 of 9600: (3, 2, 4, 0, 0, 1, 0), taking 0.41 seconds to get val score of 0.0168
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 3, 0, 0, 1, 0), which had val score of 0.0163
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 915 of 9600 combinations so far
# Trained and Tested combination 916 of 9600: (3, 3, 4, 1, 0, 1, 0), taking 37.88 seconds to get val score of 0.0115
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 4, 0, 1, 1, 0), which had val score of 0.0137
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 916 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 0, 0), which had val score of 0.0184
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 916 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 0), which had val score of 0.0074
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 916 of 9600 combinations so far
# Trained and Tested combination 917 of 9600: (3, 3, 4, 0, 0, 1, 1), taking 24.84 seconds to get val score of 0.0699
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 918 of 9600: (2, 3, 4, 0, 0, 0, 1), taking 12.17 seconds to get val score of 0.0687
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 919 of 9600: (3, 2, 4, 0, 0, 0, 1), taking 0.44 seconds to get val score of 0.1037
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 3, 0, 0, 0, 1), which had val score of 0.0846
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 919 of 9600 combinations so far
# Trained and Tested combination 920 of 9600: (3, 3, 4, 1, 0, 0, 1), taking 36.81 seconds to get val score of 0.0543
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 4, 0, 1, 0, 1), which had val score of 0.0661
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 920 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 1, 1), which had val score of 0.0699
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 920 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 0, 0), which had val score of 0.0184
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 920 of 9600 combinations so far
# Trained and Tested combination 921 of 9600: (3, 3, 4, 0, 0, 0, 2), taking 24.71 seconds to get val score of 0.0195
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# % Combos Checked Thus Far: 921 out of 9600 which is 9.59375%
# Cruising Coordrdinate 0 of 128
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 922 of 9600: (2, 3, 4, 0, 0, 2, 0), taking 10.68 seconds to get val score of 0.0
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 2, 4, 0, 0, 2, 0), which had val score of 0.0111
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 922 of 9600 combinations so far
# Trained and Tested combination 923 of 9600: (3, 3, 3, 0, 0, 2, 0), taking 24.12 seconds to get val score of 0.0062
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 924 of 9600: (3, 3, 4, 1, 0, 2, 0), taking 36.29 seconds to get val score of 0.0059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 4, 0, 1, 2, 0), which had val score of 0.0057
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 924 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 1, 0), which had val score of 0.0168
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 924 of 9600 combinations so far
# Trained and Tested combination 925 of 9600: (3, 3, 4, 0, 0, 2, 1), taking 24.21 seconds to get val score of 0.0672
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# 	round 3 iteration:  1
#
# Trained and Tested combination 926 of 9600: (2, 3, 3, 0, 0, 2, 0), taking 11.27 seconds to get val score of -0.0023
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 927 of 9600: (3, 2, 3, 0, 0, 2, 0), taking 0.4 seconds to get val score of 0.0117
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 928 of 9600: (3, 3, 2, 0, 0, 2, 0), taking 27.48 seconds to get val score of 0.0064
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 0), which had val score of 0.0074
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 928 of 9600 combinations so far
# Trained and Tested combination 929 of 9600: (3, 3, 3, 1, 0, 2, 0), taking 37.88 seconds to get val score of 0.0063
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 930 of 9600: (3, 3, 3, 0, 1, 2, 0), taking 60.47 seconds to get val score of 0.0059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 3, 0, 0, 1, 0), which had val score of 0.0163
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 930 of 9600 combinations so far
# Trained and Tested combination 931 of 9600: (3, 3, 3, 0, 0, 2, 1), taking 25.98 seconds to get val score of 0.0743
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 932 of 9600: (2, 3, 4, 1, 0, 2, 0), taking 17.51 seconds to get val score of -0.0017
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 933 of 9600: (3, 2, 4, 1, 0, 2, 0), taking 0.48 seconds to get val score of 0.0088
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 3, 1, 0, 2, 0), which had val score of 0.0063
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 933 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 0), which had val score of 0.0074
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 933 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 2, 0, 2, 0), which had val score of 0.0066
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 933 of 9600 combinations so far
# Trained and Tested combination 934 of 9600: (3, 3, 4, 1, 1, 2, 0), taking 95.57 seconds to get val score of 0.005
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 4, 1, 0, 1, 0), which had val score of 0.0115
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 934 of 9600 combinations so far
# Trained and Tested combination 935 of 9600: (3, 3, 4, 1, 0, 2, 1), taking 35.18 seconds to get val score of 0.0546
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 936 of 9600: (2, 3, 4, 0, 1, 2, 0), taking 34.13 seconds to get val score of -0.0017
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Trained and Tested combination 937 of 9600: (3, 2, 4, 0, 1, 2, 0), taking 0.77 seconds to get val score of 0.0129
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976
# Already Trained and Tested combination (3, 3, 3, 0, 1, 2, 0), which had val score of 0.0059
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 937 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 1, 1, 2, 0), which had val score of 0.005
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
#         Has trained 937 of 9600 combinations so far
# Already Trained and Tested combination (3, 3, 4, 0, 0, 2, 0), which had val score of 0.0074
#         Current best combo: (1, 2, 2, 0, 1, 1, 2) with val score 0.1976.
# ...
#         Has trained 1216 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 1, 3), which had val score of -0.1191
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1216 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 2, 2), which had val score of 0.0754
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1216 of 9600 combinations so far
# % Combos Checked Thus Far: 1216 out of 9600 which is 12.666667%
# Cruising Coordrdinate 0 of 128
#
# Cruise suspended due to suspicious case
# Guidance: round 33
#
# 	round 33 iteration:  0
#
# Already Trained and Tested combination (1, 3, 0, 0, 0, 2, 3), which had val score of -0.0476
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1216 of 9600 combinations so far
# Trained and Tested combination 1217 of 9600: (0, 2, 0, 0, 0, 2, 3), taking 0.08 seconds to get val score of -0.7501
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1218 of 9600: (0, 3, 1, 0, 0, 2, 3), taking 3.33 seconds to get val score of -0.0204
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1219 of 9600: (0, 3, 0, 1, 0, 2, 3), taking 4.4 seconds to get val score of -0.0824
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Already Trained and Tested combination (0, 3, 0, 0, 1, 2, 3), which had val score of -0.0073
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1219 of 9600 combinations so far
# Trained and Tested combination 1220 of 9600: (0, 3, 0, 0, 0, 1, 3), taking 2.71 seconds to get val score of -0.2733
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1221 of 9600: (0, 3, 0, 0, 0, 2, 2), taking 2.11 seconds to get val score of 0.0343
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# 	round 33 iteration:  1
#
# Trained and Tested combination 1222 of 9600: (1, 3, 1, 0, 0, 2, 3), taking 6.85 seconds to get val score of -0.0204
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1223 of 9600: (0, 2, 1, 0, 0, 2, 3), taking 0.1 seconds to get val score of -0.127
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Already Trained and Tested combination (0, 3, 0, 0, 0, 2, 3), which had val score of -0.0476
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1223 of 9600 combinations so far
# Trained and Tested combination 1224 of 9600: (0, 3, 2, 0, 0, 2, 3), taking 3.88 seconds to get val score of -0.026
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1225 of 9600: (0, 3, 1, 1, 0, 2, 3), taking 5.84 seconds to get val score of 0.0141
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Already Trained and Tested combination (0, 3, 1, 0, 1, 2, 3), which had val score of -0.0643
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1225 of 9600 combinations so far
# Trained and Tested combination 1226 of 9600: (0, 3, 1, 0, 0, 1, 3), taking 2.93 seconds to get val score of -0.0184
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1227 of 9600: (0, 3, 1, 0, 0, 2, 2), taking 3.31 seconds to get val score of 0.116
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1228 of 9600: (1, 3, 0, 0, 0, 2, 2), taking 5.2 seconds to get val score of 0.0394
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1229 of 9600: (0, 2, 0, 0, 0, 2, 2), taking 0.09 seconds to get val score of -0.0132
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Already Trained and Tested combination (0, 3, 1, 0, 0, 2, 2), which had val score of 0.116
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1229 of 9600 combinations so far
# Trained and Tested combination 1230 of 9600: (0, 3, 0, 1, 0, 2, 2), taking 5.23 seconds to get val score of 0.0106
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Already Trained and Tested combination (0, 3, 0, 0, 1, 2, 2), which had val score of 0.0754
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1230 of 9600 combinations so far
# Trained and Tested combination 1231 of 9600: (0, 3, 0, 0, 0, 1, 2), taking 2.74 seconds to get val score of 0.0495
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Already Trained and Tested combination (0, 3, 0, 0, 0, 2, 1), which had val score of 0.0157
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1231 of 9600 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 2, 3), which had val score of -0.0476
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987.
#         Has trained 1231 of 9600 combinations so far
# % Combos Checked Thus Far: 1231 out of 9600 which is 12.822917%
# Cruising Coordrdinate 0 of 128
#
# Cruise suspended due to suspicious case
# Guidance: round 34
#
# 	round 34 iteration:  0
#
# Trained and Tested combination 1232 of 9600: (1, 0, 0, 0, 1, 0, 3), taking 0.05 seconds to get val score of -0.0189
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1233 of 9600: (0, 1, 0, 0, 1, 0, 3), taking 0.06 seconds to get val score of -1.1895
#         Current best combo: (1, 0, 0, 1, 0, 2, 3) with val score 0.1987
# Trained and Tested combination 1234 of 9600: (0, 0, 1, 0, 1, 0, 3), taking 0.05 seconds to get val score of 0.2117
#         Current best combo: (0, 0, 1, 0, 1, 0, 3) with val score 0.2117
# Trained and Tested combination 1235 of 9600: (0, 0, 0, 1, 1, 0, 3), taking 0.05 seconds to get val score of -0.473
#         Current best combo: (0, 0, 1, 0, 1, 0, 3) with val score 0.2117
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 3), which had val score of -0.5859
#         Current best combo: (0, 0, 1, 0, 1, 0, 3) with val score 0.2117.
#         Has trained 1235 of 9600 combinations so far
# Trained and Tested combination 1236 of 9600: (0, 0, 0, 0, 1, 1, 3), taking 0.05 seconds to get val score of -0.2561
#         Current best combo: (0, 0, 1, 0, 1, 0, 3) with val score 0.2117
# Trained and Tested combination 1237 of 9600: (0, 0, 0, 0, 1, 0, 2), taking 0.05 seconds to get val score of 0.0718
#         Current best combo: (0, 0, 1, 0, 1, 0, 3) with val score 0.2117
# 	round 34 iteration:  1
#
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0, 3), which had val score of -0.0339
#         Current best combo: (0, 0, 1, 0, 1, 0, 3) with val score 0.2117.
#         Has trained 1237 of 9600 combinations so far
# Trained and Tested combination 1238 of 9600: (2, 0, 0, 0, 1, 0, 3), taking 0.08 seconds to get val score of -0.1845
#         Current best combo: (0, 0, 1, 0, 1, 0, 3) with val score 0.2117
# Trained and Tested combination 1239 of 9600: (1, 1, 0, 0, 1, 0, 3), taking 0.06 seconds to get val score of -1.233
#         Current best combo: (0, 0, 1, 0, 1, 0, 3) with val score 0.2117
# Trained and Tested combination 1240 of 9600: (1, 0, 1, 0, 1, 0, 3), taking 0.06 seconds to get val score of 0.2363
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1241 of 9600: (1, 0, 0, 1, 1, 0, 3), taking 0.05 seconds to get val score of -0.4775
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1242 of 9600: (1, 0, 0, 0, 0, 0, 3), taking 0.05 seconds to get val score of -0.6297
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1243 of 9600: (1, 0, 0, 0, 1, 1, 3), taking 0.06 seconds to get val score of -0.3336
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1244 of 9600: (1, 0, 0, 0, 1, 0, 2), taking 0.06 seconds to get val score of 0.096
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Already Trained and Tested combination (1, 0, 1, 0, 1, 0, 3), which had val score of 0.2363
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1244 of 9600 combinations so far
# Trained and Tested combination 1245 of 9600: (0, 1, 1, 0, 1, 0, 3), taking 0.06 seconds to get val score of -0.1294
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0, 3), which had val score of -0.0339
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1245 of 9600 combinations so far
# Trained and Tested combination 1246 of 9600: (0, 0, 2, 0, 1, 0, 3), taking 0.05 seconds to get val score of -0.0544
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1247 of 9600: (0, 0, 1, 1, 1, 0, 3), taking 0.04 seconds to get val score of -0.044
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1248 of 9600: (0, 0, 1, 0, 0, 0, 3), taking 0.05 seconds to get val score of -0.5922
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1249 of 9600: (0, 0, 1, 0, 1, 1, 3), taking 0.05 seconds to get val score of 0.1298
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1250 of 9600: (0, 0, 1, 0, 1, 0, 2), taking 0.1 seconds to get val score of 0.0764
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Already Trained and Tested combination (1, 0, 0, 0, 1, 0, 2), which had val score of 0.096
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1250 of 9600 combinations so far
# Trained and Tested combination 1251 of 9600: (0, 1, 0, 0, 1, 0, 2), taking 0.09 seconds to get val score of 0.0787
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Already Trained and Tested combination (0, 0, 1, 0, 1, 0, 2), which had val score of 0.0764
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1251 of 9600 combinations so far
# Trained and Tested combination 1252 of 9600: (0, 0, 0, 1, 1, 0, 2), taking 0.05 seconds to get val score of 0.0438
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 2), which had val score of 0.0857
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1252 of 9600 combinations so far
# Trained and Tested combination 1253 of 9600: (0, 0, 0, 0, 1, 1, 2), taking 0.05 seconds to get val score of 0.0873
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0, 1), which had val score of 0.0066
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1253 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 1, 0, 3), which had val score of -0.0339
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1253 of 9600 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 1, 0, 3), which had val score of 0.2117
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1253 of 9600 combinations so far
# Trained and Tested combination 1254 of 9600: (2, 0, 1, 0, 1, 0, 3), taking 0.08 seconds to get val score of 0.1527
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1255 of 9600: (1, 1, 1, 0, 1, 0, 3), taking 0.07 seconds to get val score of -0.1603
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Already Trained and Tested combination (1, 0, 0, 0, 1, 0, 3), which had val score of -0.0189
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1255 of 9600 combinations so far
# Trained and Tested combination 1256 of 9600: (1, 0, 2, 0, 1, 0, 3), taking 0.06 seconds to get val score of -0.1491
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1257 of 9600: (1, 0, 1, 1, 1, 0, 3), taking 0.06 seconds to get val score of 0.0849
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1258 of 9600: (1, 0, 1, 0, 0, 0, 3), taking 0.05 seconds to get val score of -0.5313
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1259 of 9600: (1, 0, 1, 0, 1, 1, 3), taking 0.06 seconds to get val score of 0.1248
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# Trained and Tested combination 1260 of 9600: (1, 0, 1, 0, 1, 0, 2), taking 0.06 seconds to get val score of 0.1186
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363
# % Combos Checked Thus Far: 1260 out of 9600 which is 13.125%
# Cruising Coordrdinate 0 of 128
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (0, 0, 1, 0, 1, 0, 3), which had val score of 0.2117
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1260 of 9600 combinations so far
# Already Trained and Tested combination (2, 0, 1, 0, 1, 0, 3), which had val score of 0.1527
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1260 of 9600 combinations so far
# Already Trained and Tested combination (1, 1, 1, 0, 1, 0, 3), which had val score of -0.1603
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1260 of 9600 combinations so far
# Already Trained and Tested combination (1, 0, 0, 0, 1, 0, 3), which had val score of -0.0189
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1260 of 9600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 1, 0, 3), which had val score of -0.1491
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1260 of 9600 combinations so far
# Already Trained and Tested combination (1, 0, 1, 1, 1, 0, 3), which had val score of 0.0849
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1260 of 9600 combinations so far
# Already Trained and Tested combination (1, 0, 1, 0, 0, 0, 3), which had val score of -0.5313
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1260 of 9600 combinations so far
# Already Trained and Tested combination (1, 0, 1, 0, 1, 1, 3), which had val score of 0.1248
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1260 of 9600 combinations so far
# Already Trained and Tested combination (1, 0, 1, 0, 1, 0, 2), which had val score of 0.1186
#         Current best combo: (1, 0, 1, 0, 1, 0, 3) with val score 0.2363.
#         Has trained 1260 of 9600 combinations so far
# % Combos Checked Thus Far: 1260 out of 9600 which is 13.125%
# Max Score:
#  0.23627677880271492
# Max Test Score:
#  -0.248765
# Max Combo Index:
#  (1, 0, 1, 0, 1, 0, 3) out of [4, 4, 5, 5, 2, 3, 4] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 2, 'subsample': 0.55, 'colsample_bylevel': 0.4, 'max_bin': 256, 'reg_lambda': 0.01, 'learning_rate': 1}
# % Combos Checked: 1260 out of 9600 which is 13.125%
