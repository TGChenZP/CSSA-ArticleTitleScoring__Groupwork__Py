# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'hgb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'google-bert_bert-base-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import HistGradientBoostingRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_bins': (4, 16, 64, 255),
    'interaction_cst': ('no_interactions', 'pairwise'),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'l2_regularization': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (25, 50, 100, 200, 400)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 8400: (3, 3, 0, 4, 0, 0), taking 0.19 seconds to get val score of 0.1203
#         Current best combo: (3, 3, 0, 4, 0, 0) with val score 0.1203
# Trained and Tested combination 2 of 8400: (3, 3, 0, 0, 5, 4), taking 0.24 seconds to get val score of -0.009
#         Current best combo: (3, 3, 0, 4, 0, 0) with val score 0.1203
# Trained and Tested combination 3 of 8400: (3, 0, 0, 4, 0, 0), taking 0.02 seconds to get val score of 0.0321
#         Current best combo: (3, 3, 0, 4, 0, 0) with val score 0.1203
# Trained and Tested combination 4 of 8400: (0, 0, 0, 0, 5, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (3, 3, 0, 4, 0, 0) with val score 0.1203
# Trained and Tested combination 5 of 8400: (3, 0, 1, 4, 0, 0), taking 0.03 seconds to get val score of 0.0482
#         Current best combo: (3, 3, 0, 4, 0, 0) with val score 0.1203
# Trained and Tested combination 6 of 8400: (0, 0, 0, 4, 0, 0), taking 0.02 seconds to get val score of 0.0321
#         Current best combo: (3, 3, 0, 4, 0, 0) with val score 0.1203
# Trained and Tested combination 7 of 8400: (3, 3, 0, 4, 0, 4), taking 0.29 seconds to get val score of 0.0407
#         Current best combo: (3, 3, 0, 4, 0, 0) with val score 0.1203
# Trained and Tested combination 8 of 8400: (0, 3, 0, 4, 0, 0), taking 0.02 seconds to get val score of 0.1239
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 9 of 8400: (0, 0, 1, 0, 0, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 10 of 8400: (6, 0, 1, 0, 5, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 11 of 8400: (3, 0, 1, 4, 5, 0), taking 0.04 seconds to get val score of 0.0531
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 12 of 8400: (0, 3, 1, 0, 0, 4), taking 0.35 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 13 of 8400: (0, 3, 0, 0, 0, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 14 of 8400: (0, 3, 1, 0, 5, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 15 of 8400: (6, 0, 0, 0, 0, 4), taking 0.25 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 16 of 8400: (3, 3, 0, 0, 0, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 17 of 8400: (0, 3, 1, 0, 5, 4), taking 0.38 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 18 of 8400: (3, 0, 0, 4, 5, 4), taking 0.23 seconds to get val score of 0.0772
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 19 of 8400: (3, 3, 1, 0, 5, 4), taking 0.34 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 20 of 8400: (6, 0, 1, 4, 5, 0), taking 0.03 seconds to get val score of 0.0531
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 21 of 8400: (6, 0, 0, 4, 0, 0), taking 0.02 seconds to get val score of 0.0321
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 22 of 8400: (0, 3, 0, 0, 5, 4), taking 0.24 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 23 of 8400: (6, 3, 1, 0, 5, 4), taking 0.33 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 24 of 8400: (3, 0, 0, 0, 5, 4), taking 0.16 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 25 of 8400: (6, 3, 1, 0, 0, 4), taking 0.36 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 26 of 8400: (6, 3, 0, 0, 0, 4), taking 0.31 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 27 of 8400: (0, 3, 1, 4, 0, 4), taking 0.35 seconds to get val score of -0.0563
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 28 of 8400: (3, 0, 1, 0, 0, 4), taking 0.35 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 29 of 8400: (3, 3, 0, 4, 5, 4), taking 0.27 seconds to get val score of -0.0177
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 30 of 8400: (0, 3, 0, 4, 5, 0), taking 0.02 seconds to get val score of 0.1043
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 31 of 8400: (6, 0, 0, 4, 5, 0), taking 0.02 seconds to get val score of 0.0347
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 32 of 8400: (6, 0, 0, 4, 5, 4), taking 0.22 seconds to get val score of 0.0772
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 33 of 8400: (3, 0, 0, 0, 0, 4), taking 0.25 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 34 of 8400: (0, 3, 0, 0, 5, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 35 of 8400: (0, 3, 0, 0, 0, 4), taking 0.28 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 36 of 8400: (0, 3, 0, 4, 0, 4), taking 0.27 seconds to get val score of -0.0354
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 37 of 8400: (6, 0, 1, 4, 5, 4), taking 0.39 seconds to get val score of -0.1713
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 38 of 8400: (3, 3, 1, 4, 0, 4), taking 0.38 seconds to get val score of -0.0115
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 39 of 8400: (6, 0, 1, 4, 0, 0), taking 0.03 seconds to get val score of 0.0482
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 40 of 8400: (0, 0, 0, 4, 5, 0), taking 0.02 seconds to get val score of 0.0347
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 41 of 8400: (6, 3, 1, 0, 0, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 42 of 8400: (6, 0, 0, 4, 0, 4), taking 0.29 seconds to get val score of 0.0723
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 43 of 8400: (3, 0, 0, 0, 5, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 44 of 8400: (6, 3, 1, 4, 0, 4), taking 0.42 seconds to get val score of -0.0115
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 45 of 8400: (0, 0, 1, 0, 5, 4), taking 0.33 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 46 of 8400: (3, 0, 0, 4, 5, 0), taking 0.02 seconds to get val score of 0.0347
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 47 of 8400: (3, 0, 1, 0, 5, 4), taking 0.34 seconds to get val score of -0.009
#         Current best combo: (0, 3, 0, 4, 0, 0) with val score 0.1239
# Trained and Tested combination 48 of 8400: (6, 3, 1, 4, 0, 0), taking 0.03 seconds to get val score of 0.133
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 49 of 8400: (0, 3, 0, 4, 5, 4), taking 0.27 seconds to get val score of -0.0359
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 50 of 8400: (6, 3, 0, 0, 5, 4), taking 0.25 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 51 of 8400: (6, 3, 0, 4, 0, 0), taking 0.02 seconds to get val score of 0.1203
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 52 of 8400: (6, 0, 1, 0, 0, 4), taking 0.37 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 53 of 8400: (3, 0, 1, 4, 0, 4), taking 0.37 seconds to get val score of -0.2145
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 54 of 8400: (0, 0, 1, 4, 0, 4), taking 0.35 seconds to get val score of -0.1731
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 55 of 8400: (6, 0, 0, 0, 5, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 56 of 8400: (3, 3, 0, 0, 5, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 57 of 8400: (3, 0, 0, 0, 0, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 58 of 8400: (0, 0, 1, 0, 0, 4), taking 0.39 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 59 of 8400: (0, 0, 0, 0, 0, 4), taking 0.26 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 60 of 8400: (3, 3, 1, 0, 5, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 61 of 8400: (6, 3, 0, 4, 5, 4), taking 0.29 seconds to get val score of -0.0177
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 62 of 8400: (0, 3, 1, 4, 5, 0), taking 0.03 seconds to get val score of 0.1243
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 63 of 8400: (3, 0, 0, 4, 0, 4), taking 0.25 seconds to get val score of 0.0723
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 64 of 8400: (6, 0, 1, 0, 5, 4), taking 0.31 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 65 of 8400: (0, 0, 1, 4, 5, 4), taking 0.33 seconds to get val score of -0.1687
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 66 of 8400: (6, 0, 1, 4, 0, 4), taking 0.37 seconds to get val score of -0.2145
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 67 of 8400: (3, 0, 1, 0, 0, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 68 of 8400: (3, 3, 1, 4, 5, 4), taking 0.38 seconds to get val score of 0.0019
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 69 of 8400: (3, 3, 1, 4, 5, 0), taking 0.03 seconds to get val score of 0.1105
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 70 of 8400: (3, 3, 0, 4, 5, 0), taking 0.02 seconds to get val score of 0.0937
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 71 of 8400: (3, 3, 0, 0, 0, 4), taking 0.32 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 72 of 8400: (6, 3, 1, 4, 5, 0), taking 0.03 seconds to get val score of 0.1105
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 73 of 8400: (0, 3, 1, 4, 0, 0), taking 0.02 seconds to get val score of 0.0841
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 74 of 8400: (0, 0, 0, 4, 0, 4), taking 0.24 seconds to get val score of 0.0723
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 75 of 8400: (0, 0, 1, 4, 0, 0), taking 0.03 seconds to get val score of 0.0427
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 76 of 8400: (0, 0, 0, 0, 0, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 77 of 8400: (6, 3, 0, 4, 0, 4), taking 0.32 seconds to get val score of 0.0407
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 78 of 8400: (6, 3, 1, 4, 5, 4), taking 0.36 seconds to get val score of 0.0019
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 79 of 8400: (3, 3, 1, 0, 0, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 80 of 8400: (6, 0, 0, 0, 5, 4), taking 0.17 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 81 of 8400: (0, 3, 1, 0, 0, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 82 of 8400: (6, 3, 0, 4, 5, 0), taking 0.05 seconds to get val score of 0.0937
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 83 of 8400: (0, 0, 0, 4, 5, 4), taking 0.26 seconds to get val score of 0.0772
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 84 of 8400: (3, 3, 1, 4, 0, 0), taking 0.03 seconds to get val score of 0.133
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 85 of 8400: (0, 3, 1, 4, 5, 4), taking 0.43 seconds to get val score of -0.0682
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 86 of 8400: (6, 3, 1, 0, 5, 0), taking 0.04 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 87 of 8400: (0, 0, 1, 4, 5, 0), taking 0.03 seconds to get val score of 0.0509
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 88 of 8400: (6, 3, 0, 0, 0, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 89 of 8400: (3, 3, 1, 0, 0, 4), taking 0.41 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 90 of 8400: (0, 0, 1, 0, 5, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 91 of 8400: (0, 0, 0, 0, 5, 4), taking 0.22 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 92 of 8400: (6, 3, 0, 0, 5, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 93 of 8400: (6, 0, 1, 0, 0, 0), taking 0.04 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 94 of 8400: (3, 0, 1, 0, 5, 0), taking 0.04 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 95 of 8400: (3, 2, 1, 2, 3, 2), taking 0.11 seconds to get val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 96 of 8400: (3, 0, 1, 4, 5, 4), taking 0.42 seconds to get val score of -0.1713
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 97 of 8400: (6, 0, 0, 0, 0, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 98 of 8400: (2, 2, 1, 2, 3, 2), taking 0.1 seconds to get val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 99 of 8400: (4, 2, 1, 2, 3, 2), taking 0.11 seconds to get val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 100 of 8400: (3, 1, 1, 2, 3, 2), taking 0.11 seconds to get val score of -0.0059
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 101 of 8400: (3, 3, 1, 2, 3, 2), taking 0.09 seconds to get val score of -0.0077
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 102 of 8400: (3, 2, 0, 2, 3, 2), taking 0.09 seconds to get val score of -0.0075
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 103 of 8400: (3, 2, 1, 1, 3, 2), taking 0.1 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 104 of 8400: (3, 2, 1, 3, 3, 2), taking 0.11 seconds to get val score of 0.0968
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 105 of 8400: (3, 2, 1, 2, 2, 2), taking 0.1 seconds to get val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 106 of 8400: (3, 2, 1, 2, 4, 2), taking 0.1 seconds to get val score of -0.007
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 107 of 8400: (3, 2, 1, 2, 3, 1), taking 0.06 seconds to get val score of -0.008
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 108 of 8400: (3, 2, 1, 2, 3, 3), taking 0.19 seconds to get val score of -0.0049
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# 	round 0 iteration:  1
#
# Trained and Tested combination 109 of 8400: (1, 2, 1, 2, 3, 2), taking 0.1 seconds to get val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 109 of 8400 combinations so far
# Trained and Tested combination 110 of 8400: (2, 1, 1, 2, 3, 2), taking 0.1 seconds to get val score of -0.0059
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 111 of 8400: (2, 3, 1, 2, 3, 2), taking 0.17 seconds to get val score of -0.0077
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 112 of 8400: (2, 2, 0, 2, 3, 2), taking 0.1 seconds to get val score of -0.0075
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 113 of 8400: (2, 2, 1, 1, 3, 2), taking 0.1 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 114 of 8400: (2, 2, 1, 3, 3, 2), taking 0.1 seconds to get val score of 0.0968
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 115 of 8400: (2, 2, 1, 2, 2, 2), taking 0.1 seconds to get val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 116 of 8400: (2, 2, 1, 2, 4, 2), taking 0.12 seconds to get val score of -0.007
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 117 of 8400: (2, 2, 1, 2, 3, 1), taking 0.06 seconds to get val score of -0.008
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 118 of 8400: (2, 2, 1, 2, 3, 3), taking 0.2 seconds to get val score of -0.0049
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 118 of 8400 combinations so far
# Trained and Tested combination 119 of 8400: (5, 2, 1, 2, 3, 2), taking 0.1 seconds to get val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 120 of 8400: (4, 1, 1, 2, 3, 2), taking 0.11 seconds to get val score of -0.0059
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 121 of 8400: (4, 3, 1, 2, 3, 2), taking 0.1 seconds to get val score of -0.0077
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 122 of 8400: (4, 2, 0, 2, 3, 2), taking 0.09 seconds to get val score of -0.0075
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 123 of 8400: (4, 2, 1, 1, 3, 2), taking 0.1 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 124 of 8400: (4, 2, 1, 3, 3, 2), taking 0.1 seconds to get val score of 0.0968
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 125 of 8400: (4, 2, 1, 2, 2, 2), taking 0.1 seconds to get val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 126 of 8400: (4, 2, 1, 2, 4, 2), taking 0.11 seconds to get val score of -0.007
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 127 of 8400: (4, 2, 1, 2, 3, 1), taking 0.06 seconds to get val score of -0.008
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 128 of 8400: (4, 2, 1, 2, 3, 3), taking 0.2 seconds to get val score of -0.0049
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Already Trained and Tested combination (2, 1, 1, 2, 3, 2), which had val score of -0.0059
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 128 of 8400 combinations so far
# Already Trained and Tested combination (4, 1, 1, 2, 3, 2), which had val score of -0.0059
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 128 of 8400 combinations so far
# Trained and Tested combination 129 of 8400: (3, 0, 1, 2, 3, 2), taking 0.1 seconds to get val score of -0.0076
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 129 of 8400 combinations so far
# Trained and Tested combination 130 of 8400: (3, 1, 0, 2, 3, 2), taking 0.09 seconds to get val score of -0.0074
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 131 of 8400: (3, 1, 1, 1, 3, 2), taking 0.14 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 132 of 8400: (3, 1, 1, 3, 3, 2), taking 0.1 seconds to get val score of 0.1149
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 133 of 8400: (3, 1, 1, 2, 2, 2), taking 0.1 seconds to get val score of -0.0059
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 134 of 8400: (3, 1, 1, 2, 4, 2), taking 0.11 seconds to get val score of -0.006
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 135 of 8400: (3, 1, 1, 2, 3, 1), taking 0.06 seconds to get val score of -0.0074
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 136 of 8400: (3, 1, 1, 2, 3, 3), taking 0.2 seconds to get val score of -0.0029
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Already Trained and Tested combination (2, 3, 1, 2, 3, 2), which had val score of -0.0077
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 136 of 8400 combinations so far
# Already Trained and Tested combination (4, 3, 1, 2, 3, 2), which had val score of -0.0077
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 136 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 136 of 8400 combinations so far
# Trained and Tested combination 137 of 8400: (3, 3, 0, 2, 3, 2), taking 0.08 seconds to get val score of -0.007
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 138 of 8400: (3, 3, 1, 1, 3, 2), taking 0.1 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 139 of 8400: (3, 3, 1, 3, 3, 2), taking 0.1 seconds to get val score of 0.0976
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 140 of 8400: (3, 3, 1, 2, 2, 2), taking 0.09 seconds to get val score of -0.0077
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 141 of 8400: (3, 3, 1, 2, 4, 2), taking 0.1 seconds to get val score of -0.0077
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 142 of 8400: (3, 3, 1, 2, 3, 1), taking 0.05 seconds to get val score of -0.0084
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 143 of 8400: (3, 3, 1, 2, 3, 3), taking 0.19 seconds to get val score of -0.0064
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Already Trained and Tested combination (2, 2, 0, 2, 3, 2), which had val score of -0.0075
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 143 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 0, 2, 3, 2), which had val score of -0.0075
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 143 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 0, 2, 3, 2), which had val score of -0.0074
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 143 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 2, 3, 2), which had val score of -0.007
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 143 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 143 of 8400 combinations so far
# Trained and Tested combination 144 of 8400: (3, 2, 0, 1, 3, 2), taking 0.09 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 145 of 8400: (3, 2, 0, 3, 3, 2), taking 0.09 seconds to get val score of 0.1079
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 146 of 8400: (3, 2, 0, 2, 2, 2), taking 0.09 seconds to get val score of -0.0075
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 147 of 8400: (3, 2, 0, 2, 4, 2), taking 0.09 seconds to get val score of -0.0075
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 148 of 8400: (3, 2, 0, 2, 3, 1), taking 0.05 seconds to get val score of -0.0082
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 149 of 8400: (3, 2, 0, 2, 3, 3), taking 0.17 seconds to get val score of -0.0058
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Already Trained and Tested combination (2, 2, 1, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 149 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 149 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 149 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 149 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 149 of 8400 combinations so far
# Trained and Tested combination 150 of 8400: (3, 2, 1, 0, 3, 2), taking 0.1 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 150 of 8400 combinations so far
# Trained and Tested combination 151 of 8400: (3, 2, 1, 1, 2, 2), taking 0.1 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 152 of 8400: (3, 2, 1, 1, 4, 2), taking 0.11 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 153 of 8400: (3, 2, 1, 1, 3, 1), taking 0.06 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 154 of 8400: (3, 2, 1, 1, 3, 3), taking 0.21 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Already Trained and Tested combination (2, 2, 1, 3, 3, 2), which had val score of 0.0968
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 3, 3, 2), which had val score of 0.0968
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 3, 3, 2), which had val score of 0.1149
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 3, 2), which had val score of 0.0976
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 3, 3, 2), which had val score of 0.1079
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133.
#         Has trained 154 of 8400 combinations so far
# Trained and Tested combination 155 of 8400: (3, 2, 1, 4, 3, 2), taking 0.11 seconds to get val score of 0.1259
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 156 of 8400: (3, 2, 1, 3, 2, 2), taking 0.1 seconds to get val score of 0.096
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 157 of 8400: (3, 2, 1, 3, 4, 2), taking 0.1 seconds to get val score of 0.0956
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 158 of 8400: (3, 2, 1, 3, 3, 1), taking 0.05 seconds to get val score of 0.0632
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.133
# Trained and Tested combination 159 of 8400: (3, 2, 1, 3, 3, 3), taking 0.19 seconds to get val score of 0.1389
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Already Trained and Tested combination (2, 2, 1, 2, 2, 2), which had val score of -0.0069
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 2, 2), which had val score of -0.0069
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 2, 2), which had val score of -0.0059
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 2), which had val score of -0.0077
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 2, 2), which had val score of -0.0075
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.009
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 2, 2), which had val score of 0.096
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 159 of 8400 combinations so far
# Trained and Tested combination 160 of 8400: (3, 2, 1, 2, 1, 2), taking 0.1 seconds to get val score of -0.0069
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 160 of 8400 combinations so far
# Trained and Tested combination 161 of 8400: (3, 2, 1, 2, 2, 1), taking 0.05 seconds to get val score of -0.008
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Trained and Tested combination 162 of 8400: (3, 2, 1, 2, 2, 3), taking 0.19 seconds to get val score of -0.0049
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Already Trained and Tested combination (2, 2, 1, 2, 4, 2), which had val score of -0.007
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 4, 2), which had val score of -0.007
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 4, 2), which had val score of -0.006
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 4, 2), which had val score of -0.0077
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 4, 2), which had val score of -0.0075
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 4, 2), which had val score of -0.009
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 4, 2), which had val score of 0.0956
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 162 of 8400 combinations so far
# Trained and Tested combination 163 of 8400: (3, 2, 1, 2, 5, 2), taking 0.1 seconds to get val score of -0.0074
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Trained and Tested combination 164 of 8400: (3, 2, 1, 2, 4, 1), taking 0.05 seconds to get val score of -0.008
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Trained and Tested combination 165 of 8400: (3, 2, 1, 2, 4, 3), taking 0.19 seconds to get val score of -0.005
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Already Trained and Tested combination (2, 2, 1, 2, 3, 1), which had val score of -0.008
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 3, 1), which had val score of -0.008
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 3, 1), which had val score of -0.0074
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 3, 1), which had val score of -0.0084
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 3, 1), which had val score of -0.0082
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 3, 1), which had val score of -0.009
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 3, 1), which had val score of 0.0632
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2, 1), which had val score of -0.008
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 4, 1), which had val score of -0.008
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 165 of 8400 combinations so far
# Trained and Tested combination 166 of 8400: (3, 2, 1, 2, 3, 0), taking 0.03 seconds to get val score of -0.0085
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (2, 2, 1, 2, 3, 3), which had val score of -0.0049
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 3, 3), which had val score of -0.0049
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 3, 3), which had val score of -0.0029
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 3, 3), which had val score of -0.0064
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 3, 3), which had val score of -0.0058
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 3, 3), which had val score of -0.009
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 3, 3), which had val score of 0.1389
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2, 3), which had val score of -0.0049
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 4, 3), which had val score of -0.005
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0069
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389.
#         Has trained 166 of 8400 combinations so far
# Trained and Tested combination 167 of 8400: (3, 2, 1, 2, 3, 4), taking 0.37 seconds to get val score of -0.0011
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Trained and Tested combination 168 of 8400: (2, 2, 1, 3, 3, 3), taking 0.24 seconds to get val score of 0.1389
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Trained and Tested combination 169 of 8400: (4, 2, 1, 3, 3, 3), taking 0.2 seconds to get val score of 0.1389
#         Current best combo: (3, 2, 1, 3, 3, 3) with val score 0.1389
# Trained and Tested combination 170 of 8400: (3, 1, 1, 3, 3, 3), taking 0.21 seconds to get val score of 0.1539
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Trained and Tested combination 171 of 8400: (3, 3, 1, 3, 3, 3), taking 0.21 seconds to get val score of 0.1455
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Trained and Tested combination 172 of 8400: (3, 2, 0, 3, 3, 3), taking 0.19 seconds to get val score of 0.1395
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Already Trained and Tested combination (3, 2, 1, 2, 3, 3), which had val score of -0.0049
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539.
#         Has trained 172 of 8400 combinations so far
# Trained and Tested combination 173 of 8400: (3, 2, 1, 4, 3, 3), taking 0.2 seconds to get val score of 0.1147
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Trained and Tested combination 174 of 8400: (3, 2, 1, 3, 2, 3), taking 0.22 seconds to get val score of 0.1389
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Trained and Tested combination 175 of 8400: (3, 2, 1, 3, 4, 3), taking 0.2 seconds to get val score of 0.1317
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Already Trained and Tested combination (3, 2, 1, 3, 3, 2), which had val score of 0.0968
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539.
#         Has trained 175 of 8400 combinations so far
# Trained and Tested combination 176 of 8400: (3, 2, 1, 3, 3, 4), taking 0.42 seconds to get val score of 0.1219
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Trained and Tested combination 177 of 8400: (2, 1, 1, 3, 3, 3), taking 0.2 seconds to get val score of 0.1539
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Trained and Tested combination 178 of 8400: (4, 1, 1, 3, 3, 3), taking 0.21 seconds to get val score of 0.1539
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Trained and Tested combination 179 of 8400: (3, 0, 1, 3, 3, 3), taking 0.21 seconds to get val score of 0.0505
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Already Trained and Tested combination (3, 2, 1, 3, 3, 3), which had val score of 0.1389
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539.
#         Has trained 179 of 8400 combinations so far
# Trained and Tested combination 180 of 8400: (3, 1, 0, 3, 3, 3), taking 0.21 seconds to get val score of 0.1223
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Already Trained and Tested combination (3, 1, 1, 2, 3, 3), which had val score of -0.0029
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539.
#         Has trained 180 of 8400 combinations so far
# Trained and Tested combination 181 of 8400: (3, 1, 1, 4, 3, 3), taking 0.24 seconds to get val score of -0.0049
#         Current best combo: (3, 1, 1, 3, 3, 3) with val score 0.1539
# Trained and Tested combination 182 of 8400: (3, 1, 1, 3, 2, 3), taking 0.21 seconds to get val score of 0.1558
#         Current best combo: (3, 1, 1, 3, 2, 3) with val score 0.1558
# Trained and Tested combination 183 of 8400: (3, 1, 1, 3, 4, 3), taking 0.21 seconds to get val score of 0.1467
#         Current best combo: (3, 1, 1, 3, 2, 3) with val score 0.1558
# Already Trained and Tested combination (3, 1, 1, 3, 3, 2), which had val score of 0.1149
#         Current best combo: (3, 1, 1, 3, 2, 3) with val score 0.1558.
#         Has trained 183 of 8400 combinations so far
# Trained and Tested combination 184 of 8400: (3, 1, 1, 3, 3, 4), taking 0.41 seconds to get val score of 0.1309
#         Current best combo: (3, 1, 1, 3, 2, 3) with val score 0.1558
# Trained and Tested combination 185 of 8400: (2, 1, 1, 3, 2, 3), taking 0.21 seconds to get val score of 0.1558
#         Current best combo: (3, 1, 1, 3, 2, 3) with val score 0.1558
# Trained and Tested combination 186 of 8400: (4, 1, 1, 3, 2, 3), taking 0.22 seconds to get val score of 0.1558
#         Current best combo: (3, 1, 1, 3, 2, 3) with val score 0.1558
# Trained and Tested combination 187 of 8400: (3, 0, 1, 3, 2, 3), taking 0.23 seconds to get val score of 0.0494
#         Current best combo: (3, 1, 1, 3, 2, 3) with val score 0.1558
# Already Trained and Tested combination (3, 2, 1, 3, 2, 3), which had val score of 0.1389
#         Current best combo: (3, 1, 1, 3, 2, 3) with val score 0.1558.
#         Has trained 187 of 8400 combinations so far
# Trained and Tested combination 188 of 8400: (3, 1, 0, 3, 2, 3), taking 0.2 seconds to get val score of 0.1221
# ...
# Trained and Tested combination 286 of 8400: (4, 3, 1, 4, 1, 0), taking 0.03 seconds to get val score of 0.133
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (3, 2, 1, 4, 1, 0), which had val score of 0.1462
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 286 of 8400 combinations so far
# Trained and Tested combination 287 of 8400: (3, 3, 0, 4, 1, 0), taking 0.02 seconds to get val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 288 of 8400: (3, 3, 1, 3, 1, 0), taking 0.03 seconds to get val score of 0.0203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (3, 3, 1, 4, 0, 0), which had val score of 0.133
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 288 of 8400 combinations so far
# Trained and Tested combination 289 of 8400: (3, 3, 1, 4, 2, 0), taking 0.03 seconds to get val score of 0.1329
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 290 of 8400: (3, 3, 1, 4, 1, 1), taking 0.05 seconds to get val score of 0.0824
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# % Combos Checked Thus Far: 290 out of 8400 which is 3.4523810000000004%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Already Trained and Tested combination (2, 3, 0, 4, 0, 0), which had val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 290 of 8400 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 0), which had val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 290 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 4, 0, 0), which had val score of 0.1529
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 290 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 4, 0, 0), which had val score of 0.133
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 290 of 8400 combinations so far
# Trained and Tested combination 291 of 8400: (3, 3, 0, 3, 0, 0), taking 0.02 seconds to get val score of 0.0322
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (3, 3, 0, 4, 1, 0), which had val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 291 of 8400 combinations so far
# Trained and Tested combination 292 of 8400: (3, 3, 0, 4, 0, 1), taking 0.05 seconds to get val score of 0.1296
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# 	round 5 iteration:  1
#
# Trained and Tested combination 293 of 8400: (1, 3, 0, 4, 0, 0), taking 0.03 seconds to get val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (3, 3, 0, 4, 0, 0), which had val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 293 of 8400 combinations so far
# Trained and Tested combination 294 of 8400: (2, 2, 0, 4, 0, 0), taking 0.03 seconds to get val score of 0.1529
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (2, 3, 1, 4, 0, 0), which had val score of 0.133
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 294 of 8400 combinations so far
# Trained and Tested combination 295 of 8400: (2, 3, 0, 3, 0, 0), taking 0.03 seconds to get val score of 0.0322
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 296 of 8400: (2, 3, 0, 4, 1, 0), taking 0.03 seconds to get val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 297 of 8400: (2, 3, 0, 4, 0, 1), taking 0.05 seconds to get val score of 0.1296
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (2, 3, 0, 4, 1, 0), which had val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 297 of 8400 combinations so far
# Trained and Tested combination 298 of 8400: (4, 3, 0, 4, 1, 0), taking 0.03 seconds to get val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 299 of 8400: (3, 2, 0, 4, 1, 0), taking 0.03 seconds to get val score of 0.1529
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (3, 3, 1, 4, 1, 0), which had val score of 0.133
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 299 of 8400 combinations so far
# Trained and Tested combination 300 of 8400: (3, 3, 0, 3, 1, 0), taking 0.03 seconds to get val score of 0.0322
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (3, 3, 0, 4, 0, 0), which had val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 300 of 8400 combinations so far
# Trained and Tested combination 301 of 8400: (3, 3, 0, 4, 2, 0), taking 0.03 seconds to get val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 302 of 8400: (3, 3, 0, 4, 1, 1), taking 0.05 seconds to get val score of 0.1296
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (2, 3, 0, 4, 0, 1), which had val score of 0.1296
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 302 of 8400 combinations so far
# Trained and Tested combination 303 of 8400: (4, 3, 0, 4, 0, 1), taking 0.04 seconds to get val score of 0.1296
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 304 of 8400: (3, 2, 0, 4, 0, 1), taking 0.05 seconds to get val score of 0.1574
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (3, 3, 1, 4, 0, 1), which had val score of 0.0824
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 304 of 8400 combinations so far
# Trained and Tested combination 305 of 8400: (3, 3, 0, 3, 0, 1), taking 0.05 seconds to get val score of 0.0621
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (3, 3, 0, 4, 1, 1), which had val score of 0.1296
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 305 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 0), which had val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 305 of 8400 combinations so far
# Trained and Tested combination 306 of 8400: (3, 3, 0, 4, 0, 2), taking 0.08 seconds to get val score of 0.1033
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# % Combos Checked Thus Far: 306 out of 8400 which is 3.6428570000000002%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# Already Trained and Tested combination (1, 3, 0, 4, 0, 0), which had val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 306 of 8400 combinations so far
# Trained and Tested combination 307 of 8400: (0, 2, 0, 4, 0, 0), taking 0.03 seconds to get val score of 0.159
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (0, 3, 1, 4, 0, 0), which had val score of 0.0841
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 307 of 8400 combinations so far
# Trained and Tested combination 308 of 8400: (0, 3, 0, 3, 0, 0), taking 0.02 seconds to get val score of 0.0347
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 309 of 8400: (0, 3, 0, 4, 1, 0), taking 0.02 seconds to get val score of 0.1239
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 310 of 8400: (0, 3, 0, 4, 0, 1), taking 0.04 seconds to get val score of 0.1464
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# 	round 6 iteration:  1
#
# Trained and Tested combination 311 of 8400: (1, 2, 0, 4, 0, 0), taking 0.03 seconds to get val score of 0.1529
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 312 of 8400: (0, 1, 0, 4, 0, 0), taking 0.03 seconds to get val score of 0.1177
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0), which had val score of 0.1239
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 312 of 8400 combinations so far
# Trained and Tested combination 313 of 8400: (0, 2, 1, 4, 0, 0), taking 0.04 seconds to get val score of 0.123
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 314 of 8400: (0, 2, 0, 3, 0, 0), taking 0.03 seconds to get val score of 0.0391
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 315 of 8400: (0, 2, 0, 4, 1, 0), taking 0.03 seconds to get val score of 0.159
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 316 of 8400: (0, 2, 0, 4, 0, 1), taking 0.05 seconds to get val score of 0.1755
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 317 of 8400: (1, 3, 0, 4, 1, 0), taking 0.02 seconds to get val score of 0.1203
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (0, 2, 0, 4, 1, 0), which had val score of 0.159
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 317 of 8400 combinations so far
# Trained and Tested combination 318 of 8400: (0, 3, 1, 4, 1, 0), taking 0.03 seconds to get val score of 0.0841
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 319 of 8400: (0, 3, 0, 3, 1, 0), taking 0.03 seconds to get val score of 0.0347
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0), which had val score of 0.1239
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 319 of 8400 combinations so far
# Trained and Tested combination 320 of 8400: (0, 3, 0, 4, 2, 0), taking 0.03 seconds to get val score of 0.1239
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 321 of 8400: (0, 3, 0, 4, 1, 1), taking 0.04 seconds to get val score of 0.1464
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 322 of 8400: (1, 3, 0, 4, 0, 1), taking 0.05 seconds to get val score of 0.1296
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (0, 2, 0, 4, 0, 1), which had val score of 0.1755
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 322 of 8400 combinations so far
# Trained and Tested combination 323 of 8400: (0, 3, 1, 4, 0, 1), taking 0.05 seconds to get val score of 0.0558
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Trained and Tested combination 324 of 8400: (0, 3, 0, 3, 0, 1), taking 0.06 seconds to get val score of 0.0669
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# Already Trained and Tested combination (0, 3, 0, 4, 1, 1), which had val score of 0.1464
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 324 of 8400 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0), which had val score of 0.1239
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 324 of 8400 combinations so far
# Trained and Tested combination 325 of 8400: (0, 3, 0, 4, 0, 2), taking 0.15 seconds to get val score of 0.1391
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807
# % Combos Checked Thus Far: 325 out of 8400 which is 3.869048%
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# % Combos Checked Thus Far: 325 out of 8400 which is 3.869048%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (1, 2, 0, 4, 4, 1), which had val score of 0.16
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 325 of 8400 combinations so far
# Already Trained and Tested combination (0, 1, 0, 4, 4, 1), which had val score of 0.1422
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 325 of 8400 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 4, 1), which had val score of 0.1381
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 325 of 8400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 4, 4, 1), which had val score of 0.0672
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 325 of 8400 combinations so far
# Already Trained and Tested combination (0, 2, 0, 3, 4, 1), which had val score of 0.0667
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 325 of 8400 combinations so far
# Already Trained and Tested combination (0, 2, 0, 4, 3, 1), which had val score of 0.1688
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 325 of 8400 combinations so far
# Already Trained and Tested combination (0, 2, 0, 4, 5, 1), which had val score of 0.1342
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 325 of 8400 combinations so far
# Already Trained and Tested combination (0, 2, 0, 4, 4, 0), which had val score of 0.1676
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 325 of 8400 combinations so far
# Already Trained and Tested combination (0, 2, 0, 4, 4, 2), which had val score of 0.1622
#         Current best combo: (0, 2, 0, 4, 4, 1) with val score 0.1807.
#         Has trained 325 of 8400 combinations so far
# % Combos Checked Thus Far: 325 out of 8400 which is 3.869048%
# Max Score:
#  0.18071972999043395
# Max Test Score:
#  0.013316
# Max Combo Index:
#  (0, 2, 0, 4, 4, 1) out of [7, 4, 2, 5, 6, 5] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 50}
# % Combos Checked: 325 out of 8400 which is 3.869048%
