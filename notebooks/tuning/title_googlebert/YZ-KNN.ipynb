# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'knn'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'google-bert_bert-base-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.neighbors import KNeighborsRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_neighbors': [i for i in range(1, 101)],
    'p': (1, 2),
    'weights': ('uniform', 'distance')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.neighbors._regression.KNeighborsRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 400: (30, 1, 0), taking 0.0 seconds to get val score of 0.1322
#         Current best combo: (30, 1, 0) with val score 0.1322
# Trained and Tested combination 2 of 400: (99, 1, 0), taking 0.0 seconds to get val score of 0.0699
#         Current best combo: (30, 1, 0) with val score 0.1322
# Trained and Tested combination 3 of 400: (0, 1, 0), taking 0.0 seconds to get val score of -0.8245
#         Current best combo: (30, 1, 0) with val score 0.1322
# Trained and Tested combination 4 of 400: (20, 1, 1), taking 0.0 seconds to get val score of 0.0864
#         Current best combo: (30, 1, 0) with val score 0.1322
# Trained and Tested combination 5 of 400: (65, 0, 0), taking 0.0 seconds to get val score of 0.0764
#         Current best combo: (30, 1, 0) with val score 0.1322
# Trained and Tested combination 6 of 400: (20, 0, 0), taking 0.0 seconds to get val score of 0.1533
#         Current best combo: (20, 0, 0) with val score 0.1533
# Trained and Tested combination 7 of 400: (50, 0, 1), taking 0.0 seconds to get val score of 0.0705
#         Current best combo: (20, 0, 0) with val score 0.1533
# Trained and Tested combination 8 of 400: (99, 0, 1), taking 0.0 seconds to get val score of -0.0114
#         Current best combo: (20, 0, 0) with val score 0.1533
# Trained and Tested combination 9 of 400: (40, 1, 0), taking 0.0 seconds to get val score of 0.0855
#         Current best combo: (20, 0, 0) with val score 0.1533
# Trained and Tested combination 10 of 400: (85, 0, 1), taking 0.0 seconds to get val score of 0.0063
#         Current best combo: (20, 0, 0) with val score 0.1533
# Trained and Tested combination 11 of 400: (20, 0, 1), taking 0.0 seconds to get val score of 0.1567
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 12 of 400: (25, 0, 1), taking 0.0 seconds to get val score of 0.1346
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 13 of 400: (35, 0, 1), taking 0.0 seconds to get val score of 0.1006
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 14 of 400: (5, 0, 0), taking 0.0 seconds to get val score of -0.0706
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 15 of 400: (45, 1, 0), taking 0.0 seconds to get val score of 0.0764
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 16 of 400: (70, 1, 0), taking 0.0 seconds to get val score of 0.0583
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 17 of 400: (70, 1, 1), taking 0.0 seconds to get val score of 0.0097
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 18 of 400: (25, 1, 0), taking 0.0 seconds to get val score of 0.1208
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 19 of 400: (40, 1, 1), taking 0.0 seconds to get val score of 0.042
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 20 of 400: (75, 1, 0), taking 0.0 seconds to get val score of 0.07
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 21 of 400: (60, 0, 1), taking 0.0 seconds to get val score of 0.0326
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 22 of 400: (55, 1, 0), taking 0.0 seconds to get val score of 0.0491
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 23 of 400: (60, 1, 1), taking 0.0 seconds to get val score of 0.0046
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 24 of 400: (30, 0, 1), taking 0.0 seconds to get val score of 0.1007
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 25 of 400: (65, 1, 0), taking 0.0 seconds to get val score of 0.062
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 26 of 400: (40, 0, 1), taking 0.0 seconds to get val score of 0.0682
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 27 of 400: (10, 0, 0), taking 0.0 seconds to get val score of 0.0842
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 28 of 400: (20, 1, 0), taking 0.0 seconds to get val score of 0.1131
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 29 of 400: (95, 1, 0), taking 0.0 seconds to get val score of 0.0672
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 30 of 400: (60, 0, 0), taking 0.0 seconds to get val score of 0.0845
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 31 of 400: (15, 1, 1), taking 0.0 seconds to get val score of 0.0696
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 32 of 400: (80, 1, 0), taking 0.0 seconds to get val score of 0.0707
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 33 of 400: (5, 1, 0), taking 0.0 seconds to get val score of 0.0317
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 34 of 400: (85, 0, 0), taking 0.0 seconds to get val score of 0.0694
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 35 of 400: (10, 1, 1), taking 0.0 seconds to get val score of 0.0965
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 36 of 400: (35, 0, 0), taking 0.0 seconds to get val score of 0.1446
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 37 of 400: (65, 0, 1), taking 0.0 seconds to get val score of 0.0194
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 38 of 400: (55, 0, 1), taking 0.0 seconds to get val score of 0.0457
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 39 of 400: (65, 1, 1), taking 0.0 seconds to get val score of 0.0164
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 40 of 400: (75, 1, 1), taking 0.0 seconds to get val score of 0.0259
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 41 of 400: (15, 0, 1), taking 0.0 seconds to get val score of 0.1343
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 42 of 400: (50, 0, 0), taking 0.0 seconds to get val score of 0.1152
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 43 of 400: (60, 1, 0), taking 0.0 seconds to get val score of 0.0558
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 44 of 400: (10, 0, 1), taking 0.0 seconds to get val score of 0.092
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 45 of 400: (0, 0, 1), taking 0.0 seconds to get val score of -0.6655
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 46 of 400: (90, 0, 1), taking 0.0 seconds to get val score of -0.0071
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 47 of 400: (35, 1, 0), taking 0.0 seconds to get val score of 0.1074
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 48 of 400: (45, 0, 1), taking 0.0 seconds to get val score of 0.0752
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 49 of 400: (80, 0, 1), taking 0.0 seconds to get val score of 0.0211
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 50 of 400: (45, 0, 0), taking 0.0 seconds to get val score of 0.1161
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 51 of 400: (75, 0, 1), taking 0.0 seconds to get val score of 0.0202
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 52 of 400: (99, 0, 0), taking 0.0 seconds to get val score of 0.0565
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 53 of 400: (45, 1, 1), taking 0.0 seconds to get val score of 0.0214
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 54 of 400: (25, 1, 1), taking 0.0 seconds to get val score of 0.0927
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 55 of 400: (25, 0, 0), taking 0.0 seconds to get val score of 0.142
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 56 of 400: (95, 0, 1), taking 0.0 seconds to get val score of -0.016
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 57 of 400: (50, 1, 1), taking 0.0 seconds to get val score of 0.0053
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 58 of 400: (90, 1, 0), taking 0.0 seconds to get val score of 0.0635
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 59 of 400: (55, 0, 0), taking 0.0 seconds to get val score of 0.0948
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 60 of 400: (30, 1, 1), taking 0.0 seconds to get val score of 0.0954
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 61 of 400: (85, 1, 0), taking 0.0 seconds to get val score of 0.066
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 62 of 400: (40, 0, 0), taking 0.0 seconds to get val score of 0.1211
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 63 of 400: (85, 1, 1), taking 0.0 seconds to get val score of 0.0166
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 64 of 400: (5, 0, 1), taking 0.0 seconds to get val score of -0.1241
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 65 of 400: (15, 0, 0), taking 0.0 seconds to get val score of 0.1299
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 66 of 400: (0, 0, 0), taking 0.0 seconds to get val score of -0.6655
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 67 of 400: (90, 1, 1), taking 0.0 seconds to get val score of 0.0148
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 68 of 400: (99, 1, 1), taking 0.0 seconds to get val score of 0.0227
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 69 of 400: (70, 0, 0), taking 0.0 seconds to get val score of 0.0778
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 70 of 400: (80, 1, 1), taking 0.0 seconds to get val score of 0.0235
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 71 of 400: (30, 0, 0), taking 0.0 seconds to get val score of 0.1379
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 72 of 400: (95, 0, 0), taking 0.0 seconds to get val score of 0.0543
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 73 of 400: (5, 1, 1), taking 0.0 seconds to get val score of 0.0084
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 74 of 400: (75, 0, 0), taking 0.0 seconds to get val score of 0.0784
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 75 of 400: (35, 1, 1), taking 0.0 seconds to get val score of 0.069
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 76 of 400: (95, 1, 1), taking 0.0 seconds to get val score of 0.0148
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 77 of 400: (15, 1, 0), taking 0.0 seconds to get val score of 0.0874
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 78 of 400: (70, 0, 1), taking 0.0 seconds to get val score of 0.0238
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 79 of 400: (10, 1, 0), taking 0.0 seconds to get val score of 0.0902
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 80 of 400: (0, 1, 1), taking 0.0 seconds to get val score of -0.8245
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 81 of 400: (90, 0, 0), taking 0.0 seconds to get val score of 0.0588
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 82 of 400: (50, 1, 0), taking 0.0 seconds to get val score of 0.0589
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (50, 1, 1), which had val score of 0.0053
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 82 of 400 combinations so far
# Trained and Tested combination 83 of 400: (55, 1, 1), taking 0.0 seconds to get val score of -0.0093
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 84 of 400: (80, 0, 0), taking 0.0 seconds to get val score of 0.0799
#         Current best combo: (20, 0, 1) with val score 0.1567
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 85 of 400: (49, 1, 1), taking 0.0 seconds to get val score of 0.0125
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 86 of 400: (51, 1, 1), taking 0.0 seconds to get val score of 0.0024
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (50, 0, 1), which had val score of 0.0705
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 86 of 400 combinations so far
# Already Trained and Tested combination (50, 1, 0), which had val score of 0.0589
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 86 of 400 combinations so far
# 	round 0 iteration:  1
#
# Trained and Tested combination 87 of 400: (48, 1, 1), taking 0.0 seconds to get val score of 0.0179
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (50, 1, 1), which had val score of 0.0053
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 87 of 400 combinations so far
# Trained and Tested combination 88 of 400: (49, 0, 1), taking 0.0 seconds to get val score of 0.0764
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 89 of 400: (49, 1, 0), taking 0.0 seconds to get val score of 0.0665
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (50, 1, 1), which had val score of 0.0053
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 89 of 400 combinations so far
# Trained and Tested combination 90 of 400: (52, 1, 1), taking 0.0 seconds to get val score of -0.0066
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 91 of 400: (51, 0, 1), taking 0.0 seconds to get val score of 0.0654
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 92 of 400: (51, 1, 0), taking 0.0 seconds to get val score of 0.055
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (49, 0, 1), which had val score of 0.0764
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 92 of 400 combinations so far
# Already Trained and Tested combination (51, 0, 1), which had val score of 0.0654
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 92 of 400 combinations so far
# Already Trained and Tested combination (50, 1, 1), which had val score of 0.0053
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 92 of 400 combinations so far
# Already Trained and Tested combination (50, 0, 0), which had val score of 0.1152
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 92 of 400 combinations so far
# Already Trained and Tested combination (49, 1, 0), which had val score of 0.0665
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 92 of 400 combinations so far
# Already Trained and Tested combination (51, 1, 0), which had val score of 0.055
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 92 of 400 combinations so far
# Already Trained and Tested combination (50, 0, 0), which had val score of 0.1152
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 92 of 400 combinations so far
# Already Trained and Tested combination (50, 1, 1), which had val score of 0.0053
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 92 of 400 combinations so far
# Trained and Tested combination 93 of 400: (19, 0, 1), taking 0.0 seconds to get val score of 0.1443
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 94 of 400: (21, 0, 1), taking 0.0 seconds to get val score of 0.1562
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (20, 1, 1), which had val score of 0.0864
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 94 of 400 combinations so far
# Already Trained and Tested combination (20, 0, 0), which had val score of 0.1533
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 94 of 400 combinations so far
# % Combos Checked Thus Far: 94 out of 400 which is 23.5%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 95 of 400: (49, 0, 0), taking 0.0 seconds to get val score of 0.1219
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 96 of 400: (51, 0, 0), taking 0.0 seconds to get val score of 0.1122
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (50, 1, 0), which had val score of 0.0589
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 96 of 400 combinations so far
# Already Trained and Tested combination (50, 0, 1), which had val score of 0.0705
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 96 of 400 combinations so far
# 	round 1 iteration:  1
#
# Trained and Tested combination 97 of 400: (48, 0, 0), taking 0.0 seconds to get val score of 0.1226
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (50, 0, 0), which had val score of 0.1152
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 97 of 400 combinations so far
# Already Trained and Tested combination (49, 1, 0), which had val score of 0.0665
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 97 of 400 combinations so far
# Already Trained and Tested combination (49, 0, 1), which had val score of 0.0764
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 97 of 400 combinations so far
# Already Trained and Tested combination (50, 0, 0), which had val score of 0.1152
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 97 of 400 combinations so far
# Trained and Tested combination 98 of 400: (52, 0, 0), taking 0.0 seconds to get val score of 0.108
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (51, 1, 0), which had val score of 0.055
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 98 of 400 combinations so far
# Already Trained and Tested combination (51, 0, 1), which had val score of 0.0654
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 98 of 400 combinations so far
# % Combos Checked Thus Far: 98 out of 400 which is 24.5%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 99 of 400: (44, 0, 0), taking 0.0 seconds to get val score of 0.1213
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 100 of 400: (46, 0, 0), taking 0.0 seconds to get val score of 0.1124
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (45, 1, 0), which had val score of 0.0764
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 100 of 400 combinations so far
# Already Trained and Tested combination (45, 0, 1), which had val score of 0.0752
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 100 of 400 combinations so far
# 	round 2 iteration:  1
#
# Trained and Tested combination 101 of 400: (43, 0, 0), taking 0.0 seconds to get val score of 0.1145
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (45, 0, 0), which had val score of 0.1161
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 101 of 400 combinations so far
# Trained and Tested combination 102 of 400: (44, 1, 0), taking 0.0 seconds to get val score of 0.0807
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 103 of 400: (44, 0, 1), taking 0.0 seconds to get val score of 0.0777
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (45, 0, 0), which had val score of 0.1161
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 103 of 400 combinations so far
# Trained and Tested combination 104 of 400: (47, 0, 0), taking 0.0 seconds to get val score of 0.1187
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 105 of 400: (46, 1, 0), taking 0.0 seconds to get val score of 0.0752
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 106 of 400: (46, 0, 1), taking 0.0 seconds to get val score of 0.0702
#         Current best combo: (20, 0, 1) with val score 0.1567
# % Combos Checked Thus Far: 106 out of 400 which is 26.5%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 107 of 400: (39, 0, 0), taking 0.0 seconds to get val score of 0.117
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 108 of 400: (41, 0, 0), taking 0.0 seconds to get val score of 0.1166
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (40, 1, 0), which had val score of 0.0855
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 108 of 400 combinations so far
# Already Trained and Tested combination (40, 0, 1), which had val score of 0.0682
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 108 of 400 combinations so far
# 	round 3 iteration:  1
#
# Trained and Tested combination 109 of 400: (38, 0, 0), taking 0.0 seconds to get val score of 0.1269
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (40, 0, 0), which had val score of 0.1211
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 109 of 400 combinations so far
# Trained and Tested combination 110 of 400: (39, 1, 0), taking 0.0 seconds to get val score of 0.0933
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 111 of 400: (39, 0, 1), taking 0.0 seconds to get val score of 0.0654
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (40, 0, 0), which had val score of 0.1211
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 111 of 400 combinations so far
# Trained and Tested combination 112 of 400: (42, 0, 0), taking 0.0 seconds to get val score of 0.1174
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 113 of 400: (41, 1, 0), taking 0.0 seconds to get val score of 0.086
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 114 of 400: (41, 0, 1), taking 0.0 seconds to get val score of 0.0688
#         Current best combo: (20, 0, 1) with val score 0.1567
# % Combos Checked Thus Far: 114 out of 400 which is 28.499999999999996%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Trained and Tested combination 115 of 400: (34, 0, 0), taking 0.0 seconds to get val score of 0.1461
#         Current best combo: (20, 0, 1) with val score 0.1567
# Trained and Tested combination 116 of 400: (36, 0, 0), taking 0.0 seconds to get val score of 0.1334
#         Current best combo: (20, 0, 1) with val score 0.1567
# Already Trained and Tested combination (35, 1, 0), which had val score of 0.1074
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 116 of 400 combinations so far
# Already Trained and Tested combination (35, 0, 1), which had val score of 0.1006
#         Current best combo: (20, 0, 1) with val score 0.1567.
#         Has trained 116 of 400 combinations so far
# 	round 4 iteration:  1
#
# Trained and Tested combination 117 of 400: (33, 0, 0), taking 0.0 seconds to get val score of 0.1588
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (35, 0, 0), which had val score of 0.1446
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 117 of 400 combinations so far
# Trained and Tested combination 118 of 400: (34, 1, 0), taking 0.0 seconds to get val score of 0.1136
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 119 of 400: (34, 0, 1), taking 0.0 seconds to get val score of 0.1027
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 120 of 400: (32, 0, 0), taking 0.0 seconds to get val score of 0.1516
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (34, 0, 0), which had val score of 0.1461
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 120 of 400 combinations so far
# Trained and Tested combination 121 of 400: (33, 1, 0), taking 0.0 seconds to get val score of 0.1191
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 122 of 400: (33, 0, 1), taking 0.0 seconds to get val score of 0.1218
#         Current best combo: (33, 0, 0) with val score 0.1588
# % Combos Checked Thus Far: 122 out of 400 which is 30.5%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Trained and Tested combination 123 of 400: (14, 0, 1), taking 0.0 seconds to get val score of 0.1248
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 124 of 400: (16, 0, 1), taking 0.0 seconds to get val score of 0.136
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (15, 1, 1), which had val score of 0.0696
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 124 of 400 combinations so far
# Already Trained and Tested combination (15, 0, 0), which had val score of 0.1299
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 124 of 400 combinations so far
# 	round 5 iteration:  1
#
# Already Trained and Tested combination (15, 0, 1), which had val score of 0.1343
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 124 of 400 combinations so far
# Trained and Tested combination 125 of 400: (17, 0, 1), taking 0.0 seconds to get val score of 0.1458
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 126 of 400: (16, 1, 1), taking 0.0 seconds to get val score of 0.0794
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 127 of 400: (16, 0, 0), taking 0.0 seconds to get val score of 0.1271
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 128 of 400: (14, 0, 0), taking 0.0 seconds to get val score of 0.1236
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (16, 0, 0), which had val score of 0.1271
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 128 of 400 combinations so far
# Already Trained and Tested combination (15, 1, 0), which had val score of 0.0874
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 128 of 400 combinations so far
# Already Trained and Tested combination (15, 0, 1), which had val score of 0.1343
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 128 of 400 combinations so far
# % Combos Checked Thus Far: 128 out of 400 which is 32.0%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# % Combos Checked Thus Far: 128 out of 400 which is 32.0%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Already Trained and Tested combination (19, 0, 1), which had val score of 0.1443
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 128 of 400 combinations so far
# Already Trained and Tested combination (21, 0, 1), which had val score of 0.1562
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 128 of 400 combinations so far
# Already Trained and Tested combination (20, 1, 1), which had val score of 0.0864
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 128 of 400 combinations so far
# Already Trained and Tested combination (20, 0, 0), which had val score of 0.1533
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 128 of 400 combinations so far
# 	round 7 iteration:  1
#
# Already Trained and Tested combination (20, 0, 1), which had val score of 0.1567
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 128 of 400 combinations so far
# Trained and Tested combination 129 of 400: (22, 0, 1), taking 0.0 seconds to get val score of 0.1437
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 130 of 400: (21, 1, 1), taking 0.0 seconds to get val score of 0.0634
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 131 of 400: (21, 0, 0), taking 0.0 seconds to get val score of 0.1531
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 132 of 400: (19, 0, 0), taking 0.0 seconds to get val score of 0.1402
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (21, 0, 0), which had val score of 0.1531
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 132 of 400 combinations so far
# Already Trained and Tested combination (20, 1, 0), which had val score of 0.1131
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 132 of 400 combinations so far
# Already Trained and Tested combination (20, 0, 1), which had val score of 0.1567
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 132 of 400 combinations so far
# % Combos Checked Thus Far: 132 out of 400 which is 33.0%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# % Combos Checked Thus Far: 132 out of 400 which is 33.0%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# Trained and Tested combination 133 of 400: (24, 0, 1), taking 0.0 seconds to get val score of 0.1518
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 134 of 400: (26, 0, 1), taking 0.0 seconds to get val score of 0.1279
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (25, 1, 1), which had val score of 0.0927
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 134 of 400 combinations so far
# Already Trained and Tested combination (25, 0, 0), which had val score of 0.142
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 134 of 400 combinations so far
# 	round 9 iteration:  1
#
# Trained and Tested combination 135 of 400: (23, 0, 1), taking 0.0 seconds to get val score of 0.1466
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (25, 0, 1), which had val score of 0.1346
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 135 of 400 combinations so far
# Trained and Tested combination 136 of 400: (24, 1, 1), taking 0.0 seconds to get val score of 0.0799
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 137 of 400: (24, 0, 0), taking 0.0 seconds to get val score of 0.1525
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (24, 0, 0), which had val score of 0.1525
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 137 of 400 combinations so far
# Trained and Tested combination 138 of 400: (26, 0, 0), taking 0.0 seconds to get val score of 0.1409
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (25, 1, 0), which had val score of 0.1208
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 138 of 400 combinations so far
# Already Trained and Tested combination (25, 0, 1), which had val score of 0.1346
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 138 of 400 combinations so far
# % Combos Checked Thus Far: 138 out of 400 which is 34.5%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 10
#
# 	round 10 iteration:  0
#
# % Combos Checked Thus Far: 138 out of 400 which is 34.5%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 11
#
# 	round 11 iteration:  0
#
# Trained and Tested combination 139 of 400: (29, 1, 0), taking 0.0 seconds to get val score of 0.1186
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 140 of 400: (31, 1, 0), taking 0.0 seconds to get val score of 0.1227
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (30, 0, 0), which had val score of 0.1379
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 140 of 400 combinations so far
# Already Trained and Tested combination (30, 1, 1), which had val score of 0.0954
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 140 of 400 combinations so far
# 	round 11 iteration:  1
#
# Trained and Tested combination 141 of 400: (29, 0, 0), taking 0.0 seconds to get val score of 0.1404
#         Current best combo: (33, 0, 0) with val score 0.1588
# Trained and Tested combination 142 of 400: (31, 0, 0), taking 0.0 seconds to get val score of 0.1481
#         Current best combo: (33, 0, 0) with val score 0.1588
# Already Trained and Tested combination (30, 1, 0), which had val score of 0.1322
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 142 of 400 combinations so far
# Already Trained and Tested combination (30, 0, 1), which had val score of 0.1007
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 142 of 400 combinations so far
# % Combos Checked Thus Far: 142 out of 400 which is 35.5%
# Cruising Coordrdinate 0 of 84
#
# Cruise suspended due to suspicious case
# Guidance: round 12
#
# 	round 12 iteration:  0
#
# % Combos Checked Thus Far: 142 out of 400 which is 35.5%
# Cruising Coordrdinate 0 of 84
#
# Cruising Coordrdinate 0 of 84
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (32, 0, 0), which had val score of 0.1516
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 142 of 400 combinations so far
# Already Trained and Tested combination (34, 0, 0), which had val score of 0.1461
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 142 of 400 combinations so far
# Already Trained and Tested combination (33, 1, 0), which had val score of 0.1191
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 142 of 400 combinations so far
# Already Trained and Tested combination (33, 0, 1), which had val score of 0.1218
#         Current best combo: (33, 0, 0) with val score 0.1588.
#         Has trained 142 of 400 combinations so far
# % Combos Checked Thus Far: 142 out of 400 which is 35.5%
# Max Score:
#  0.15880826909690227
# Max Test Score:
#  0.0296
# Max Combo Index:
#  (33, 0, 0) out of [100, 2, 2] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_neighbors': 34, 'p': 1, 'weights': 'distance'}
# % Combos Checked: 142 out of 400 which is 35.5%
