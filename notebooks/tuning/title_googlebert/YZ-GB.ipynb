# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title'
EMBEDDING_MODEL = 'google-bert_bert-base-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
# Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = False

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import GradientBoostingRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'learning_rate': (1e-8, 1e-6, 1e-4, 1e-2, 1e-1, 1, 10),
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'subsample': (0.25, 0.4, 0.55, 0.7, 0.85, 1),
    'min_samples_split': (2, 4, 8, 16, 32, 64),
    'max_depth': (3, 6, 12, 24, 48, 96, 192, 384),
    'max_features': (0.25, 0.4, 0.55, 0.7, 0.85, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': 42,
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis=1)
train_y = train_data['label']
val_X = val_data.drop('label', axis=1)
val_y = val_data['label']
test_X = test_data.drop('label', axis=1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 72576: (0, 5, 5, 5, 4, 5), taking 0.52 seconds to get val score of -0.009
#         Current best combo: (0, 5, 5, 5, 4, 5) with val score -0.009
# Trained and Tested combination 2 of 72576: (6, 5, 0, 5, 7, 0), taking 0.22 seconds to get val score of 0
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0
# Trained and Tested combination 3 of 72576: (0, 0, 5, 0, 7, 0), taking 0.17 seconds to get val score of -0.009
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0
# Trained and Tested combination 4 of 72576: (0, 0, 5, 0, 4, 0), taking 0.09 seconds to get val score of -0.009
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0
# Trained and Tested combination 5 of 72576: (3, 5, 0, 0, 0, 5), taking 0.35 seconds to get val score of 0.1809
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 6 of 72576: (3, 0, 0, 0, 4, 0), taking 0.02 seconds to get val score of 0.0146
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 7 of 72576: (0, 0, 5, 5, 7, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 8 of 72576: (6, 5, 5, 5, 4, 5), taking 0.4 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 9 of 72576: (3, 0, 0, 5, 0, 5), taking 0.01 seconds to get val score of -0.0072
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 10 of 72576: (6, 0, 0, 0, 0, 0), taking 0.02 seconds to get val score of -1.248607992322145e+46
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 11 of 72576: (6, 5, 0, 5, 4, 5), taking 0.24 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 12 of 72576: (6, 5, 5, 0, 4, 0), taking 1.34 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
#
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 147 of 72576: (4, 3, 3, 3, 4, 3), taking 0.42 seconds to get val score of 0.0733
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 148 of 72576: (3, 2, 3, 3, 4, 3), taking 0.14 seconds to get val score of 0.1235
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 149 of 72576: (3, 4, 3, 3, 4, 3), taking 0.69 seconds to get val score of 0.1286
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 150 of 72576: (3, 3, 2, 3, 4, 3), taking 0.21 seconds to get val score of 0.1332
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 151 of 72576: (3, 3, 4, 3, 4, 3), taking 0.36 seconds to get val score of 0.112
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 152 of 72576: (3, 3, 3, 2, 4, 3), taking 0.32 seconds to get val score of 0.1196
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 153 of 72576: (3, 3, 3, 4, 4, 3), taking 0.23 seconds to get val score of 0.1251
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 154 of 72576: (3, 3, 3, 3, 3, 3), taking 0.28 seconds to get val score of 0.1277
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 155 of 72576: (3, 3, 3, 3, 5, 3), taking 0.28 seconds to get val score of 0.1277
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 156 of 72576: (3, 3, 3, 3, 4, 2), taking 0.23 seconds to get val score of 0.1012
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 157 of 72576: (3, 3, 3, 3, 4, 4), taking 0.33 seconds to get val score of 0.1
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# 	round 0 iteration:  1
#
# Trained and Tested combination 158 of 72576: (2, 2, 3, 3, 4, 3), taking 0.14 seconds to get val score of -0.0064
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 159 of 72576: (4, 2, 3, 3, 4, 3), taking 0.22 seconds to get val score of 0.075
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 160 of 72576: (3, 1, 3, 3, 4, 3), taking 0.08 seconds to get val score of 0.0861
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.1277
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 160 of 72576 combinations so far
# Trained and Tested combination 161 of 72576: (3, 2, 2, 3, 4, 3), taking 0.11 seconds to get val score of 0.1055
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 162 of 72576: (3, 2, 4, 3, 4, 3), taking 0.19 seconds to get val score of 0.1143
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 163 of 72576: (3, 2, 3, 2, 4, 3), taking 0.25 seconds to get val score of 0.1139
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 164 of 72576: (3, 2, 3, 4, 4, 3), taking 0.12 seconds to get val score of 0.0902
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 165 of 72576: (3, 2, 3, 3, 3, 3), taking 0.14 seconds to get val score of 0.1235
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 166 of 72576: (3, 2, 3, 3, 5, 3), taking 0.14 seconds to get val score of 0.1235
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 167 of 72576: (3, 2, 3, 3, 4, 2), taking 0.12 seconds to get val score of 0.0916
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 168 of 72576: (3, 2, 3, 3, 4, 4), taking 0.16 seconds to get val score of 0.0909
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 169 of 72576: (2, 4, 3, 3, 4, 3), taking 0.55 seconds to get val score of 0.0005
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 170 of 72576: (4, 4, 3, 3, 4, 3), taking 1.02 seconds to get val score of 0.0742
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.1277
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 170 of 72576 combinations so far
# Trained and Tested combination 171 of 72576: (3, 5, 3, 3, 4, 3), taking 1.25 seconds to get val score of 0.1376
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 172 of 72576: (3, 4, 2, 3, 4, 3), taking 0.47 seconds to get val score of 0.1565
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 173 of 72576: (3, 4, 4, 3, 4, 3), taking 0.78 seconds to get val score of 0.1129
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 174 of 72576: (3, 4, 3, 2, 4, 3), taking 0.74 seconds to get val score of 0.1152
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 175 of 72576: (3, 4, 3, 4, 4, 3), taking 0.56 seconds to get val score of 0.1308
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 176 of 72576: (3, 4, 3, 3, 3, 3), taking 0.62 seconds to get val score of 0.1286
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 177 of 72576: (3, 4, 3, 3, 5, 3), taking 0.61 seconds to get val score of 0.1286
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 178 of 72576: (3, 4, 3, 3, 4, 2), taking 0.51 seconds to get val score of 0.1081
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 179 of 72576: (3, 4, 3, 3, 4, 4), taking 0.72 seconds to get val score of 0.1152
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 180 of 72576: (2, 3, 2, 3, 4, 3), taking 0.22 seconds to get val score of -0.0046
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 181 of 72576: (4, 3, 2, 3, 4, 3), taking 0.76 seconds to get val score of 0.0822
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 2, 2, 3, 4, 3), which had val score of 0.1055
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 181 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 4, 3), which had val score of 0.1565
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 181 of 72576 combinations so far
# Trained and Tested combination 182 of 72576: (3, 3, 1, 3, 4, 3), taking 0.39 seconds to get val score of 0.0818
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.1277
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 182 of 72576 combinations so far
# Trained and Tested combination 183 of 72576: (3, 3, 2, 2, 4, 3), taking 0.56 seconds to get val score of 0.0859
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 184 of 72576: (3, 3, 2, 4, 4, 3), taking 0.2 seconds to get val score of 0.1104
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 185 of 72576: (3, 3, 2, 3, 3, 3), taking 0.24 seconds to get val score of 0.1332
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 186 of 72576: (3, 3, 2, 3, 5, 3), taking 0.26 seconds to get val score of 0.1332
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 187 of 72576: (3, 3, 2, 3, 4, 2), taking 0.21 seconds to get val score of 0.0996
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 188 of 72576: (3, 3, 2, 3, 4, 4), taking 0.26 seconds to get val score of 0.1055
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 189 of 72576: (2, 3, 3, 4, 4, 3), taking 0.25 seconds to get val score of -0.0049
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 190 of 72576: (4, 3, 3, 4, 4, 3), taking 0.31 seconds to get val score of 0.0511
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 2, 3, 4, 4, 3), which had val score of 0.0902
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 190 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 4, 3), which had val score of 0.1308
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 190 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 4, 3), which had val score of 0.1104
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 190 of 72576 combinations so far
# Trained and Tested combination 191 of 72576: (3, 3, 4, 4, 4, 3), taking 0.32 seconds to get val score of 0.1202
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.1277
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 191 of 72576 combinations so far
# Trained and Tested combination 192 of 72576: (3, 3, 3, 5, 4, 3), taking 0.18 seconds to get val score of 0.0896
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 193 of 72576: (3, 3, 3, 4, 3, 3), taking 0.27 seconds to get val score of 0.1251
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 194 of 72576: (3, 3, 3, 4, 5, 3), taking 0.24 seconds to get val score of 0.1251
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 195 of 72576: (3, 3, 3, 4, 4, 2), taking 0.19 seconds to get val score of 0.1199
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 196 of 72576: (3, 3, 3, 4, 4, 4), taking 0.29 seconds to get val score of 0.1238
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 197 of 72576: (2, 3, 3, 3, 3, 3), taking 0.31 seconds to get val score of -0.0043
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 198 of 72576: (4, 3, 3, 3, 3, 3), taking 0.65 seconds to get val score of 0.0733
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 2, 3, 3, 3, 3), which had val score of 0.1235
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 198 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 3, 3), which had val score of 0.1286
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 198 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3), which had val score of 0.1332
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 198 of 72576 combinations so far
# Trained and Tested combination 199 of 72576: (3, 3, 4, 3, 3, 3), taking 0.46 seconds to get val score of 0.112
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 200 of 72576: (3, 3, 3, 2, 3, 3), taking 0.36 seconds to get val score of 0.1196
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 3, 3, 4, 3, 3), which had val score of 0.1251
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 200 of 72576 combinations so far
# Trained and Tested combination 201 of 72576: (3, 3, 3, 3, 2, 3), taking 0.29 seconds to get val score of 0.1235
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.1277
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 201 of 72576 combinations so far
# Trained and Tested combination 202 of 72576: (3, 3, 3, 3, 3, 2), taking 0.24 seconds to get val score of 0.1012
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 203 of 72576: (3, 3, 3, 3, 3, 4), taking 0.33 seconds to get val score of 0.1
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 204 of 72576: (2, 3, 3, 3, 5, 3), taking 0.27 seconds to get val score of -0.0043
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 205 of 72576: (4, 3, 3, 3, 5, 3), taking 0.41 seconds to get val score of 0.0733
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 2, 3, 3, 5, 3), which had val score of 0.1235
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 205 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 5, 3), which had val score of 0.1286
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 205 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 5, 3), which had val score of 0.1332
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 205 of 72576 combinations so far
# Trained and Tested combination 206 of 72576: (3, 3, 4, 3, 5, 3), taking 0.77 seconds to get val score of 0.112
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 207 of 72576: (3, 3, 3, 2, 5, 3), taking 0.5 seconds to get val score of 0.1196
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Already Trained and Tested combination (3, 3, 3, 4, 5, 3), which had val score of 0.1251
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 207 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.1277
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809.
#         Has trained 207 of 72576 combinations so far
# Trained and Tested combination 208 of 72576: (3, 3, 3, 3, 6, 3), taking 0.42 seconds to get val score of 0.1277
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 209 of 72576: (3, 3, 3, 3, 5, 2), taking 0.24 seconds to get val score of 0.1012
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 210 of 72576: (3, 3, 3, 3, 5, 4), taking 0.34 seconds to get val score of 0.1
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 211 of 72576: (2, 5, 0, 0, 0, 5), taking 0.21 seconds to get val score of -0.0037
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 212 of 72576: (4, 5, 0, 0, 0, 5), taking 0.61 seconds to get val score of -0.042
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 213 of 72576: (3, 4, 0, 0, 0, 5), taking 0.28 seconds to get val score of 0.1172
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1809
# Trained and Tested combination 214 of 72576: (3, 5, 1, 0, 0, 5), taking 0.51 seconds to get val score of 0.1851
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 215 of 72576: (3, 5, 0, 1, 0, 5), taking 0.34 seconds to get val score of 0.1483
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 216 of 72576: (3, 5, 0, 0, 1, 5), taking 0.24 seconds to get val score of 0.121
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 217 of 72576: (3, 5, 0, 0, 0, 4), taking 0.4 seconds to get val score of 0.1144
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 218 of 72576: (2, 5, 1, 0, 0, 5), taking 0.2 seconds to get val score of -0.0041
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 219 of 72576: (4, 5, 1, 0, 0, 5), taking 0.23 seconds to get val score of 0.0819
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 220 of 72576: (3, 4, 1, 0, 0, 5), taking 0.21 seconds to get val score of 0.154
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 0, 0, 0, 5), which had val score of 0.1809
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 220 of 72576 combinations so far
# Trained and Tested combination 221 of 72576: (3, 5, 2, 0, 0, 5), taking 0.42 seconds to get val score of 0.1265
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 222 of 72576: (3, 5, 1, 1, 0, 5), taking 0.21 seconds to get val score of 0.1808
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 223 of 72576: (3, 5, 1, 0, 1, 5), taking 0.26 seconds to get val score of 0.1072
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 224 of 72576: (3, 5, 1, 0, 0, 4), taking 0.83 seconds to get val score of 0.0818
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# % Combos Checked Thus Far: 224 out of 72576 which is 0.30864199999999997%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 225 of 72576: (2, 5, 5, 5, 7, 0), taking 0.5 seconds to get val score of 0.0031
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 226 of 72576: (4, 5, 5, 5, 7, 0), taking 0.62 seconds to get val score of 0.0523
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 227 of 72576: (3, 4, 5, 5, 7, 0), taking 0.27 seconds to get val score of 0.117
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 228 of 72576: (3, 5, 4, 5, 7, 0), taking 0.69 seconds to get val score of 0.1074
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 229 of 72576: (3, 5, 5, 4, 7, 0), taking 1.18 seconds to get val score of 0.0716
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 230 of 72576: (3, 5, 5, 5, 6, 0), taking 0.54 seconds to get val score of 0.1111
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 231 of 72576: (3, 5, 5, 5, 7, 1), taking 0.79 seconds to get val score of 0.1288
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# 	round 1 iteration:  1
#
# Trained and Tested combination 232 of 72576: (2, 4, 5, 5, 7, 0), taking 0.23 seconds to get val score of -0.003
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 233 of 72576: (4, 4, 5, 5, 7, 0), taking 0.28 seconds to get val score of 0.0533
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 234 of 72576: (3, 3, 5, 5, 7, 0), taking 0.12 seconds to get val score of 0.1057
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 5, 5, 7, 0), which had val score of 0.1111
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 234 of 72576 combinations so far
# ...
# Trained and Tested combination 539 of 72576: (3, 4, 0, 0, 0, 0), taking 0.12 seconds to get val score of 0.1029
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 540 of 72576: (3, 5, 1, 0, 0, 0), taking 0.31 seconds to get val score of 0.1277
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 541 of 72576: (3, 5, 0, 1, 0, 0), taking 0.25 seconds to get val score of 0.1182
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 542 of 72576: (3, 5, 0, 0, 1, 0), taking 0.31 seconds to get val score of 0.1035
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 543 of 72576: (3, 5, 0, 0, 0, 1), taking 0.28 seconds to get val score of 0.115
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# 	round 13 iteration:  1
#
# Trained and Tested combination 544 of 72576: (2, 5, 1, 0, 0, 0), taking 0.39 seconds to get val score of 0.001
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 545 of 72576: (4, 5, 1, 0, 0, 0), taking 0.34 seconds to get val score of 0.049
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 546 of 72576: (3, 4, 1, 0, 0, 0), taking 0.15 seconds to get val score of 0.1044
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 0, 0, 0, 0), which had val score of 0.1281
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 546 of 72576 combinations so far
# Trained and Tested combination 547 of 72576: (3, 5, 2, 0, 0, 0), taking 0.35 seconds to get val score of 0.0807
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 548 of 72576: (3, 5, 1, 1, 0, 0), taking 0.29 seconds to get val score of 0.1154
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 549 of 72576: (3, 5, 1, 0, 1, 0), taking 0.38 seconds to get val score of 0.1216
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 550 of 72576: (3, 5, 1, 0, 0, 1), taking 0.37 seconds to get val score of 0.0915
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# % Combos Checked Thus Far: 550 out of 72576 which is 0.757826%
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 14
#
# 	round 14 iteration:  0
#
# Trained and Tested combination 551 of 72576: (2, 5, 0, 0, 4, 5), taking 0.21 seconds to get val score of 0.001
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 552 of 72576: (4, 5, 0, 0, 4, 5), taking 0.21 seconds to get val score of 0.1227
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 553 of 72576: (3, 4, 0, 0, 4, 5), taking 0.11 seconds to get val score of 0.1356
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 554 of 72576: (3, 5, 1, 0, 4, 5), taking 0.24 seconds to get val score of 0.1593
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 555 of 72576: (3, 5, 0, 1, 4, 5), taking 0.2 seconds to get val score of 0.1268
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 556 of 72576: (3, 5, 0, 0, 3, 5), taking 0.26 seconds to get val score of 0.1565
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 0, 0, 5, 5), which had val score of 0.1565
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 556 of 72576 combinations so far
# Trained and Tested combination 557 of 72576: (3, 5, 0, 0, 4, 4), taking 0.74 seconds to get val score of 0.1496
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# 	round 14 iteration:  1
#
# Trained and Tested combination 558 of 72576: (2, 5, 1, 0, 4, 5), taking 0.33 seconds to get val score of 0.0039
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 559 of 72576: (4, 5, 1, 0, 4, 5), taking 0.26 seconds to get val score of 0.1241
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 560 of 72576: (3, 4, 1, 0, 4, 5), taking 0.12 seconds to get val score of 0.1505
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 0, 0, 4, 5), which had val score of 0.1565
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 560 of 72576 combinations so far
# Trained and Tested combination 561 of 72576: (3, 5, 2, 0, 4, 5), taking 0.29 seconds to get val score of 0.1709
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 562 of 72576: (3, 5, 1, 1, 4, 5), taking 0.23 seconds to get val score of 0.1168
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 563 of 72576: (3, 5, 1, 0, 3, 5), taking 0.27 seconds to get val score of 0.1593
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 564 of 72576: (3, 5, 1, 0, 5, 5), taking 0.27 seconds to get val score of 0.1593
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 565 of 72576: (3, 5, 1, 0, 4, 4), taking 1.17 seconds to get val score of 0.1208
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 566 of 72576: (2, 5, 0, 0, 3, 5), taking 0.22 seconds to get val score of 0.001
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 567 of 72576: (4, 5, 0, 0, 3, 5), taking 0.23 seconds to get val score of 0.1227
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 568 of 72576: (3, 4, 0, 0, 3, 5), taking 0.11 seconds to get val score of 0.1356
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 1, 0, 3, 5), which had val score of 0.1593
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 568 of 72576 combinations so far
# Trained and Tested combination 569 of 72576: (3, 5, 0, 1, 3, 5), taking 0.26 seconds to get val score of 0.1268
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 570 of 72576: (3, 5, 0, 0, 2, 5), taking 0.45 seconds to get val score of 0.1281
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 0, 0, 4, 5), which had val score of 0.1565
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 570 of 72576 combinations so far
# Trained and Tested combination 571 of 72576: (3, 5, 0, 0, 3, 4), taking 0.89 seconds to get val score of 0.1496
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# % Combos Checked Thus Far: 571 out of 72576 which is 0.786761%
# Cruising Coordrdinate 0 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 15
#
# 	round 15 iteration:  0
#
# Trained and Tested combination 572 of 72576: (2, 5, 5, 0, 0, 5), taking 0.27 seconds to get val score of -0.0031
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 573 of 72576: (4, 5, 5, 0, 0, 5), taking 0.19 seconds to get val score of 0.0869
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 574 of 72576: (3, 4, 5, 0, 0, 5), taking 0.11 seconds to get val score of 0.0944
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 575 of 72576: (3, 5, 4, 0, 0, 5), taking 0.25 seconds to get val score of 0.1364
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 576 of 72576: (3, 5, 5, 1, 0, 5), taking 0.51 seconds to get val score of 0.0954
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 577 of 72576: (3, 5, 5, 0, 1, 5), taking 0.3 seconds to get val score of 0.1156
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 578 of 72576: (3, 5, 5, 0, 0, 4), taking 1.23 seconds to get val score of 0.0706
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# 	round 15 iteration:  1
#
# Trained and Tested combination 579 of 72576: (2, 5, 4, 0, 0, 5), taking 0.21 seconds to get val score of -0.0032
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 580 of 72576: (4, 5, 4, 0, 0, 5), taking 0.24 seconds to get val score of 0.0615
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 581 of 72576: (3, 4, 4, 0, 0, 5), taking 0.12 seconds to get val score of 0.1329
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 582 of 72576: (3, 5, 3, 0, 0, 5), taking 0.27 seconds to get val score of 0.0996
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 5, 0, 0, 5), which had val score of 0.1047
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 582 of 72576 combinations so far
# Trained and Tested combination 583 of 72576: (3, 5, 4, 1, 0, 5), taking 0.23 seconds to get val score of 0.1229
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 584 of 72576: (3, 5, 4, 0, 1, 5), taking 0.25 seconds to get val score of 0.1487
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 585 of 72576: (3, 5, 4, 0, 0, 4), taking 1.06 seconds to get val score of 0.1122
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 586 of 72576: (2, 5, 5, 0, 1, 5), taking 0.41 seconds to get val score of 0.0024
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 587 of 72576: (4, 5, 5, 0, 1, 5), taking 0.26 seconds to get val score of -0.0394
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Trained and Tested combination 588 of 72576: (3, 4, 5, 0, 1, 5), taking 0.12 seconds to get val score of 0.1202
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 4, 0, 1, 5), which had val score of 0.1487
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 588 of 72576 combinations so far
# Trained and Tested combination 589 of 72576: (3, 5, 5, 1, 1, 5), taking 0.24 seconds to get val score of 0.0996
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# Already Trained and Tested combination (3, 5, 5, 0, 0, 5), which had val score of 0.1047
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 589 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 5, 0, 2, 5), which had val score of 0.1468
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 589 of 72576 combinations so far
# Trained and Tested combination 590 of 72576: (3, 5, 5, 0, 1, 4), taking 2.16 seconds to get val score of -0.1046
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851
# % Combos Checked Thus Far: 590 out of 72576 which is 0.812941%
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 16
#
# 	round 16 iteration:  0
#
# Already Trained and Tested combination (2, 5, 0, 0, 0, 5), which had val score of -0.0037
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (4, 5, 0, 0, 0, 5), which had val score of -0.042
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 0, 0, 0, 5), which had val score of 0.1172
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 1, 0, 0, 5), which had val score of 0.1851
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 0, 1, 0, 5), which had val score of 0.1483
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 0, 0, 1, 5), which had val score of 0.121
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 0, 0, 0, 4), which had val score of 0.1144
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# 	round 16 iteration:  1
#
# Already Trained and Tested combination (2, 5, 1, 0, 0, 5), which had val score of -0.0041
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (4, 5, 1, 0, 0, 5), which had val score of 0.0819
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 1, 0, 0, 5), which had val score of 0.154
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 0, 0, 0, 5), which had val score of 0.1809
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 2, 0, 0, 5), which had val score of 0.1265
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 1, 1, 0, 5), which had val score of 0.1808
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 1, 0, 1, 5), which had val score of 0.1072
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 1, 0, 0, 4), which had val score of 0.0818
#         Current best combo: (3, 5, 1, 0, 0, 5) with val score 0.1851.
#         Has trained 590 of 72576 combinations so far
# % Combos Checked Thus Far: 590 out of 72576 which is 0.812941%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 590 out of 72576 which is 0.812941%
# Max Score:
#  0.18513192274450696
# Max Test Score:
#  0.071257
# Max Combo Index:
#  (3, 5, 1, 0, 0, 5) out of [7, 6, 6, 6, 8, 6] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'learning_rate': 0.01, 'n_estimators': 800, 'subsample': 0.4, 'min_samples_split': 2, 'max_depth': 3, 'max_features': 1}
# % Combos Checked: 590 out of 72576 which is 0.812941%
