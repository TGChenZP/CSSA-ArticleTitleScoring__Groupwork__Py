# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'ada'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title&pyq'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import AdaBoostRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'learning_rate': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# Successfully read in tuning result of 27 rows, for 27.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (0, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 3), which had val score of 0.2241
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (0, 0), which had val score of 0.1163
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 0), which had val score of 0.0411
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 6), which had val score of -3.0101
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (0, 6), which had val score of -3.0101
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 3), which had val score of 0.1001
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (3, 3), which had val score of 0.0957
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (2, 3), which had val score of 0.1581
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (4, 3), which had val score of 0.1071
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (3, 2), which had val score of 0.0533
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (3, 4), which had val score of 0.1158
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (1, 3), which had val score of 0.156
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (3, 3), which had val score of 0.0957
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (2, 2), which had val score of 0.036
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (2, 4), which had val score of 0.1781
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (3, 3), which had val score of 0.0957
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 3), which had val score of 0.1001
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (4, 2), which had val score of 0.0519
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (4, 4), which had val score of 0.0839
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (2, 4), which had val score of 0.1781
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (4, 4), which had val score of 0.0839
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (3, 3), which had val score of 0.0957
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (3, 5), which had val score of -0.8805
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (1, 3), which had val score of 0.156
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (0, 2), which had val score of 0.0582
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (0, 4), which had val score of 0.0787
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# % Combos Checked Thus Far: 27 out of 42 which is 64.285714%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 6
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Already Trained and Tested combination (4, 0), which had val score of 0.0545
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 1), which had val score of 0.0605
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (3, 0), which had val score of 0.0426
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 0), which had val score of 0.0411
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (4, 1), which had val score of 0.0535
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (4, 1), which had val score of 0.0535
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 0), which had val score of 0.0411
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 2), which had val score of 0.0704
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# % Combos Checked Thus Far: 27 out of 42 which is 64.285714%
# Cruising Coordrdinate 0 of 6
#
# Cruising Coordrdinate 0 of 6
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Already Trained and Tested combination (4, 3), which had val score of 0.1071
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 2), which had val score of 0.0704
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (5, 4), which had val score of 0.0817
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# % Combos Checked Thus Far: 27 out of 42 which is 64.285714%
# Cruising Coordrdinate 0 of 6
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (1, 0), which had val score of 0.0492
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (0, 1), which had val score of 0.0843
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# % Combos Checked Thus Far: 27 out of 42 which is 64.285714%
# Cruising Coordrdinate 0 of 6
#
# Cruising Coordrdinate 0 of 6
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Already Trained and Tested combination (1, 3), which had val score of 0.156
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (0, 2), which had val score of 0.0582
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# Already Trained and Tested combination (0, 4), which had val score of 0.0787
#         Current best combo: (0, 3) with val score 0.2241.
#         Has trained 27 of 42 combinations so far
# % Combos Checked Thus Far: 27 out of 42 which is 64.285714%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 27 out of 42 which is 64.285714%
# Max Score:
#  0.224103
# Max Test Score:
#  0.041504
# Max Combo Index:
#  (0, 3) out of [6, 7] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'learning_rate': 0.1}
# % Combos Checked: 27 out of 42 which is 64.285714%
