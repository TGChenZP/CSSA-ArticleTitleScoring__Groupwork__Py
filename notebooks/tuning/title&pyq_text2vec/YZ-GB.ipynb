# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title&pyq'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
# Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = False

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import GradientBoostingRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'learning_rate': (1e-8, 1e-6, 1e-4, 1e-2, 1e-1, 1, 10),
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'subsample': (0.25, 0.4, 0.55, 0.7, 0.85, 1),
    'min_samples_split': (2, 4, 8, 16, 32, 64),
    'max_depth': (3, 6, 12, 24, 48, 96, 192, 384),
    'max_features': (0.25, 0.4, 0.55, 0.7, 0.85, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': 42,
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis=1)
train_y = train_data['label']
val_X = val_data.drop('label', axis=1)
val_y = val_data['label']
test_X = test_data.drop('label', axis=1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# Error message: nan
# Error Importing this Row: (0, n_restarts_optimizer     0.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.050000
# random_state            42.000000
# Precedence               0.000000
# learning_rate                 NaN
# n_estimators                  NaN
# subsample                     NaN
# min_samples_split             NaN
# max_depth                     NaN
# max_features                  NaN
# Name: 0, dtype: float64)
# Error message: nan
# Error Importing this Row: (1, n_restarts_optimizer     5.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.030000
# random_state            42.000000
# Precedence               1.000000
# learning_rate                 NaN
# n_estimators                  NaN
# subsample                     NaN
# min_samples_split             NaN
# max_depth                     NaN
# max_features                  NaN
# Name: 1, dtype: float64)
# Error message: nan
# Error Importing this Row: (2, n_restarts_optimizer     3.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.020000
# random_state            42.000000
# Precedence               2.000000
# learning_rate                 NaN
# n_estimators                  NaN
# subsample                     NaN
# min_samples_split             NaN
# max_depth                     NaN
# max_features                  NaN
# Name: 2, dtype: float64)
# Error message: nan
# Error Importing this Row: (3, n_restarts_optimizer     2.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.020000
# random_state            42.000000
# Precedence               3.000000
# learning_rate                 NaN
# n_estimators                  NaN
# subsample                     NaN
# min_samples_split             NaN
# max_depth                     NaN
# max_features                  NaN
# Name: 3, dtype: float64)
# Error message: nan
# Error Importing this Row: (4, n_restarts_optimizer     4.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.020000
# random_state            42.000000
# Precedence               4.000000
# learning_rate                 NaN
# n_estimators                  NaN
# subsample                     NaN
# min_samples_split             NaN
# max_depth                     NaN
# max_features                  NaN
# Name: 4, dtype: float64)
# Error message: nan
# Error Importing this Row: (5, n_restarts_optimizer     1.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.010000
# random_state            42.000000
# Precedence               5.000000
# learning_rate                 NaN
# n_estimators                  NaN
# subsample                     NaN
# min_samples_split             NaN
# max_depth                     NaN
# max_features                  NaN
# Name: 5, dtype: float64)
# Successfully read in tuning result of 3602 rows, for 3596.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (0, 5, 5, 5, 4, 5) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 5, 5, 5, 4, 5), which had val score of -0.009
#         Current best combo: (0, 5, 5, 5, 4, 5) with val score -0.009.
#         Has trained 3596 of 72576 combinations so far
# As new Best Combo (6, 5, 0, 5, 7, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (6, 5, 0, 5, 7, 0), which had val score of 0.0
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0.0.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 7, 0), which had val score of -0.009
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0.0.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 4, 0), which had val score of -0.009
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0.0.
#         Has trained 3596 of 72576 combinations so far
# As new Best Combo (3, 5, 0, 0, 0, 5) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 5, 0, 0, 0, 5), which had val score of 0.1026
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 7, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 5, 5, 5, 4, 5), which had val score of 0.0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 5, 0, 5), which had val score of -0.0072
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 0, 0, 0, 0), which had val score of -9.22241018081529e+46
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 5, 0, 5, 4, 5), which had val score of 0.0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 5, 5, 0, 4, 0), which had val score of 0.0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 5, 0, 4, 5), which had val score of -2.188378324236383e+47
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 5, 5, 4, 0), which had val score of -1.1840522865392927e+44
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 5, 5, 7, 0), which had val score of 0.0051
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 5, 0, 7, 5), which had val score of -2.188378324236383e+47
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 5), which had val score of -0.0055
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 5, 5, 4, 0), which had val score of 0.0476
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 0, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 5, 0, 4, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 4, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 5, 5, 7, 5), which had val score of -0.0006
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 0, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 5, 4, 5), which had val score of -0.0072
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 5, 5, 4, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 5, 0, 0, 7, 0), which had val score of 0.0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 0, 0, 4, 0), which had val score of -1.8474981069987751e+49
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 4, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 5, 5, 5, 0, 5), which had val score of 0.0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 5, 7, 5), which had val score of -0.0072
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 5, 5, 7, 5), which had val score of -3.620277435953958e+29
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 5, 0, 0, 7, 5), which had val score of 0.0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 5, 5, 0, 0), which had val score of -4.0776844795655704e+40
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 5, 5, 4, 5), which had val score of 0.0915
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 0, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 5, 0, 0, 0), which had val score of 0.0116
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 0, 0, 0, 5), which had val score of -2.0250652588440705e+46
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 5, 5, 4, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 0, 5, 0, 5), which had val score of -2.7725817313406334e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 7, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 0, 5, 7, 0), which had val score of -0.0096
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 5, 0, 4, 0), which had val score of -5.3527893447373365e+47
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 5, 5, 0, 5), which had val score of -0.0045
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 0, 5, 7, 5), which had val score of -2.7725817313406334e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 0, 5, 0, 5), which had val score of -0.0096
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 0, 5, 4, 0), which had val score of -2.7725817313406334e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 4, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 5, 5, 7, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 0, 5, 7, 0), which had val score of -2.7725817313406334e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 0, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 4, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 5, 5, 0, 0), which had val score of -0.0042
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 5, 5, 4, 0), which had val score of 0.0051
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 7, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 0, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 0, 0, 5, 0, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 5, 0, 7, 0), which had val score of 0.0653
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 0, 0, 0, 4, 5), which had val score of -2.1980309032472217e+49
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 0, 5, 7, 5), which had val score of -0.0096
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 5, 5, 0, 5), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (0, 5, 0, 5, 4, 0), which had val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 7, 5), which had val score of -0.0055
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 7, 0), which had val score of -0.0162
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 5, 0, 0, 0, 5), which had val score of 0.0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (6, 5, 5, 5, 7, 5), which had val score of 0.0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 5, 0,
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 4, 3), which had val score of 0.0868
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 4, 3), which had val score of 0.098
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 4, 3), which had val score of 0.0895
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3), which had val score of 0.1057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 5, 3), which had val score of 0.1057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 4, 2), which had val score of 0.0768
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 4, 4), which had val score of 0.1062
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (2, 3, 4, 3, 4, 3), which had val score of -0.0061
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 3, 4, 3, 4, 3), which had val score of -0.0232
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 2, 4, 3, 4, 3), which had val score of 0.0523
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 4, 3, 4, 3), which had val score of 0.0682
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 5, 3, 4, 3), which had val score of -0.0191
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 2, 4, 3), which had val score of 0.0405
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 4, 3), which had val score of 0.0606
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 3, 3), which had val score of 0.0732
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 5, 3), which had val score of 0.0732
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 4, 2), which had val score of 0.0631
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 4, 4), which had val score of 0.0742
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (2, 3, 3, 2, 4, 3), which had val score of -0.0057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 3, 3, 2, 4, 3), which had val score of -0.1005
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 2, 3, 2, 4, 3), which had val score of 0.0542
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 3, 2, 4, 3), which had val score of 0.0439
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 4, 3), which had val score of 0.098
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 2, 4, 3), which had val score of 0.0405
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 1, 4, 3), which had val score of 0.0959
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 3, 3), which had val score of 0.0615
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 5, 3), which had val score of 0.0615
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 4, 2), which had val score of 0.0372
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 4, 4), which had val score of 0.111
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (2, 3, 3, 4, 4, 3), which had val score of -0.0069
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 3, 3, 4, 4, 3), which had val score of 0.0162
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 2, 3, 4, 4, 3), which had val score of 0.0338
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 4, 3), which had val score of 0.0815
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 4, 3), which had val score of 0.0895
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 4, 3), which had val score of 0.0606
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 5, 4, 3), which had val score of 0.0516
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 3, 3), which had val score of 0.0736
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 5, 3), which had val score of 0.0736
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 4, 2), which had val score of 0.0679
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 4, 4), which had val score of 0.0767
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (2, 3, 3, 3, 3, 3), which had val score of -0.0065
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 3, 3), which had val score of -0.0156
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 2, 3, 3, 3, 3), which had val score of 0.0439
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 3, 3), which had val score of 0.0527
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3), which had val score of 0.1057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 3, 3), which had val score of 0.0732
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 3, 3), which had val score of 0.0615
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 3, 3), which had val score of 0.0736
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 2, 3), which had val score of 0.0592
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 3, 2), which had val score of 0.055
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 3, 4), which had val score of 0.0724
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (2, 3, 3, 3, 5, 3), which had val score of -0.0065
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 5, 3), which had val score of -0.0156
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 2, 3, 3, 5, 3), which had val score of 0.0439
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 5, 3), which had val score of 0.0527
# ...
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 5, 0, 7, 2), which had val score of 0.0312
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# % Combos Checked Thus Far: 3596 out of 72576 which is 4.954806%
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 120
#
# 	round 120 iteration:  0
#
# Already Trained and Tested combination (2, 0, 0, 0, 4, 0), which had val score of -0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 4, 0), which had val score of -0.1185
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 0, 0, 4, 0), which had val score of 0.0005
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 4, 0), which had val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 4, 0), which had val score of -0.0057
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 3, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 5, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 1), which had val score of 0.019
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# 	round 120 iteration:  1
#
# Already Trained and Tested combination (2, 1, 0, 0, 4, 0), which had val score of -0.0089
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 1, 0, 0, 4, 0), which had val score of -0.2496
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 2, 0, 0, 4, 0), which had val score of -0.0103
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0, 4, 0), which had val score of 0.0726
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 0, 1, 4, 0), which had val score of 0.0062
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 0, 0, 3, 0), which had val score of 0.0005
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 0, 0, 5, 0), which had val score of 0.0005
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 0, 0, 4, 1), which had val score of 0.0177
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (2, 0, 1, 0, 4, 0), which had val score of -0.0083
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 4, 0), which had val score of 0.3421
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0, 4, 0), which had val score of 0.0726
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 2, 0, 4, 0), which had val score of 0.0135
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 1, 4, 0), which had val score of 0.0423
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 3, 0), which had val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 5, 0), which had val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 4, 1), which had val score of 0.0153
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (2, 0, 0, 1, 4, 0), which had val score of -0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 1, 4, 0), which had val score of 0.0513
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 0, 1, 4, 0), which had val score of 0.0062
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 1, 4, 0), which had val score of 0.0423
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 2, 4, 0), which had val score of 0.0108
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 3, 0), which had val score of -0.0057
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 5, 0), which had val score of -0.0057
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 4, 1), which had val score of 0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (2, 0, 0, 0, 3, 0), which had val score of -0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 3, 0), which had val score of -0.1185
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 0, 0, 3, 0), which had val score of 0.0005
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 3, 0), which had val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 3, 0), which had val score of -0.0057
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 2, 0), which had val score of -0.0092
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 3, 1), which had val score of 0.019
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (2, 0, 0, 0, 4, 1), which had val score of -0.0086
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 4, 1), which had val score of -0.0552
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 0, 0, 4, 1), which had val score of 0.0177
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 4, 1), which had val score of 0.0153
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 4, 1), which had val score of 0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 3, 1), which had val score of 0.019
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 5, 1), which had val score of 0.019
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 2), which had val score of 0.0177
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# % Combos Checked Thus Far: 3596 out of 72576 which is 4.954806%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (3, 0, 1, 0, 7, 0), which had val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (5, 0, 1, 0, 7, 0), which had val score of -48.4196
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 1, 1, 0, 7, 0), which had val score of 0.3297
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 7, 0), which had val score of -0.1185
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 7, 0), which had val score of 0.0812
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 1, 7, 0), which had val score of 0.1067
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 6, 0), which had val score of 0.3421
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 7, 1), which had val score of -0.0314
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (3, 0, 1, 0, 6, 0), which had val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (5, 0, 1, 0, 6, 0), which had val score of -48.4196
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 1, 1, 0, 6, 0), which had val score of 0.3297
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 6, 0), which had val score of -0.1185
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 6, 0), which had val score of 0.0812
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 1, 6, 0), which had val score of 0.1067
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 5, 0), which had val score of 0.3421
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 7, 0), which had val score of 0.3421
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 6, 1), which had val score of -0.0314
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3596 of 72576 combinations so far
# % Combos Checked Thus Far: 3596 out of 72576 which is 4.954806%
# Max Score:
#  0.342059
# Max Test Score:
#  0.070344
# Max Combo Index:
#  (4, 0, 1, 0, 7, 0) out of [7, 6, 6, 6, 8, 6] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'learning_rate': 0.1, 'n_estimators': 25, 'subsample': 0.4, 'min_samples_split': 2, 'max_depth': 384, 'max_features': 0.25}
# % Combos Checked: 3596 out of 72576 which is 4.954806%
