# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title&pyq'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
# Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = False

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import GradientBoostingRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'learning_rate': (1e-8, 1e-6, 1e-4, 1e-2, 1e-1, 1, 10),
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'subsample': (0.25, 0.4, 0.55, 0.7, 0.85, 1),
    'min_samples_split': (2, 4, 8, 16, 32, 64),
    'max_depth': (3, 6, 12, 24, 48, 96, 192, 384),
    'max_features': (0.25, 0.4, 0.55, 0.7, 0.85, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': 42,
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis=1)
train_y = train_data['label']
val_X = val_data.drop('label', axis=1)
val_y = val_data['label']
test_X = test_data.drop('label', axis=1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# Error message: 'learning_rate'
# Error Importing this Row: (0, n_restarts_optimizer     0.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.050000
# random_state            42.000000
# Precedence               0.000000
# Name: 0, dtype: float64)
# Error message: 'learning_rate'
# Error Importing this Row: (1, n_restarts_optimizer     5.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.030000
# random_state            42.000000
# Precedence               1.000000
# Name: 1, dtype: float64)
# Error message: 'learning_rate'
# Error Importing this Row: (2, n_restarts_optimizer     3.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.020000
# random_state            42.000000
# Precedence               2.000000
# Name: 2, dtype: float64)
# Error message: 'learning_rate'
# Error Importing this Row: (3, n_restarts_optimizer     2.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.020000
# random_state            42.000000
# Precedence               3.000000
# Name: 3, dtype: float64)
# Error message: 'learning_rate'
# Error Importing this Row: (4, n_restarts_optimizer     4.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.020000
# random_state            42.000000
# Precedence               4.000000
# Name: 4, dtype: float64)
# Error message: 'learning_rate'
# Error Importing this Row: (5, n_restarts_optimizer     1.000000
# Train r2                 0.999992
# Val r2                  -3.120072
# Test r2                 -4.203346
# Train RMSE               0.000834
# Val RMSE                 0.611300
# Test RMSE                0.624881
# Train MAPE                    NaN
# Val MAPE                      NaN
# Test MAPE                     NaN
# Time                     0.010000
# random_state            42.000000
# Precedence               5.000000
# Name: 5, dtype: float64)
# Successfully read in tuning result of 6 rows, for 0.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 72576: (0, 5, 5, 5, 4, 5), taking 0.31 seconds to get val score of -0.009
#         Current best combo: (0, 5, 5, 5, 4, 5) with val score -0.009
# Trained and Tested combination 2 of 72576: (6, 5, 0, 5, 7, 0), taking 0.41 seconds to get val score of 0
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0
# Trained and Tested combination 3 of 72576: (0, 0, 5, 0, 7, 0), taking 0.06 seconds to get val score of -0.009
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0
# Trained and Tested combination 4 of 72576: (0, 0, 5, 0, 4, 0), taking 0.06 seconds to get val score of -0.009
#         Current best combo: (6, 5, 0, 5, 7, 0) with val score 0
# Trained and Tested combination 5 of 72576: (3, 5, 0, 0, 0, 5), taking 0.31 seconds to get val score of 0.1026
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 6 of 72576: (3, 0, 0, 0, 4, 0), taking 0.02 seconds to get val score of -0.0162
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 7 of 72576: (0, 0, 5, 5, 7, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 8 of 72576: (6, 5, 5, 5, 4, 5), taking 0.34 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 9 of 72576: (3, 0, 0, 5, 0, 5), taking 0.01 seconds to get val score of -0.0072
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 10 of 72576: (6, 0, 0, 0, 0, 0), taking 0.02 seconds to get val score of -9.22241018081529e+46
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 11 of 72576: (6, 5, 0, 5, 4, 5), taking 0.28 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 12 of 72576: (6, 5, 5, 0, 4, 0), taking 2.21 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 13 of 72576: (6, 0, 5, 0, 4, 5), taking 0.02 seconds to get val score of -2.1883783242363837e+47
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 14 of 72576: (6, 0, 5, 5, 4, 0), taking 0.05 seconds to get val score of -1.1840522865392927e+44
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 15 of 72576: (3, 0, 5, 5, 7, 0), taking 0.03 seconds to get val score of 0.0051
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 16 of 72576: (6, 0, 5, 0, 7, 5), taking 0.02 seconds to get val score of -2.1883783242363837e+47
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 17 of 72576: (3, 0, 0, 0, 4, 5), taking 0.01 seconds to get val score of -0.0055
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 18 of 72576: (3, 5, 5, 5, 4, 0), taking 1.04 seconds to get val score of 0.0476
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 19 of 72576: (0, 0, 5, 5, 0, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 20 of 72576: (0, 5, 5, 0, 4, 5), taking 0.46 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 21 of 72576: (0, 5, 0, 0, 4, 0), taking 0.6 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 22 of 72576: (3, 0, 5, 5, 7, 5), taking 0.01 seconds to get val score of -0.0006
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 23 of 72576: (0, 5, 0, 0, 0, 5), taking 0.3 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 24 of 72576: (3, 0, 0, 5, 4, 5), taking 0.01 seconds to get val score of -0.0072
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 25 of 72576: (0, 5, 5, 5, 4, 0), taking 0.95 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 26 of 72576: (6, 5, 0, 0, 7, 0), taking 0.54 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 27 of 72576: (6, 0, 0, 0, 4, 0), taking 0.02 seconds to get val score of -1.8474981069987754e+49
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 28 of 72576: (0, 0, 0, 5, 4, 0), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 29 of 72576: (6, 5, 5, 5, 0, 5), taking 0.24 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 30 of 72576: (3, 0, 0, 5, 7, 5), taking 0.01 seconds to get val score of -0.0072
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 31 of 72576: (6, 0, 5, 5, 7, 5), taking 0.01 seconds to get val score of -3.620277435953958e+29
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 32 of 72576: (6, 5, 0, 0, 7, 5), taking 0.31 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 33 of 72576: (6, 0, 5, 5, 0, 0), taking 0.03 seconds to get val score of -4.0776844795655695e+40
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 34 of 72576: (3, 5, 5, 5, 4, 5), taking 0.29 seconds to get val score of 0.0915
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 35 of 72576: (0, 5, 0, 0, 0, 0), taking 0.41 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 36 of 72576: (3, 0, 5, 0, 0, 0), taking 0.03 seconds to get val score of 0.0116
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 37 of 72576: (6, 0, 0, 0, 0, 5), taking 0.01 seconds to get val score of -2.0250652588440705e+46
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 38 of 72576: (0, 0, 5, 5, 4, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 39 of 72576: (6, 0, 0, 5, 0, 5), taking 0.01 seconds to get val score of -2.7725817313406338e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 40 of 72576: (0, 5, 0, 5, 7, 5), taking 0.28 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 41 of 72576: (3, 5, 0, 5, 7, 0), taking 0.28 seconds to get val score of -0.0096
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 42 of 72576: (6, 0, 5, 0, 4, 0), taking 0.06 seconds to get val score of -5.3527893447373365e+47
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 43 of 72576: (3, 0, 5, 5, 0, 5), taking 0.01 seconds to get val score of -0.0045
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 44 of 72576: (6, 0, 0, 5, 7, 5), taking 0.01 seconds to get val score of -2.7725817313406338e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 45 of 72576: (3, 5, 0, 5, 0, 5), taking 0.28 seconds to get val score of -0.0096
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 46 of 72576: (6, 0, 0, 5, 4, 0), taking 0.01 seconds to get val score of -2.7725817313406338e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 47 of 72576: (0, 5, 0, 5, 4, 5), taking 0.28 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 48 of 72576: (0, 5, 5, 5, 7, 0), taking 0.94 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 49 of 72576: (6, 0, 0, 5, 7, 0), taking 0.01 seconds to get val score of -2.7725817313406338e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 50 of 72576: (0, 0, 5, 0, 0, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 51 of 72576: (0, 0, 0, 5, 4, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 52 of 72576: (3, 0, 5, 5, 0, 0), taking 0.02 seconds to get val score of -0.0042
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 53 of 72576: (3, 0, 5, 5, 4, 0), taking 0.03 seconds to get val score of 0.0051
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 54 of 72576: (0, 0, 0, 0, 4, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 55 of 72576: (0, 0, 5, 0, 7, 5), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 56 of 72576: (0, 5, 0, 5, 0, 5), taking 0.28 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 57 of 72576: (0, 0, 0, 5, 0, 0), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 58 of 72576: (3, 5, 5, 0, 7, 0), taking 1.94 seconds to get val score of 0.0653
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 59 of 72576: (6, 0, 0, 0, 4, 5), taking 0.01 seconds to get val score of -2.1980309032472217e+49
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 60 of 72576: (3, 5, 0, 5, 7, 5), taking 0.31 seconds to get val score of -0.0096
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 61 of 72576: (0, 5, 5, 5, 0, 5), taking 0.26 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 62 of 72576: (0, 5, 0, 5, 4, 0), taking 0.28 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 63 of 72576: (3, 0, 0, 0, 7, 5), taking 0.01 seconds to get val score of -0.0055
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 64 of 72576: (3, 0, 0, 0, 7, 0), taking 0.02 seconds to get val score of -0.0162
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 65 of 72576: (6, 5, 0, 0, 0, 5), taking 0.41 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 66 of 72576: (6, 5, 5, 5, 7, 5), taking 0.39 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 67 of 72576: (3, 5, 0, 0, 7, 5), taking 0.33 seconds to get val score of 0.1007
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 68 of 72576: (0, 0, 0, 5, 7, 0), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 69 of 72576: (6, 0, 5, 5, 7, 0), taking 0.05 seconds to get val score of -1.1840522865392927e+44
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 70 of 72576: (0, 5, 5, 0, 4, 0), taking 1.92 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 71 of 72576: (6, 0, 0, 0, 7, 5), taking 0.01 seconds to get val score of -2.1980309032472217e+49
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 72 of 72576: (0, 0, 0, 0, 7, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 73 of 72576: (6, 0, 5, 0, 0, 5), taking 0.01 seconds to get val score of -1.1830446434449862e+38
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 74 of 72576: (0, 5, 0, 0, 7, 5), taking 0.34 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 75 of 72576: (0, 5, 5, 0, 7, 5), taking 0.44 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 76 of 72576: (3, 0, 0, 5, 7, 0), taking 0.01 seconds to get val score of -0.0072
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 77 of 72576: (0, 5, 5, 0, 0, 0), taking 0.78 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 78 of 72576: (3, 5, 5, 5, 0, 5), taking 0.26 seconds to get val score of 0.0898
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 79 of 72576: (0, 5, 0, 5, 0, 0), taking 0.28 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 80 of 72576: (6, 0, 0, 5, 0, 0), taking 0.01 seconds to get val score of -2.7725817313406338e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 81 of 72576: (0, 5, 5, 0, 0, 5), taking 0.27 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 82 of 72576: (0, 5, 0, 5, 7, 0), taking 0.29 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 83 of 72576: (3, 5, 0, 0, 4, 5), taking 0.34 seconds to get val score of 0.1007
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 84 of 72576: (0, 5, 5, 5, 0, 0), taking 0.72 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 85 of 72576: (6, 5, 0, 5, 0, 5), taking 0.28 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 86 of 72576: (6, 0, 5, 0, 0, 0), taking 0.03 seconds to get val score of -2.6445235359904232e+44
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 87 of 72576: (6, 5, 5, 5, 7, 0), taking 2.68 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 88 of 72576: (6, 5, 0, 5, 0, 0), taking 0.29 seconds to get val score of 0
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 89 of 72576: (6, 0, 0, 5, 4, 5), taking 0.01 seconds to get val score of -2.7725817313406338e+45
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 90 of 72576: (3, 5, 0, 5, 4, 5), taking 0.28 seconds to get val score of -0.0096
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 91 of 72576: (3, 0, 5, 5, 4, 5), taking 0.01 seconds to get val score of -0.0006
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 92 of 72576: (3, 5, 5, 0, 0, 5), taking 0.27 seconds to get val score of 0.0831
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 93 of 72576: (0, 0, 5, 5, 7, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 94 of 72576: (3, 5, 0, 0, 7, 0), taking 0.56 seconds to get val score of 0.0704
#         Current best combo: (3, 5, 0, 0, 0, 5) with val score 0.1026
# Trained and Tested combination 95 of 72576: (3, 5, 5, 0, 4, 5), taking 0.44 seconds to get val score of 0.1186
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 96 of 72576: (3, 0, 0, 5, 4, 0), taking 0.01 seconds to get val score of -0.0072
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 97 of 72576: (6, 5, 5, 5, 0, 0), taking 0.57 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 98 of 72576: (6, 5, 0, 5, 7, 5), taking 0.28 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 99 of 72576: (6, 0, 5, 5, 4, 5), taking 0.01 seconds to get val score of -3.620277435953958e+29
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 100 of 72576: (0, 0, 0, 5, 7, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 101 of 72576: (3, 5, 5, 5, 0, 0), taking 0.73 seconds to get val score of 0.0463
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 102 of 72576: (0, 5, 0, 0, 4, 5), taking 0.34 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 103 of 72576: (3, 5, 0, 5, 4, 0), taking 0.28 seconds to get val score of -0.0096
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 104 of 72576: (6, 0, 0, 0, 7, 0), taking 0.02 seconds to get val score of -1.8474981069987754e+49
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 105 of 72576: (6, 5, 0, 0, 4, 5), taking 0.31 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 106 of 72576: (0, 0, 5, 5, 0, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 107 of 72576: (0, 0, 0, 0, 4, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 108 of 72576: (6, 5, 0, 0, 4, 0), taking 0.53 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 109 of 72576: (3, 0, 5, 0, 0, 5), taking 0.01 seconds to get val score of -0.0041
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 110 of 72576: (3, 5, 0, 0, 4, 0), taking 0.69 seconds to get val score of 0.0704
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 111 of 72576: (0, 0, 0, 0, 0, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 112 of 72576: (3, 5, 0, 0, 0, 0), taking 0.41 seconds to get val score of 0.0925
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 113 of 72576: (3, 0, 5, 0, 7, 5), taking 0.02 seconds to get val score of 0.0521
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 114 of 72576: (6, 5, 5, 0, 0, 5), taking 0.27 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 115 of 72576: (3, 5, 0, 5, 0, 0), taking 0.28 seconds to get val score of -0.0096
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 116 of 72576: (0, 5, 5, 5, 7, 5), taking 0.29 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 117 of 72576: (0, 5, 5, 0, 7, 0), taking 1.89 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 118 of 72576: (6, 5, 5, 0, 4, 5), taking 0.39 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 119 of 72576: (3, 5, 5, 0, 4, 0), taking 1.99 seconds to get val score of 0.0653
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 120 of 72576: (3, 0, 5, 0, 4, 0), taking 0.06 seconds to get val score of 0.0148
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 121 of 72576: (3, 5, 5, 0, 7, 5), taking 0.47 seconds to get val score of 0.1186
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 122 of 72576: (3, 0, 0, 5, 0, 0), taking 0.01 seconds to get val score of -0.0072
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 123 of 72576: (3, 0, 0, 0, 0, 5), taking 0.01 seconds to get val score of -0.0093
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 124 of 72576: (3, 0, 5, 0, 7, 0), taking 0.06 seconds to get val score of 0.0148
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 125 of 72576: (6, 5, 5, 0, 0, 0), taking 0.57 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 126 of 72576: (0, 0, 0, 0, 7, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 127 of 72576: (0, 0, 5, 0, 0, 0), taking 0.03 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 128 of 72576: (0, 0, 0, 0, 0, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 129 of 72576: (6, 5, 5, 0, 7, 0), taking 3.3 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 130 of 72576: (3, 5, 5, 5, 7, 5), taking 0.29 seconds to get val score of 0.0915
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 131 of 72576: (6, 0, 5, 0, 7, 0), taking 0.06 seconds to get val score of -5.3527893447373365e+47
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 132 of 72576: (3, 0, 0, 0, 0, 0), taking 0.02 seconds to get val score of 0.0159
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 133 of 72576: (6, 5, 5, 0, 7, 5), taking 0.47 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 134 of 72576: (0, 0, 5, 0, 4, 5), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 135 of 72576: (6, 5, 0, 0, 0, 0), taking 0.35 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 136 of 72576: (3, 0, 5, 0, 4, 5), taking 0.02 seconds to get val score of 0.0521
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 137 of 72576: (6, 5, 5, 5, 4, 0), taking 2.02 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 138 of 72576: (0, 5, 0, 0, 7, 0), taking 0.56 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 139 of 72576: (6, 0, 5, 5, 0, 5), taking 0.01 seconds to get val score of -8.685690179020988e+24
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 140 of 72576: (0, 0, 5, 5, 4, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 141 of 72576: (0, 0, 0, 5, 0, 5), taking 0.01 seconds to get val score of -0.009
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 142 of 72576: (3, 5, 5, 0, 0, 0), taking 0.79 seconds to get val score of 0.0941
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 143 of 72576: (3, 3, 3, 3, 4, 3), taking 0.5 seconds to get val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 144 of 72576: (3, 5, 5, 5, 7, 0), taking 1.11 seconds to get val score of 0.0476
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 145 of 72576: (6, 5, 0, 5, 4, 0), taking 0.29 seconds to get val score of 0
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 146 of 72576: (2, 3, 3, 3, 4, 3), taking 0.49 seconds to get val score of -0.0065
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 147 of 72576: (4, 3, 3, 3, 4, 3), taking 0.64 seconds to get val score of -0.0156
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 148 of 72576: (3, 2, 3, 3, 4, 3), taking 0.25 seconds to get val score of 0.0439
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 149 of 72576: (3, 4, 3, 3, 4, 3), taking 1.06 seconds to get val score of 0.0527
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 150 of 72576: (3, 3, 2, 3, 4, 3), taking 0.36 seconds to get val score of 0.1057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 151 of 72576: (3, 3, 4, 3, 4, 3), taking 0.66 seconds to get val score of 0.0732
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 152 of 72576: (3, 3, 3, 2, 4, 3), taking 0.66 seconds to get val score of 0.0615
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 153 of 72576: (3, 3, 3, 4, 4, 3), taking 0.41 seconds to get val score of 0.0736
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 154 of 72576: (3, 3, 3, 3, 3, 3), taking 0.5 seconds to get val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 155 of 72576: (3, 3, 3, 3, 5, 3), taking 0.65 seconds to get val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 156 of 72576: (3, 3, 3, 3, 4, 2), taking 0.42 seconds to get val score of 0.055
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 157 of 72576: (3, 3, 3, 3, 4, 4), taking 0.61 seconds to get val score of 0.0724
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# 	round 0 iteration:  1
#
# Trained and Tested combination 158 of 72576: (2, 3, 2, 3, 4, 3), taking 0.36 seconds to get val score of -0.006
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 159 of 72576: (4, 3, 2, 3, 4, 3), taking 0.46 seconds to get val score of 0.0615
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 160 of 72576: (3, 2, 2, 3, 4, 3), taking 0.18 seconds to get val score of 0.0885
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 161 of 72576: (3, 4, 2, 3, 4, 3), taking 0.74 seconds to get val score of 0.0839
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 162 of 72576: (3, 3, 1, 3, 4, 3), taking 0.27 seconds to get val score of 0.0868
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 162 of 72576 combinations so far
# Trained and Tested combination 163 of 72576: (3, 3, 2, 2, 4, 3), taking 0.54 seconds to get val score of 0.098
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 164 of 72576: (3, 3, 2, 4, 4, 3), taking 0.29 seconds to get val score of 0.0895
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 165 of 72576: (3, 3, 2, 3, 3, 3), taking 0.36 seconds to get val score of 0.1057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 166 of 72576: (3, 3, 2, 3, 5, 3), taking 0.39 seconds to get val score of 0.1057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 167 of 72576: (3, 3, 2, 3, 4, 2), taking 0.3 seconds to get val score of 0.0769
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 168 of 72576: (3, 3, 2, 3, 4, 4), taking 0.42 seconds to get val score of 0.1062
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 169 of 72576: (2, 3, 4, 3, 4, 3), taking 0.65 seconds to get val score of -0.0061
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 170 of 72576: (4, 3, 4, 3, 4, 3), taking 0.97 seconds to get val score of -0.0233
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 171 of 72576: (3, 2, 4, 3, 4, 3), taking 0.33 seconds to get val score of 0.0523
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 172 of 72576: (3, 4, 4, 3, 4, 3), taking 1.37 seconds to get val score of 0.0682
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 172 of 72576 combinations so far
# Trained and Tested combination 173 of 72576: (3, 3, 5, 3, 4, 3), taking 0.81 seconds to get val score of -0.0191
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 174 of 72576: (3, 3, 4, 2, 4, 3), taking 0.74 seconds to get val score of 0.0405
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 175 of 72576: (3, 3, 4, 4, 4, 3), taking 0.54 seconds to get val score of 0.0606
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 176 of 72576: (3, 3, 4, 3, 3, 3), taking 0.66 seconds to get val score of 0.0732
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 177 of 72576: (3, 3, 4, 3, 5, 3), taking 0.69 seconds to get val score of 0.0732
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 178 of 72576: (3, 3, 4, 3, 4, 2), taking 0.53 seconds to get val score of 0.0631
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 179 of 72576: (3, 3, 4, 3, 4, 4), taking 0.77 seconds to get val score of 0.0742
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 180 of 72576: (2, 3, 3, 2, 4, 3), taking 0.57 seconds to get val score of -0.0057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 181 of 72576: (4, 3, 3, 2, 4, 3), taking 0.99 seconds to get val score of -0.1005
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 182 of 72576: (3, 2, 3, 2, 4, 3), taking 0.32 seconds to get val score of 0.0542
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 183 of 72576: (3, 4, 3, 2, 4, 3), taking 1.2 seconds to get val score of 0.0439
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 2, 2, 4, 3), which had val score of 0.098
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 183 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 2, 4, 3), which had val score of 0.0405
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 183 of 72576 combinations so far
# Trained and Tested combination 184 of 72576: (3, 3, 3, 1, 4, 3), taking 0.65 seconds to get val score of 0.0959
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 184 of 72576 combinations so far
# Trained and Tested combination 185 of 72576: (3, 3, 3, 2, 3, 3), taking 0.69 seconds to get val score of 0.0615
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 186 of 72576: (3, 3, 3, 2, 5, 3), taking 0.58 seconds to get val score of 0.0615
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 187 of 72576: (3, 3, 3, 2, 4, 2), taking 0.48 seconds to get val score of 0.0372
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 188 of 72576: (3, 3, 3, 2, 4, 4), taking 0.69 seconds to get val score of 0.111
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 189 of 72576: (2, 3, 3, 4, 4, 3), taking 0.4 seconds to get val score of -0.0069
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 190 of 72576: (4, 3, 3, 4, 4, 3), taking 0.46 seconds to get val score of 0.0162
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 191 of 72576: (3, 2, 3, 4, 4, 3), taking 0.21 seconds to get val score of 0.0338
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 192 of 72576: (3, 4, 3, 4, 4, 3), taking 0.84 seconds to get val score of 0.0815
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 2, 4, 4, 3), which had val score of 0.0895
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 192 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 4, 4, 3), which had val score of 0.0606
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 192 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 192 of 72576 combinations so far
# Trained and Tested combination 193 of 72576: (3, 3, 3, 5, 4, 3), taking 0.3 seconds to get val score of 0.0516
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 194 of 72576: (3, 3, 3, 4, 3, 3), taking 0.53 seconds to get val score of 0.0736
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 195 of 72576: (3, 3, 3, 4, 5, 3), taking 0.43 seconds to get val score of 0.0736
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 196 of 72576: (3, 3, 3, 4, 4, 2), taking 0.34 seconds to get val score of 0.0679
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 197 of 72576: (3, 3, 3, 4, 4, 4), taking 0.48 seconds to get val score of 0.0767
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 198 of 72576: (2, 3, 3, 3, 3, 3), taking 0.49 seconds to get val score of -0.0065
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 199 of 72576: (4, 3, 3, 3, 3, 3), taking 0.64 seconds to get val score of -0.0156
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 200 of 72576: (3, 2, 3, 3, 3, 3), taking 0.25 seconds to get val score of 0.0439
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 201 of 72576: (3, 4, 3, 3, 3, 3), taking 1.07 seconds to get val score of 0.0527
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3), which had val score of 0.1057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 201 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 3, 3), which had val score of 0.0732
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 201 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 3, 3), which had val score of 0.0615
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 201 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 3, 3), which had val score of 0.0736
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 201 of 72576 combinations so far
# Trained and Tested combination 202 of 72576: (3, 3, 3, 3, 2, 3), taking 0.51 seconds to get val score of 0.0592
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 202 of 72576 combinations so far
# Trained and Tested combination 203 of 72576: (3, 3, 3, 3, 3, 2), taking 0.42 seconds to get val score of 0.055
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 204 of 72576: (3, 3, 3, 3, 3, 4), taking 0.59 seconds to get val score of 0.0724
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 205 of 72576: (2, 3, 3, 3, 5, 3), taking 0.49 seconds to get val score of -0.0065
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 206 of 72576: (4, 3, 3, 3, 5, 3), taking 0.7 seconds to get val score of -0.0156
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 207 of 72576: (3, 2, 3, 3, 5, 3), taking 0.25 seconds to get val score of 0.0439
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 208 of 72576: (3, 4, 3, 3, 5, 3), taking 1.07 seconds to get val score of 0.0527
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 2, 3, 5, 3), which had val score of 0.1057
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 208 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 5, 3), which had val score of 0.0732
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 208 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 5, 3), which had val score of 0.0615
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 208 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 5, 3), which had val score of 0.0736
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 208 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 208 of 72576 combinations so far
# Trained and Tested combination 209 of 72576: (3, 3, 3, 3, 6, 3), taking 0.5 seconds to get val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 210 of 72576: (3, 3, 3, 3, 5, 2), taking 0.42 seconds to get val score of 0.055
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 211 of 72576: (3, 3, 3, 3, 5, 4), taking 0.6 seconds to get val score of 0.0724
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 212 of 72576: (2, 3, 3, 3, 4, 2), taking 0.43 seconds to get val score of -0.0058
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 213 of 72576: (4, 3, 3, 3, 4, 2), taking 0.54 seconds to get val score of -0.0248
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 214 of 72576: (3, 2, 3, 3, 4, 2), taking 0.21 seconds to get val score of 0.0314
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 215 of 72576: (3, 4, 3, 3, 4, 2), taking 0.86 seconds to get val score of 0.0662
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 2, 3, 4, 2), which had val score of 0.0769
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 215 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 4, 2), which had val score of 0.0631
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 215 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 4, 2), which had val score of 0.0372
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 215 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 4, 2), which had val score of 0.0679
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 215 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 3, 2), which had val score of 0.055
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 215 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 5, 2), which had val score of 0.055
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 215 of 72576 combinations so far
# Trained and Tested combination 216 of 72576: (3, 3, 3, 3, 4, 1), taking 0.33 seconds to get val score of 0.0455
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 216 of 72576 combinations so far
# Trained and Tested combination 217 of 72576: (2, 3, 3, 3, 4, 4), taking 0.72 seconds to get val score of -0.0059
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 218 of 72576: (4, 3, 3, 3, 4, 4), taking 0.8 seconds to get val score of -0.1291
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 219 of 72576: (3, 2, 3, 3, 4, 4), taking 0.29 seconds to get val score of 0.0725
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 220 of 72576: (3, 4, 3, 3, 4, 4), taking 1.26 seconds to get val score of 0.0555
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Already Trained and Tested combination (3, 3, 2, 3, 4, 4), which had val score of 0.1062
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 220 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 4, 3, 4, 4), which had val score of 0.0742
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 220 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 4, 4), which had val score of 0.111
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 220 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 4, 4), which had val score of 0.0767
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 220 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 3, 4), which had val score of 0.0724
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 220 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 5, 4), which had val score of 0.0724
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 220 of 72576 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 4, 3), which had val score of 0.0597
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186.
#         Has trained 220 of 72576 combinations so far
# Trained and Tested combination 221 of 72576: (3, 3, 3, 3, 4, 5), taking 0.09 seconds to get val score of 0.069
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 222 of 72576: (2, 5, 5, 0, 4, 5), taking 0.44 seconds to get val score of 0.0054
#         Current best combo: (3, 5, 5, 0, 4, 5) with val score 0.1186
# Trained and Tested combination 223 of 72576: (4, 5, 5, 0, 4, 5), taking 0.34 seconds to get val score of 0.1876
#         Current best combo: (4, 5, 5, 0, 4, 5) with val score 0.1876
# Trained and Tested combination 224 of 72576: (3, 4, 5, 0, 4, 5), taking 0.22 seconds to get val score of 0.1177
#         Current best combo: (4, 5, 5, 0, 4, 5) with val score 0.1876
# Trained and Tested combination 225 of 72576: (3, 5, 4, 0, 4, 5), taking 0.47 seconds to get val score of 0.1096
#         Current best combo: (4, 5, 5, 0, 4, 5) with val score 0.1876
# ...
# Trained and Tested combination 3553 of 72576: (2, 0, 5, 0, 7, 1), taking 0.09 seconds to get val score of -0.0082
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (4, 0, 5, 0, 7, 1), which had val score of 0.1075
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3553 of 72576 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0, 7, 1), which had val score of 0.0608
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3553 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 7, 1), which had val score of 0.0307
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3553 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 5, 1, 7, 1), which had val score of 0.0516
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3553 of 72576 combinations so far
# Trained and Tested combination 3554 of 72576: (3, 0, 5, 0, 6, 1), taking 0.1 seconds to get val score of 0.0513
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (3, 0, 5, 0, 7, 0), which had val score of 0.0148
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3554 of 72576 combinations so far
# Trained and Tested combination 3555 of 72576: (3, 0, 5, 0, 7, 2), taking 0.12 seconds to get val score of 0.0312
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# % Combos Checked Thus Far: 3555 out of 72576 which is 4.898313%
# Cruising Coordrdinate 0 of 144
#
# Cruising Coordrdinate 0 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 120
#
# 	round 120 iteration:  0
#
# Already Trained and Tested combination (2, 0, 0, 0, 4, 0), which had val score of -0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3555 of 72576 combinations so far
# Trained and Tested combination 3556 of 72576: (4, 0, 0, 0, 4, 0), taking 0.02 seconds to get val score of -0.1185
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3557 of 72576: (3, 1, 0, 0, 4, 0), taking 0.04 seconds to get val score of 0.0005
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3558 of 72576: (3, 0, 1, 0, 4, 0), taking 0.03 seconds to get val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3559 of 72576: (3, 0, 0, 1, 4, 0), taking 0.02 seconds to get val score of -0.0057
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3560 of 72576: (3, 0, 0, 0, 3, 0), taking 0.02 seconds to get val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (3, 0, 0, 0, 5, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3560 of 72576 combinations so far
# Trained and Tested combination 3561 of 72576: (3, 0, 0, 0, 4, 1), taking 0.02 seconds to get val score of 0.019
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# 	round 120 iteration:  1
#
# Trained and Tested combination 3562 of 72576: (2, 1, 0, 0, 4, 0), taking 0.04 seconds to get val score of -0.0089
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3563 of 72576: (4, 1, 0, 0, 4, 0), taking 0.05 seconds to get val score of -0.2496
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3563 of 72576 combinations so far
# Trained and Tested combination 3564 of 72576: (3, 2, 0, 0, 4, 0), taking 0.07 seconds to get val score of -0.0103
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3565 of 72576: (3, 1, 1, 0, 4, 0), taking 0.05 seconds to get val score of 0.0726
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3566 of 72576: (3, 1, 0, 1, 4, 0), taking 0.03 seconds to get val score of 0.0063
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3567 of 72576: (3, 1, 0, 0, 3, 0), taking 0.04 seconds to get val score of 0.0005
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3568 of 72576: (3, 1, 0, 0, 5, 0), taking 0.04 seconds to get val score of 0.0005
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3569 of 72576: (3, 1, 0, 0, 4, 1), taking 0.06 seconds to get val score of 0.0177
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3570 of 72576: (2, 0, 1, 0, 4, 0), taking 0.03 seconds to get val score of -0.0083
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3571 of 72576: (4, 0, 1, 0, 4, 0), taking 0.03 seconds to get val score of 0.3421
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (3, 1, 1, 0, 4, 0), which had val score of 0.0726
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3571 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3571 of 72576 combinations so far
# Trained and Tested combination 3572 of 72576: (3, 0, 2, 0, 4, 0), taking 0.04 seconds to get val score of 0.0135
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3573 of 72576: (3, 0, 1, 1, 4, 0), taking 0.03 seconds to get val score of 0.0423
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3574 of 72576: (3, 0, 1, 0, 3, 0), taking 0.03 seconds to get val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3575 of 72576: (3, 0, 1, 0, 5, 0), taking 0.03 seconds to get val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3576 of 72576: (3, 0, 1, 0, 4, 1), taking 0.04 seconds to get val score of 0.0153
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3577 of 72576: (2, 0, 0, 1, 4, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3578 of 72576: (4, 0, 0, 1, 4, 0), taking 0.02 seconds to get val score of 0.0513
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (3, 1, 0, 1, 4, 0), which had val score of 0.0063
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3578 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 1, 4, 0), which had val score of 0.0423
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3578 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3578 of 72576 combinations so far
# Trained and Tested combination 3579 of 72576: (3, 0, 0, 2, 4, 0), taking 0.02 seconds to get val score of 0.0108
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3580 of 72576: (3, 0, 0, 1, 3, 0), taking 0.02 seconds to get val score of -0.0057
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3581 of 72576: (3, 0, 0, 1, 5, 0), taking 0.02 seconds to get val score of -0.0057
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3582 of 72576: (3, 0, 0, 1, 4, 1), taking 0.02 seconds to get val score of 0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3583 of 72576: (2, 0, 0, 0, 3, 0), taking 0.02 seconds to get val score of -0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3584 of 72576: (4, 0, 0, 0, 3, 0), taking 0.02 seconds to get val score of -0.1185
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (3, 1, 0, 0, 3, 0), which had val score of 0.0005
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3584 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 3, 0), which had val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3584 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 3, 0), which had val score of -0.0057
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3584 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 2, 0), which had val score of -0.0092
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3584 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3584 of 72576 combinations so far
# Trained and Tested combination 3585 of 72576: (3, 0, 0, 0, 3, 1), taking 0.03 seconds to get val score of 0.019
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3586 of 72576: (2, 0, 0, 0, 4, 1), taking 0.02 seconds to get val score of -0.0086
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3587 of 72576: (4, 0, 0, 0, 4, 1), taking 0.02 seconds to get val score of -0.0552
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (3, 1, 0, 0, 4, 1), which had val score of 0.0177
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3587 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 1, 0, 4, 1), which had val score of 0.0153
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3587 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 1, 4, 1), which had val score of 0.009
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3587 of 72576 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0, 3, 1), which had val score of 0.019
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3587 of 72576 combinations so far
# Trained and Tested combination 3588 of 72576: (3, 0, 0, 0, 5, 1), taking 0.03 seconds to get val score of 0.019
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (3, 0, 0, 0, 4, 0), which had val score of -0.0162
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3588 of 72576 combinations so far
# Trained and Tested combination 3589 of 72576: (3, 0, 0, 0, 4, 2), taking 0.03 seconds to get val score of 0.0177
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# % Combos Checked Thus Far: 3589 out of 72576 which is 4.945161%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (3, 0, 1, 0, 7, 0), which had val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3589 of 72576 combinations so far
# Already Trained and Tested combination (5, 0, 1, 0, 7, 0), which had val score of -48.4196
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3589 of 72576 combinations so far
# Already Trained and Tested combination (4, 1, 1, 0, 7, 0), which had val score of 0.3297
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3589 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 7, 0), which had val score of -0.1185
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3589 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 7, 0), which had val score of 0.0812
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3589 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 1, 7, 0), which had val score of 0.1067
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3589 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 6, 0), which had val score of 0.3421
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3589 of 72576 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 7, 1), which had val score of -0.0314
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3589 of 72576 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (3, 0, 1, 0, 6, 0), which had val score of 0.0533
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3589 of 72576 combinations so far
# Trained and Tested combination 3590 of 72576: (5, 0, 1, 0, 6, 0), taking 0.04 seconds to get val score of -48.4196
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3591 of 72576: (4, 1, 1, 0, 6, 0), taking 0.06 seconds to get val score of 0.3297
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (4, 0, 0, 0, 6, 0), which had val score of -0.1185
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3591 of 72576 combinations so far
# Trained and Tested combination 3592 of 72576: (4, 0, 2, 0, 6, 0), taking 0.04 seconds to get val score of 0.0812
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3593 of 72576: (4, 0, 1, 1, 6, 0), taking 0.03 seconds to get val score of 0.1067
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Trained and Tested combination 3594 of 72576: (4, 0, 1, 0, 5, 0), taking 0.03 seconds to get val score of 0.3421
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# Already Trained and Tested combination (4, 0, 1, 0, 7, 0), which had val score of 0.3421
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421.
#         Has trained 3594 of 72576 combinations so far
# Trained and Tested combination 3595 of 72576: (4, 0, 1, 0, 6, 1), taking 0.06 seconds to get val score of -0.0314
#         Current best combo: (4, 0, 1, 0, 7, 0) with val score 0.3421
# % Combos Checked Thus Far: 3595 out of 72576 which is 4.953428%
# Max Score:
#  0.34205923462205945
# Max Test Score:
#  0.070344
# Max Combo Index:
#  (4, 0, 1, 0, 7, 0) out of [7, 6, 6, 6, 8, 6] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'learning_rate': 0.1, 'n_estimators': 25, 'subsample': 0.4, 'min_samples_split': 2, 'max_depth': 384, 'max_features': 0.25}
# % Combos Checked: 3595 out of 72576 which is 4.953428%
