# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'hgb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title&pyq'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import HistGradientBoostingRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_bins': (4, 16, 64, 255),
    'interaction_cst': ('no_interactions', 'pairwise'),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'l2_regularization': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (25, 50, 100, 200, 400)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 8400: (3, 3, 0, 4, 0, 0), taking 25.59 seconds to get val score of 0.0122
#         Current best combo: (3, 3, 0, 4, 0, 0) with val score 0.0122
# Trained and Tested combination 2 of 8400: (3, 3, 0, 0, 5, 4), taking 399.89 seconds to get val score of -0.009
#         Current best combo: (3, 3, 0, 4, 0, 0) with val score 0.0122
# Trained and Tested combination 3 of 8400: (3, 0, 0, 4, 0, 0), taking 21.62 seconds to get val score of 0.0237
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 4 of 8400: (0, 0, 0, 0, 5, 0), taking 10.01 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 5 of 8400: (3, 0, 1, 4, 0, 0), taking 24.5 seconds to get val score of -0.0656
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 6 of 8400: (0, 0, 0, 4, 0, 0), taking 19.94 seconds to get val score of 0.0237
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 7 of 8400: (3, 3, 0, 4, 0, 4), taking 250.06 seconds to get val score of -0.1056
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 8 of 8400: (0, 3, 0, 4, 0, 0), taking 7.89 seconds to get val score of 0.0018
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 9 of 8400: (0, 0, 1, 0, 0, 0), taking 8.74 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 10 of 8400: (6, 0, 1, 0, 5, 0), taking 7.13 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 11 of 8400: (3, 0, 1, 4, 5, 0), taking 12.16 seconds to get val score of -0.018
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 12 of 8400: (0, 3, 1, 0, 0, 4), taking 70.5 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 13 of 8400: (0, 3, 0, 0, 0, 0), taking 7.14 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 14 of 8400: (0, 3, 1, 0, 5, 0), taking 7.02 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 15 of 8400: (6, 0, 0, 0, 0, 4), taking 35.64 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 16 of 8400: (3, 3, 0, 0, 0, 0), taking 1.54 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 17 of 8400: (0, 3, 1, 0, 5, 4), taking 54.52 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 18 of 8400: (3, 0, 0, 4, 5, 4), taking 35.35 seconds to get val score of 0.0049
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 19 of 8400: (3, 3, 1, 0, 5, 4), taking 82.3 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 20 of 8400: (6, 0, 1, 4, 5, 0), taking 5.96 seconds to get val score of -0.018
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 21 of 8400: (6, 0, 0, 4, 0, 0), taking 3.64 seconds to get val score of 0.0237
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 22 of 8400: (0, 3, 0, 0, 5, 4), taking 39.59 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 23 of 8400: (6, 3, 1, 0, 5, 4), taking 139.0 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 24 of 8400: (3, 0, 0, 0, 5, 4), taking 10.73 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 25 of 8400: (6, 3, 1, 0, 0, 4), taking 139.52 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 26 of 8400: (6, 3, 0, 0, 0, 4), taking 21.78 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 27 of 8400: (0, 3, 1, 4, 0, 4), taking 28.74 seconds to get val score of -0.0622
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 28 of 8400: (3, 0, 1, 0, 0, 4), taking 113.86 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 29 of 8400: (3, 3, 0, 4, 5, 4), taking 23.33 seconds to get val score of -0.1078
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 30 of 8400: (0, 3, 0, 4, 5, 0), taking 7.33 seconds to get val score of 0.0152
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 31 of 8400: (6, 0, 0, 4, 5, 0), taking 4.75 seconds to get val score of 0.0166
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 32 of 8400: (6, 0, 0, 4, 5, 4), taking 18.99 seconds to get val score of 0.0049
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 33 of 8400: (3, 0, 0, 0, 0, 4), taking 129.01 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 34 of 8400: (0, 3, 0, 0, 5, 0), taking 1.16 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 35 of 8400: (0, 3, 0, 0, 0, 4), taking 40.91 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 36 of 8400: (0, 3, 0, 4, 0, 4), taking 40.54 seconds to get val score of -0.1291
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 37 of 8400: (6, 0, 1, 4, 5, 4), taking 101.56 seconds to get val score of -0.1639
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 38 of 8400: (3, 3, 1, 4, 0, 4), taking 62.65 seconds to get val score of -0.0486
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 39 of 8400: (6, 0, 1, 4, 0, 0), taking 6.93 seconds to get val score of -0.0656
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 40 of 8400: (0, 0, 0, 4, 5, 0), taking 3.02 seconds to get val score of 0.0166
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 41 of 8400: (6, 3, 1, 0, 0, 0), taking 9.85 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 42 of 8400: (6, 0, 0, 4, 0, 4), taking 109.51 seconds to get val score of -0.0467
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 43 of 8400: (3, 0, 0, 0, 5, 0), taking 10.71 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 44 of 8400: (6, 3, 1, 4, 0, 4), taking 567.02 seconds to get val score of -0.0486
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 45 of 8400: (0, 0, 1, 0, 5, 4), taking 107.88 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 46 of 8400: (3, 0, 0, 4, 5, 0), taking 3.42 seconds to get val score of 0.0166
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 47 of 8400: (3, 0, 1, 0, 5, 4), taking 29.98 seconds to get val score of -0.009
#         Current best combo: (3, 0, 0, 4, 0, 0) with val score 0.0237
# Trained and Tested combination 48 of 8400: (6, 3, 1, 4, 0, 0), taking 7.99 seconds to get val score of 0.0484
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 49 of 8400: (0, 3, 0, 4, 5, 4), taking 16.48 seconds to get val score of -0.1202
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 50 of 8400: (6, 3, 0, 0, 5, 4), taking 27.51 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 51 of 8400: (6, 3, 0, 4, 0, 0), taking 2.25 seconds to get val score of 0.0122
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 52 of 8400: (6, 0, 1, 0, 0, 4), taking 24.1 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 53 of 8400: (3, 0, 1, 4, 0, 4), taking 24.9 seconds to get val score of -0.1545
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 54 of 8400: (0, 0, 1, 4, 0, 4), taking 17.78 seconds to get val score of -0.2797
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 55 of 8400: (6, 0, 0, 0, 5, 0), taking 3.64 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 56 of 8400: (3, 3, 0, 0, 5, 0), taking 1.49 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 57 of 8400: (3, 0, 0, 0, 0, 0), taking 1.13 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 58 of 8400: (0, 0, 1, 0, 0, 4), taking 25.89 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 59 of 8400: (0, 0, 0, 0, 0, 4), taking 28.38 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 60 of 8400: (3, 3, 1, 0, 5, 0), taking 0.93 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 61 of 8400: (6, 3, 0, 4, 5, 4), taking 28.97 seconds to get val score of -0.1078
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 62 of 8400: (0, 3, 1, 4, 5, 0), taking 5.26 seconds to get val score of -0.0214
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 63 of 8400: (3, 0, 0, 4, 0, 4), taking 15.52 seconds to get val score of -0.0467
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 64 of 8400: (6, 0, 1, 0, 5, 4), taking 22.38 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 65 of 8400: (0, 0, 1, 4, 5, 4), taking 22.93 seconds to get val score of -0.2638
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 66 of 8400: (6, 0, 1, 4, 0, 4), taking 27.97 seconds to get val score of -0.1545
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 67 of 8400: (3, 0, 1, 0, 0, 0), taking 3.11 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 68 of 8400: (3, 3, 1, 4, 5, 4), taking 22.37 seconds to get val score of 0.0329
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 69 of 8400: (3, 3, 1, 4, 5, 0), taking 4.97 seconds to get val score of -0.0053
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 70 of 8400: (3, 3, 0, 4, 5, 0), taking 3.83 seconds to get val score of 0.0215
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 71 of 8400: (3, 3, 0, 0, 0, 4), taking 10.15 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 72 of 8400: (6, 3, 1, 4, 5, 0), taking 4.08 seconds to get val score of -0.0053
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 73 of 8400: (0, 3, 1, 4, 0, 0), taking 1.83 seconds to get val score of -0.0155
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 74 of 8400: (0, 0, 0, 4, 0, 4), taking 14.02 seconds to get val score of -0.0467
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 75 of 8400: (0, 0, 1, 4, 0, 0), taking 5.16 seconds to get val score of -0.057
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 76 of 8400: (0, 0, 0, 0, 0, 0), taking 2.9 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 77 of 8400: (6, 3, 0, 4, 0, 4), taking 17.5 seconds to get val score of -0.1056
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 78 of 8400: (6, 3, 1, 4, 5, 4), taking 25.16 seconds to get val score of 0.0329
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 79 of 8400: (3, 3, 1, 0, 0, 0), taking 3.7 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 80 of 8400: (6, 0, 0, 0, 5, 4), taking 8.22 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 81 of 8400: (0, 3, 1, 0, 0, 0), taking 5.0 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 82 of 8400: (6, 3, 0, 4, 5, 0), taking 4.62 seconds to get val score of 0.0215
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 83 of 8400: (0, 0, 0, 4, 5, 4), taking 12.44 seconds to get val score of 0.0049
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 84 of 8400: (3, 3, 1, 4, 0, 0), taking 4.73 seconds to get val score of 0.0484
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 85 of 8400: (0, 3, 1, 4, 5, 4), taking 7.82 seconds to get val score of -0.087
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 86 of 8400: (6, 3, 1, 0, 5, 0), taking 5.29 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 87 of 8400: (0, 0, 1, 4, 5, 0), taking 1.8 seconds to get val score of -0.0296
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 88 of 8400: (6, 3, 0, 0, 0, 0), taking 3.61 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 89 of 8400: (3, 3, 1, 0, 0, 4), taking 32.31 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 90 of 8400: (0, 0, 1, 0, 5, 0), taking 0.73 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 91 of 8400: (0, 0, 0, 0, 5, 4), taking 11.41 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 92 of 8400: (6, 3, 0, 0, 5, 0), taking 5.14 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 93 of 8400: (6, 0, 1, 0, 0, 0), taking 3.73 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 94 of 8400: (3, 0, 1, 0, 5, 0), taking 3.24 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 95 of 8400: (3, 2, 1, 2, 3, 2), taking 5.47 seconds to get val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 96 of 8400: (3, 0, 1, 4, 5, 4), taking 12.3 seconds to get val score of -0.1639
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 97 of 8400: (6, 0, 0, 0, 0, 0), taking 3.68 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 98 of 8400: (2, 2, 1, 2, 3, 2), taking 6.43 seconds to get val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 99 of 8400: (4, 2, 1, 2, 3, 2), taking 7.65 seconds to get val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 100 of 8400: (3, 1, 1, 2, 3, 2), taking 5.96 seconds to get val score of -0.0109
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 101 of 8400: (3, 3, 1, 2, 3, 2), taking 8.55 seconds to get val score of -0.0119
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 102 of 8400: (3, 2, 0, 2, 3, 2), taking 6.66 seconds to get val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 103 of 8400: (3, 2, 1, 1, 3, 2), taking 9.66 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 104 of 8400: (3, 2, 1, 3, 3, 2), taking 7.48 seconds to get val score of -0.0136
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 105 of 8400: (3, 2, 1, 2, 2, 2), taking 5.32 seconds to get val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 106 of 8400: (3, 2, 1, 2, 4, 2), taking 5.16 seconds to get val score of -0.0112
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 107 of 8400: (3, 2, 1, 2, 3, 1), taking 4.07 seconds to get val score of -0.0104
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 108 of 8400: (3, 2, 1, 2, 3, 3), taking 12.29 seconds to get val score of -0.0133
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# 	round 0 iteration:  1
#
# Trained and Tested combination 109 of 8400: (1, 2, 1, 2, 3, 2), taking 6.55 seconds to get val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 109 of 8400 combinations so far
# Trained and Tested combination 110 of 8400: (2, 1, 1, 2, 3, 2), taking 6.59 seconds to get val score of -0.0109
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 111 of 8400: (2, 3, 1, 2, 3, 2), taking 3.93 seconds to get val score of -0.0119
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 112 of 8400: (2, 2, 0, 2, 3, 2), taking 6.83 seconds to get val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 113 of 8400: (2, 2, 1, 1, 3, 2), taking 5.08 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 114 of 8400: (2, 2, 1, 3, 3, 2), taking 4.96 seconds to get val score of -0.0136
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 115 of 8400: (2, 2, 1, 2, 2, 2), taking 6.43 seconds to get val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 116 of 8400: (2, 2, 1, 2, 4, 2), taking 5.71 seconds to get val score of -0.0112
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 117 of 8400: (2, 2, 1, 2, 3, 1), taking 3.43 seconds to get val score of -0.0104
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 118 of 8400: (2, 2, 1, 2, 3, 3), taking 179.52 seconds to get val score of -0.0133
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 118 of 8400 combinations so far
# Trained and Tested combination 119 of 8400: (5, 2, 1, 2, 3, 2), taking 18.18 seconds to get val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 120 of 8400: (4, 1, 1, 2, 3, 2), taking 34.14 seconds to get val score of -0.0109
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 121 of 8400: (4, 3, 1, 2, 3, 2), taking 149.15 seconds to get val score of -0.0119
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 122 of 8400: (4, 2, 0, 2, 3, 2), taking 19.0 seconds to get val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 123 of 8400: (4, 2, 1, 1, 3, 2), taking 35.51 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 124 of 8400: (4, 2, 1, 3, 3, 2), taking 11.97 seconds to get val score of -0.0136
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 125 of 8400: (4, 2, 1, 2, 2, 2), taking 11.34 seconds to get val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 126 of 8400: (4, 2, 1, 2, 4, 2), taking 147.77 seconds to get val score of -0.0112
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 127 of 8400: (4, 2, 1, 2, 3, 1), taking 7.94 seconds to get val score of -0.0104
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 128 of 8400: (4, 2, 1, 2, 3, 3), taking 145.06 seconds to get val score of -0.0133
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (2, 1, 1, 2, 3, 2), which had val score of -0.0109
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 128 of 8400 combinations so far
# Already Trained and Tested combination (4, 1, 1, 2, 3, 2), which had val score of -0.0109
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 128 of 8400 combinations so far
# Trained and Tested combination 129 of 8400: (3, 0, 1, 2, 3, 2), taking 42.9 seconds to get val score of -0.0093
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 129 of 8400 combinations so far
# Trained and Tested combination 130 of 8400: (3, 1, 0, 2, 3, 2), taking 91.9 seconds to get val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 131 of 8400: (3, 1, 1, 1, 3, 2), taking 2.21 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 132 of 8400: (3, 1, 1, 3, 3, 2), taking 0.6 seconds to get val score of -0.001
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 133 of 8400: (3, 1, 1, 2, 2, 2), taking 0.38 seconds to get val score of -0.0109
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 134 of 8400: (3, 1, 1, 2, 4, 2), taking 0.47 seconds to get val score of -0.0108
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 135 of 8400: (3, 1, 1, 2, 3, 1), taking 0.64 seconds to get val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 136 of 8400: (3, 1, 1, 2, 3, 3), taking 0.67 seconds to get val score of -0.0128
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (2, 3, 1, 2, 3, 2), which had val score of -0.0119
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 136 of 8400 combinations so far
# Already Trained and Tested combination (4, 3, 1, 2, 3, 2), which had val score of -0.0119
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 136 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 136 of 8400 combinations so far
# Trained and Tested combination 137 of 8400: (3, 3, 0, 2, 3, 2), taking 0.25 seconds to get val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 138 of 8400: (3, 3, 1, 1, 3, 2), taking 0.27 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 139 of 8400: (3, 3, 1, 3, 3, 2), taking 0.39 seconds to get val score of -0.0204
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 140 of 8400: (3, 3, 1, 2, 2, 2), taking 0.36 seconds to get val score of -0.0119
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 141 of 8400: (3, 3, 1, 2, 4, 2), taking 0.31 seconds to get val score of -0.0116
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 142 of 8400: (3, 3, 1, 2, 3, 1), taking 0.11 seconds to get val score of -0.0104
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 143 of 8400: (3, 3, 1, 2, 3, 3), taking 0.43 seconds to get val score of -0.0145
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (2, 2, 0, 2, 3, 2), which had val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 143 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 0, 2, 3, 2), which had val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 143 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 0, 2, 3, 2), which had val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 143 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 2, 3, 2), which had val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 143 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 143 of 8400 combinations so far
# Trained and Tested combination 144 of 8400: (3, 2, 0, 1, 3, 2), taking 0.32 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 145 of 8400: (3, 2, 0, 3, 3, 2), taking 0.12 seconds to get val score of 0.0049
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 146 of 8400: (3, 2, 0, 2, 2, 2), taking 0.12 seconds to get val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 147 of 8400: (3, 2, 0, 2, 4, 2), taking 0.13 seconds to get val score of -0.0097
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 148 of 8400: (3, 2, 0, 2, 3, 1), taking 0.07 seconds to get val score of -0.0095
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 149 of 8400: (3, 2, 0, 2, 3, 3), taking 0.25 seconds to get val score of -0.0102
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (2, 2, 1, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 149 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 149 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 149 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 149 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 1, 3, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 149 of 8400 combinations so far
# Trained and Tested combination 150 of 8400: (3, 2, 1, 0, 3, 2), taking 0.3 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 150 of 8400 combinations so far
# Trained and Tested combination 151 of 8400: (3, 2, 1, 1, 2, 2), taking 0.25 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 152 of 8400: (3, 2, 1, 1, 4, 2), taking 0.21 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 153 of 8400: (3, 2, 1, 1, 3, 1), taking 0.16 seconds to get val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 154 of 8400: (3, 2, 1, 1, 3, 3), taking 0.52 seconds to get val score of -0.0091
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (2, 2, 1, 3, 3, 2), which had val score of -0.0136
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 3, 3, 2), which had val score of -0.0136
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 3, 3, 2), which had val score of -0.001
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 3, 2), which had val score of -0.0204
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 3, 3, 2), which had val score of 0.0049
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 154 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 154 of 8400 combinations so far
# Trained and Tested combination 155 of 8400: (3, 2, 1, 4, 3, 2), taking 93.44 seconds to get val score of 0.0266
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 156 of 8400: (3, 2, 1, 3, 2, 2), taking 9.31 seconds to get val score of -0.0192
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 157 of 8400: (3, 2, 1, 3, 4, 2), taking 6.56 seconds to get val score of -0.012
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 158 of 8400: (3, 2, 1, 3, 3, 1), taking 9.58 seconds to get val score of -0.0204
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 159 of 8400: (3, 2, 1, 3, 3, 3), taking 19.29 seconds to get val score of 0.0071
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (2, 2, 1, 2, 2, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 2, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 2, 2), which had val score of -0.0109
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 2), which had val score of -0.0119
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 2, 2), which had val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 159 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 2, 2), which had val score of -0.0192
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 159 of 8400 combinations so far
# Trained and Tested combination 160 of 8400: (3, 2, 1, 2, 1, 2), taking 12.67 seconds to get val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 160 of 8400 combinations so far
# Trained and Tested combination 161 of 8400: (3, 2, 1, 2, 2, 1), taking 13.24 seconds to get val score of -0.0104
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 162 of 8400: (3, 2, 1, 2, 2, 3), taking 11.74 seconds to get val score of -0.0134
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (2, 2, 1, 2, 4, 2), which had val score of -0.0112
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 4, 2), which had val score of -0.0112
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 4, 2), which had val score of -0.0108
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 4, 2), which had val score of -0.0116
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 4, 2), which had val score of -0.0097
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 4, 2), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 4, 2), which had val score of -0.012
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 162 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 162 of 8400 combinations so far
# Trained and Tested combination 163 of 8400: (3, 2, 1, 2, 5, 2), taking 5.19 seconds to get val score of -0.0073
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 164 of 8400: (3, 2, 1, 2, 4, 1), taking 8.07 seconds to get val score of -0.0103
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Trained and Tested combination 165 of 8400: (3, 2, 1, 2, 4, 3), taking 18.61 seconds to get val score of -0.0114
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (2, 2, 1, 2, 3, 1), which had val score of -0.0104
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 3, 1), which had val score of -0.0104
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 3, 1), which had val score of -0.0099
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 3, 1), which had val score of -0.0104
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 3, 1), which had val score of -0.0095
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 3, 1), which had val score of -0.009
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 3, 1), which had val score of -0.0204
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2, 1), which had val score of -0.0104
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 165 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 4, 1), which had val score of -0.0103
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 165 of 8400 combinations so far
# Trained and Tested combination 166 of 8400: (3, 2, 1, 2, 3, 0), taking 4.41 seconds to get val score of -0.0097
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (2, 2, 1, 2, 3, 3), which had val score of -0.0133
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 3, 3), which had val score of -0.0133
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 3, 3), which had val score of -0.0128
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 3, 3), which had val score of -0.0145
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 3, 3), which had val score of -0.0102
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 3, 3), which had val score of -0.0091
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 3, 3, 3), which had val score of 0.0071
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2, 3), which had val score of -0.0134
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 4, 3), which had val score of -0.0114
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 3, 2), which had val score of -0.0118
#         Current best combo: (6, 3, 1, 4, 0, 0) with val score 0.0484.
#         Has trained 166 of 8400 combinations so far
