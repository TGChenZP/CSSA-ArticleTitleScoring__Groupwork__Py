# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nusvc(poly)'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title&pyq'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import NuSVR as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto'),
    'nu': (0.1, 0.3, 0.5, 0.7, 0.9)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.NuSVR'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 19440: (5, 0, 0, 5, 0, 0), taking 0.03 seconds to get val score of 0.1601
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score 0.1601
# Trained and Tested combination 2 of 19440: (5, 0, 0, 0, 1, 4), taking 0.01 seconds to get val score of 0.0337
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score 0.1601
# Trained and Tested combination 3 of 19440: (0, 8, 0, 5, 0, 0), taking 0.03 seconds to get val score of -0.6377
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score 0.1601
# Trained and Tested combination 4 of 19440: (0, 0, 0, 0, 1, 0), taking 0.03 seconds to get val score of -0.0093
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score 0.1601
# Trained and Tested combination 5 of 19440: (0, 8, 5, 5, 0, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score 0.1601
# Trained and Tested combination 6 of 19440: (0, 0, 0, 5, 0, 0), taking 0.01 seconds to get val score of -0.0108
#         Current best combo: (5, 0, 0, 5, 0, 0) with val score 0.1601
# Trained and Tested combination 7 of 19440: (5, 0, 0, 5, 0, 4), taking 0.06 seconds to get val score of 0.1605
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 8 of 19440: (0, 4, 0, 5, 0, 0), taking 0.02 seconds to get val score of 0.0051
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 9 of 19440: (0, 0, 5, 0, 0, 0), taking 0.05 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 10 of 19440: (5, 4, 5, 0, 1, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 11 of 19440: (0, 8, 5, 5, 1, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 12 of 19440: (0, 4, 5, 0, 0, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 13 of 19440: (0, 4, 0, 0, 0, 0), taking 0.01 seconds to get val score of 0.0079
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 14 of 19440: (0, 4, 5, 0, 1, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 15 of 19440: (5, 4, 0, 0, 0, 4), taking 0.03 seconds to get val score of -0.1826
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 16 of 19440: (5, 0, 0, 0, 0, 0), taking 0.03 seconds to get val score of -0.7018
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 17 of 19440: (0, 4, 5, 0, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 18 of 19440: (0, 8, 0, 5, 1, 4), taking 0.01 seconds to get val score of -0.0071
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 19 of 19440: (5, 0, 5, 0, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 20 of 19440: (5, 4, 5, 5, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 21 of 19440: (5, 4, 0, 5, 0, 0), taking 0.11 seconds to get val score of 0.0463
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 22 of 19440: (0, 4, 0, 0, 1, 4), taking 0.02 seconds to get val score of -0.4948
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 23 of 19440: (5, 8, 5, 0, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 24 of 19440: (0, 8, 0, 0, 1, 4), taking 0.01 seconds to get val score of -0.2731
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 25 of 19440: (5, 8, 5, 0, 0, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 26 of 19440: (5, 8, 0, 0, 0, 4), taking 0.01 seconds to get val score of -0.2106
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 27 of 19440: (0, 4, 5, 5, 0, 4), taking 0.07 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 28 of 19440: (0, 8, 5, 0, 0, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 0, 4) with val score 0.1605
# Trained and Tested combination 29 of 19440: (5, 0, 0, 5, 1, 4), taking 0.04 seconds to get val score of 0.2864
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 30 of 19440: (0, 4, 0, 5, 1, 0), taking 0.01 seconds to get val score of -0.0092
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 31 of 19440: (5, 4, 0, 5, 1, 0), taking 0.02 seconds to get val score of 0.1362
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 32 of 19440: (5, 4, 0, 5, 1, 4), taking 0.03 seconds to get val score of 0.1427
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 33 of 19440: (0, 8, 0, 0, 0, 4), taking 0.01 seconds to get val score of -0.2106
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 34 of 19440: (0, 4, 0, 0, 1, 0), taking 0.01 seconds to get val score of -0.0092
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 35 of 19440: (0, 4, 0, 0, 0, 4), taking 0.03 seconds to get val score of -0.1271
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 36 of 19440: (0, 4, 0, 5, 0, 4), taking 0.04 seconds to get val score of 0.1193
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 37 of 19440: (5, 4, 5, 5, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 38 of 19440: (5, 0, 5, 5, 0, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 39 of 19440: (5, 4, 5, 5, 0, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 40 of 19440: (0, 0, 0, 5, 1, 0), taking 0.01 seconds to get val score of -0.0093
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 41 of 19440: (5, 8, 5, 0, 0, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 42 of 19440: (5, 4, 0, 5, 0, 4), taking 0.06 seconds to get val score of 0.0446
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 43 of 19440: (0, 8, 0, 0, 1, 0), taking 0.05 seconds to get val score of -0.0114
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 44 of 19440: (5, 8, 5, 5, 0, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 45 of 19440: (0, 0, 5, 0, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 46 of 19440: (0, 8, 0, 5, 1, 0), taking 0.0 seconds to get val score of -0.0114
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 47 of 19440: (0, 8, 5, 0, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 48 of 19440: (5, 8, 5, 5, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 49 of 19440: (0, 4, 0, 5, 1, 4), taking 0.03 seconds to get val score of -0.0089
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 50 of 19440: (5, 8, 0, 0, 1, 4), taking 0.08 seconds to get val score of -0.0255
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 51 of 19440: (5, 8, 0, 5, 0, 0), taking 0.02 seconds to get val score of -0.6341
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 52 of 19440: (5, 4, 5, 0, 0, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 53 of 19440: (0, 8, 5, 5, 0, 4), taking 0.02 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 54 of 19440: (0, 0, 5, 5, 0, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 55 of 19440: (5, 4, 0, 0, 1, 0), taking 0.05 seconds to get val score of -0.1958
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 56 of 19440: (5, 0, 0, 0, 1, 0), taking 0.01 seconds to get val score of -0.1101
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 57 of 19440: (0, 8, 0, 0, 0, 0), taking 0.02 seconds to get val score of -1.2879
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 58 of 19440: (0, 0, 5, 0, 0, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 59 of 19440: (0, 0, 0, 0, 0, 4), taking 0.01 seconds to get val score of -0.0046
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 60 of 19440: (5, 0, 5, 0, 1, 0), taking 0.03 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 61 of 19440: (5, 8, 0, 5, 1, 4), taking 0.09 seconds to get val score of 0.15
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 62 of 19440: (0, 4, 5, 5, 1, 0), taking 0.02 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 63 of 19440: (0, 8, 0, 5, 0, 4), taking 0.04 seconds to get val score of -0.6229
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 64 of 19440: (5, 4, 5, 0, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 65 of 19440: (0, 0, 5, 5, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 66 of 19440: (5, 4, 5, 5, 0, 4), taking 0.03 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 67 of 19440: (0, 8, 5, 0, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 68 of 19440: (5, 0, 5, 5, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 69 of 19440: (5, 0, 5, 5, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 70 of 19440: (5, 0, 0, 5, 1, 0), taking 0.01 seconds to get val score of 0.1978
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 71 of 19440: (5, 0, 0, 0, 0, 4), taking 0.01 seconds to get val score of -0.07
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 72 of 19440: (5, 8, 5, 5, 1, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 73 of 19440: (0, 4, 5, 5, 0, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 74 of 19440: (0, 0, 0, 5, 0, 4), taking 0.01 seconds to get val score of -0.0065
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 75 of 19440: (0, 0, 5, 5, 0, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 76 of 19440: (0, 0, 0, 0, 0, 0), taking 0.01 seconds to get val score of -0.0108
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 77 of 19440: (5, 8, 0, 5, 0, 4), taking 0.04 seconds to get val score of -0.6229
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 78 of 19440: (5, 8, 5, 5, 1, 4), taking 0.05 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 79 of 19440: (5, 0, 5, 0, 0, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 80 of 19440: (5, 4, 0, 0, 1, 4), taking 0.01 seconds to get val score of -0.1593
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 81 of 19440: (0, 4, 5, 0, 0, 0), taking 0.0 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 82 of 19440: (5, 8, 0, 5, 1, 0), taking 0.06 seconds to get val score of 0.1044
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 83 of 19440: (0, 0, 0, 5, 1, 4), taking 0.02 seconds to get val score of -0.0085
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 84 of 19440: (5, 0, 5, 5, 0, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 85 of 19440: (0, 4, 5, 5, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 86 of 19440: (5, 8, 5, 0, 1, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 87 of 19440: (0, 0, 5, 5, 1, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 88 of 19440: (5, 8, 0, 0, 0, 0), taking 0.01 seconds to get val score of -1.2879
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 89 of 19440: (5, 0, 5, 0, 0, 4), taking 0.04 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 90 of 19440: (0, 0, 5, 0, 1, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 91 of 19440: (0, 0, 0, 0, 1, 4), taking 0.01 seconds to get val score of -0.0054
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 92 of 19440: (5, 8, 0, 0, 1, 0), taking 0.01 seconds to get val score of -0.1839
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 93 of 19440: (5, 4, 5, 0, 0, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 94 of 19440: (0, 8, 5, 0, 1, 0), taking 0.01 seconds to get val score of -0.5332
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 95 of 19440: (3, 4, 3, 3, 1, 2), taking 0.02 seconds to get val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 96 of 19440: (0, 8, 5, 5, 1, 4), taking 0.01 seconds to get val score of -1.2797
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 97 of 19440: (5, 4, 0, 0, 0, 0), taking 0.01 seconds to get val score of -0.3111
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 98 of 19440: (2, 4, 3, 3, 1, 2), taking 0.02 seconds to get val score of -0.001
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 99 of 19440: (4, 4, 3, 3, 1, 2), taking 0.02 seconds to get val score of 0.1186
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 100 of 19440: (3, 3, 3, 3, 1, 2), taking 0.02 seconds to get val score of 0.0597
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 101 of 19440: (3, 5, 3, 3, 1, 2), taking 0.02 seconds to get val score of 0.045
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 102 of 19440: (3, 4, 2, 3, 1, 2), taking 0.01 seconds to get val score of 0.0501
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 103 of 19440: (3, 4, 4, 3, 1, 2), taking 0.01 seconds to get val score of -0.6903
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 104 of 19440: (3, 4, 3, 2, 1, 2), taking 0.01 seconds to get val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 105 of 19440: (3, 4, 3, 4, 1, 2), taking 0.01 seconds to get val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 106 of 19440: (3, 4, 3, 3, 0, 2), taking 0.02 seconds to get val score of 0.0366
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 107 of 19440: (3, 4, 3, 3, 1, 1), taking 0.02 seconds to get val score of 0.0078
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 108 of 19440: (3, 4, 3, 3, 1, 3), taking 0.01 seconds to get val score of 0.0635
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 108 of 19440 combinations so far
# Trained and Tested combination 109 of 19440: (5, 4, 3, 3, 1, 2), taking 0.11 seconds to get val score of 0.1247
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 110 of 19440: (4, 3, 3, 3, 1, 2), taking 0.01 seconds to get val score of 0.1405
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 111 of 19440: (4, 5, 3, 3, 1, 2), taking 0.04 seconds to get val score of 0.1059
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 112 of 19440: (4, 4, 2, 3, 1, 2), taking 0.01 seconds to get val score of 0.1186
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 113 of 19440: (4, 4, 4, 3, 1, 2), taking 0.03 seconds to get val score of -0.6903
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 114 of 19440: (4, 4, 3, 2, 1, 2), taking 0.01 seconds to get val score of 0.1009
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 115 of 19440: (4, 4, 3, 4, 1, 2), taking 0.04 seconds to get val score of 0.1258
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 116 of 19440: (4, 4, 3, 3, 0, 2), taking 0.01 seconds to get val score of 0.0366
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 117 of 19440: (4, 4, 3, 3, 1, 1), taking 0.01 seconds to get val score of 0.1105
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 118 of 19440: (4, 4, 3, 3, 1, 3), taking 0.05 seconds to get val score of 0.1281
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 119 of 19440: (2, 3, 3, 3, 1, 2), taking 0.01 seconds to get val score of 0.0138
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (4, 3, 3, 3, 1, 2), which had val score of 0.1405
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 119 of 19440 combinations so far
# Trained and Tested combination 120 of 19440: (3, 2, 3, 3, 1, 2), taking 0.01 seconds to get val score of 0.066
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 120 of 19440 combinations so far
# Trained and Tested combination 121 of 19440: (3, 3, 2, 3, 1, 2), taking 0.01 seconds to get val score of 0.0607
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 122 of 19440: (3, 3, 4, 3, 1, 2), taking 0.01 seconds to get val score of -0.6903
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 123 of 19440: (3, 3, 3, 2, 1, 2), taking 0.01 seconds to get val score of 0.0597
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 124 of 19440: (3, 3, 3, 4, 1, 2), taking 0.01 seconds to get val score of 0.0597
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 125 of 19440: (3, 3, 3, 3, 0, 2), taking 0.01 seconds to get val score of 0.1092
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 126 of 19440: (3, 3, 3, 3, 1, 1), taking 0.03 seconds to get val score of 0.0026
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 127 of 19440: (3, 3, 3, 3, 1, 3), taking 0.02 seconds to get val score of 0.0688
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 128 of 19440: (2, 5, 3, 3, 1, 2), taking 0.01 seconds to get val score of -0.0007
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (4, 5, 3, 3, 1, 2), which had val score of 0.1059
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 128 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 128 of 19440 combinations so far
# Trained and Tested combination 129 of 19440: (3, 6, 3, 3, 1, 2), taking 0.0 seconds to get val score of 0.0494
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 130 of 19440: (3, 5, 2, 3, 1, 2), taking 0.01 seconds to get val score of 0.0466
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 131 of 19440: (3, 5, 4, 3, 1, 2), taking 0.01 seconds to get val score of -0.6903
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 132 of 19440: (3, 5, 3, 2, 1, 2), taking 0.13 seconds to get val score of 0.045
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 133 of 19440: (3, 5, 3, 4, 1, 2), taking 0.01 seconds to get val score of 0.045
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 134 of 19440: (3, 5, 3, 3, 0, 2), taking 0.01 seconds to get val score of -0.0713
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 135 of 19440: (3, 5, 3, 3, 1, 1), taking 0.02 seconds to get val score of 0.0041
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 136 of 19440: (3, 5, 3, 3, 1, 3), taking 0.14 seconds to get val score of 0.0653
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 137 of 19440: (2, 4, 2, 3, 1, 2), taking 0.01 seconds to get val score of 0.002
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (4, 4, 2, 3, 1, 2), which had val score of 0.1186
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 137 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 2), which had val score of 0.0607
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 137 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 2, 3, 1, 2), which had val score of 0.0466
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 137 of 19440 combinations so far
# Trained and Tested combination 138 of 19440: (3, 4, 1, 3, 1, 2), taking 0.08 seconds to get val score of 0.0505
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 138 of 19440 combinations so far
# Trained and Tested combination 139 of 19440: (3, 4, 2, 2, 1, 2), taking 0.01 seconds to get val score of 0.0501
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 140 of 19440: (3, 4, 2, 4, 1, 2), taking 0.02 seconds to get val score of 0.0501
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 141 of 19440: (3, 4, 2, 3, 0, 2), taking 0.14 seconds to get val score of 0.0462
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 142 of 19440: (3, 4, 2, 3, 1, 1), taking 0.01 seconds to get val score of 0.0135
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 143 of 19440: (3, 4, 2, 3, 1, 3), taking 0.03 seconds to get val score of 0.066
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 144 of 19440: (2, 4, 3, 2, 1, 2), taking 0.01 seconds to get val score of -0.001
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (4, 4, 3, 2, 1, 2), which had val score of 0.1009
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 144 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 1, 2), which had val score of 0.0597
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 144 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 2, 1, 2), which had val score of 0.045
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 144 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 1, 2), which had val score of 0.0501
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 144 of 19440 combinations so far
# Trained and Tested combination 145 of 19440: (3, 4, 4, 2, 1, 2), taking 0.02 seconds to get val score of -0.6903
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 146 of 19440: (3, 4, 3, 1, 1, 2), taking 0.01 seconds to get val score of 0.0369
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 146 of 19440 combinations so far
# Trained and Tested combination 147 of 19440: (3, 4, 3, 2, 0, 2), taking 0.01 seconds to get val score of 0.0245
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 148 of 19440: (3, 4, 3, 2, 1, 1), taking 0.07 seconds to get val score of 0.0078
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 149 of 19440: (3, 4, 3, 2, 1, 3), taking 0.01 seconds to get val score of 0.0666
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 150 of 19440: (2, 4, 3, 4, 1, 2), taking 0.01 seconds to get val score of -0.001
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (4, 4, 3, 4, 1, 2), which had val score of 0.1258
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 150 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 4, 1, 2), which had val score of 0.0597
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 150 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 4, 1, 2), which had val score of 0.045
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 150 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 1, 2), which had val score of 0.0501
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 150 of 19440 combinations so far
# Trained and Tested combination 151 of 19440: (3, 4, 4, 4, 1, 2), taking 0.0 seconds to get val score of -0.6903
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 151 of 19440 combinations so far
# Trained and Tested combination 152 of 19440: (3, 4, 3, 5, 1, 2), taking 0.01 seconds to get val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 153 of 19440: (3, 4, 3, 4, 0, 2), taking 0.03 seconds to get val score of 0.0366
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 154 of 19440: (3, 4, 3, 4, 1, 1), taking 0.01 seconds to get val score of 0.0078
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 155 of 19440: (3, 4, 3, 4, 1, 3), taking 0.01 seconds to get val score of 0.0635
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 156 of 19440: (2, 4, 3, 3, 0, 2), taking 0.01 seconds to get val score of 0.0366
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (4, 4, 3, 3, 0, 2), which had val score of 0.0366
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 156 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 0, 2), which had val score of 0.1092
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 156 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 0, 2), which had val score of -0.0713
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 156 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 0, 2), which had val score of 0.0462
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 156 of 19440 combinations so far
# Trained and Tested combination 157 of 19440: (3, 4, 4, 3, 0, 2), taking 0.01 seconds to get val score of -0.6903
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (3, 4, 3, 2, 0, 2), which had val score of 0.0245
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 157 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 0, 2), which had val score of 0.0366
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 157 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 157 of 19440 combinations so far
# Trained and Tested combination 158 of 19440: (3, 4, 3, 3, 0, 1), taking 0.07 seconds to get val score of 0.0191
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 159 of 19440: (3, 4, 3, 3, 0, 3), taking 0.23 seconds to get val score of 0.0454
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 160 of 19440: (2, 4, 3, 3, 1, 3), taking 0.01 seconds to get val score of 0.0057
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (4, 4, 3, 3, 1, 3), which had val score of 0.1281
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 160 of 19440 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 1, 3), which had val score of 0.0688
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 160 of 19440 combinations so far
# Already Trained and Tested combination (3, 5, 3, 3, 1, 3), which had val score of 0.0653
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 160 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 1, 3), which had val score of 0.066
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 160 of 19440 combinations so far
# Trained and Tested combination 161 of 19440: (3, 4, 4, 3, 1, 3), taking 0.24 seconds to get val score of -0.8097
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (3, 4, 3, 2, 1, 3), which had val score of 0.0666
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 161 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 4, 1, 3), which had val score of 0.0635
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 161 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 0, 3), which had val score of 0.0454
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 161 of 19440 combinations so far
# Already Trained and Tested combination (3, 4, 3, 3, 1, 2), which had val score of 0.0388
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 161 of 19440 combinations so far
# Trained and Tested combination 162 of 19440: (3, 4, 3, 3, 1, 4), taking 0.01 seconds to get val score of 0.0565
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 163 of 19440: (4, 0, 0, 5, 1, 4), taking 0.12 seconds to get val score of 0.2299
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 164 of 19440: (5, 1, 0, 5, 1, 4), taking 0.17 seconds to get val score of 0.2529
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 165 of 19440: (5, 0, 1, 5, 1, 4), taking 0.11 seconds to get val score of 0.2864
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Trained and Tested combination 166 of 19440: (5, 0, 0, 4, 1, 4), taking 0.01 seconds to get val score of 0.1892
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864
# Already Trained and Tested combination (5, 0, 0, 5, 0, 4), which had val score of 0.1605
#         Current best combo: (5, 0, 0, 5, 1, 4) with val score 0.2864.
#         Has trained 166 of 19440 combinations so far
# Trained and Tested combination 167 of 19440: (5, 0, 0, 5, 1, 3), taking 0.26 seconds to get val score of 0.299
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Trained and Tested combination 168 of 19440: (4, 0, 0, 5, 1, 3), taking 0.07 seconds to get val score of 0.2274
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Trained and Tested combination 169 of 19440: (5, 1, 0, 5, 1, 3), taking 0.13 seconds to get val score of 0.2525
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Trained and Tested combination 170 of 19440: (5, 0, 1, 5, 1, 3), taking 0.02 seconds to get val score of 0.299
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Trained and Tested combination 171 of 19440: (5, 0, 0, 4, 1, 3), taking 0.08 seconds to get val score of 0.2733
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Trained and Tested combination 172 of 19440: (5, 0, 0, 5, 0, 3), taking 0.08 seconds to get val score of 0.072
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Trained and Tested combination 173 of 19440: (5, 0, 0, 5, 1, 2), taking 0.08 seconds to get val score of 0.2482
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Already Trained and Tested combination (5, 0, 0, 5, 1, 4), which had val score of 0.2864
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 173 of 19440 combinations so far
# % Combos Checked Thus Far: 173 out of 19440 which is 0.889918%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Already Trained and Tested combination (4, 0, 0, 5, 1, 4), which had val score of 0.2299
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 173 of 19440 combinations so far
# Already Trained and Tested combination (5, 1, 0, 5, 1, 4), which had val score of 0.2529
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 173 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 1, 5, 1, 4), which had val score of 0.2864
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 173 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 1, 4), which had val score of 0.1892
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 173 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 0, 4), which had val score of 0.1605
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 173 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 1, 3), which had val score of 0.299
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 173 of 19440 combinations so far
# 	round 1 iteration:  1
#
# Trained and Tested combination 174 of 19440: (4, 0, 1, 5, 1, 4), taking 0.03 seconds to get val score of 0.2284
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Trained and Tested combination 175 of 19440: (5, 1, 1, 5, 1, 4), taking 0.06 seconds to get val score of 0.2528
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Already Trained and Tested combination (5, 0, 0, 5, 1, 4), which had val score of 0.2864
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 175 of 19440 combinations so far
# Trained and Tested combination 176 of 19440: (5, 0, 2, 5, 1, 4), taking 0.02 seconds to get val score of 0.2864
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Trained and Tested combination 177 of 19440: (5, 0, 1, 4, 1, 4), taking 0.07 seconds to get val score of 0.1892
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Trained and Tested combination 178 of 19440: (5, 0, 1, 5, 0, 4), taking 0.15 seconds to get val score of 0.1605
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299
# Already Trained and Tested combination (5, 0, 1, 5, 1, 3), which had val score of 0.299
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 178 of 19440 combinations so far
# Already Trained and Tested combination (4, 0, 0, 5, 1, 3), which had val score of 0.2274
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 178 of 19440 combinations so far
# Already Trained and Tested combination (5, 1, 0, 5, 1, 3), which had val score of 0.2525
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 178 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 1, 5, 1, 3), which had val score of 0.299
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 178 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 1, 3), which had val score of 0.2733
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 178 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 0, 3), which had val score of 0.072
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 178 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 1, 2), which had val score of 0.2482
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 178 of 19440 combinations so far
# Already Trained and Tested combination (5, 0, 0, 5, 1, 4), which had val score of 0.2864
#         Current best combo: (5, 0, 0, 5, 1, 3) with val score 0.299.
#         Has trained 178 of 19440 combinations so far
# % Combos Checked Thus Far: 178 out of 19440 which is 0.9156380000000001%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 178 out of 19440 which is 0.9156380000000001%
# Max Score:
#  0.29902614252798076
# Max Test Score:
#  -0.082818
# Max Combo Index:
#  (5, 0, 0, 5, 1, 3) out of [6, 9, 6, 6, 2, 5] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'nu': 0.7}
# % Combos Checked: 178 out of 19440 which is 0.9156380000000001%
