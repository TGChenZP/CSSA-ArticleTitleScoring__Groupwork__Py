# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'eb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title&pyq'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %%
# python3 -m pip install --upgrade pip

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
## Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from interpret.glassbox import ExplainableBoostingRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_bins': (4, 6, 64, 256, 1024, 4096),
    'min_samples_leaf': (2, 4, 8, 16, 32),
    'interactions': (2, 4, 8),
    'max_leaves': (100, 1000, 10000),
    'learning_rate': (0.001, 0.01, 0.1, 1),
    'max_rounds': (25, 50, 100, 200),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 19260817,
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis = 1)
train_y = train_data['label']
val_X = val_data.drop('label', axis = 1)
val_y = val_data['label']
test_X = test_data.drop('label', axis = 1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'interpret.glassbox._ebm._ebm.ExplainableBoostingRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# Successfully read in tuning result of 110 rows, for 110.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (0, 4, 0, 2, 3, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 4, 0, 2, 3, 0), which had val score of 0.0325
#         Current best combo: (0, 4, 0, 2, 3, 0) with val score 0.0325.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 0, 2, 3, 3), which had val score of -0.1693
#         Current best combo: (0, 4, 0, 2, 3, 0) with val score 0.0325.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 2, 0, 0, 3), which had val score of -0.0105
#         Current best combo: (0, 4, 0, 2, 3, 0) with val score 0.0325.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 0, 3), which had val score of -0.066
#         Current best combo: (0, 4, 0, 2, 3, 0) with val score 0.0325.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 3, 3), which had val score of 0.0194
#         Current best combo: (0, 4, 0, 2, 3, 0) with val score 0.0325.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 3), which had val score of -0.0111
#         Current best combo: (0, 4, 0, 2, 3, 0) with val score 0.0325.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 0, 2, 3, 0), which had val score of -0.1693
#         Current best combo: (0, 4, 0, 2, 3, 0) with val score 0.0325.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 2, 0, 3, 3), which had val score of -0.1068
#         Current best combo: (0, 4, 0, 2, 3, 0) with val score 0.0325.
#         Has trained 110 of 4320 combinations so far
# As new Best Combo (0, 4, 0, 0, 0, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 4, 0, 0, 0, 3), which had val score of 0.0644
#         Current best combo: (0, 4, 0, 0, 0, 3) with val score 0.0644.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 0, 0), which had val score of -0.1487
#         Current best combo: (0, 4, 0, 0, 0, 3) with val score 0.0644.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 0, 3), which had val score of 0.0382
#         Current best combo: (0, 4, 0, 0, 0, 3) with val score 0.0644.
#         Has trained 110 of 4320 combinations so far
# As new Best Combo (0, 4, 2, 0, 3, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 4, 2, 0, 3, 0), which had val score of 0.089
#         Current best combo: (0, 4, 2, 0, 3, 0) with val score 0.089.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 0, 3), which had val score of 0.0382
#         Current best combo: (0, 4, 2, 0, 3, 0) with val score 0.089.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 3, 0), which had val score of 0.0764
#         Current best combo: (0, 4, 2, 0, 3, 0) with val score 0.089.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 3, 0), which had val score of -0.1387
#         Current best combo: (0, 4, 2, 0, 3, 0) with val score 0.089.
#         Has trained 110 of 4320 combinations so far
# As new Best Combo (0, 0, 2, 0, 3, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 2, 0, 3, 3), which had val score of 0.1105
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 0, 2, 0, 3), which had val score of -0.0661
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 0, 3), which had val score of 0.1073
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 0, 2, 3, 3), which had val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 2, 0, 3, 3), which had val score of -0.1183
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 2, 2, 3, 0), which had val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 3, 0), which had val score of -0.1156
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 0, 2, 0, 0), which had val score of -0.1612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 0, 0), which had val score of -0.2966
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 3, 3), which had val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 3, 3), which had val score of -0.1116
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 0, 2, 0, 0), which had val score of -0.3126
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 2, 0, 3, 0), which had val score of -0.086
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 3, 0), which had val score of 0.0325
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 2, 0, 3), which had val score of 0.1073
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 0), which had val score of -0.1637
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 0), which had val score of -0.2177
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 2, 2, 0, 0), which had val score of -0.3042
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 0, 2, 0, 0), which had val score of -0.1637
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 3, 3), which had val score of -0.1559
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 2, 3, 3), which had val score of 0.0912
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 3, 3), which had val score of 0.0912
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 0, 0), which had val score of -0.1439
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 3, 0), which had val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 3, 0), which had val score of 0.0764
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 3, 0), which had val score of -0.0213
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 0, 2, 3, 0), which had val score of -0.0213
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0), which had val score of -0.1612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 0, 2, 0, 3), which had val score of -0.066
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 0, 2, 3, 3), which had val score of 0.0194
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 2, 0, 0, 0), which had val score of -0.202
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 3), which had val score of -0.0117
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 0, 0), which had val score of -0.1487
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 0, 2, 3, 0), which had val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 3, 3), which had val score of -0.0356
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 2, 3, 0), which had val score of 0.089
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 3, 3), which had val score of 0.1105
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 2, 2, 0, 3), which had val score of -0.0661
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 4, 2, 0, 3, 0), which had val score of -0.1063
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 0, 2, 3, 3), which had val score of -0.0356
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 2, 0, 0, 0), which had val score of -0.2114
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 2, 0, 0), which had val score of -0.1439
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 0, 2, 0, 3), which had val score of 0.044
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 3), which had val score of 0.044
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 2, 0, 0, 3), which had val score of -0.0116
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 0, 2, 0, 0), which had val score of -0.314
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 0, 2, 0, 3), which had val score of 0.0644
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 0), which had val score of -0.2149
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 0, 2, 2, 3, 3), which had val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (2, 2, 1, 1, 2, 2), which had val score of -0.0059
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 2, 2), which had val score of -0.0628
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 3, 1, 1, 2, 2), which had val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 0, 1, 2, 2), which had val score of -0.0623
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 2, 1, 2, 2), which had val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 0, 2, 2), which had val score of -0.0306
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 1, 2), which had val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 3, 2), which had val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 1), which had val score of -0.0615
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 3), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (1, 2, 1, 1, 2, 2), which had val score of 0.0542
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 1, 1, 1, 2, 2), which had val score of -0.0194
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 3, 1, 1, 2, 2), which had val score of -0.0028
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 2, 0, 1, 2, 2), which had val score of -0.0157
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 2, 2, 1, 2, 2), which had val score of -0.0059
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 2, 1, 0, 2, 2), which had val score of -0.0059
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 2, 1, 2, 2, 2), which had val score of -0.0059
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 2, 1, 1, 1, 2), which had val score of -0.0077
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 2, 1, 1, 3, 2), which had val score of -0.1438
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 2, 1, 1, 2, 1), which had val score of -0.0049
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 2, 1, 1, 2, 3), which had val score of -0.0057
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (5, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 1, 1, 1, 2, 2), which had val score of -0.0628
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 3, 1, 1, 2, 2), which had val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 0, 1, 2, 2), which had val score of -0.0623
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 2, 1, 2, 2), which had val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 0, 2, 2), which had val score of -0.0306
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 1, 2), which had val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 3, 2), which had val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 2, 1), which had val score of -0.0615
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 2, 3), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 1, 1, 1, 2, 2), which had val score of -0.0194
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 1, 1, 1, 2, 2), which had val score of -0.0628
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 0, 1, 1, 2, 2), which had val score of -0.0636
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 0, 1, 2, 2), which had val score of -0.064
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 2), which had val score of -0.062
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0, 2, 2), which had val score of -0.0322
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 2, 2), which had val score of -0.0628
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 1, 2), which had val score of -0.0646
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 3, 2), which had val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 2, 1), which had val score of -0.0629
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 2, 3), which had val score of -0.0628
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (2, 3, 1, 1, 2, 2), which had val score of -0.0028
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (4, 3, 1, 1, 2, 2), which had val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 4, 1, 1, 2, 2), which had val score of -0.0624
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Already Trained and Tested combination (3, 3, 0, 1, 2, 2), which had val score of -0.06
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 110 of 4320 combinations so far
# Trained and Tested combination 111 of 4320: (3, 3, 2, 1, 2, 2), taking 16.83 seconds to get val score of -0.0605
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 112 of 4320: (3, 3, 1, 0, 2, 2), taking 6.39 seconds to get val score of -0.0327
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 113 of 4320: (3, 3, 1, 2, 2, 2), taking 7.63 seconds to get val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 114 of 4320: (3, 3, 1, 1, 1, 2), taking 20.55 seconds to get val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 115 of 4320: (3, 3, 1, 1, 3, 2), taking 16.49 seconds to get val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 116 of 4320: (3, 3, 1, 1, 2, 1), taking 5.12 seconds to get val score of -0.0609
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 117 of 4320: (3, 3, 1, 1, 2, 3), taking 18.48 seconds to get val score of -0.0596
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Already Trained and Tested combination (2, 2, 0, 1, 2, 2), which had val score of -0.0157
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 117 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 0, 1, 2, 2), which had val score of -0.0623
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 117 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 0, 1, 2, 2), which had val score of -0.064
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 117 of 4320 combinations so far
# Already Trained and Tested combination (3, 3, 0, 1, 2, 2), which had val score of -0.06
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 117 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 117 of 4320 combinations so far
# Trained and Tested combination 118 of 4320: (3, 2, 0, 0, 2, 2), taking 7.55 seconds to get val score of -0.029
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 119 of 4320: (3, 2, 0, 2, 2, 2), taking 10.32 seconds to get val score of -0.0623
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 120 of 4320: (3, 2, 0, 1, 1, 2), taking 10.26 seconds to get val score of -0.0644
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 121 of 4320: (3, 2, 0, 1, 3, 2), taking 9.82 seconds to get val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 122 of 4320: (3, 2, 0, 1, 2, 1), taking 6.95 seconds to get val score of -0.0622
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 123 of 4320: (3, 2, 0, 1, 2, 3), taking 15.67 seconds to get val score of -0.0622
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Already Trained and Tested combination (2, 2, 2, 1, 2, 2), which had val score of -0.0059
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 123 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 2, 1, 2, 2), which had val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 123 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 2), which had val score of -0.062
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 123 of 4320 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 2, 2), which had val score of -0.0605
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 123 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 123 of 4320 combinations so far
# Trained and Tested combination 124 of 4320: (3, 2, 2, 0, 2, 2), taking 6.81 seconds to get val score of -0.0323
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 125 of 4320: (3, 2, 2, 2, 2, 2), taking 7.65 seconds to get val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 126 of 4320: (3, 2, 2, 1, 1, 2), taking 8.63 seconds to get val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 127 of 4320: (3, 2, 2, 1, 3, 2), taking 9.02 seconds to get val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 128 of 4320: (3, 2, 2, 1, 2, 1), taking 4.41 seconds to get val score of -0.0613
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 129 of 4320: (3, 2, 2, 1, 2, 3), taking 11.94 seconds to get val score of -0.0613
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Already Trained and Tested combination (2, 2, 1, 0, 2, 2), which had val score of -0.0059
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 129 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 0, 2, 2), which had val score of -0.0306
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 129 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0, 2, 2), which had val score of -0.0322
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 129 of 4320 combinations so far
# Already Trained and Tested combination (3, 3, 1, 0, 2, 2), which had val score of -0.0327
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 129 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 0, 0, 2, 2), which had val score of -0.029
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 129 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 2, 0, 2, 2), which had val score of -0.0323
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 129 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 129 of 4320 combinations so far
# Trained and Tested combination 130 of 4320: (3, 2, 1, 0, 1, 2), taking 6.47 seconds to get val score of -0.0142
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 131 of 4320: (3, 2, 1, 0, 3, 2), taking 5.7 seconds to get val score of -0.1554
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 132 of 4320: (3, 2, 1, 0, 2, 1), taking 3.56 seconds to get val score of -0.0308
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 133 of 4320: (3, 2, 1, 0, 2, 3), taking 8.54 seconds to get val score of -0.0304
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Already Trained and Tested combination (2, 2, 1, 2, 2, 2), which had val score of -0.0059
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 133 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 2, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 133 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 2, 2, 2), which had val score of -0.0628
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 133 of 4320 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 2), which had val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 133 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 0, 2, 2, 2), which had val score of -0.0623
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 133 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 2, 2), which had val score of -0.0612
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 133 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 133 of 4320 combinations so far
# Trained and Tested combination 134 of 4320: (3, 2, 1, 2, 1, 2), taking 6.16 seconds to get val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 135 of 4320: (3, 2, 1, 2, 3, 2), taking 8.24 seconds to get val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 136 of 4320: (3, 2, 1, 2, 2, 1), taking 4.31 seconds to get val score of -0.0615
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 137 of 4320: (3, 2, 1, 2, 2, 3), taking 9.93 seconds to get val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Already Trained and Tested combination (2, 2, 1, 1, 1, 2), which had val score of -0.0077
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 137 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 1, 2), which had val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 137 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 1, 2), which had val score of -0.0646
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 137 of 4320 combinations so far
# Already Trained and Tested combination (3, 3, 1, 1, 1, 2), which had val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 137 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 0, 1, 1, 2), which had val score of -0.0644
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 137 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 2, 1, 1, 2), which had val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 137 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 0, 1, 2), which had val score of -0.0142
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 137 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 1, 2), which had val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 137 of 4320 combinations so far
# Trained and Tested combination 138 of 4320: (3, 2, 1, 1, 0, 2), taking 7.77 seconds to get val score of -0.0671
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 138 of 4320 combinations so far
# Trained and Tested combination 139 of 4320: (3, 2, 1, 1, 1, 1), taking 4.3 seconds to get val score of -0.0646
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 140 of 4320: (3, 2, 1, 1, 1, 3), taking 11.01 seconds to get val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Already Trained and Tested combination (2, 2, 1, 1, 2, 1), which had val score of -0.0049
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 140 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 2, 1), which had val score of -0.0615
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 140 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 2, 1), which had val score of -0.0629
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 140 of 4320 combinations so far
# Already Trained and Tested combination (3, 3, 1, 1, 2, 1), which had val score of -0.0609
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 140 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 0, 1, 2, 1), which had val score of -0.0622
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 140 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 2, 1, 2, 1), which had val score of -0.0613
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 140 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 0, 2, 1), which had val score of -0.0308
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 140 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2, 1), which had val score of -0.0615
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 140 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 1, 1), which had val score of -0.0646
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 140 of 4320 combinations so far
# Trained and Tested combination 141 of 4320: (3, 2, 1, 1, 3, 1), taking 4.75 seconds to get val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 142 of 4320: (3, 2, 1, 1, 2, 0), taking 2.98 seconds to get val score of -0.0617
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Already Trained and Tested combination (2, 2, 1, 1, 2, 3), which had val score of -0.0057
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 2, 3), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 2, 3), which had val score of -0.0628
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Already Trained and Tested combination (3, 3, 1, 1, 2, 3), which had val score of -0.0596
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 0, 1, 2, 3), which had val score of -0.0622
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 2, 1, 2, 3), which had val score of -0.0613
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 0, 2, 3), which had val score of -0.0304
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2, 3), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 1, 3), which had val score of -0.0645
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 142 of 4320 combinations so far
# Trained and Tested combination 143 of 4320: (3, 2, 1, 1, 3, 3), taking 13.33 seconds to get val score of -0.1693
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Already Trained and Tested combination (3, 2, 1, 1, 2, 2), which had val score of -0.0604
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105.
#         Has trained 143 of 4320 combinations so far
# Trained and Tested combination 144 of 4320: (1, 0, 2, 0, 3, 3), taking 8.83 seconds to get val score of 0.0256
#         Current best combo: (0, 0, 2, 0, 3, 3) with val score 0.1105
# Trained and Tested combination 145 of 4320: (0, 1, 2, 0, 3, 3), taking 8.68 seconds to get val score of 0.144
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Trained and Tested combination 146 of 4320: (0, 0, 1, 0, 3, 3), taking 8.39 seconds to get val score of 0.0797
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Trained and Tested combination 147 of 4320: (0, 0, 2, 1, 3, 3), taking 9.33 seconds to get val score of 0.1105
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Trained and Tested combination 148 of 4320: (0, 0, 2, 0, 2, 3), taking 8.34 seconds to get val score of 0.0908
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Trained and Tested combination 149 of 4320: (0, 0, 2, 0, 3, 2), taking 5.93 seconds to get val score of 0.0769
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Trained and Tested combination 150 of 4320: (1, 1, 2, 0, 3, 3), taking 9.56 seconds to get val score of 0.0725
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Already Trained and Tested combination (0, 0, 2, 0, 3, 3), which had val score of 0.1105
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144.
#         Has trained 150 of 4320 combinations so far
# Trained and Tested combination 151 of 4320: (0, 2, 2, 0, 3, 3), taking 9.15 seconds to get val score of 0.0984
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Trained and Tested combination 152 of 4320: (0, 1, 1, 0, 3, 3), taking 9.9 seconds to get val score of 0.1014
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Trained and Tested combination 153 of 4320: (0, 1, 2, 1, 3, 3), taking 9.15 seconds to get val score of 0.144
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Trained and Tested combination 154 of 4320: (0, 1, 2, 0, 2, 3), taking 9.23 seconds to get val score of 0.1003
#         Current best combo: (0, 1, 2, 0, 3, 3) with val score 0.144
# Trained and Tested combination 155 of 4320: (0, 1, 2, 0, 3, 2), taking 5.89 seconds to get val score of 0.1538
#         Current best combo: (0, 1, 2, 0, 3, 2) with val score 0.1538
# Trained and Tested combination 156 of 4320: (1, 1, 2, 0, 3, 2), taking 7.01 seconds to get val score of 0.0052
#         Current best combo: (0, 1, 2, 0, 3, 2) with val score 0.1538
# Already Trained and Tested combination (0, 0, 2, 0, 3, 2), which had val score of 0.0769
#         Current best combo: (0, 1, 2, 0, 3, 2) with val score 0.1538.
#         Has trained 156 of 4320 combinations so far
# Trained and Tested combination 157 of 4320: (0, 2, 2, 0, 3, 2), taking 6.79 seconds to get val score of 0.0689
#         Current best combo: (0, 1, 2, 0, 3, 2) with val score 0.1538
# Trained and Tested combination 158 of 4320: (0, 1, 1, 0, 3, 2), taking 5.87 seconds to get val score of 0.014
#         Current best combo: (0, 1, 2, 0, 3, 2) with val score 0.1538
# Trained and Tested combination 159 of 4320: (0, 1, 2, 1, 3, 2), taking 9.45 seconds to get val score of 0.1538
#         Current best combo: (0, 1, 2, 0, 3, 2) with val score 0.1538
# Trained and Tested combination 160 of 4320: (0, 1, 2, 0, 2, 2), taking 6.77 seconds to get val score of 0.1066
#         Current best combo: (0, 1, 2, 0, 3, 2) with val score 0.1538
# Trained and Tested combination 161 of 4320: (0, 1, 2, 0, 3, 1), taking 4.37 seconds to get val score of 0.1333
#         Current best combo: (0, 1, 2, 0, 3, 2) with val score 0.1538
# Already Trained and Tested combination (0, 1, 2, 0, 3, 3), which had val score of 0.144
#         Current best combo: (0, 1, 2, 0, 3, 2) with val score 0.1538.
#         Has trained 161 of 4320 combinations so far
# % Combos Checked Thus Far: 161 out of 4320 which is 3.726852%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# Cruising Coordrdinate 0 of 64
#
# ...
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 245 of 4320: (0, 1, 2, 2, 3, 3), taking 8.55 seconds to get val score of 0.144
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 246 of 4320: (0, 0, 1, 2, 3, 3), taking 9.11 seconds to get val score of 0.0797
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 0, 2, 1, 3, 3), which had val score of 0.1105
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 246 of 4320 combinations so far
# Trained and Tested combination 247 of 4320: (0, 0, 2, 2, 2, 3), taking 9.41 seconds to get val score of 0.0908
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 248 of 4320: (0, 0, 2, 2, 3, 2), taking 5.99 seconds to get val score of 0.0769
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# 	round 6 iteration:  1
#
# Trained and Tested combination 249 of 4320: (1, 1, 2, 2, 3, 3), taking 9.48 seconds to get val score of 0.0725
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 0, 2, 2, 3, 3), which had val score of 0.1105
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 249 of 4320 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 3, 3), which had val score of 0.0984
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 249 of 4320 combinations so far
# Trained and Tested combination 250 of 4320: (0, 1, 1, 2, 3, 3), taking 8.54 seconds to get val score of 0.1014
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 1, 2, 1, 3, 3), which had val score of 0.144
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 250 of 4320 combinations so far
# Trained and Tested combination 251 of 4320: (0, 1, 2, 2, 2, 3), taking 9.36 seconds to get val score of 0.1003
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 252 of 4320: (0, 1, 2, 2, 3, 2), taking 5.79 seconds to get val score of 0.1538
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# % Combos Checked Thus Far: 252 out of 4320 which is 5.8333330000000005%
# Cruising Coordrdinate 0 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Trained and Tested combination 253 of 4320: (1, 4, 2, 0, 3, 0), taking 2.61 seconds to get val score of 0.072
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 254 of 4320: (0, 3, 2, 0, 3, 0), taking 2.43 seconds to get val score of 0.0805
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 255 of 4320: (0, 4, 1, 0, 3, 0), taking 2.05 seconds to get val score of 0.082
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 4, 2, 1, 3, 0), which had val score of 0.089
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 255 of 4320 combinations so far
# Trained and Tested combination 256 of 4320: (0, 4, 2, 0, 2, 0), taking 2.3 seconds to get val score of 0.0902
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 257 of 4320: (0, 4, 2, 0, 3, 1), taking 2.61 seconds to get val score of 0.107
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# 	round 7 iteration:  1
#
# Trained and Tested combination 258 of 4320: (1, 4, 2, 0, 2, 0), taking 2.03 seconds to get val score of 0.0827
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 259 of 4320: (0, 3, 2, 0, 2, 0), taking 2.15 seconds to get val score of 0.1068
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 260 of 4320: (0, 4, 1, 0, 2, 0), taking 1.78 seconds to get val score of 0.0775
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 4, 2, 1, 2, 0), which had val score of 0.0902
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 260 of 4320 combinations so far
# Trained and Tested combination 261 of 4320: (0, 4, 2, 0, 1, 0), taking 2.29 seconds to get val score of 0.0472
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 4, 2, 0, 3, 0), which had val score of 0.089
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 261 of 4320 combinations so far
# Trained and Tested combination 262 of 4320: (0, 4, 2, 0, 2, 1), taking 3.05 seconds to get val score of 0.0947
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 263 of 4320: (1, 4, 2, 0, 3, 1), taking 2.92 seconds to get val score of 0.0948
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 264 of 4320: (0, 3, 2, 0, 3, 1), taking 3.06 seconds to get val score of 0.108
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 265 of 4320: (0, 4, 1, 0, 3, 1), taking 2.63 seconds to get val score of 0.1179
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 4, 2, 1, 3, 1), which had val score of 0.107
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 265 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 2, 1), which had val score of 0.0947
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 265 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 3, 0), which had val score of 0.089
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 265 of 4320 combinations so far
# Trained and Tested combination 266 of 4320: (0, 4, 2, 0, 3, 2), taking 4.49 seconds to get val score of 0.113
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# % Combos Checked Thus Far: 266 out of 4320 which is 6.157407%
# Cruising Coordrdinate 0 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# Trained and Tested combination 267 of 4320: (1, 4, 2, 0, 3, 3), taking 7.81 seconds to get val score of 0.0689
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 268 of 4320: (0, 3, 2, 0, 3, 3), taking 8.51 seconds to get val score of 0.1479
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 269 of 4320: (0, 4, 1, 0, 3, 3), taking 7.9 seconds to get val score of 0.0973
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 4, 2, 1, 3, 3), which had val score of 0.0912
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 269 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 2, 3), which had val score of 0.0941
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 269 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 3, 2), which had val score of 0.113
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 269 of 4320 combinations so far
# 	round 8 iteration:  1
#
# Trained and Tested combination 270 of 4320: (1, 3, 2, 0, 3, 3), taking 8.32 seconds to get val score of 0.0876
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 2, 2, 0, 3, 3), which had val score of 0.0984
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 270 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 3, 3), which had val score of 0.0912
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 270 of 4320 combinations so far
# Trained and Tested combination 271 of 4320: (0, 3, 1, 0, 3, 3), taking 8.1 seconds to get val score of 0.0549
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 3, 2, 1, 3, 3), which had val score of 0.1479
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 271 of 4320 combinations so far
# Trained and Tested combination 272 of 4320: (0, 3, 2, 0, 2, 3), taking 8.61 seconds to get val score of 0.1085
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 273 of 4320: (0, 3, 2, 0, 3, 2), taking 5.74 seconds to get val score of 0.1603
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 274 of 4320: (1, 4, 1, 0, 3, 3), taking 8.69 seconds to get val score of 0.0681
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 3, 1, 0, 3, 3), which had val score of 0.0549
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 274 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 3, 3), which had val score of 0.0194
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 274 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 3, 3), which had val score of 0.0912
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 274 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 1, 1, 3, 3), which had val score of 0.0973
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 274 of 4320 combinations so far
# Trained and Tested combination 275 of 4320: (0, 4, 1, 0, 2, 3), taking 7.99 seconds to get val score of 0.0828
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 276 of 4320: (0, 4, 1, 0, 3, 2), taking 5.14 seconds to get val score of 0.0657
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 277 of 4320: (1, 4, 2, 0, 2, 3), taking 8.63 seconds to get val score of 0.085
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 3, 2, 0, 2, 3), which had val score of 0.1085
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 277 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 1, 0, 2, 3), which had val score of 0.0828
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 277 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 1, 2, 3), which had val score of 0.0941
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 277 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 1, 3), which had val score of 0.1053
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 277 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 3, 3), which had val score of 0.0912
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 277 of 4320 combinations so far
# Trained and Tested combination 278 of 4320: (0, 4, 2, 0, 2, 2), taking 5.18 seconds to get val score of 0.0953
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# % Combos Checked Thus Far: 278 out of 4320 which is 6.435185000000001%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (1, 3, 2, 2, 3, 2), which had val score of 0.0944
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 278 of 4320 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 3, 2), which had val score of 0.0689
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 278 of 4320 combinations so far
# Already Trained and Tested combination (0, 4, 2, 2, 3, 2), which had val score of 0.113
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 278 of 4320 combinations so far
# Already Trained and Tested combination (0, 3, 1, 2, 3, 2), which had val score of 0.0364
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 278 of 4320 combinations so far
# Already Trained and Tested combination (0, 3, 2, 1, 3, 2), which had val score of 0.1603
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 278 of 4320 combinations so far
# Already Trained and Tested combination (0, 3, 2, 2, 2, 2), which had val score of 0.1005
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 278 of 4320 combinations so far
# Already Trained and Tested combination (0, 3, 2, 2, 3, 1), which had val score of 0.108
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 278 of 4320 combinations so far
# Already Trained and Tested combination (0, 3, 2, 2, 3, 3), which had val score of 0.1479
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 278 of 4320 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 279 of 4320: (1, 3, 2, 1, 3, 2), taking 6.34 seconds to get val score of 0.0944
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 280 of 4320: (0, 2, 2, 1, 3, 2), taking 6.2 seconds to get val score of 0.0689
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 4, 2, 1, 3, 2), which had val score of 0.113
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 280 of 4320 combinations so far
# Trained and Tested combination 281 of 4320: (0, 3, 1, 1, 3, 2), taking 5.1 seconds to get val score of 0.0364
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 3, 2, 0, 3, 2), which had val score of 0.1603
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 281 of 4320 combinations so far
# Already Trained and Tested combination (0, 3, 2, 2, 3, 2), which had val score of 0.1603
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 281 of 4320 combinations so far
# Trained and Tested combination 282 of 4320: (0, 3, 2, 1, 2, 2), taking 6.12 seconds to get val score of 0.1005
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Trained and Tested combination 283 of 4320: (0, 3, 2, 1, 3, 1), taking 3.93 seconds to get val score of 0.108
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603
# Already Trained and Tested combination (0, 3, 2, 1, 3, 3), which had val score of 0.1479
#         Current best combo: (0, 3, 2, 2, 3, 2) with val score 0.1603.
#         Has trained 283 of 4320 combinations so far
# % Combos Checked Thus Far: 283 out of 4320 which is 6.550926%
# Max Score:
#  0.1603199899946105
# Max Test Score:
#  -0.166885
# Max Combo Index:
#  (0, 3, 2, 2, 3, 2) out of [6, 5, 3, 3, 4, 4] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_bins': 4, 'min_samples_leaf': 16, 'interactions': 8, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 100}
# % Combos Checked: 283 out of 4320 which is 6.550926%
