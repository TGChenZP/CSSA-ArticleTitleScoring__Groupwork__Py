# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgb'
TUNER = 'yangzhoub'
EXPERIMENT_TYPE = 'title&pyq'
EMBEDDING_MODEL = 'GanymedeNil_text2vec-large-chinese'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
else:
    py_file_location = '../../../PrivatePackages'
    home_directory = '../../../'

sys.path.append(os.path.abspath(py_file_location))

import YangZhouB

import pandas as pd

# %%
# Parameters that are same for every script
SEED = 19260817

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = False

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': 19260817,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/train_dataset_{EXPERIMENT_TYPE}.csv')
val_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/val_dataset_{EXPERIMENT_TYPE}.csv')
test_data = pd.read_csv(
    f'{home_directory}/data/curated/{EMBEDDING_MODEL}/test_dataset_{EXPERIMENT_TYPE}.csv')

train_X = train_data.drop('label', axis=1)
train_y = train_data['label']
val_X = val_data.drop('label', axis=1)
val_y = val_data['label']
test_X = test_data.drop('label', axis=1)
test_y = test_data['label']

# %%
# # Import feature importance ordering

# with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = YangZhouB.YangZhouB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{EXPERIMENT_TYPE}_{EMBEDDING_MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBRegressor'>, which is a Regression model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 31500: (5, 0, 0, 4, 0, 0), taking 11.72 seconds to get val score of -0.002
#         Current best combo: (5, 0, 0, 4, 0, 0) with val score -0.002
# Trained and Tested combination 2 of 31500: (5, 0, 0, 0, 4, 5), taking 18.54 seconds to get val score of 0
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 3 of 31500: (0, 6, 0, 4, 0, 0), taking 4.65 seconds to get val score of -0.0103
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 4 of 31500: (0, 0, 0, 0, 4, 0), taking 1.42 seconds to get val score of -0.0108
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 5 of 31500: (0, 6, 4, 4, 0, 0), taking 6.76 seconds to get val score of -0.0104
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 6 of 31500: (0, 0, 0, 4, 0, 0), taking 1.54 seconds to get val score of -0.0106
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 7 of 31500: (5, 0, 0, 4, 0, 5), taking 21.89 seconds to get val score of 0
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 8 of 31500: (0, 3, 0, 4, 0, 0), taking 4.53 seconds to get val score of -0.0103
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 9 of 31500: (0, 0, 4, 0, 0, 0), taking 1.91 seconds to get val score of -0.011
#         Current best combo: (5, 0, 0, 0, 4, 5) with val score 0
# Trained and Tested combination 10 of 31500: (5, 3, 4, 0, 4, 0), taking 224.47 seconds to get val score of 0.0043
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 11 of 31500: (0, 6, 4, 4, 4, 0), taking 6.94 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 12 of 31500: (0, 3, 4, 0, 0, 5), taking 9.41 seconds to get val score of -1.1535376404913388e+42
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 13 of 31500: (0, 3, 0, 0, 0, 0), taking 4.54 seconds to get val score of -0.0107
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 14 of 31500: (0, 3, 4, 0, 4, 0), taking 6.78 seconds to get val score of -0.0107
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 15 of 31500: (5, 3, 0, 0, 0, 5), taking 24.95 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 16 of 31500: (5, 0, 0, 0, 0, 0), taking 52.72 seconds to get val score of -0.0042
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 17 of 31500: (0, 3, 4, 0, 4, 5), taking 7.87 seconds to get val score of -4.841063840767077e+41
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 18 of 31500: (0, 6, 0, 4, 4, 5), taking 3.19 seconds to get val score of -5.0453149616547216e+44
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 19 of 31500: (5, 0, 4, 0, 4, 5), taking 15.53 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 20 of 31500: (5, 3, 4, 4, 4, 0), taking 183.74 seconds to get val score of -0.0013
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 21 of 31500: (5, 3, 0, 4, 0, 0), taking 108.08 seconds to get val score of 0.0015
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 22 of 31500: (0, 3, 0, 0, 4, 5), taking 3.56 seconds to get val score of -9.186150766851575e+44
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 23 of 31500: (5, 6, 4, 0, 4, 5), taking 27.4 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 24 of 31500: (0, 6, 0, 0, 4, 5), taking 3.84 seconds to get val score of -9.186150766851575e+44
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 25 of 31500: (5, 6, 4, 0, 0, 5), taking 29.49 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 26 of 31500: (5, 6, 0, 0, 0, 5), taking 21.4 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 27 of 31500: (0, 3, 4, 4, 0, 5), taking 6.64 seconds to get val score of -1.4711457562335235e+44
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 28 of 31500: (0, 6, 4, 0, 0, 5), taking 7.76 seconds to get val score of -1.1535376404913388e+42
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 29 of 31500: (5, 0, 0, 4, 4, 5), taking 21.06 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 30 of 31500: (0, 3, 0, 4, 4, 0), taking 4.02 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 31 of 31500: (5, 3, 0, 4, 4, 0), taking 47.1 seconds to get val score of 0.0005
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 32 of 31500: (5, 3, 0, 4, 4, 5), taking 5.79 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 33 of 31500: (0, 6, 0, 0, 0, 5), taking 0.49 seconds to get val score of -9.01093534564539e+43
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 34 of 31500: (0, 3, 0, 0, 4, 0), taking 0.41 seconds to get val score of -0.0107
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 35 of 31500: (0, 3, 0, 0, 0, 5), taking 0.55 seconds to get val score of -9.01093534564539e+43
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 36 of 31500: (0, 3, 0, 4, 0, 5), taking 1.55 seconds to get val score of -8.412972077755326e+42
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 37 of 31500: (5, 3, 4, 4, 4, 5), taking 20.86 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 38 of 31500: (5, 0, 4, 4, 0, 5), taking 24.01 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 0, 4, 0) with val score 0.0043
# Trained and Tested combination 39 of 31500: (5, 3, 4, 4, 0, 0), taking 225.6 seconds to get val score of 0.0055
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 40 of 31500: (0, 0, 0, 4, 4, 0), taking 2.29 seconds to get val score of -0.0106
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 41 of 31500: (5, 6, 4, 0, 0, 0), taking 196.18 seconds to get val score of 0.0051
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 42 of 31500: (5, 3, 0, 4, 0, 5), taking 24.41 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 43 of 31500: (0, 6, 0, 0, 4, 0), taking 4.53 seconds to get val score of -0.0107
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 44 of 31500: (5, 6, 4, 4, 0, 5), taking 32.01 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 45 of 31500: (0, 0, 4, 0, 4, 5), taking 1.44 seconds to get val score of -1.3125621019961734e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 46 of 31500: (0, 6, 0, 4, 4, 0), taking 4.59 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 47 of 31500: (0, 6, 4, 0, 4, 5), taking 8.25 seconds to get val score of -4.841063840767077e+41
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 48 of 31500: (5, 6, 4, 4, 0, 0), taking 192.02 seconds to get val score of 0.0055
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 49 of 31500: (0, 3, 0, 4, 4, 5), taking 1.14 seconds to get val score of -5.0453149616547216e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 50 of 31500: (5, 6, 0, 0, 4, 5), taking 2.53 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 51 of 31500: (5, 6, 0, 4, 0, 0), taking 85.58 seconds to get val score of 0.0015
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 52 of 31500: (5, 3, 4, 0, 0, 5), taking 13.68 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 53 of 31500: (0, 6, 4, 4, 0, 5), taking 3.95 seconds to get val score of -1.4711469546393445e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 54 of 31500: (0, 0, 4, 4, 0, 5), taking 0.15 seconds to get val score of -1.7082234381308105e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 55 of 31500: (5, 3, 0, 0, 4, 0), taking 59.97 seconds to get val score of -0.0017
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 56 of 31500: (5, 0, 0, 0, 4, 0), taking 49.41 seconds to get val score of -0.0042
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 57 of 31500: (0, 6, 0, 0, 0, 0), taking 3.79 seconds to get val score of -0.0107
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 58 of 31500: (0, 0, 4, 0, 0, 5), taking 1.33 seconds to get val score of -1.3125621019961734e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 59 of 31500: (0, 0, 0, 0, 0, 5), taking 1.6 seconds to get val score of -1.3031627191230155e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 60 of 31500: (5, 0, 4, 0, 4, 0), taking 58.44 seconds to get val score of -0.0056
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 61 of 31500: (5, 6, 0, 4, 4, 5), taking 24.94 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 62 of 31500: (0, 3, 4, 4, 4, 0), taking 6.63 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 63 of 31500: (0, 6, 0, 4, 0, 5), taking 3.19 seconds to get val score of -8.412972077755326e+42
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 64 of 31500: (5, 3, 4, 0, 4, 5), taking 28.86 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 65 of 31500: (0, 0, 4, 4, 4, 5), taking 1.5 seconds to get val score of -1.6919594087250347e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 66 of 31500: (5, 3, 4, 4, 0, 5), taking 28.51 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 67 of 31500: (0, 6, 4, 0, 0, 0), taking 7.25 seconds to get val score of -0.0107
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 68 of 31500: (5, 0, 4, 4, 4, 5), taking 22.52 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 69 of 31500: (5, 0, 4, 4, 4, 0), taking 59.64 seconds to get val score of -0.0157
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 70 of 31500: (5, 0, 0, 4, 4, 0), taking 27.11 seconds to get val score of -0.0021
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 71 of 31500: (5, 0, 0, 0, 0, 5), taking 1.85 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 72 of 31500: (5, 6, 4, 4, 4, 0), taking 139.47 seconds to get val score of -0.0013
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 73 of 31500: (0, 3, 4, 4, 0, 0), taking 5.7 seconds to get val score of -0.0104
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 74 of 31500: (0, 0, 0, 4, 0, 5), taking 1.3 seconds to get val score of -3.712933128133233e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 75 of 31500: (0, 0, 4, 4, 0, 0), taking 1.52 seconds to get val score of -0.0109
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 76 of 31500: (0, 0, 0, 0, 0, 0), taking 1.75 seconds to get val score of -0.0108
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 77 of 31500: (5, 6, 0, 4, 0, 5), taking 25.33 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 78 of 31500: (5, 6, 4, 4, 4, 5), taking 27.33 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 79 of 31500: (5, 0, 4, 0, 0, 0), taking 57.64 seconds to get val score of -0.0056
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 80 of 31500: (5, 3, 0, 0, 4, 5), taking 24.34 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 81 of 31500: (0, 3, 4, 0, 0, 0), taking 6.92 seconds to get val score of -0.0107
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 82 of 31500: (5, 6, 0, 4, 4, 0), taking 97.75 seconds to get val score of 0.0005
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 83 of 31500: (0, 0, 0, 4, 4, 5), taking 0.07 seconds to get val score of -3.6729189891531163e+45
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 84 of 31500: (5, 0, 4, 4, 0, 0), taking 42.71 seconds to get val score of -0.0154
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 85 of 31500: (0, 3, 4, 4, 4, 5), taking 6.07 seconds to get val score of -1.6385392462303734e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 86 of 31500: (5, 6, 4, 0, 4, 0), taking 137.8 seconds to get val score of 0.0043
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 87 of 31500: (0, 0, 4, 4, 4, 0), taking 1.75 seconds to get val score of -0.0109
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 88 of 31500: (5, 6, 0, 0, 0, 0), taking 115.85 seconds to get val score of -0.0014
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 89 of 31500: (5, 0, 4, 0, 0, 5), taking 24.07 seconds to get val score of 0
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 90 of 31500: (0, 0, 4, 0, 4, 0), taking 1.84 seconds to get val score of -0.011
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 91 of 31500: (0, 0, 0, 0, 4, 5), taking 1.5 seconds to get val score of -2.8240609281702225e+44
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 92 of 31500: (5, 6, 0, 0, 4, 0), taking 121.46 seconds to get val score of -0.0017
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 93 of 31500: (5, 3, 4, 0, 0, 0), taking 213.6 seconds to get val score of 0.0051
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 94 of 31500: (0, 6, 4, 0, 4, 0), taking 8.05 seconds to get val score of -0.0107
#         Current best combo: (5, 3, 4, 4, 0, 0) with val score 0.0055
# Trained and Tested combination 95 of 31500: (3, 3, 2, 2, 2, 3), taking 48.59 seconds to get val score of 0.0826
#         Current best combo: (3, 3, 2, 2, 2, 3) with val score 0.0826
# Trained and Tested combination 96 of 31500: (0, 6, 4, 4, 4, 5), taking 5.35 seconds to get val score of -1.6385392462303734e+44
#         Current best combo: (3, 3, 2, 2, 2, 3) with val score 0.0826
# Trained and Tested combination 97 of 31500: (5, 3, 0, 0, 0, 0), taking 77.58 seconds to get val score of -0.0014
#         Current best combo: (3, 3, 2, 2, 2, 3) with val score 0.0826
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 98 of 31500: (2, 3, 2, 2, 2, 3), taking 17.24 seconds to get val score of 0.0828
#         Current best combo: (2, 3, 2, 2, 2, 3) with val score 0.0828
# Trained and Tested combination 99 of 31500: (4, 3, 2, 2, 2, 3), taking 48.14 seconds to get val score of 0.0829
#         Current best combo: (4, 3, 2, 2, 2, 3) with val score 0.0829
# Trained and Tested combination 100 of 31500: (3, 2, 2, 2, 2, 3), taking 45.88 seconds to get val score of 0.1316
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 101 of 31500: (3, 4, 2, 2, 2, 3), taking 47.41 seconds to get val score of 0.0826
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 102 of 31500: (3, 3, 1, 2, 2, 3), taking 39.46 seconds to get val score of 0.1198
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 103 of 31500: (3, 3, 3, 2, 2, 3), taking 49.13 seconds to get val score of 0.0736
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 104 of 31500: (3, 3, 2, 1, 2, 3), taking 44.3 seconds to get val score of 0.047
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 105 of 31500: (3, 3, 2, 3, 2, 3), taking 21.23 seconds to get val score of 0.1226
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 106 of 31500: (3, 3, 2, 2, 1, 3), taking 3.97 seconds to get val score of 0.027
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 107 of 31500: (3, 3, 2, 2, 3, 3), taking 33.78 seconds to get val score of 0.0356
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 108 of 31500: (3, 3, 2, 2, 2, 2), taking 3.85 seconds to get val score of 0.0567
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 109 of 31500: (3, 3, 2, 2, 2, 4), taking 2.53 seconds to get val score of -0.6369
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# 	round 0 iteration:  1
#
# Trained and Tested combination 110 of 31500: (1, 3, 2, 2, 2, 3), taking 1.0 seconds to get val score of 0.0883
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0826
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 110 of 31500 combinations so far
# Trained and Tested combination 111 of 31500: (2, 2, 2, 2, 2, 3), taking 2.54 seconds to get val score of 0.1316
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 112 of 31500: (2, 4, 2, 2, 2, 3), taking 2.91 seconds to get val score of 0.0828
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 113 of 31500: (2, 3, 1, 2, 2, 3), taking 1.85 seconds to get val score of 0.1202
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 114 of 31500: (2, 3, 3, 2, 2, 3), taking 2.76 seconds to get val score of 0.0733
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 115 of 31500: (2, 3, 2, 1, 2, 3), taking 2.81 seconds to get val score of 0.0478
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 116 of 31500: (2, 3, 2, 3, 2, 3), taking 2.33 seconds to get val score of 0.1221
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 117 of 31500: (2, 3, 2, 2, 1, 3), taking 2.05 seconds to get val score of 0.026
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 118 of 31500: (2, 3, 2, 2, 3, 3), taking 2.26 seconds to get val score of 0.0414
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 119 of 31500: (2, 3, 2, 2, 2, 2), taking 2.13 seconds to get val score of 0.0553
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 120 of 31500: (2, 3, 2, 2, 2, 4), taking 1.66 seconds to get val score of -0.6369
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0826
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 120 of 31500 combinations so far
# Trained and Tested combination 121 of 31500: (5, 3, 2, 2, 2, 3), taking 15.79 seconds to get val score of 0.083
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 122 of 31500: (4, 2, 2, 2, 2, 3), taking 6.76 seconds to get val score of 0.1316
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 123 of 31500: (4, 4, 2, 2, 2, 3), taking 6.91 seconds to get val score of 0.0829
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 124 of 31500: (4, 3, 1, 2, 2, 3), taking 5.55 seconds to get val score of 0.1202
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 125 of 31500: (4, 3, 3, 2, 2, 3), taking 5.9 seconds to get val score of 0.0735
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 126 of 31500: (4, 3, 2, 1, 2, 3), taking 5.81 seconds to get val score of 0.0469
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 127 of 31500: (4, 3, 2, 3, 2, 3), taking 5.98 seconds to get val score of 0.1222
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 128 of 31500: (4, 3, 2, 2, 1, 3), taking 2.97 seconds to get val score of 0.0275
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 129 of 31500: (4, 3, 2, 2, 3, 3), taking 6.54 seconds to get val score of 0.0343
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 130 of 31500: (4, 3, 2, 2, 2, 2), taking 5.59 seconds to get val score of 0.0399
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 131 of 31500: (4, 3, 2, 2, 2, 4), taking 5.66 seconds to get val score of -0.6373
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Already Trained and Tested combination (2, 2, 2, 2, 2, 3), which had val score of 0.1316
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 131 of 31500 combinations so far
# Already Trained and Tested combination (4, 2, 2, 2, 2, 3), which had val score of 0.1316
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 131 of 31500 combinations so far
# Trained and Tested combination 132 of 31500: (3, 1, 2, 2, 2, 3), taking 2.05 seconds to get val score of 0.0722
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0826
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 132 of 31500 combinations so far
# Trained and Tested combination 133 of 31500: (3, 2, 1, 2, 2, 3), taking 2.84 seconds to get val score of 0.1035
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 134 of 31500: (3, 2, 3, 2, 2, 3), taking 3.46 seconds to get val score of 0.0677
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 135 of 31500: (3, 2, 2, 1, 2, 3), taking 3.29 seconds to get val score of 0.047
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 136 of 31500: (3, 2, 2, 3, 2, 3), taking 2.27 seconds to get val score of 0.1189
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 137 of 31500: (3, 2, 2, 2, 1, 3), taking 1.76 seconds to get val score of 0.0474
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 138 of 31500: (3, 2, 2, 2, 3, 3), taking 2.46 seconds to get val score of 0.0356
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 139 of 31500: (3, 2, 2, 2, 2, 2), taking 2.29 seconds to get val score of 0.0638
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 140 of 31500: (3, 2, 2, 2, 2, 4), taking 2.38 seconds to get val score of -0.5807
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Already Trained and Tested combination (2, 4, 2, 2, 2, 3), which had val score of 0.0828
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 140 of 31500 combinations so far
# Already Trained and Tested combination (4, 4, 2, 2, 2, 3), which had val score of 0.0829
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 140 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0826
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 140 of 31500 combinations so far
# Trained and Tested combination 141 of 31500: (3, 5, 2, 2, 2, 3), taking 2.33 seconds to get val score of 0.0826
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 142 of 31500: (3, 4, 1, 2, 2, 3), taking 2.08 seconds to get val score of 0.1198
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 143 of 31500: (3, 4, 3, 2, 2, 3), taking 2.45 seconds to get val score of 0.0736
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 144 of 31500: (3, 4, 2, 1, 2, 3), taking 2.49 seconds to get val score of 0.047
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 145 of 31500: (3, 4, 2, 3, 2, 3), taking 2.3 seconds to get val score of 0.1226
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 146 of 31500: (3, 4, 2, 2, 1, 3), taking 1.84 seconds to get val score of 0.027
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 147 of 31500: (3, 4, 2, 2, 3, 3), taking 2.47 seconds to get val score of 0.0356
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 148 of 31500: (3, 4, 2, 2, 2, 2), taking 2.25 seconds to get val score of 0.0567
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Trained and Tested combination 149 of 31500: (3, 4, 2, 2, 2, 4), taking 2.11 seconds to get val score of -0.6369
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316
# Already Trained and Tested combination (2, 3, 1, 2, 2, 3), which had val score of 0.1202
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 149 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 1, 2, 2, 3), which had val score of 0.1202
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 149 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 1, 2, 2, 3), which had val score of 0.1035
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 149 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 1, 2, 2, 3), which had val score of 0.1198
#         Current best combo: (3, 2, 2, 2, 2, 3) with val score 0.1316.
#         Has trained 149 of 31500 combinations so far
# Trained and Tested combination 150 of 31500: (3, 3, 0, 2, 2, 3), taking 1.72 seconds to get val score of 0.1515
#         Current best combo: (3, 3, 0, 2, 2, 3) with val score 0.1515
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0826
#         Current best combo: (3, 3, 0, 2, 2, 3) with val score 0.1515.
#         Has trained 150 of 31500 combinations so far
# Trained and Tested combination 151 of 31500: (3, 3, 1, 1, 2, 3), taking 2.08 seconds to get val score of 0.1791
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791
# Trained and Tested combination 152 of 31500: (3, 3, 1, 3, 2, 3), taking 2.06 seconds to get val score of 0.0829
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791
# Trained and Tested combination 153 of 31500: (3, 3, 1, 2, 1, 3), taking 2.13 seconds to get val score of 0.0989
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791
# Trained and Tested combination 154 of 31500: (3, 3, 1, 2, 3, 3), taking 2.17 seconds to get val score of 0.0441
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791
# Trained and Tested combination 155 of 31500: (3, 3, 1, 2, 2, 2), taking 1.88 seconds to get val score of 0.1038
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791
# Trained and Tested combination 156 of 31500: (3, 3, 1, 2, 2, 4), taking 1.87 seconds to get val score of -1.8562
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791
# Already Trained and Tested combination (2, 3, 2, 3, 2, 3), which had val score of 0.1221
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791.
#         Has trained 156 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 2, 3), which had val score of 0.1222
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791.
#         Has trained 156 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 2, 3), which had val score of 0.1189
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791.
#         Has trained 156 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 2, 3), which had val score of 0.1226
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791.
#         Has trained 156 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 2, 3), which had val score of 0.0829
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791.
#         Has trained 156 of 31500 combinations so far
# Trained and Tested combination 157 of 31500: (3, 3, 3, 3, 2, 3), taking 2.56 seconds to get val score of 0.0722
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3), which had val score of 0.0826
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791.
#         Has trained 157 of 31500 combinations so far
# Trained and Tested combination 158 of 31500: (3, 3, 2, 4, 2, 3), taking 2.41 seconds to get val score of 0.1462
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791
# Trained and Tested combination 159 of 31500: (3, 3, 2, 3, 1, 3), taking 1.87 seconds to get val score of 0.0705
#         Current best combo: (3, 3, 1, 1, 2, 3) with val score 0.1791
# Trained and Tested combination 160 of 31500: (3, 3, 2, 3, 3, 3), taking 2.51 seconds to get val score of 0.1821
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 161 of 31500: (3, 3, 2, 3, 2, 2), taking 2.44 seconds to get val score of 0.1122
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 162 of 31500: (3, 3, 2, 3, 2, 4), taking 2.09 seconds to get val score of -0.4881
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 163 of 31500: (2, 3, 2, 3, 3, 3), taking 1.22 seconds to get val score of 0.1795
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 164 of 31500: (4, 3, 2, 3, 3, 3), taking 4.96 seconds to get val score of 0.1794
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 165 of 31500: (3, 2, 2, 3, 3, 3), taking 2.45 seconds to get val score of 0.1821
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 166 of 31500: (3, 4, 2, 3, 3, 3), taking 2.52 seconds to get val score of 0.1821
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 167 of 31500: (3, 3, 1, 3, 3, 3), taking 2.14 seconds to get val score of 0.1019
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 168 of 31500: (3, 3, 3, 3, 3, 3), taking 2.81 seconds to get val score of 0.1254
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Already Trained and Tested combination (3, 3, 2, 2, 3, 3), which had val score of 0.0356
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 168 of 31500 combinations so far
# Trained and Tested combination 169 of 31500: (3, 3, 2, 4, 3, 3), taking 2.47 seconds to get val score of 0.1463
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Already Trained and Tested combination (3, 3, 2, 3, 2, 3), which had val score of 0.1226
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 169 of 31500 combinations so far
# Trained and Tested combination 170 of 31500: (3, 3, 2, 3, 4, 3), taking 2.38 seconds to get val score of 0.0945
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 171 of 31500: (3, 3, 2, 3, 3, 2), taking 2.86 seconds to get val score of 0.1209
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# Trained and Tested combination 172 of 31500: (3, 3, 2, 3, 3, 4), taking 3.01 seconds to get val score of -0.2218
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821
# % Combos Checked Thus Far: 172 out of 31500 which is 0.5460320000000001%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# Cruising Coordrdinate 0 of 96
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (2, 3, 2, 3, 3, 3), which had val score of 0.1795
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 3, 3), which had val score of 0.1794
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 3, 3), which had val score of 0.1821
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 3, 3), which had val score of 0.1821
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 3, 3), which had val score of 0.1019
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 3, 3), which had val score of 0.1254
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 3), which had val score of 0.0356
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 3, 3), which had val score of 0.1463
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 3), which had val score of 0.1226
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 4, 3), which had val score of 0.0945
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 3, 2), which had val score of 0.1209
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 3, 4), which had val score of -0.2218
#         Current best combo: (3, 3, 2, 3, 3, 3) with val score 0.1821.
#         Has trained 172 of 31500 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 173 of 31500: (1, 3, 2, 3, 3, 3), taking 0.65 seconds to get val score of 0.1869
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3), which had val score of 0.1821
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 173 of 31500 combinations so far
# Trained and Tested combination 174 of 31500: (2, 2, 2, 3, 3, 3), taking 1.23 seconds to get val score of 0.1795
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 175 of 31500: (2, 4, 2, 3, 3, 3), taking 1.23 seconds to get val score of 0.1795
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 176 of 31500: (2, 3, 1, 3, 3, 3), taking 1.08 seconds to get val score of 0.0993
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 177 of 31500: (2, 3, 3, 3, 3, 3), taking 1.43 seconds to get val score of 0.1256
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (2, 3, 2, 2, 3, 3), which had val score of 0.0414
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 177 of 31500 combinations so far
# Trained and Tested combination 178 of 31500: (2, 3, 2, 4, 3, 3), taking 1.28 seconds to get val score of 0.1449
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (2, 3, 2, 3, 2, 3), which had val score of 0.1221
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 178 of 31500 combinations so far
# Trained and Tested combination 179 of 31500: (2, 3, 2, 3, 4, 3), taking 1.2 seconds to get val score of 0.1153
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 180 of 31500: (2, 3, 2, 3, 3, 2), taking 1.25 seconds to get val score of 0.1093
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 181 of 31500: (2, 3, 2, 3, 3, 4), taking 1.26 seconds to get val score of -0.2225
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3), which had val score of 0.1821
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 181 of 31500 combinations so far
# Trained and Tested combination 182 of 31500: (5, 3, 2, 3, 3, 3), taking 9.91 seconds to get val score of 0.1795
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 183 of 31500: (4, 2, 2, 3, 3, 3), taking 4.98 seconds to get val score of 0.1794
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 184 of 31500: (4, 4, 2, 3, 3, 3), taking 5.09 seconds to get val score of 0.1794
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 185 of 31500: (4, 3, 1, 3, 3, 3), taking 4.38 seconds to get val score of 0.1009
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 186 of 31500: (4, 3, 3, 3, 3, 3), taking 5.46 seconds to get val score of 0.125
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (4, 3, 2, 2, 3, 3), which had val score of 0.0343
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 186 of 31500 combinations so far
# Trained and Tested combination 187 of 31500: (4, 3, 2, 4, 3, 3), taking 5.01 seconds to get val score of 0.147
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (4, 3, 2, 3, 2, 3), which had val score of 0.1222
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 187 of 31500 combinations so far
# Trained and Tested combination 188 of 31500: (4, 3, 2, 3, 4, 3), taking 4.86 seconds to get val score of 0.0938
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 189 of 31500: (4, 3, 2, 3, 3, 2), taking 4.98 seconds to get val score of 0.115
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 190 of 31500: (4, 3, 2, 3, 3, 4), taking 5.01 seconds to get val score of -0.2182
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (2, 2, 2, 3, 3, 3), which had val score of 0.1795
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 190 of 31500 combinations so far
# Already Trained and Tested combination (4, 2, 2, 3, 3, 3), which had val score of 0.1794
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 190 of 31500 combinations so far
# Trained and Tested combination 191 of 31500: (3, 1, 2, 3, 3, 3), taking 1.37 seconds to get val score of 0.093
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3), which had val score of 0.1821
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 191 of 31500 combinations so far
# Trained and Tested combination 192 of 31500: (3, 2, 1, 3, 3, 3), taking 1.93 seconds to get val score of 0.1019
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 193 of 31500: (3, 2, 3, 3, 3, 3), taking 2.62 seconds to get val score of 0.1254
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (3, 2, 2, 2, 3, 3), which had val score of 0.0356
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 193 of 31500 combinations so far
# Trained and Tested combination 194 of 31500: (3, 2, 2, 4, 3, 3), taking 2.57 seconds to get val score of 0.1463
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (3, 2, 2, 3, 2, 3), which had val score of 0.1189
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 194 of 31500 combinations so far
# Trained and Tested combination 195 of 31500: (3, 2, 2, 3, 4, 3), taking 2.36 seconds to get val score of 0.0945
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 196 of 31500: (3, 2, 2, 3, 3, 2), taking 2.28 seconds to get val score of 0.1273
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 197 of 31500: (3, 2, 2, 3, 3, 4), taking 2.41 seconds to get val score of -0.2218
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (2, 4, 2, 3, 3, 3), which had val score of 0.1795
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 197 of 31500 combinations so far
# Already Trained and Tested combination (4, 4, 2, 3, 3, 3), which had val score of 0.1794
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 197 of 31500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3), which had val score of 0.1821
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 197 of 31500 combinations so far
# Trained and Tested combination 198 of 31500: (3, 5, 2, 3, 3, 3), taking 2.43 seconds to get val score of 0.1821
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 199 of 31500: (3, 4, 1, 3, 3, 3), taking 2.12 seconds to get val score of 0.1019
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 200 of 31500: (3, 4, 3, 3, 3, 3), taking 1.65 seconds to get val score of 0.1254
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (3, 4, 2, 2, 3, 3), which had val score of 0.0356
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 200 of 31500 combinations so far
# Trained and Tested combination 201 of 31500: (3, 4, 2, 4, 3, 3), taking 1.5 seconds to get val score of 0.1463
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (3, 4, 2, 3, 2, 3), which had val score of 0.1226
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 201 of 31500 combinations so far
# Trained and Tested combination 202 of 31500: (3, 4, 2, 3, 4, 3), taking 1.4 seconds to get val score of 0.0945
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 203 of 31500: (3, 4, 2, 3, 3, 2), taking 1.35 seconds to get val score of 0.1209
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 204 of 31500: (3, 4, 2, 3, 3, 4), taking 1.45 seconds to get val score of -0.2218
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 205 of 31500: (0, 3, 2, 3, 3, 3), taking 0.18 seconds to get val score of 0.1798
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (2, 3, 2, 3, 3, 3), which had val score of 0.1795
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 205 of 31500 combinations so far
# Trained and Tested combination 206 of 31500: (1, 2, 2, 3, 3, 3), taking 0.38 seconds to get val score of 0.1869
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 207 of 31500: (1, 4, 2, 3, 3, 3), taking 0.36 seconds to get val score of 0.1869
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 208 of 31500: (1, 3, 1, 3, 3, 3), taking 0.32 seconds to get val score of 0.1142
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 209 of 31500: (1, 3, 3, 3, 3, 3), taking 0.41 seconds to get val score of 0.1268
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 210 of 31500: (1, 3, 2, 2, 3, 3), taking 0.35 seconds to get val score of 0.0421
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 211 of 31500: (1, 3, 2, 4, 3, 3), taking 0.39 seconds to get val score of 0.1482
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 212 of 31500: (1, 3, 2, 3, 2, 3), taking 0.37 seconds to get val score of 0.1204
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 213 of 31500: (1, 3, 2, 3, 4, 3), taking 0.35 seconds to get val score of 0.1149
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 214 of 31500: (1, 3, 2, 3, 3, 2), taking 0.34 seconds to get val score of 0.0791
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 215 of 31500: (1, 3, 2, 3, 3, 4), taking 0.37 seconds to get val score of -0.2263
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# % Combos Checked Thus Far: 215 out of 31500 which is 0.6825399999999999%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (0, 3, 2, 3, 3, 3), which had val score of 0.1798
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (2, 3, 2, 3, 3, 3), which had val score of 0.1795
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 2, 2, 3, 3, 3), which had val score of 0.1869
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 4, 2, 3, 3, 3), which had val score of 0.1869
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 3, 1, 3, 3, 3), which had val score of 0.1142
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 3, 3, 3, 3, 3), which had val score of 0.1268
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 3, 3), which had val score of 0.0421
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 3, 2, 4, 3, 3), which had val score of 0.1482
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 2, 3), which had val score of 0.1204
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 4, 3), which had val score of 0.1149
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 3, 2), which had val score of 0.0791
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 3, 4), which had val score of -0.2263
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 215 of 31500 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 216 of 31500: (0, 2, 2, 3, 3, 3), taking 0.18 seconds to get val score of 0.1798
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (2, 2, 2, 3, 3, 3), which had val score of 0.1795
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 216 of 31500 combinations so far
# Trained and Tested combination 217 of 31500: (1, 1, 2, 3, 3, 3), taking 0.23 seconds to get val score of 0.1062
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (1, 3, 2, 3, 3, 3), which had val score of 0.1869
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 217 of 31500 combinations so far
# Trained and Tested combination 218 of 31500: (1, 2, 1, 3, 3, 3), taking 0.3 seconds to get val score of 0.1142
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 219 of 31500: (1, 2, 3, 3, 3, 3), taking 0.39 seconds to get val score of 0.1268
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 220 of 31500: (1, 2, 2, 2, 3, 3), taking 0.33 seconds to get val score of 0.0421
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 221 of 31500: (1, 2, 2, 4, 3, 3), taking 0.37 seconds to get val score of 0.1482
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 222 of 31500: (1, 2, 2, 3, 2, 3), taking 0.36 seconds to get val score of 0.1222
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 223 of 31500: (1, 2, 2, 3, 4, 3), taking 0.36 seconds to get val score of 0.1149
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 224 of 31500: (1, 2, 2, 3, 3, 2), taking 0.33 seconds to get val score of 0.0816
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 225 of 31500: (1, 2, 2, 3, 3, 4), taking 0.36 seconds to get val score of -0.2263
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 226 of 31500: (0, 4, 2, 3, 3, 3), taking 0.18 seconds to get val score of 0.1798
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Already Trained and Tested combination (2, 4, 2, 3, 3, 3), which had val score of 0.1795
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 226 of 31500 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 3, 3), which had val score of 0.1869
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869.
#         Has trained 226 of 31500 combinations so far
# Trained and Tested combination 227 of 31500: (1, 5, 2, 3, 3, 3), taking 0.35 seconds to get val score of 0.1869
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 228 of 31500: (1, 4, 1, 3, 3, 3), taking 0.31 seconds to get val score of 0.1142
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 229 of 31500: (1, 4, 3, 3, 3, 3), taking 0.4 seconds to get val score of 0.1268
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 230 of 31500: (1, 4, 2, 2, 3, 3), taking 0.41 seconds to get val score of 0.0421
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 231 of 31500: (1, 4, 2, 4, 3, 3), taking 0.37 seconds to get val score of 0.1482
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 232 of 31500: (1, 4, 2, 3, 2, 3), taking 0.37 seconds to get val score of 0.1204
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 233 of 31500: (1, 4, 2, 3, 4, 3), taking 0.36 seconds to get val score of 0.1149
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 234 of 31500: (1, 4, 2, 3, 3, 2), taking 0.33 seconds to get val score of 0.0791
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# Trained and Tested combination 235 of 31500: (1, 4, 2, 3, 3, 4), taking 0.36 seconds to get val score of -0.2263
#         Current best combo: (1, 3, 2, 3, 3, 3) with val score 0.1869
# % Combos Checked Thus Far: 235 out of 31500 which is 0.746032%
# Max Score:
#  0.1868518028665036
# Max Test Score:
#  0.113917
# Max Combo Index:
#  (1, 3, 2, 3, 3, 3) out of [6, 7, 5, 5, 5, 6] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.01, 'eta': 0.1}
# % Combos Checked: 235 out of 31500 which is 0.746032%
